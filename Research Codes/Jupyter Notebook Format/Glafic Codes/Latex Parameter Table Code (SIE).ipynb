# %%
# Python script to process and rename optresult files and save the output to a text file


def extract_shear_and_convergence(filename):
    """
    Extract the shear amplitude and convergence values from the latest "lens   pert" line in the file.
    """
    
    shear_amplitude = None
    convergence = None

    with open(filename, 'r') as file:
        lines = file.readlines()

    # Iterate through the file from bottom to top to find the latest "lens   pert" line
    for line in reversed(lines):
        if "lens   sie" in line:
            # Extract the numerical values correctly using a fixed format approach
            # Split the line by whitespace but ensure consistent indexing
            parts = [value for value in line.split() if value]

            try:
                # Extract the 5th and 8th numbers (counted left-to-right)
                shear_amplitude = float(parts[6])  # 5th parameter
                convergence = float(parts[9])     # 8th parameter

            except (ValueError, IndexError):
                print(f"Error: Failed to extract numbers from file: {filename}. Check the 'lens pert' line format.")
                return None, None

            # Once found, stop searching
            break

    if shear_amplitude is not None and convergence is not None:
        return shear_amplitude, convergence

    else:
        print(f"Error: 'lens pert' line not found in file: {filename}.")
        return None, None


def rename_file(file_path):
    """
    Rename a file based on its naming conventions.
    """
    
    # Split the file path to extract components
    parts = file_path.split("/")
    lens_system = parts[0]  # Extract the lens system (e.g., RXJ0911)
    file_name = parts[-1]  # Extract the file name (e.g., outSPFR_optresult.dat)

    # Extract the relevant part of the filename before "_optresult"
    key = file_name.split("_optresult")[0][3:]  # Remove "out" prefix

    # Determine the profile type from the first letter
    profile_map = {"S": "SIE", "P": "POW", "N": "NFW"}
    profile = profile_map.get(key[0], "Unknown")

    # Determine the constraint type based on the second character or characters
    if key[1:3] == "PF":
        constraint = "position and flux constraint"

    elif key[1] == "P":
        constraint = "position constraint"

    else:
        constraint = "Unknown constraint"

    # Determine if "G2" or "Shear" is present
    extras = []
    if "G" in key:
        extras.append("G2")

    if "R" in key:
        extras.append("Shear")

    # Construct the new name
    new_name = f"{lens_system}: {profile} {constraint}"
    if extras:
        new_name += ", " + " + ".join(extras)

    return new_name


def process_multiple_files(file_list, output_file):
    """
    Process a list of files, rename them, and write the extracted results to an output file.
    """
    
    with open(output_file, 'w') as out_file:
        for file_name in file_list:
            # Rename the file based on naming conventions
            description = rename_file(file_name)

            # Extract shear amplitude and convergence
            shear_amplitude, convergence = extract_shear_and_convergence(file_name)

            if shear_amplitude is not None and convergence is not None:
                # Format the output and write to the file
                output_line = f"{description} : Shear Amplitude = {shear_amplitude}, Convergence = {convergence}\n\n"
                out_file.write(output_line)
                print(output_line.strip())  # Print to console without the trailing newline

            else:
                # Log an error entry if values could not be extracted
                error_line = f"{description}: Failed to extract shear amplitude and convergence.\n\n"
                out_file.write(error_line)
                print(error_line.strip())  # Print to console without the trailing newline


# List of file paths to process
file_list = [
    "RXJ0911/SPC/outSP_optresult.dat",
    "RXJ0911/SPC/outSPR_optresult.dat",
    "RXJ0911/SPC/outSPG_optresult.dat",
    "RXJ0911/SPC/outSPGR_optresult.dat",
    "RXJ0911/SPFC/outSPF_optresult.dat",
    "RXJ0911/SPFC/outSPFR_optresult.dat",
    "RXJ0911/SPFC/outSPFG_optresult.dat",
    "RXJ0911/SPFC/outSPFGR_optresult.dat",
]

# Output file to store results
output_file = "SIE_Parameter_results_test.txt"

# Process the files and save output to the specified file
process_multiple_files(file_list, output_file)
# Out:
# RXJ0911: SIE position constraint : Ellipiticy = 0.5999452, Core_radius = 0.0
# RXJ0911: SIE position constraint, Shear : Ellipiticy = 0.3031236, Core_radius = 0.0
# RXJ0911: SIE position constraint, G2 : Ellipiticy = 0.5998526, Core_radius = 0.0
# RXJ0911: SIE position constraint, G2 + Shear : Ellipiticy = 0.3988564, Core_radius = 0.0
# RXJ0911: SIE position and flux constraint : Ellipiticy = 0.5999951, Core_radius = 0.0
# RXJ0911: SIE position and flux constraint, Shear : Ellipiticy = 0.3060796, Core_radius = 0.0
# RXJ0911: SIE position and flux constraint, G2 : Ellipiticy = 0.5999937, Core_radius = 0.0
# RXJ0911: SIE position and flux constraint, G2 + Shear : Ellipiticy = 0.5986286, Core_radius = 0.0

# %%
def extract_sie_parameters(filename):
    """
    Extract the SIE lens parameters from the latest "lens   sie" line in the file.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()

    # Iterate through the file from bottom to top to find the latest "lens   sie" line
    for line in reversed(lines):
        if "lens   sie" in line:
            # Split the line by whitespace but ensure consistent indexing
            parts = line.split()

            try:
                # Extract the specified parameters using index position
                lens_redshift = float(parts[2])
                velocity_dispersion = float(parts[3])
                x_coord = float(parts[4])
                y_coord = float(parts[5])
                ellipticity = float(parts[6])
                position_angle = float(parts[7])

            except (ValueError, IndexError):
                print(f"Error: Failed to extract numbers from file: {filename}. Check the 'lens sie' line format.")
                return None

            # Once found, return the extracted values as a tuple
            return (lens_redshift, velocity_dispersion, x_coord, y_coord, ellipticity, position_angle)

    print(f"Error: 'lens sie' line not found in file: {filename}.")
    return None


def process_multiple_files(file_list, output_file):
    """
    Process a list of files, rename them, and write the extracted SIE lens parameters to an output file.
    """
    with open(output_file, 'w') as out_file:
        for file_name in file_list:
            # Rename the file based on naming conventions
            description = rename_file(file_name)

            # Extract SIE lens parameters
            sie_parameters = extract_sie_parameters(file_name)

            if sie_parameters:
                # Format the output and write to the file
                output_line = f"{description} : Lens Redshift = {sie_parameters[0]}, Velocity Dispersion = {sie_parameters[1]}, X-coord = {sie_parameters[2]}, Y-coord = {sie_parameters[3]}, Ellipticity = {sie_parameters[4]}, Position Angle = {sie_parameters[5]}\n\n"
                out_file.write(output_line)
                print(output_line.strip())  # Print to console without the trailing newline

            else:
                # Log an error entry if values could not be extracted
                error_line = f"{description}: Failed to extract SIE parameters.\n\n"
                out_file.write(error_line)
                print(error_line.strip())  # Print to console without the trailing newline


# List of file paths to process
file_list = [
    "RXJ0911/SPC/outSP_optresult.dat",
    "RXJ0911/SPC/outSPR_optresult.dat",
    "RXJ0911/SPC/outSPG_optresult.dat",
    "RXJ0911/SPC/outSPGR_optresult.dat",
    "RXJ0911/SPFC/outSPF_optresult.dat",
    "RXJ0911/SPFC/outSPFR_optresult.dat",
    "RXJ0911/SPFC/outSPFG_optresult.dat",
    "RXJ0911/SPFC/outSPFGR_optresult.dat",
]

# Output file to store results
output_file = "SIE_Parameter_results_test.txt"

# Process the files and save output to the specified file
process_multiple_files(file_list, output_file)
# Out:
# RXJ0911: SIE position constraint : Lens Redshift = 0.769, Velocity Dispersion = 299.9993, X-coord = -0.09093027, Y-coord = 0.03471901, Ellipticity = 0.5999452, Position Angle = 174.195
# RXJ0911: SIE position constraint, Shear : Lens Redshift = 0.769, Velocity Dispersion = 220.2739, X-coord = -8.853659e-05, Y-coord = 0.03159181, Ellipticity = 0.3031236, Position Angle = 208.7716
# RXJ0911: SIE position constraint, G2 : Lens Redshift = 0.769, Velocity Dispersion = 148.9, X-coord = -0.7702991, Y-coord = 0.6604997, Ellipticity = 0.5998526, Position Angle = 155.8685
# RXJ0911: SIE position constraint, G2 + Shear : Lens Redshift = 0.769, Velocity Dispersion = 116.9458, X-coord = -0.7670011, Y-coord = 0.6570046, Ellipticity = 0.3988564, Position Angle = 217.3452
# RXJ0911: SIE position and flux constraint : Lens Redshift = 0.769, Velocity Dispersion = 299.9998, X-coord = -0.09092218, Y-coord = 0.03503759, Ellipticity = 0.5999951, Position Angle = 174.1426
# RXJ0911: SIE position and flux constraint, Shear : Lens Redshift = 0.769, Velocity Dispersion = 238.5804, X-coord = -0.0005396177, Y-coord = 0.03151202, Ellipticity = 0.3060796, Position Angle = 208.879
# RXJ0911: SIE position and flux constraint, G2 : Lens Redshift = 0.769, Velocity Dispersion = 149.8471, X-coord = -0.7558569, Y-coord = 0.6594154, Ellipticity = 0.5999937, Position Angle = 159.6592
# RXJ0911: SIE position and flux constraint, G2 + Shear : Lens Redshift = 0.769, Velocity Dispersion = 100.6896, X-coord = -0.767136, Y-coord = 0.6569236, Ellipticity = 0.5986286, Position Angle = 266.5657

# %%
def extract_sie_parameters(filename):
    """
    Extract the SIE lens parameters from the first "lens   sie" line that appears after the final mention of "chi^2" in the file.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()

    # Locate the last occurrence of "chi^2"
    last_chi2_index = None
    for index, line in enumerate(lines):
        if "chi^2" in line:
            last_chi2_index = index

    # If no "chi^2" was found, we can't process further
    if last_chi2_index is None:
        print(f"Error: 'chi^2' line not found in file: {filename}.")
        return None

    # Scan downwards from the last "chi^2" line to find the first "lens sie" line
    for line in lines[last_chi2_index:]:
        if "lens   sie" in line:
            parts = line.split()
            try:
                # The index positions may need to be adjusted based on the specific formatting of the data
                lens_redshift = float(parts[2])
                velocity_dispersion = float(parts[3])
                x_coord = float(parts[4])
                y_coord = float(parts[5])
                ellipticity = float(parts[6])
                position_angle = float(parts[7])
                return (lens_redshift, velocity_dispersion, x_coord, y_coord, ellipticity, position_angle)
            except (ValueError, IndexError):
                print(f"Error: Failed to extract numbers from file: {filename}. Check the 'lens sie' line format.")
                return None

    print(f"Error: 'lens sie' line not found after last 'chi^2' in file: {filename}.")
    return None

def rename_file(file_path):
    """
    Rename a file based on its naming conventions.
    """
    parts = file_path.split("/")
    lens_system = parts[0]  # Extract the lens system
    file_name = parts[-1]  # Extract the file name

    key = file_name.split("_optresult")[0][3:]  # Remove "out" prefix
    profile_map = {"S": "SIE", "P": "POW", "N": "NFW"}
    profile = profile_map.get(key[0], "Unknown")

    constraint = "Unknown constraint"
    if key[1:3] == "PF":
        constraint = "position and flux constraint"
    elif key[1] == "P":
        constraint = "position constraint"

    extras = []
    if "G" in key:
        extras.append("G2")
    if "R" in key:
        extras.append("Shear")

    new_name = f"{lens_system}: {profile} {constraint}" + (", " + " + ".join(extras) if extras else "")
    return new_name

def process_multiple_files(file_list, output_file):
    """
    Process a list of files, rename them, and write the extracted SIE lens parameters to an output file.
    """
    with open(output_file, 'w') as out_file:
        for file_name in file_list:
            description = rename_file(file_name)
            sie_parameters = extract_sie_parameters(file_name)

            if sie_parameters:
                output_line = f"{description} : Lens Redshift = {sie_parameters[0]}, Velocity Dispersion = {sie_parameters[1]}, X-coord = {sie_parameters[2]}, Y-coord = {sie_parameters[3]}, Ellipticity = {sie_parameters[4]}, Position Angle = {sie_parameters[5]}\n\n"
                out_file.write(output_line)
                print(output_line.strip())
            else:
                error_line = f"{description}: Failed to extract SIE parameters.\n\n"
                out_file.write(error_line)
                print(error_line.strip())

# List of file paths to process
file_list = [
    "RXJ0911/SPC/outSP_optresult.dat",
    "RXJ0911/SPC/outSPR_optresult.dat",
    "RXJ0911/SPC/outSPG_optresult.dat",
    "RXJ0911/SPC/outSPGR_optresult.dat",
    "RXJ0911/SPFC/outSPF_optresult.dat",
    "RXJ0911/SPFC/outSPFR_optresult.dat",
    "RXJ0911/SPFC/outSPFG_optresult.dat",
    "RXJ0911/SPFC/outSPFGR_optresult.dat",
]

# Output file to store results
output_file = "SIE_Parameter_results_test.txt"

# Process the files and save output to the specified file
process_multiple_files(file_list, output_file)
# Out:
# RXJ0911: SIE position constraint : Lens Redshift = 0.769, Velocity Dispersion = 299.9993, X-coord = -0.09093027, Y-coord = 0.03471901, Ellipticity = 0.5999452, Position Angle = 174.195
# RXJ0911: SIE position constraint, Shear : Lens Redshift = 0.769, Velocity Dispersion = 220.2739, X-coord = -8.853659e-05, Y-coord = 0.03159181, Ellipticity = 0.3031236, Position Angle = 208.7716
# RXJ0911: SIE position constraint, G2 : Lens Redshift = 0.769, Velocity Dispersion = 265.0183, X-coord = 0.02241472, Y-coord = -0.06796709, Ellipticity = 0.5999973, Position Angle = 175.3846
# RXJ0911: SIE position constraint, G2 + Shear : Lens Redshift = 0.769, Velocity Dispersion = 240.4392, X-coord = 9.012696e-07, Y-coord = 1.345252e-05, Ellipticity = 0.2013531, Position Angle = 237.8886
# RXJ0911: SIE position and flux constraint : Lens Redshift = 0.769, Velocity Dispersion = 299.9998, X-coord = -0.09092218, Y-coord = 0.03503759, Ellipticity = 0.5999951, Position Angle = 174.1426
# RXJ0911: SIE position and flux constraint, Shear : Lens Redshift = 0.769, Velocity Dispersion = 238.5804, X-coord = -0.0005396177, Y-coord = 0.03151202, Ellipticity = 0.3060796, Position Angle = 208.879
# RXJ0911: SIE position and flux constraint, G2 : Lens Redshift = 0.769, Velocity Dispersion = 264.129, X-coord = 0.02489965, Y-coord = -0.06162456, Ellipticity = 0.5999933, Position Angle = 174.7534
# RXJ0911: SIE position and flux constraint, G2 + Shear : Lens Redshift = 0.769, Velocity Dispersion = 233.6738, X-coord = -0.0004699347, Y-coord = -0.001717117, Ellipticity = 0.2391044, Position Angle = 223.447

# %%
def extract_sie_parameters(filename):
    """
    Extract the SIE lens parameters from the first "lens   sie" line that appears after the final mention of "chi^2" in the file.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()

    last_chi2_index = None
    for index, line in enumerate(lines):
        if "chi^2" in line:
            last_chi2_index = index

    if last_chi2_index is None:
        print(f"Error: 'chi^2' line not found in file: {filename}.")
        return None

    for line in lines[last_chi2_index:]:
        if "lens   sie" in line:
            parts = line.split()
            try:
                lens_redshift = float(parts[2])
                velocity_dispersion = float(parts[3])
                x_coord = float(parts[4])
                y_coord = float(parts[5])
                ellipticity = float(parts[6])
                position_angle = float(parts[7])
                return (lens_redshift, velocity_dispersion, x_coord, y_coord, ellipticity, position_angle)
            except (ValueError, IndexError):
                print(f"Error: Failed to extract numbers from file: {filename}. Check the 'lens sie' line format.")
                return None

    print(f"Error: 'lens sie' line not found after last 'chi^2' in file: {filename}.")
    return None

def rename_file(file_path):
    parts = file_path.split("/")
    lens_system = parts[0]
    file_name = parts[-1]

    key = file_name.split("_optresult")[0][3:]
    profile_map = {"S": "SIE", "P": "POW", "N": "NFW"}
    profile = profile_map.get(key[0], "Unknown")

    constraint = "Unknown constraint"
    if key[1:3] == "PF":
        constraint = "position and flux constraint"
    elif key[1] == "P":
        constraint = "position constraint"

    extras = []
    if "G" in key:
        extras.append("G2")
    if "R" in key:
        extras.append("Shear")

    new_name = f"{lens_system}: {profile} {constraint}" + (", " + " + ".join(extras) if extras else "")
    return new_name

def process_multiple_files(file_list):
    results = []
    for file_name in file_list:
        model_description = rename_file(file_name)
        sie_parameters = extract_sie_parameters(file_name)
        if sie_parameters:
            results.append(f"{model_description} & {sie_parameters[0]:.3f} & {sie_parameters[1]:.3f} & {sie_parameters[2]:.3f} & {sie_parameters[3]:.3f} & {sie_parameters[4]:.3f} & {sie_parameters[5]:.3f} \\\\")
        else:
            results.append(f"{model_description}: Failed to extract SIE parameters.")
    return results

# List of file paths to process
file_list = [
    "RXJ0911/SPC/outSP_optresult.dat",
    "RXJ0911/SPC/outSPR_optresult.dat",
    "RXJ0911/SPC/outSPG_optresult.dat",
    "RXJ0911/SPC/outSPGR_optresult.dat",
    "RXJ0911/SPFC/outSPF_optresult.dat",
    "RXJ0911/SPFC/outSPFR_optresult.dat",
    "RXJ0911/SPFC/outSPFG_optresult.dat",
    "RXJ0911/SPFC/outSPFGR_optresult.dat",
    "PSJ1606/SPC/outSP_optresult.dat"
]

# Process the files and print LaTeX-formatted results
latex_results = process_multiple_files(file_list)
for result in latex_results:
    print(result)
# Out:
# RXJ0911: SIE position constraint & 0.769 & 299.999 & -0.091 & 0.035 & 0.600 & 174.195 \\
# RXJ0911: SIE position constraint, Shear & 0.769 & 220.274 & -0.000 & 0.032 & 0.303 & 208.772 \\
# RXJ0911: SIE position constraint, G2 & 0.769 & 265.018 & 0.022 & -0.068 & 0.600 & 175.385 \\
# RXJ0911: SIE position constraint, G2 + Shear & 0.769 & 240.439 & 0.000 & 0.000 & 0.201 & 237.889 \\
# RXJ0911: SIE position and flux constraint & 0.769 & 300.000 & -0.091 & 0.035 & 0.600 & 174.143 \\
# RXJ0911: SIE position and flux constraint, Shear & 0.769 & 238.580 & -0.001 & 0.032 & 0.306 & 208.879 \\
# RXJ0911: SIE position and flux constraint, G2 & 0.769 & 264.129 & 0.025 & -0.062 & 0.600 & 174.753 \\
# RXJ0911: SIE position and flux constraint, G2 + Shear & 0.769 & 233.674 & -0.000 & -0.002 & 0.239 & 223.447 \\
# PSJ1606: SIE position constraint & 0.300 & 188.603 & -0.036 & 0.020 & 0.600 & 199.294 \\

# %%
def extract_sie_parameters(filename):
    """
    Extract the SIE lens parameters from the first "lens   sie" line that appears after the final mention of "chi^2" in the file.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()

    last_chi2_index = None
    for index, line in enumerate(lines):
        if "chi^2" in line:
            last_chi2_index = index

    if last_chi2_index is None:
        print(f"Error: 'chi^2' line not found in file: {filename}.")
        return None

    for line in lines[last_chi2_index:]:
        if "lens   sie" in line:
            parts = line.split()
            try:
                lens_redshift = float(parts[2])
                velocity_dispersion = float(parts[3])
                x_coord = float(parts[4])
                y_coord = float(parts[5])
                ellipticity = float(parts[6])
                position_angle = float(parts[7])
                return (lens_redshift, velocity_dispersion, x_coord, y_coord, ellipticity, position_angle)
            except (ValueError, IndexError):
                print(f"Error: Failed to extract numbers from file: {filename}. Check the 'lens sie' line format.")
                return None

    print(f"Error: 'lens sie' line not found after last 'chi^2' in file: {filename}.")
    return None

def rename_file(file_path):
    parts = file_path.split("/")
    lens_system = parts[0]  # Now correctly fetching the first part of the file path
    file_name = parts[-1]

    key = file_name.split("_optresult")[0][3:]
    profile_map = {"S": "SIE", "P": "POW", "N": "NFW"}
    profile = profile_map.get(key[0], "Unknown")

    constraint = "Unknown constraint"
    if key[1:3] == "PF":
        constraint = "position and flux constraint"
    elif key[1] == "P":
        constraint = "position constraint"

    extras = []
    if "G" in key:
        extras.append("G2")
    if "R" in key:
        extras.append("Shear")

    new_name = f"{lens_system} & {profile} {constraint}" + (", " + " + ".join(extras) if extras else "")
    return new_name

def process_multiple_files(file_list):
    results = []
    for file_name in file_list:
        model_description = rename_file(file_name)
        sie_parameters = extract_sie_parameters(file_name)
        if sie_parameters:
            results.append(f"{model_description} & {sie_parameters[0]:.3f} & {sie_parameters[1]:.3f} & {sie_parameters[2]:.3f} & {sie_parameters[3]:.3f} & {sie_parameters[4]:.3f} & {sie_parameters[5]:.3f} \\\\")
        else:
            results.append(f"{model_description} Failed to extract SIE parameters.")
    return results

# List of file paths to process
file_list = [
    "RXJ0911/SPC/outSP_optresult.dat",
    "RXJ0911/SPC/outSPR_optresult.dat",
    "RXJ0911/SPC/outSPG_optresult.dat",
    "RXJ0911/SPC/outSPGR_optresult.dat",
    "RXJ0911/SPFC/outSPF_optresult.dat",
    "RXJ0911/SPFC/outSPFR_optresult.dat",
    "RXJ0911/SPFC/outSPFG_optresult.dat",
    "RXJ0911/SPFC/outSPFGR_optresult.dat",
    "PSJ1606/SPC/outSP_optresult.dat"
]

def process_multiple_files(file_list):
    results = []
    for file_name in file_list:
        model_description = rename_file(file_name)
        sie_parameters = extract_sie_parameters(file_name)
        if sie_parameters:
            lens_redshift, velocity_dispersion, x_coord, y_coord, ellipticity, position_angle = sie_parameters
            result_text = f"{model_description} & {lens_redshift:.3f} & {velocity_dispersion:.3f} & {x_coord:.3f} & {y_coord:.3f} & {ellipticity:.3f} & {position_angle:.3f} \\\\"
            results.append(result_text)
            print(f"Model: {file_name}")
            print(f"Lens Redshift: {lens_redshift:.3f}")
            print(f"Velocity Dispersion: {velocity_dispersion:.3f}")
            print(f"X Coordinate: {x_coord:.3f}")
            print(f"Y Coordinate: {y_coord:.3f}")
            print(f"Ellipticity: {ellipticity:.3f}")
            print(f"Position Angle: {position_angle:.3f}\n")
        else:
            results.append(f"{model_description} Failed to extract SIE parameters.")
            print(f"Model: {file_name} Failed to extract SIE parameters.\n")
    return results

# Process the files and print LaTeX-formatted results
latex_results = process_multiple_files(file_list)
for result in latex_results:
    print(result)
# Out:
# Model: RXJ0911/SPC/outSP_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 299.999
# X Coordinate: -0.091
# Y Coordinate: 0.035
# Ellipticity: 0.600
# Position Angle: 174.195
#
# Model: RXJ0911/SPC/outSPR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 220.274
# X Coordinate: -0.000
# Y Coordinate: 0.032
# Ellipticity: 0.303
# Position Angle: 208.772
#
# Model: RXJ0911/SPC/outSPG_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 265.018
# X Coordinate: 0.022
# Y Coordinate: -0.068
# Ellipticity: 0.600
# Position Angle: 175.385
#
# Model: RXJ0911/SPC/outSPGR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 240.439
# X Coordinate: 0.000
# Y Coordinate: 0.000
# Ellipticity: 0.201
# Position Angle: 237.889
#
# Model: RXJ0911/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 300.000
# X Coordinate: -0.091
# Y Coordinate: 0.035
# Ellipticity: 0.600
# Position Angle: 174.143
#
# Model: RXJ0911/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 238.580
# X Coordinate: -0.001
# Y Coordinate: 0.032
# Ellipticity: 0.306
# Position Angle: 208.879
#
# Model: RXJ0911/SPFC/outSPFG_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 264.129
# X Coordinate: 0.025
# Y Coordinate: -0.062
# Ellipticity: 0.600
# Position Angle: 174.753
#
# Model: RXJ0911/SPFC/outSPFGR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 233.674
# X Coordinate: -0.000
# Y Coordinate: -0.002
# Ellipticity: 0.239
# Position Angle: 223.447
#
# Model: PSJ1606/SPC/outSP_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 188.603
# X Coordinate: -0.036
# Y Coordinate: 0.020
# Ellipticity: 0.600
# Position Angle: 199.294
#
# RXJ0911 & SIE position constraint & 0.769 & 299.999 & -0.091 & 0.035 & 0.600 & 174.195 \\
# RXJ0911 & SIE position constraint, Shear & 0.769 & 220.274 & -0.000 & 0.032 & 0.303 & 208.772 \\
# RXJ0911 & SIE position constraint, G2 & 0.769 & 265.018 & 0.022 & -0.068 & 0.600 & 175.385 \\
# RXJ0911 & SIE position constraint, G2 + Shear & 0.769 & 240.439 & 0.000 & 0.000 & 0.201 & 237.889 \\
# RXJ0911 & SIE position and flux constraint & 0.769 & 300.000 & -0.091 & 0.035 & 0.600 & 174.143 \\
# RXJ0911 & SIE position and flux constraint, Shear & 0.769 & 238.580 & -0.001 & 0.032 & 0.306 & 208.879 \\
# RXJ0911 & SIE position and flux constraint, G2 & 0.769 & 264.129 & 0.025 & -0.062 & 0.600 & 174.753 \\
# RXJ0911 & SIE position and flux constraint, G2 + Shear & 0.769 & 233.674 & -0.000 & -0.002 & 0.239 & 223.447 \\
# PSJ1606 & SIE position constraint & 0.300 & 188.603 & -0.036 & 0.020 & 0.600 & 199.294 \\

# %%
def extract_sie_parameters(filename):
    """
    Extract the SIE lens parameters from the first "lens   sie" line that appears after the final mention of "chi^2" in the file.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()

    last_chi2_index = None
    for index, line in enumerate(lines):
        if "chi^2" in line:
            last_chi2_index = index

    if last_chi2_index is None:
        print(f"Error: 'chi^2' line not found in file: {filename}.")
        return None

    for line in lines[last_chi2_index:]:
        if "lens   sie" in line:
            parts = line.split()
            try:
                lens_redshift = float(parts[2])
                velocity_dispersion = float(parts[3])
                x_coord = float(parts[4])
                y_coord = float(parts[5])
                ellipticity = float(parts[6])
                position_angle = float(parts[7])
                return (lens_redshift, velocity_dispersion, x_coord, y_coord, ellipticity, position_angle)
            except (ValueError, IndexError):
                print(f"Error: Failed to extract numbers from file: {filename}. Check the 'lens sie' line format.")
                return None

    print(f"Error: 'lens sie' line not found after last 'chi^2' in file: {filename}.")
    return None

def rename_file(file_path):
    parts = file_path.split("/")
    lens_system = parts[0]  # Now correctly fetching the first part of the file path
    file_name = parts[-1]

    key = file_name.split("_optresult")[0][3:]
    profile_map = {"S": "SIE", "P": "POW", "N": "NFW"}
    profile = profile_map.get(key[0], "Unknown")

    constraint = "Unknown constraint"
    if key[1:3] == "PF":
        constraint = "position and flux constraint"
    elif key[1] == "P":
        constraint = "position constraint"

    extras = []
    if "G" in key:
        extras.append("G2")
    if "R" in key:
        extras.append("Shear")

    new_name = f"{lens_system} & {profile} {constraint}" + (", " + " + ".join(extras) if extras else "")
    return new_name

def process_multiple_files(file_list):
    results = []
    for file_name in file_list:
        model_description = rename_file(file_name)
        sie_parameters = extract_sie_parameters(file_name)
        if sie_parameters:
            results.append(f"{model_description} & {sie_parameters[0]:.3f} & {sie_parameters[1]:.3f} & {sie_parameters[2]:.3f} & {sie_parameters[3]:.3f} & {sie_parameters[4]:.3f} & {sie_parameters[5]:.3f} \\\\")
        else:
            results.append(f"{model_description} Failed to extract SIE parameters.")
    return results

# List of file paths to process
file_list = [
    "RXJ0911/SPC/outSP_optresult.dat",
    "RXJ0911/SPC/outSPR_optresult.dat",
    "RXJ0911/SPC/outSPG_optresult.dat",
    "RXJ0911/SPC/outSPGR_optresult.dat",
    "RXJ0911/SPFC/outSPF_optresult.dat",
    "RXJ0911/SPFC/outSPFR_optresult.dat",
    "RXJ0911/SPFC/outSPFG_optresult.dat",
    "RXJ0911/SPFC/outSPFGR_optresult.dat",
    "PSJ1606/SPC/outSP_optresult.dat",
    "PSJ1606/SPC/outSPR_optresult.dat",
    "PSJ1606/SPC/outSPG_optresult.dat",
    "PSJ1606/SPC/outSPGR_optresult.dat",
    "PSJ1606/SPFC/outSPF_optresult.dat",
    "PSJ1606/SPFC/outSPFR_optresult.dat",
    "PSJ1606/SPFC/outSPFG_optresult.dat",
    "PSJ1606/SPFC/outSPFGR_optresult.dat",
    "WFI2033/SP/outSP_optresult.dat",
    "WFI2033/SPR/outSPR_optresult.dat",
    "WFI2033/SPG/outSPG_optresult.dat",
    "WFI2033/SPGR/outSPGR_optresult.dat",
    "WFI2033/SPF/outSPF_optresult.dat",
    "WFI2033/SPFR/outSPFR_optresult.dat",
    "WFI2033/SPFG/outSPFG_optresult.dat",
    "WFI2033/SPFGR/outSPFGR_optresult.dat",
    "SDSSJ1330/SPC/outSP_optresult.dat",
    "SDSSJ1330/SPC/outSPR_optresult.dat",
    "SDSSJ1330/SPFC/outSPF_optresult.dat",
    "SDSSJ1330/SPFC/outSPFR_optresult.dat",
    "WFI2026/SPC/outSP_optresult.dat",
    "WFI2026/SPC/outSPR_optresult.dat",
    "WFI2026/SPFC/outSPF_optresult.dat",
    "WFI2026/SPFC/outSPFR_optresult.dat",
    "WGDJ0405/SPC/outSP_optresult.dat",
    "WGDJ0405/SPC/outSPR_optresult.dat",
    "WGDJ0405/SPFC/outSPF_optresult.dat",
    "WGDJ0405/SPFC/outSPFR_optresult.dat"
]

def process_multiple_files(file_list):
    results = []
    for file_name in file_list:
        model_description = rename_file(file_name)
        sie_parameters = extract_sie_parameters(file_name)
        if sie_parameters:
            lens_redshift, velocity_dispersion, x_coord, y_coord, ellipticity, position_angle = sie_parameters
            result_text = f"{model_description} & {lens_redshift:.3f} & {velocity_dispersion:.3f} & {x_coord:.3f} & {y_coord:.3f} & {ellipticity:.3f} & {position_angle:.3f} \\\\"
            results.append(result_text)
            print(f"Model: {file_name}")
            print(f"Lens Redshift: {lens_redshift:.3f}")
            print(f"Velocity Dispersion: {velocity_dispersion:.3f}")
            print(f"X Coordinate: {x_coord:}")
            print(f"Y Coordinate: {y_coord:}")
            print(f"Ellipticity: {ellipticity:.3f}")
            print(f"Position Angle: {position_angle:.3f}\n")
        else:
            results.append(f"{model_description} Failed to extract SIE parameters.")
            print(f"Model: {file_name} Failed to extract SIE parameters.\n")
    return results

# Process the files and print LaTeX-formatted results
latex_results = process_multiple_files(file_list)
for result in latex_results:
    print(result)
# Out:
# Model: RXJ0911/SPC/outSP_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 299.999
# X Coordinate: -0.09093027
# Y Coordinate: 0.03471901
# Ellipticity: 0.600
# Position Angle: 174.195
#
# Model: RXJ0911/SPC/outSPR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 220.274
# X Coordinate: -8.853659e-05
# Y Coordinate: 0.03159181
# Ellipticity: 0.303
# Position Angle: 208.772
#
# Model: RXJ0911/SPC/outSPG_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 265.018
# X Coordinate: 0.02241472
# Y Coordinate: -0.06796709
# Ellipticity: 0.600
# Position Angle: 175.385
#
# Model: RXJ0911/SPC/outSPGR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 240.439
# X Coordinate: 9.012696e-07
# Y Coordinate: 1.345252e-05
# Ellipticity: 0.201
# Position Angle: 237.889
#
# Model: RXJ0911/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 300.000
# X Coordinate: -0.09092218
# Y Coordinate: 0.03503759
# Ellipticity: 0.600
# Position Angle: 174.143
#
# Model: RXJ0911/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 238.580
# X Coordinate: -0.0005396177
# Y Coordinate: 0.03151202
# Ellipticity: 0.306
# Position Angle: 208.879
#
# Model: RXJ0911/SPFC/outSPFG_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 264.129
# X Coordinate: 0.02489965
# Y Coordinate: -0.06162456
# Ellipticity: 0.600
# Position Angle: 174.753
#
# Model: RXJ0911/SPFC/outSPFGR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 233.674
# X Coordinate: -0.0004699347
# Y Coordinate: -0.001717117
# Ellipticity: 0.239
# Position Angle: 223.447
#
# Model: PSJ1606/SPC/outSP_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 188.603
# X Coordinate: -0.03555983
# Y Coordinate: 0.02020766
# Ellipticity: 0.600
# Position Angle: 199.294
#
# Model: PSJ1606/SPC/outSPR_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 176.108
# X Coordinate: -0.01688416
# Y Coordinate: 0.01610115
# Ellipticity: 0.200
# Position Angle: 173.071
#
# Model: PSJ1606/SPC/outSPG_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 171.252
# X Coordinate: 0.06107697
# Y Coordinate: 0.05345572
# Ellipticity: 0.542
# Position Angle: 217.836
#
# Model: PSJ1606/SPC/outSPGR_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 170.543
# X Coordinate: -7.094564e-06
# Y Coordinate: 1.319316e-05
# Ellipticity: 0.600
# Position Angle: 196.876
#
# Model: PSJ1606/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 188.655
# X Coordinate: -0.03381372
# Y Coordinate: 0.01486134
# Ellipticity: 0.600
# Position Angle: 199.402
#
# Model: PSJ1606/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 172.262
# X Coordinate: -0.01260316
# Y Coordinate: 0.01581286
# Ellipticity: 0.181
# Position Angle: 151.451
#
# Model: PSJ1606/SPFC/outSPFG_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 167.883
# X Coordinate: 0.1040224
# Y Coordinate: 0.01747521
# Ellipticity: 0.486
# Position Angle: 225.009
#
# Model: PSJ1606/SPFC/outSPFGR_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 171.771
# X Coordinate: 0.01876222
# Y Coordinate: 0.02262219
# Ellipticity: 0.001
# Position Angle: 119.005
#
# Model: WFI2033/SP/outSP_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 294.484
# X Coordinate: -0.09720901
# Y Coordinate: 0.0427617
# Ellipticity: 0.576
# Position Angle: 335.123
#
# Model: WFI2033/SPR/outSPR_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 314.213
# X Coordinate: -0.01843295
# Y Coordinate: 0.03504331
# Ellipticity: 0.342
# Position Angle: 272.839
#
# Model: WFI2033/SPG/outSPG_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 279.820
# X Coordinate: -0.01663208
# Y Coordinate: 0.003622949
# Ellipticity: 0.371
# Position Angle: 324.629
#
# Model: WFI2033/SPGR/outSPGR_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 270.700
# X Coordinate: -0.001172902
# Y Coordinate: -0.004783447
# Ellipticity: 0.376
# Position Angle: 336.032
#
# Model: WFI2033/SPF/outSPF_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 292.632
# X Coordinate: -0.04743678
# Y Coordinate: 0.08002221
# Ellipticity: 0.525
# Position Angle: 335.192
#
# Model: WFI2033/SPFR/outSPFR_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 241.315
# X Coordinate: 0.03204306
# Y Coordinate: 0.06764103
# Ellipticity: 0.500
# Position Angle: 260.123
#
# Model: WFI2033/SPFG/outSPFG_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 279.299
# X Coordinate: 0.01997811
# Y Coordinate: 0.002552562
# Ellipticity: 0.327
# Position Angle: 323.679
#
# Model: WFI2033/SPFGR/outSPFGR_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 254.311
# X Coordinate: -0.007869134
# Y Coordinate: 0.01463598
# Ellipticity: 0.000
# Position Angle: 305.906
#
# Model: SDSSJ1330/SPC/outSP_optresult.dat
# Lens Redshift: 0.373
# Velocity Dispersion: 224.884
# X Coordinate: -0.02389152
# Y Coordinate: -0.01380761
# Ellipticity: 0.265
# Position Angle: 327.048
#
# Model: SDSSJ1330/SPC/outSPR_optresult.dat
# Lens Redshift: 0.373
# Velocity Dispersion: 166.450
# X Coordinate: -0.005667873
# Y Coordinate: 0.008775225
# Ellipticity: 0.446
# Position Angle: -21.920
#
# Model: SDSSJ1330/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.373
# Velocity Dispersion: 224.885
# X Coordinate: -0.02342553
# Y Coordinate: -0.01411032
# Ellipticity: 0.266
# Position Angle: 327.056
#
# Model: SDSSJ1330/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.373
# Velocity Dispersion: 106.394
# X Coordinate: -0.002039329
# Y Coordinate: 0.008403188
# Ellipticity: 0.497
# Position Angle: 336.912
#
# Model: WFI2026/SPC/outSP_optresult.dat
# Lens Redshift: 1.040
# Velocity Dispersion: 249.457
# X Coordinate: -0.05586937
# Y Coordinate: 0.002752338
# Ellipticity: 0.459
# Position Angle: 89.537
#
# Model: WFI2026/SPC/outSPR_optresult.dat
# Lens Redshift: 1.040
# Velocity Dispersion: 210.672
# X Coordinate: -0.05007213
# Y Coordinate: 0.01402434
# Ellipticity: 0.436
# Position Angle: 79.405
#
# Model: WFI2026/SPFC/outSPF_optresult.dat
# Lens Redshift: 1.040
# Velocity Dispersion: 249.301
# X Coordinate: -0.05172323
# Y Coordinate: 0.008201557
# Ellipticity: 0.443
# Position Angle: 89.521
#
# Model: WFI2026/SPFC/outSPFR_optresult.dat
# Lens Redshift: 1.040
# Velocity Dispersion: 208.154
# X Coordinate: -0.05173997
# Y Coordinate: 0.01978369
# Ellipticity: 0.355
# Position Angle: 80.355
#
# Model: WGDJ0405/SPC/outSP_optresult.dat
# Lens Redshift: 0.290
# Velocity Dispersion: 179.314
# X Coordinate: 0.01632934
# Y Coordinate: -0.009476977
# Ellipticity: 0.136
# Position Angle: -30.811
#
# Model: WGDJ0405/SPC/outSPR_optresult.dat
# Lens Redshift: 0.290
# Velocity Dispersion: 158.093
# X Coordinate: 0.01349239
# Y Coordinate: -0.01610265
# Ellipticity: 0.292
# Position Angle: -39.973
#
# Model: WGDJ0405/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.290
# Velocity Dispersion: 179.328
# X Coordinate: 0.01575379
# Y Coordinate: -0.01133888
# Ellipticity: 0.134
# Position Angle: -30.815
#
# Model: WGDJ0405/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.290
# Velocity Dispersion: 163.598
# X Coordinate: 0.01736618
# Y Coordinate: -0.01277118
# Ellipticity: 0.170
# Position Angle: -53.007
#
# RXJ0911 & SIE position constraint & 0.769 & 299.999 & -0.091 & 0.035 & 0.600 & 174.195 \\
# RXJ0911 & SIE position constraint, Shear & 0.769 & 220.274 & -0.000 & 0.032 & 0.303 & 208.772 \\
# RXJ0911 & SIE position constraint, G2 & 0.769 & 265.018 & 0.022 & -0.068 & 0.600 & 175.385 \\
# RXJ0911 & SIE position constraint, G2 + Shear & 0.769 & 240.439 & 0.000 & 0.000 & 0.201 & 237.889 \\
# RXJ0911 & SIE position and flux constraint & 0.769 & 300.000 & -0.091 & 0.035 & 0.600 & 174.143 \\
# RXJ0911 & SIE position and flux constraint, Shear & 0.769 & 238.580 & -0.001 & 0.032 & 0.306 & 208.879 \\
# RXJ0911 & SIE position and flux constraint, G2 & 0.769 & 264.129 & 0.025 & -0.062 & 0.600 & 174.753 \\
# RXJ0911 & SIE position and flux constraint, G2 + Shear & 0.769 & 233.674 & -0.000 & -0.002 & 0.239 & 223.447 \\
# PSJ1606 & SIE position constraint & 0.300 & 188.603 & -0.036 & 0.020 & 0.600 & 199.294 \\
# PSJ1606 & SIE position constraint, Shear & 0.300 & 176.108 & -0.017 & 0.016 & 0.200 & 173.071 \\
# PSJ1606 & SIE position constraint, G2 & 0.300 & 171.252 & 0.061 & 0.053 & 0.542 & 217.836 \\
# PSJ1606 & SIE position constraint, G2 + Shear & 0.300 & 170.543 & -0.000 & 0.000 & 0.600 & 196.876 \\
# PSJ1606 & SIE position and flux constraint & 0.300 & 188.655 & -0.034 & 0.015 & 0.600 & 199.402 \\
# PSJ1606 & SIE position and flux constraint, Shear & 0.300 & 172.262 & -0.013 & 0.016 & 0.181 & 151.451 \\
# PSJ1606 & SIE position and flux constraint, G2 & 0.300 & 167.883 & 0.104 & 0.017 & 0.486 & 225.009 \\
# PSJ1606 & SIE position and flux constraint, G2 + Shear & 0.300 & 171.771 & 0.019 & 0.023 & 0.001 & 119.005 \\
# WFI2033 & SIE position constraint & 0.661 & 294.484 & -0.097 & 0.043 & 0.576 & 335.123 \\
# WFI2033 & SIE position constraint, Shear & 0.661 & 314.213 & -0.018 & 0.035 & 0.342 & 272.839 \\
# WFI2033 & SIE position constraint, G2 & 0.661 & 279.820 & -0.017 & 0.004 & 0.371 & 324.629 \\
# WFI2033 & SIE position constraint, G2 + Shear & 0.661 & 270.700 & -0.001 & -0.005 & 0.376 & 336.032 \\
# WFI2033 & SIE position and flux constraint & 0.661 & 292.632 & -0.047 & 0.080 & 0.525 & 335.192 \\
# WFI2033 & SIE position and flux constraint, Shear & 0.661 & 241.315 & 0.032 & 0.068 & 0.500 & 260.123 \\
# WFI2033 & SIE position and flux constraint, G2 & 0.661 & 279.299 & 0.020 & 0.003 & 0.327 & 323.679 \\
# WFI2033 & SIE position and flux constraint, G2 + Shear & 0.661 & 254.311 & -0.008 & 0.015 & 0.000 & 305.906 \\
# SDSSJ1330 & SIE position constraint & 0.373 & 224.884 & -0.024 & -0.014 & 0.265 & 327.048 \\
# SDSSJ1330 & SIE position constraint, Shear & 0.373 & 166.450 & -0.006 & 0.009 & 0.446 & -21.920 \\
# SDSSJ1330 & SIE position and flux constraint & 0.373 & 224.885 & -0.023 & -0.014 & 0.266 & 327.056 \\
# SDSSJ1330 & SIE position and flux constraint, Shear & 0.373 & 106.394 & -0.002 & 0.008 & 0.497 & 336.912 \\
# WFI2026 & SIE position constraint & 1.040 & 249.457 & -0.056 & 0.003 & 0.459 & 89.537 \\
# WFI2026 & SIE position constraint, Shear & 1.040 & 210.672 & -0.050 & 0.014 & 0.436 & 79.405 \\
# WFI2026 & SIE position and flux constraint & 1.040 & 249.301 & -0.052 & 0.008 & 0.443 & 89.521 \\
# WFI2026 & SIE position and flux constraint, Shear & 1.040 & 208.154 & -0.052 & 0.020 & 0.355 & 80.355 \\
# WGDJ0405 & SIE position constraint & 0.290 & 179.314 & 0.016 & -0.009 & 0.136 & -30.811 \\
# WGDJ0405 & SIE position constraint, Shear & 0.290 & 158.093 & 0.013 & -0.016 & 0.292 & -39.973 \\
# WGDJ0405 & SIE position and flux constraint & 0.290 & 179.328 & 0.016 & -0.011 & 0.134 & -30.815 \\
# WGDJ0405 & SIE position and flux constraint, Shear & 0.290 & 163.598 & 0.017 & -0.013 & 0.170 & -53.007 \\

# %%
# Successful Code that outputs the parameters for SIE as required!!! 

def extract_sie_parameters(filename):
    """
    Extract the SIE lens parameters from the first "lens   sie" line that appears after the final mention of "chi^2" in the file.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()

    last_chi2_index = None
    for index, line in enumerate(lines):
        if "chi^2" in line:
            last_chi2_index = index

    if last_chi2_index is None:
        print(f"Error: 'chi^2' line not found in file: {filename}.")
        return None

    for line in lines[last_chi2_index:]:
        if "lens   sie" in line:
            parts = line.split()
            try:
                lens_redshift = float(parts[2])
                velocity_dispersion = float(parts[3])
                x_coord = float(parts[4])
                y_coord = float(parts[5])
                ellipticity = float(parts[6])
                position_angle = float(parts[7])
                return (lens_redshift, velocity_dispersion, x_coord, y_coord, ellipticity, position_angle)
            except (ValueError, IndexError):
                print(f"Error: Failed to extract numbers from file: {filename}. Check the 'lens sie' line format.")
                return None

    print(f"Error: 'lens sie' line not found after last 'chi^2' in file: {filename}.")
    return None

def rename_file(file_path):
    parts = file_path.split("/")
    lens_system = parts[0]  # Now correctly fetching the first part of the file path
    file_name = parts[-1]

    key = file_name.split("_optresult")[0][3:]
    profile_map = {"S": "SIE", "P": "POW", "N": "NFW"}
    profile = profile_map.get(key[0], "Unknown")

    constraint = "Unknown constraint"
    if key[1:3] == "PF":
        constraint = "QSO Pos + FR"
    elif key[1] == "P":
        constraint = "QSO Pos"

    extras = []
    if "G" in key:
        extras.append("G2")
    if "R" in key:
        extras.append("Shear")

    # Assemble profile descriptions with combinations
    if len(extras) == 2:
        profile_description = f"{profile} + {extras[0]} + {extras[1]}"
    elif len(extras) == 1:
        profile_description = f"{profile} + {extras[0]}"
    else:
        profile_description = profile

    new_name = f"{lens_system} & {profile_description} & {constraint}"
    return new_name

def process_multiple_files(file_list):
    results = []
    for file_name in file_list:
        model_description = rename_file(file_name)
        sie_parameters = extract_sie_parameters(file_name)
        if sie_parameters:
            lens_redshift, velocity_dispersion, x_coord, y_coord, ellipticity, position_angle = sie_parameters
            result_text = f"{model_description} & {lens_redshift:.3f} & {velocity_dispersion:.3f} & {x_coord:.3f} & {y_coord:.3f} & {ellipticity:.3f} & {position_angle:.3f} \\\\"
            results.append(result_text)
            print(f"Model: {file_name}")
            print(f"Lens Redshift: {lens_redshift:.3f}")
            print(f"Velocity Dispersion: {velocity_dispersion:.3f}")
            print(f"X Coordinate: {x_coord:}")
            print(f"Y Coordinate: {y_coord:}")
            print(f"Ellipticity: {ellipticity:.3f}")
            print(f"Position Angle: {position_angle:.3f}\n")
        else:
            results.append(f"{model_description} Failed to extract SIE parameters.")
            print(f"Model: {file_name} Failed to extract SIE parameters.\n")
    return results

# List of file paths to process
file_list = [
    "RXJ0911/SPC/outSP_optresult.dat",
    "RXJ0911/SPC/outSPR_optresult.dat",
    "RXJ0911/SPC/outSPG_optresult.dat",
    "RXJ0911/SPC/outSPGR_optresult.dat",
    "RXJ0911/SPFC/outSPF_optresult.dat",
    "RXJ0911/SPFC/outSPFR_optresult.dat",
    "RXJ0911/SPFC/outSPFG_optresult.dat",
    "RXJ0911/SPFC/outSPFGR_optresult.dat",
    "PSJ1606/SPC/outSP_optresult.dat",
    "PSJ1606/SPC/outSPR_optresult.dat",
    "PSJ1606/SPC/outSPG_optresult.dat",
    "PSJ1606/SPC/outSPGR_optresult.dat",
    "PSJ1606/SPFC/outSPF_optresult.dat",
    "PSJ1606/SPFC/outSPFR_optresult.dat",
    "PSJ1606/SPFC/outSPFG_optresult.dat",
    "PSJ1606/SPFC/outSPFGR_optresult.dat",
    "WFI2033/SP/outSP_optresult.dat",
    "WFI2033/SPR/outSPR_optresult.dat",
    "WFI2033/SPG/outSPG_optresult.dat",
    "WFI2033/SPGR/outSPGR_optresult.dat",
    "WFI2033/SPF/outSPF_optresult.dat",
    "WFI2033/SPFR/outSPFR_optresult.dat",
    "WFI2033/SPFG/outSPFG_optresult.dat",
    "WFI2033/SPFGR/outSPFGR_optresult.dat",
    "SDSSJ1330/SPC/outSP_optresult.dat",
    "SDSSJ1330/SPC/outSPR_optresult.dat",
    "SDSSJ1330/SPFC/outSPF_optresult.dat",
    "SDSSJ1330/SPFC/outSPFR_optresult.dat",
    "WFI2026/SPC/outSP_optresult.dat",
    "WFI2026/SPC/outSPR_optresult.dat",
    "WFI2026/SPFC/outSPF_optresult.dat",
    "WFI2026/SPFC/outSPFR_optresult.dat",
    "WGDJ0405/SPC/outSP_optresult.dat",
    "WGDJ0405/SPC/outSPR_optresult.dat",
    "WGDJ0405/SPFC/outSPF_optresult.dat",
    "WGDJ0405/SPFC/outSPFR_optresult.dat",
    "WGD2038/SPC/outSP_optresult.dat",
    "WGD2038/SPC/outSPR_optresult.dat",
    "WGD2038/SPFC/outSPF_optresult.dat",
    "WGD2038/SPFC/outSPFR_optresult.dat",
]

# Execute the function and print LaTeX-formatted results
latex_results = process_multiple_files(file_list)
for result in latex_results:
    print(result)
# Out:
# Model: RXJ0911/SPC/outSP_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 299.999
# X Coordinate: -0.09093027
# Y Coordinate: 0.03471901
# Ellipticity: 0.600
# Position Angle: 174.195
#
# Model: RXJ0911/SPC/outSPR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 220.274
# X Coordinate: -8.853659e-05
# Y Coordinate: 0.03159181
# Ellipticity: 0.303
# Position Angle: 208.772
#
# Model: RXJ0911/SPC/outSPG_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 265.018
# X Coordinate: 0.02241472
# Y Coordinate: -0.06796709
# Ellipticity: 0.600
# Position Angle: 175.385
#
# Model: RXJ0911/SPC/outSPGR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 240.439
# X Coordinate: 9.012696e-07
# Y Coordinate: 1.345252e-05
# Ellipticity: 0.201
# Position Angle: 237.889
#
# Model: RXJ0911/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 300.000
# X Coordinate: -0.09092218
# Y Coordinate: 0.03503759
# Ellipticity: 0.600
# Position Angle: 174.143
#
# Model: RXJ0911/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 238.580
# X Coordinate: -0.0005396177
# Y Coordinate: 0.03151202
# Ellipticity: 0.306
# Position Angle: 208.879
#
# Model: RXJ0911/SPFC/outSPFG_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 264.129
# X Coordinate: 0.02489965
# Y Coordinate: -0.06162456
# Ellipticity: 0.600
# Position Angle: 174.753
#
# Model: RXJ0911/SPFC/outSPFGR_optresult.dat
# Lens Redshift: 0.769
# Velocity Dispersion: 233.674
# X Coordinate: -0.0004699347
# Y Coordinate: -0.001717117
# Ellipticity: 0.239
# Position Angle: 223.447
#
# Model: PSJ1606/SPC/outSP_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 188.603
# X Coordinate: -0.03555983
# Y Coordinate: 0.02020766
# Ellipticity: 0.600
# Position Angle: 199.294
#
# Model: PSJ1606/SPC/outSPR_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 176.108
# X Coordinate: -0.01688416
# Y Coordinate: 0.01610115
# Ellipticity: 0.200
# Position Angle: 173.071
#
# Model: PSJ1606/SPC/outSPG_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 171.252
# X Coordinate: 0.06107697
# Y Coordinate: 0.05345572
# Ellipticity: 0.542
# Position Angle: 217.836
#
# Model: PSJ1606/SPC/outSPGR_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 170.543
# X Coordinate: -7.094564e-06
# Y Coordinate: 1.319316e-05
# Ellipticity: 0.600
# Position Angle: 196.876
#
# Model: PSJ1606/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 188.655
# X Coordinate: -0.03381372
# Y Coordinate: 0.01486134
# Ellipticity: 0.600
# Position Angle: 199.402
#
# Model: PSJ1606/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 172.262
# X Coordinate: -0.01260316
# Y Coordinate: 0.01581286
# Ellipticity: 0.181
# Position Angle: 151.451
#
# Model: PSJ1606/SPFC/outSPFG_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 167.883
# X Coordinate: 0.1040224
# Y Coordinate: 0.01747521
# Ellipticity: 0.486
# Position Angle: 225.009
#
# Model: PSJ1606/SPFC/outSPFGR_optresult.dat
# Lens Redshift: 0.300
# Velocity Dispersion: 171.771
# X Coordinate: 0.01876222
# Y Coordinate: 0.02262219
# Ellipticity: 0.001
# Position Angle: 119.005
#
# Model: WFI2033/SP/outSP_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 294.484
# X Coordinate: -0.09720901
# Y Coordinate: 0.0427617
# Ellipticity: 0.576
# Position Angle: 335.123
#
# Model: WFI2033/SPR/outSPR_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 283.178
# X Coordinate: -0.01812266
# Y Coordinate: 0.03515305
# Ellipticity: 0.343
# Position Angle: 272.803
#
# Model: WFI2033/SPG/outSPG_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 279.820
# X Coordinate: -0.01663208
# Y Coordinate: 0.003622949
# Ellipticity: 0.371
# Position Angle: 324.629
#
# Model: WFI2033/SPGR/outSPGR_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 270.700
# X Coordinate: -0.001172902
# Y Coordinate: -0.004783447
# Ellipticity: 0.376
# Position Angle: 336.032
#
# Model: WFI2033/SPF/outSPF_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 292.632
# X Coordinate: -0.04743678
# Y Coordinate: 0.08002221
# Ellipticity: 0.525
# Position Angle: 335.192
#
# Model: WFI2033/SPFR/outSPFR_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 241.315
# X Coordinate: 0.03204306
# Y Coordinate: 0.06764103
# Ellipticity: 0.500
# Position Angle: 260.123
#
# Model: WFI2033/SPFG/outSPFG_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 279.299
# X Coordinate: 0.01997811
# Y Coordinate: 0.002552562
# Ellipticity: 0.327
# Position Angle: 323.679
#
# Model: WFI2033/SPFGR/outSPFGR_optresult.dat
# Lens Redshift: 0.661
# Velocity Dispersion: 254.311
# X Coordinate: -0.007869134
# Y Coordinate: 0.01463598
# Ellipticity: 0.000
# Position Angle: 305.906
#
# Model: SDSSJ1330/SPC/outSP_optresult.dat
# Lens Redshift: 0.373
# Velocity Dispersion: 224.884
# X Coordinate: -0.02389152
# Y Coordinate: -0.01380761
# Ellipticity: 0.265
# Position Angle: 327.048
#
# Model: SDSSJ1330/SPC/outSPR_optresult.dat
# Lens Redshift: 0.373
# Velocity Dispersion: 166.450
# X Coordinate: -0.005667873
# Y Coordinate: 0.008775225
# Ellipticity: 0.446
# Position Angle: -21.920
#
# Model: SDSSJ1330/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.373
# Velocity Dispersion: 224.885
# X Coordinate: -0.02342553
# Y Coordinate: -0.01411032
# Ellipticity: 0.266
# Position Angle: 327.056
#
# Model: SDSSJ1330/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.373
# Velocity Dispersion: 106.394
# X Coordinate: -0.002039329
# Y Coordinate: 0.008403188
# Ellipticity: 0.497
# Position Angle: 336.912
#
# Model: WFI2026/SPC/outSP_optresult.dat
# Lens Redshift: 1.040
# Velocity Dispersion: 249.457
# X Coordinate: -0.05586937
# Y Coordinate: 0.002752338
# Ellipticity: 0.459
# Position Angle: 89.537
#
# Model: WFI2026/SPC/outSPR_optresult.dat
# Lens Redshift: 1.040
# Velocity Dispersion: 210.672
# X Coordinate: -0.05007213
# Y Coordinate: 0.01402434
# Ellipticity: 0.436
# Position Angle: 79.405
#
# Model: WFI2026/SPFC/outSPF_optresult.dat
# Lens Redshift: 1.040
# Velocity Dispersion: 249.301
# X Coordinate: -0.05172323
# Y Coordinate: 0.008201557
# Ellipticity: 0.443
# Position Angle: 89.521
#
# Model: WFI2026/SPFC/outSPFR_optresult.dat
# Lens Redshift: 1.040
# Velocity Dispersion: 208.154
# X Coordinate: -0.05173997
# Y Coordinate: 0.01978369
# Ellipticity: 0.355
# Position Angle: 80.355
#
# Model: WGDJ0405/SPC/outSP_optresult.dat
# Lens Redshift: 0.290
# Velocity Dispersion: 179.314
# X Coordinate: 0.01632934
# Y Coordinate: -0.009476977
# Ellipticity: 0.136
# Position Angle: -30.811
#
# Model: WGDJ0405/SPC/outSPR_optresult.dat
# Lens Redshift: 0.290
# Velocity Dispersion: 158.093
# X Coordinate: 0.01349239
# Y Coordinate: -0.01610265
# Ellipticity: 0.292
# Position Angle: -39.973
#
# Model: WGDJ0405/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.290
# Velocity Dispersion: 179.328
# X Coordinate: 0.01575379
# Y Coordinate: -0.01133888
# Ellipticity: 0.134
# Position Angle: -30.815
#
# Model: WGDJ0405/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.290
# Velocity Dispersion: 163.598
# X Coordinate: 0.01736618
# Y Coordinate: -0.01277118
# Ellipticity: 0.170
# Position Angle: -53.007
#
# Model: WGD2038/SPC/outSP_optresult.dat
# Lens Redshift: 0.230
# Velocity Dispersion: 271.789
# X Coordinate: 0.00858592
# Y Coordinate: 0.005186918
# Ellipticity: 0.417
# Position Angle: -35.332
#
# Model: WGD2038/SPC/outSPR_optresult.dat
# Lens Redshift: 0.230
# Velocity Dispersion: 247.989
# X Coordinate: 0.0006973723
# Y Coordinate: -0.0008717681
# Ellipticity: 0.348
# Position Angle: -36.841
#
# Model: WGD2038/SPFC/outSPF_optresult.dat
# Lens Redshift: 0.230
# Velocity Dispersion: 271.757
# X Coordinate: 0.007968112
# Y Coordinate: 0.004206097
# Ellipticity: 0.416
# Position Angle: -35.335
#
# Model: WGD2038/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.230
# Velocity Dispersion: 117.757
# X Coordinate: 0.008097112
# Y Coordinate: 0.003880798
# Ellipticity: 0.409
# Position Angle: -36.161
#
# RXJ0911 & SIE & QSO Pos & 0.769 & 299.999 & -0.091 & 0.035 & 0.600 & 174.195 \\
# RXJ0911 & SIE + Shear & QSO Pos & 0.769 & 220.274 & -0.000 & 0.032 & 0.303 & 208.772 \\
# RXJ0911 & SIE + G2 & QSO Pos & 0.769 & 265.018 & 0.022 & -0.068 & 0.600 & 175.385 \\
# RXJ0911 & SIE + G2 + Shear & QSO Pos & 0.769 & 240.439 & 0.000 & 0.000 & 0.201 & 237.889 \\
# RXJ0911 & SIE & QSO Pos + FR & 0.769 & 300.000 & -0.091 & 0.035 & 0.600 & 174.143 \\
# RXJ0911 & SIE + Shear & QSO Pos + FR & 0.769 & 238.580 & -0.001 & 0.032 & 0.306 & 208.879 \\
# RXJ0911 & SIE + G2 & QSO Pos + FR & 0.769 & 264.129 & 0.025 & -0.062 & 0.600 & 174.753 \\
# RXJ0911 & SIE + G2 + Shear & QSO Pos + FR & 0.769 & 233.674 & -0.000 & -0.002 & 0.239 & 223.447 \\
# PSJ1606 & SIE & QSO Pos & 0.300 & 188.603 & -0.036 & 0.020 & 0.600 & 199.294 \\
# PSJ1606 & SIE + Shear & QSO Pos & 0.300 & 176.108 & -0.017 & 0.016 & 0.200 & 173.071 \\
# PSJ1606 & SIE + G2 & QSO Pos & 0.300 & 171.252 & 0.061 & 0.053 & 0.542 & 217.836 \\
# PSJ1606 & SIE + G2 + Shear & QSO Pos & 0.300 & 170.543 & -0.000 & 0.000 & 0.600 & 196.876 \\
# PSJ1606 & SIE & QSO Pos + FR & 0.300 & 188.655 & -0.034 & 0.015 & 0.600 & 199.402 \\
# PSJ1606 & SIE + Shear & QSO Pos + FR & 0.300 & 172.262 & -0.013 & 0.016 & 0.181 & 151.451 \\
# PSJ1606 & SIE + G2 & QSO Pos + FR & 0.300 & 167.883 & 0.104 & 0.017 & 0.486 & 225.009 \\
# PSJ1606 & SIE + G2 + Shear & QSO Pos + FR & 0.300 & 171.771 & 0.019 & 0.023 & 0.001 & 119.005 \\
# WFI2033 & SIE & QSO Pos & 0.661 & 294.484 & -0.097 & 0.043 & 0.576 & 335.123 \\
# WFI2033 & SIE + Shear & QSO Pos & 0.661 & 283.178 & -0.018 & 0.035 & 0.343 & 272.803 \\
# WFI2033 & SIE + G2 & QSO Pos & 0.661 & 279.820 & -0.017 & 0.004 & 0.371 & 324.629 \\
# WFI2033 & SIE + G2 + Shear & QSO Pos & 0.661 & 270.700 & -0.001 & -0.005 & 0.376 & 336.032 \\
# WFI2033 & SIE & QSO Pos + FR & 0.661 & 292.632 & -0.047 & 0.080 & 0.525 & 335.192 \\
# WFI2033 & SIE + Shear & QSO Pos + FR & 0.661 & 241.315 & 0.032 & 0.068 & 0.500 & 260.123 \\
# WFI2033 & SIE + G2 & QSO Pos + FR & 0.661 & 279.299 & 0.020 & 0.003 & 0.327 & 323.679 \\
# WFI2033 & SIE + G2 + Shear & QSO Pos + FR & 0.661 & 254.311 & -0.008 & 0.015 & 0.000 & 305.906 \\
# SDSSJ1330 & SIE & QSO Pos & 0.373 & 224.884 & -0.024 & -0.014 & 0.265 & 327.048 \\
# SDSSJ1330 & SIE + Shear & QSO Pos & 0.373 & 166.450 & -0.006 & 0.009 & 0.446 & -21.920 \\
# SDSSJ1330 & SIE & QSO Pos + FR & 0.373 & 224.885 & -0.023 & -0.014 & 0.266 & 327.056 \\
# SDSSJ1330 & SIE + Shear & QSO Pos + FR & 0.373 & 106.394 & -0.002 & 0.008 & 0.497 & 336.912 \\
# WFI2026 & SIE & QSO Pos & 1.040 & 249.457 & -0.056 & 0.003 & 0.459 & 89.537 \\
# WFI2026 & SIE + Shear & QSO Pos & 1.040 & 210.672 & -0.050 & 0.014 & 0.436 & 79.405 \\
# WFI2026 & SIE & QSO Pos + FR & 1.040 & 249.301 & -0.052 & 0.008 & 0.443 & 89.521 \\
# WFI2026 & SIE + Shear & QSO Pos + FR & 1.040 & 208.154 & -0.052 & 0.020 & 0.355 & 80.355 \\
# WGDJ0405 & SIE & QSO Pos & 0.290 & 179.314 & 0.016 & -0.009 & 0.136 & -30.811 \\
# WGDJ0405 & SIE + Shear & QSO Pos & 0.290 & 158.093 & 0.013 & -0.016 & 0.292 & -39.973 \\
# WGDJ0405 & SIE & QSO Pos + FR & 0.290 & 179.328 & 0.016 & -0.011 & 0.134 & -30.815 \\
# WGDJ0405 & SIE + Shear & QSO Pos + FR & 0.290 & 163.598 & 0.017 & -0.013 & 0.170 & -53.007 \\
# WGD2038 & SIE & QSO Pos & 0.230 & 271.789 & 0.009 & 0.005 & 0.417 & -35.332 \\
# WGD2038 & SIE + Shear & QSO Pos & 0.230 & 247.989 & 0.001 & -0.001 & 0.348 & -36.841 \\
# WGD2038 & SIE & QSO Pos + FR & 0.230 & 271.757 & 0.008 & 0.004 & 0.416 & -35.335 \\
# WGD2038 & SIE + Shear & QSO Pos + FR & 0.230 & 117.757 & 0.008 & 0.004 & 0.409 & -36.161 \\
