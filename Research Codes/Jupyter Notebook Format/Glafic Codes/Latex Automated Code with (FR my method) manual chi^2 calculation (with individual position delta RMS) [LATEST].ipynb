# %%
# NEW LATEX AUTOMATED CODE WITH MANUAL CHI^2 CALCULATION with individual position delta RMS and flux ratio differences
# RXJ0911 
import numpy as np
import pandas as pd
from astropy.io import fits
import os

# Function to calculate distance
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Function to read observed positions, flux ratios, and uncertainties
def read_observed_positions(input_file):
    observed_positions = []
    observed_flux_ratios = []
    position_uncertainties = []
    flux_uncertainties = []
    with open(input_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            columns = line.split()
            if len(columns) >= 5:
                x1 = float(columns[0])
                y1 = float(columns[1])
                flux_ratio = float(columns[2])
                pos_err = float(columns[3])
                flux_err = float(columns[4])
                observed_positions.append((x1, y1))
                observed_flux_ratios.append(flux_ratio)
                position_uncertainties.append(pos_err)
                flux_uncertainties.append(flux_err)
    return observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties

# Function to read predicted positions and magnifications
def read_predicted_positions(output_file):
    predicted_positions = []
    predicted_magnifications = []
    with open(output_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            if line.startswith("#"):
                continue
            columns = line.split()
            if len(columns) >= 3:
                x2 = float(columns[0])
                y2 = float(columns[1])
                M2 = abs(float(columns[2]))
                predicted_positions.append((x2, y2))
                predicted_magnifications.append(M2)
    return predicted_positions, predicted_magnifications

# Function to pair predicted and observed positions
def pair_positions(observed_positions, predicted_positions, predicted_magnifications):
    paired_positions = []
    for observed_position in observed_positions:
        min_distance = float('inf')
        closest_index = None
        for i, predicted_position in enumerate(predicted_positions):
            distance = calculate_distance(*observed_position, *predicted_position)
            if distance < min_distance:
                min_distance = distance
                closest_index = i
        paired_positions.append((observed_position, predicted_positions[closest_index], predicted_magnifications[closest_index]))
    return paired_positions

# Function to calculate manual chi² with proper uncertainties
def calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties, 
                         predicted_positions, predicted_magnifications, green_index=1):
    # Pair positions
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Calculate predicted flux ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]
    
    chi2 = 0.0
    
    # Position contributions to chi²
    for i, (observed, predicted, _) in enumerate(paired_positions):
        dx = observed[0] - predicted[0]
        dy = observed[1] - predicted[1]
        pos_err = position_uncertainties[i]
        chi2 += (dx/pos_err)**2 + (dy/pos_err)**2
    
    # Flux ratio contributions to chi² (excluding the normalization image)
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_err = flux_uncertainties[i]
            chi2 += ((pred_flux - obs_flux)/flux_err)**2
    
    return chi2

# Function to extract the final chi^2 from optresult.dat file
def extract_glafic_chi2(optresult_path):
    chi2_value = None
    with open(optresult_path, 'r') as file:
        lines = file.readlines()
    
    # Find the last occurrence of chi^2 (final/best result)
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
    
    return chi2_value

# Function to process file group
def process_file_group(output_file, fits_file, input_file, n):
    observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties = read_observed_positions(input_file)
    predicted_positions, predicted_magnifications = read_predicted_positions(output_file)
    
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Calculate Delta RMS of Image Positions correctly
    squared_distances = 0.0
    individual_distances = []  # Store individual distances for each image
    for observed, predicted, _ in paired_positions:
        distance = calculate_distance(*observed, *predicted)
        individual_distances.append(distance * 1000)  # Convert to mas
        squared_distances += distance ** 2  # Summing squared distances
    
    mean_squared_distances = squared_distances / len(paired_positions)
    delta_rms = np.sqrt(mean_squared_distances)  # Taking square root of the mean of squared distances
    delta_rms *= 1000  # Convert to mas
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Determine the index of the "Green Image"
    green_index = 1  # CHOOSE WHICH IMAGE TO NORMALISE BY HERE !!!!!!!!!!!!!!!!!!!!!!!

    # Predicted Flux Ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]

    # Calculate absolute differences between predicted and observed flux ratios (excluding normalization image)
    flux_ratio_differences = []
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_ratio_differences.append(abs(pred_flux - obs_flux))

    # Calculate manual chi²
    manual_chi2 = calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties,
                                       predicted_positions, predicted_magnifications, green_index)

    with fits.open(fits_file) as hdul:
        mag = hdul[0].data[6]
    
    pixel_coords = [(int((x + mag.shape[1] // 2 * n) / n), int((y + mag.shape[0] // 2 * n) / n)) for x, y in observed_positions]
    values = [mag[y, x] for x, y in pixel_coords]
    
    abs_values = [1 / abs(value) for value in values]
    predicted_flux_ratios_observed = [abs_values[i] / abs_values[green_index] for i in range(len(abs_values))]

    # Calculate RMS excluding the green image
    squared_diffs_pred = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_rms = np.sqrt(sum(squared_diffs_pred) / len(squared_diffs_pred))

    squared_diffs_obs = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios_observed, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_observed_rms = np.sqrt(sum(squared_diffs_obs) / len(squared_diffs_obs))

    return {
        'delta_rms': delta_rms,
        'individual_position_deltas': individual_distances,  # Delta RMS for each of the 4 positions
        'flux_ratio_differences': flux_ratio_differences,    # Absolute differences for 3 flux ratios
        'predicted_flux_ratios_rms': predicted_flux_ratios_rms,
        'predicted_flux_ratios_observed_rms': predicted_flux_ratios_observed_rms,
        'manual_chi2': manual_chi2
    }

# Function to extract chi^2 and lens models from optresult.dat file (following Code 1's approach exactly)
def extract_chi2_and_lens_profiles(optresult_path):
    chi2_value = None
    profiles_used = []
    sie_count = 0

    with open(optresult_path, 'r') as file:
        lines = file.readlines()

    found_chi2 = False
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
            found_chi2 = True
            profiles_used = []
            sie_count = 0
        elif found_chi2:
            if line.startswith("lens   sie"):
                profiles_used.append("SIE")
                sie_count += 1
            elif line.startswith("lens   pow"):
                profiles_used.append("POW")
            elif line.startswith("lens   anfw"):
                profiles_used.append("NFW")
            elif line.startswith("lens   pert"):
                profiles_used.append("Shear")

    if chi2_value is None:
        raise ValueError("No chi^2 value found in the file.")

    profiles_used = list(set(profiles_used))
    return chi2_value, profiles_used, sie_count

# Function to calculate free parameters based on lens profiles (identical to Code 1)
def calculate_free_parameters(profiles_used, sie_count):
    profile_params = {
        "SIE": 5,
        "POW": 6,
        "NFW": 6,
        "Shear": 5
    }
    total_params = sum(profile_params[profile] for profile in profiles_used)
    if sie_count == 2:
        total_params += 5
    return total_params

# Function to calculate BIC (Bayesian Information Criterion)
def calculate_bic(chi2, n_data_points, n_free_params):
    return chi2 + n_free_params * np.log(n_data_points)

# Function to compute BIC using manual chi² but following Code 1's approach for free parameters
def compute_bic_with_tracking(manual_chi2, optresult_path):
    # Use Code 1's approach: extract profiles from optresult.dat file
    glafic_chi2, profiles_used, sie_count = extract_chi2_and_lens_profiles(optresult_path)
    n_free_params = calculate_free_parameters(profiles_used, sie_count)
    
    # Properly adjust n_data_points based on constraint type
    if "PF" in optresult_path:
        n_data_points = 4 * 2 + 3  # positions + flux ratios
    else:
        n_data_points = 4 * 2  # positions only
    
    # Always use manual chi² for BIC calculation
    bic_value = calculate_bic(manual_chi2, n_data_points, n_free_params)
    
    return bic_value, glafic_chi2, n_data_points, n_free_params

# Main function to process multiple files
def process_files(input_file, output_files, fits_files, optresult_files, n):
    results = []
    latex_rows = []
    bics = []  # Store BIC values separately
    glafic_chi2_values = []  # Store glafic chi² for reference
    data_points_used = []  # Store number of data points used
    free_params_used = []  # Store number of free parameters used

    for output_file, fits_file, optresult_file in zip(output_files, fits_files, optresult_files):
        # Process output and fits files
        result = process_file_group(output_file, fits_file, input_file, n)
        results.append(result)
        
        # Calculate BIC using manual chi² but track both values
        bic, glafic_chi2, n_data_points, n_free_params = compute_bic_with_tracking(result['manual_chi2'], optresult_file)
        bics.append(bic)
        glafic_chi2_values.append(glafic_chi2)
        data_points_used.append(n_data_points)
        free_params_used.append(n_free_params)
        
        # Create LaTeX row with additional information
        model_name, constraint_name = determine_model_and_constraint(output_file)
        # Format individual position deltas and flux ratio differences for LaTeX
        pos_deltas_str = " & ".join([f"{delta:.3f}" for delta in result['individual_position_deltas']])
        flux_diffs_str = " & ".join([f"{diff:.3f}" for diff in result['flux_ratio_differences']])
        
        latex_row = f"{model_name} & {constraint_name} & {pos_deltas_str} & {result['delta_rms']:.1f} & {flux_diffs_str} & {result['predicted_flux_ratios_rms']:.2f} & {bic:.1f} \\\\"
        latex_rows.append(latex_row)
    
    # Combine results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results['bic'] = bics  # Add BIC values to the DataFrame
    df_results['glafic_chi2'] = glafic_chi2_values  # Add glafic chi² for reference
    df_results['n_data_points'] = data_points_used  # Add number of data points used
    df_results['n_free_params'] = free_params_used  # Add number of free parameters used
    
    return df_results, latex_rows

# Determine model and constraint names from the filename
def determine_model_and_constraint(file_name):
    model_map = {'S': 'SIE', 'P': 'POW', 'N': 'NFW'}
    
    base_name = os.path.basename(file_name)
    model_key = base_name[3]
    constraint_key = base_name[4:6] if base_name[4:6] in ['PF'] else base_name[4]
    
    model_name = model_map.get(model_key, '')
    if 'R' in base_name:
        model_name += ' + Shear'
    if 'G' in base_name:
        model_name += ' + G2'
    
    constraint_name = 'QSO Pos + FR' if constraint_key == 'PF' else 'QSO Pos'
    
    return model_name, constraint_name

# Example usage with filenames
Input_file = "RXJ0911/SPFC/obs_point.dat"

Output_files = [
    "RXJ0911/SPC/outSP_point.dat",
    "RXJ0911/SPC/outSPR_point.dat",
    "RXJ0911/SPC/outSPG_point.dat",
    "RXJ0911/SPC/outSPGR_point.dat",
    "RXJ0911/SPFC/outSPF_point.dat",
    "RXJ0911/SPFC/outSPFR_point.dat",
    "RXJ0911/SPFC/outSPFG_point.dat",
    "RXJ0911/SPFC/outSPFGR_point.dat",
    "RXJ0911/PPC/outPP_point.dat",
    "RXJ0911/PPC/outPPR_point.dat",
    "RXJ0911/PPC/outPPG_point.dat",
    "RXJ0911/PPC/outPPGR_point.dat",
    "RXJ0911/PPFC/outPPF_point.dat",
    "RXJ0911/PPFC/outPPFR_point.dat",
    "RXJ0911/PPFC/outPPFG_point.dat",
    "RXJ0911/PPFC/outPPFGR_point.dat",
    "RXJ0911/NPC/outNP_point.dat",
    "RXJ0911/NPC/outNPR_point.dat",
    "RXJ0911/NPC/outNPG_point.dat",
    "RXJ0911/NPC/outNPGR_point.dat",
    "RXJ0911/NPFC/outNPF_point.dat",
    "RXJ0911/NPFC/outNPFR_point.dat",
    "RXJ0911/NPFC/outNPFG_point.dat",
    "RXJ0911/NPFC/outNPFGR_point.dat",
]

Fits_files = [
    "RXJ0911/SPC/outSP_lens.fits",
    "RXJ0911/SPC/outSPR_lens.fits",
    "RXJ0911/SPC/outSPG_lens.fits",
    "RXJ0911/SPC/outSPGR_lens.fits",
    "RXJ0911/SPFC/outSPF_lens.fits",
    "RXJ0911/SPFC/outSPFR_lens.fits",
    "RXJ0911/SPFC/outSPFG_lens.fits",
    "RXJ0911/SPFC/outSPFGR_lens.fits",
    "RXJ0911/PPC/outPP_lens.fits",
    "RXJ0911/PPC/outPPR_lens.fits",
    "RXJ0911/PPC/outPPG_lens.fits",
    "RXJ0911/PPC/outPPGR_lens.fits",
    "RXJ0911/PPFC/outPPF_lens.fits",
    "RXJ0911/PPFC/outPPFR_lens.fits",
    "RXJ0911/PPFC/outPPFG_lens.fits",
    "RXJ0911/PPFC/outPPFGR_lens.fits",
    "RXJ0911/NPC/outNP_lens.fits",
    "RXJ0911/NPC/outNPR_lens.fits",
    "RXJ0911/NPC/outNPG_lens.fits",
    "RXJ0911/NPC/outNPGR_lens.fits",
    "RXJ0911/NPFC/outNPF_lens.fits",
    "RXJ0911/NPFC/outNPFR_lens.fits",
    "RXJ0911/NPFC/outNPFG_lens.fits",
    "RXJ0911/NPFC/outNPFGR_lens.fits"
]

Optresult_files = [
    "RXJ0911/SPC/outSP_optresult.dat",
    "RXJ0911/SPC/outSPR_optresult.dat",
    "RXJ0911/SPC/outSPG_optresult.dat",
    "RXJ0911/SPC/outSPGR_optresult.dat",
    "RXJ0911/SPFC/outSPF_optresult.dat",
    "RXJ0911/SPFC/outSPFR_optresult.dat",
    "RXJ0911/SPFC/outSPFG_optresult.dat",
    "RXJ0911/SPFC/outSPFGR_optresult.dat",
    "RXJ0911/PPC/outPP_optresult.dat",
    "RXJ0911/PPC/outPPR_optresult.dat",
    "RXJ0911/PPC/outPPG_optresult.dat",
    "RXJ0911/PPC/outPPGR_optresult.dat",
    "RXJ0911/PPFC/outPPF_optresult.dat",
    "RXJ0911/PPFC/outPPFR_optresult.dat",
    "RXJ0911/PPFC/outPPFG_optresult.dat",
    "RXJ0911/PPFC/outPPFGR_optresult.dat",
    "RXJ0911/NPC/outNP_optresult.dat",
    "RXJ0911/NPC/outNPR_optresult.dat",
    "RXJ0911/NPC/outNPG_optresult.dat",
    "RXJ0911/NPC/outNPGR_optresult.dat",
    "RXJ0911/NPFC/outNPF_optresult.dat",
    "RXJ0911/NPFC/outNPFR_optresult.dat",
    "RXJ0911/NPFC/outNPFG_optresult.dat",
    "RXJ0911/NPFC/outNPFGR_optresult.dat"
]

n = 0.0025  # Example scale factor
results_df, latex_rows = process_files(Input_file, Output_files, Fits_files, Optresult_files, n)

# Print formatted results
for i, output_file in enumerate(Output_files):
    constraint_type = "PF" if "PF" in Optresult_files[i] else "P"
    print(f"Model: {output_file}")
    print(f"Constraint Type: {constraint_type}")
    print(f"Number of data points used: {results_df.iloc[i]['n_data_points']}")
    print(f"Number of free parameters: {results_df.iloc[i]['n_free_params']}")
    print(f"Delta RMS of Image Positions: {results_df.iloc[i]['delta_rms']:.3f}")
    
    # Print individual position deltas (4 positions)
    print(f"Individual Position Deltas (mas):")
    for j, delta in enumerate(results_df.iloc[i]['individual_position_deltas']):
        print(f"  Image {j+1}: {delta:.3f}")
    
    print(f"Delta RMS of flux ratios at the observed position: {results_df.iloc[i]['predicted_flux_ratios_observed_rms']:.3f}")
    print(f"Delta RMS of flux ratios at the predicted position: {results_df.iloc[i]['predicted_flux_ratios_rms']:.3f}")
    
    # Print absolute flux ratio differences (3 ratios, excluding normalization)
    print(f"Absolute Flux Ratio Differences:")
    flux_diff_indices = [0, 2, 3] if len(results_df.iloc[i]['flux_ratio_differences']) == 3 else range(len(results_df.iloc[i]['flux_ratio_differences']))
    for j, diff in enumerate(results_df.iloc[i]['flux_ratio_differences']):
        img_idx = flux_diff_indices[j] + 1
        print(f"  Image {img_idx}: {diff:.3f}")
    
    print(f"Manual Chi²: {results_df.iloc[i]['manual_chi2']:.3f}")
    if results_df.iloc[i]['glafic_chi2'] is not None:
        print(f"Glafic Chi² (final, reference): {results_df.iloc[i]['glafic_chi2']:.3f}")
        print(f"Chi² Difference (Manual - Glafic): {results_df.iloc[i]['manual_chi2'] - results_df.iloc[i]['glafic_chi2']:.3f}")
    else:
        print(f"Glafic Chi² (reference): Not found")
    print(f"BIC (using manual Chi²): {results_df.iloc[i]['bic']:.3f}")
    
    # Manual verification of BIC calculation
    manual_bic_check = results_df.iloc[i]['manual_chi2'] + results_df.iloc[i]['n_free_params'] * np.log(results_df.iloc[i]['n_data_points'])
    print(f"Manual BIC verification: {results_df.iloc[i]['manual_chi2']:.3f} + {results_df.iloc[i]['n_free_params']} × ln({results_df.iloc[i]['n_data_points']}) = {manual_bic_check:.3f}")
    print()

# Print LaTeX-formatted rows
print("LaTeX Table Rows:")
print("Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC")
for row in latex_rows:
    print(row)
# Out:
# Model: RXJ0911/SPC/outSP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 5
# Delta RMS of Image Positions: 66.832
# Individual Position Deltas (mas):
#   Image 1: 13.606
#   Image 2: 88.701
#   Image 3: 36.686
#   Image 4: 92.018
# Delta RMS of flux ratios at the observed position: 0.629
# Delta RMS of flux ratios at the predicted position: 0.116
# Absolute Flux Ratio Differences:
#   Image 1: 0.015
#   Image 3: 0.165
#   Image 4: 0.115
# Manual Chi²: 740.020
# Glafic Chi² (final, reference): 809.035
# Chi² Difference (Manual - Glafic): -69.015
# BIC (using manual Chi²): 750.417
# Manual BIC verification: 740.020 + 5 × ln(8) = 750.417
#
# Model: RXJ0911/SPC/outSPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 2.299
# Individual Position Deltas (mas):
#   Image 1: 2.102
#   Image 2: 1.421
#   Image 3: 2.102
#   Image 4: 3.206
# Delta RMS of flux ratios at the observed position: 0.066
# Delta RMS of flux ratios at the predicted position: 0.065
# Absolute Flux Ratio Differences:
#   Image 1: 0.056
#   Image 3: 0.018
#   Image 4: 0.095
# Manual Chi²: 8.689
# Glafic Chi² (final, reference): 10.798
# Chi² Difference (Manual - Glafic): -2.109
# BIC (using manual Chi²): 29.483
# Manual BIC verification: 8.689 + 10 × ln(8) = 29.483
#
# Model: RXJ0911/SPC/outSPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 49.763
# Individual Position Deltas (mas):
#   Image 1: 28.821
#   Image 2: 77.396
#   Image 3: 3.625
#   Image 4: 55.422
# Delta RMS of flux ratios at the observed position: 0.265
# Delta RMS of flux ratios at the predicted position: 0.108
# Absolute Flux Ratio Differences:
#   Image 1: 0.019
#   Image 3: 0.152
#   Image 4: 0.106
# Manual Chi²: 417.895
# Glafic Chi² (final, reference): 447.253
# Chi² Difference (Manual - Glafic): -29.359
# BIC (using manual Chi²): 438.689
# Manual BIC verification: 417.895 + 10 × ln(8) = 438.689
#
# Model: RXJ0911/SPC/outSPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 15
# Delta RMS of Image Positions: 0.000
# Individual Position Deltas (mas):
#   Image 1: 0.000
#   Image 2: 0.000
#   Image 3: 0.000
#   Image 4: 0.000
# Delta RMS of flux ratios at the observed position: 0.049
# Delta RMS of flux ratios at the predicted position: 0.049
# Absolute Flux Ratio Differences:
#   Image 1: 0.031
#   Image 3: 0.049
#   Image 4: 0.063
# Manual Chi²: 4.529
# Glafic Chi² (final, reference): 0.000
# Chi² Difference (Manual - Glafic): 4.529
# BIC (using manual Chi²): 35.721
# Manual BIC verification: 4.529 + 15 × ln(8) = 35.721
#
# Model: RXJ0911/SPFC/outSPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 5
# Delta RMS of Image Positions: 66.802
# Individual Position Deltas (mas):
#   Image 1: 15.384
#   Image 2: 88.514
#   Image 3: 35.386
#   Image 4: 92.337
# Delta RMS of flux ratios at the observed position: 0.637
# Delta RMS of flux ratios at the predicted position: 0.116
# Absolute Flux Ratio Differences:
#   Image 1: 0.017
#   Image 3: 0.164
#   Image 4: 0.113
# Manual Chi²: 739.042
# Glafic Chi² (final, reference): 831.534
# Chi² Difference (Manual - Glafic): -92.492
# BIC (using manual Chi²): 751.032
# Manual BIC verification: 739.042 + 5 × ln(11) = 751.032
#
# Model: RXJ0911/SPFC/outSPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 2.371
# Individual Position Deltas (mas):
#   Image 1: 2.500
#   Image 2: 1.005
#   Image 3: 1.903
#   Image 4: 3.406
# Delta RMS of flux ratios at the observed position: 0.065
# Delta RMS of flux ratios at the predicted position: 0.064
# Absolute Flux Ratio Differences:
#   Image 1: 0.058
#   Image 3: 0.018
#   Image 4: 0.094
# Manual Chi²: 8.659
# Glafic Chi² (final, reference): 15.588
# Chi² Difference (Manual - Glafic): -6.930
# BIC (using manual Chi²): 32.638
# Manual BIC verification: 8.659 + 10 × ln(11) = 32.638
#
# Model: RXJ0911/SPFC/outSPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 50.371
# Individual Position Deltas (mas):
#   Image 1: 24.873
#   Image 2: 77.435
#   Image 3: 3.941
#   Image 4: 59.318
# Delta RMS of flux ratios at the observed position: 0.289
# Delta RMS of flux ratios at the predicted position: 0.108
# Absolute Flux Ratio Differences:
#   Image 1: 0.020
#   Image 3: 0.153
#   Image 4: 0.106
# Manual Chi²: 427.762
# Glafic Chi² (final, reference): 470.970
# Chi² Difference (Manual - Glafic): -43.208
# BIC (using manual Chi²): 451.741
# Manual BIC verification: 427.762 + 10 × ln(11) = 451.741
#
# Model: RXJ0911/SPFC/outSPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 15
# Delta RMS of Image Positions: 0.166
# Individual Position Deltas (mas):
#   Image 1: 0.141
#   Image 2: 0.000
#   Image 3: 0.224
#   Image 4: 0.200
# Delta RMS of flux ratios at the observed position: 0.043
# Delta RMS of flux ratios at the predicted position: 0.043
# Absolute Flux Ratio Differences:
#   Image 1: 0.055
#   Image 3: 0.017
#   Image 4: 0.048
# Manual Chi²: 3.552
# Glafic Chi² (final, reference): 1.980
# Chi² Difference (Manual - Glafic): 1.572
# BIC (using manual Chi²): 39.520
# Manual BIC verification: 3.552 + 15 × ln(11) = 39.520
#
# Model: RXJ0911/PPC/outPP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 73.169
# Individual Position Deltas (mas):
#   Image 1: 20.216
#   Image 2: 90.127
#   Image 3: 26.931
#   Image 4: 110.262
# Delta RMS of flux ratios at the observed position: 0.615
# Delta RMS of flux ratios at the predicted position: 0.124
# Absolute Flux Ratio Differences:
#   Image 1: 0.015
#   Image 3: 0.182
#   Image 4: 0.112
# Manual Chi²: 885.326
# Glafic Chi² (final, reference): 1140.274
# Chi² Difference (Manual - Glafic): -254.948
# BIC (using manual Chi²): 897.802
# Manual BIC verification: 885.326 + 6 × ln(8) = 897.802
#
# Model: RXJ0911/PPC/outPPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.221
# Individual Position Deltas (mas):
#   Image 1: 1.879
#   Image 2: 1.500
#   Image 3: 1.903
#   Image 4: 3.214
# Delta RMS of flux ratios at the observed position: 0.069
# Delta RMS of flux ratios at the predicted position: 0.068
# Absolute Flux Ratio Differences:
#   Image 1: 0.058
#   Image 3: 0.007
#   Image 4: 0.103
# Manual Chi²: 9.519
# Glafic Chi² (final, reference): 10.143
# Chi² Difference (Manual - Glafic): -0.624
# BIC (using manual Chi²): 32.393
# Manual BIC verification: 9.519 + 11 × ln(8) = 32.393
#
# Model: RXJ0911/PPC/outPPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 46.201
# Individual Position Deltas (mas):
#   Image 1: 14.730
#   Image 2: 66.001
#   Image 3: 9.688
#   Image 4: 62.219
# Delta RMS of flux ratios at the observed position: 0.251
# Delta RMS of flux ratios at the predicted position: 0.101
# Absolute Flux Ratio Differences:
#   Image 1: 0.022
#   Image 3: 0.134
#   Image 4: 0.110
# Manual Chi²: 360.559
# Glafic Chi² (final, reference): 350.445
# Chi² Difference (Manual - Glafic): 10.114
# BIC (using manual Chi²): 383.433
# Manual BIC verification: 360.559 + 11 × ln(8) = 383.433
#
# Model: RXJ0911/PPC/outPPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 16
# Delta RMS of Image Positions: 0.000
# Individual Position Deltas (mas):
#   Image 1: 0.000
#   Image 2: 0.000
#   Image 3: 0.000
#   Image 4: 0.000
# Delta RMS of flux ratios at the observed position: 0.055
# Delta RMS of flux ratios at the predicted position: 0.056
# Absolute Flux Ratio Differences:
#   Image 1: 0.025
#   Image 3: 0.078
#   Image 4: 0.051
# Manual Chi²: 5.776
# Glafic Chi² (final, reference): 0.000
# Chi² Difference (Manual - Glafic): 5.776
# BIC (using manual Chi²): 39.047
# Manual BIC verification: 5.776 + 16 × ln(8) = 39.047
#
# Model: RXJ0911/PPFC/outPPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 39.230
# Individual Position Deltas (mas):
#   Image 1: 26.323
#   Image 2: 41.705
#   Image 3: 16.399
#   Image 4: 58.777
# Delta RMS of flux ratios at the observed position: 0.231
# Delta RMS of flux ratios at the predicted position: 0.099
# Absolute Flux Ratio Differences:
#   Image 1: 0.019
#   Image 3: 0.111
#   Image 4: 0.129
# Manual Chi²: 264.544
# Glafic Chi² (final, reference): 299.691
# Chi² Difference (Manual - Glafic): -35.147
# BIC (using manual Chi²): 278.931
# Manual BIC verification: 264.544 + 6 × ln(11) = 278.931
#
# Model: RXJ0911/PPFC/outPPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.505
# Individual Position Deltas (mas):
#   Image 1: 2.751
#   Image 2: 1.315
#   Image 3: 2.000
#   Image 4: 3.437
# Delta RMS of flux ratios at the observed position: 0.065
# Delta RMS of flux ratios at the predicted position: 0.064
# Absolute Flux Ratio Differences:
#   Image 1: 0.050
#   Image 3: 0.062
#   Image 4: 0.077
# Manual Chi²: 8.634
# Glafic Chi² (final, reference): 16.677
# Chi² Difference (Manual - Glafic): -8.043
# BIC (using manual Chi²): 35.011
# Manual BIC verification: 8.634 + 11 × ln(11) = 35.011
#
# Model: RXJ0911/PPFC/outPPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 46.392
# Individual Position Deltas (mas):
#   Image 1: 16.161
#   Image 2: 63.132
#   Image 3: 9.534
#   Image 4: 65.354
# Delta RMS of flux ratios at the observed position: 0.226
# Delta RMS of flux ratios at the predicted position: 0.100
# Absolute Flux Ratio Differences:
#   Image 1: 0.023
#   Image 3: 0.133
#   Image 4: 0.108
# Manual Chi²: 363.151
# Glafic Chi² (final, reference): 370.262
# Chi² Difference (Manual - Glafic): -7.111
# BIC (using manual Chi²): 389.528
# Manual BIC verification: 363.151 + 11 × ln(11) = 389.528
#
# Model: RXJ0911/PPFC/outPPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 16
# Delta RMS of Image Positions: 0.642
# Individual Position Deltas (mas):
#   Image 1: 0.500
#   Image 2: 1.077
#   Image 3: 0.200
#   Image 4: 0.447
# Delta RMS of flux ratios at the observed position: 0.055
# Delta RMS of flux ratios at the predicted position: 0.054
# Absolute Flux Ratio Differences:
#   Image 1: 0.029
#   Image 3: 0.074
#   Image 4: 0.050
# Manual Chi²: 5.585
# Glafic Chi² (final, reference): 4.192
# Chi² Difference (Manual - Glafic): 1.393
# BIC (using manual Chi²): 43.951
# Manual BIC verification: 5.585 + 16 × ln(11) = 43.951
#
# Model: RXJ0911/NPC/outNP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 66.817
# Individual Position Deltas (mas):
#   Image 1: 15.539
#   Image 2: 86.800
#   Image 3: 22.318
#   Image 4: 97.900
# Delta RMS of flux ratios at the observed position: 0.522
# Delta RMS of flux ratios at the predicted position: 0.120
# Absolute Flux Ratio Differences:
#   Image 1: 0.009
#   Image 3: 0.177
#   Image 4: 0.110
# Manual Chi²: 741.362
# Glafic Chi² (final, reference): 756.931
# Chi² Difference (Manual - Glafic): -15.569
# BIC (using manual Chi²): 753.838
# Manual BIC verification: 741.362 + 6 × ln(8) = 753.838
#
# Model: RXJ0911/NPC/outNPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.552
# Individual Position Deltas (mas):
#   Image 1: 2.470
#   Image 2: 1.628
#   Image 3: 2.502
#   Image 4: 3.324
# Delta RMS of flux ratios at the observed position: 0.054
# Delta RMS of flux ratios at the predicted position: 0.053
# Absolute Flux Ratio Differences:
#   Image 1: 0.043
#   Image 3: 0.029
#   Image 4: 0.075
# Manual Chi²: 6.244
# Glafic Chi² (final, reference): 14.170
# Chi² Difference (Manual - Glafic): -7.926
# BIC (using manual Chi²): 29.118
# Manual BIC verification: 6.244 + 11 × ln(8) = 29.118
#
# Model: RXJ0911/NPC/outNPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 57.637
# Individual Position Deltas (mas):
#   Image 1: 25.041
#   Image 2: 88.218
#   Image 3: 7.300
#   Image 4: 69.466
# Delta RMS of flux ratios at the observed position: 0.378
# Delta RMS of flux ratios at the predicted position: 0.114
# Absolute Flux Ratio Differences:
#   Image 1: 0.016
#   Image 3: 0.169
#   Image 4: 0.102
# Manual Chi²: 556.099
# Glafic Chi² (final, reference): 568.735
# Chi² Difference (Manual - Glafic): -12.637
# BIC (using manual Chi²): 578.972
# Manual BIC verification: 556.099 + 11 × ln(8) = 578.972
#
# Model: RXJ0911/NPC/outNPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 16
# Delta RMS of Image Positions: 1.517
# Individual Position Deltas (mas):
#   Image 1: 2.147
#   Image 2: 0.224
#   Image 3: 0.806
#   Image 4: 1.972
# Delta RMS of flux ratios at the observed position: 0.070
# Delta RMS of flux ratios at the predicted position: 0.069
# Absolute Flux Ratio Differences:
#   Image 1: 0.015
#   Image 3: 0.116
#   Image 4: 0.027
# Manual Chi²: 9.290
# Glafic Chi² (final, reference): 2.683
# Chi² Difference (Manual - Glafic): 6.607
# BIC (using manual Chi²): 42.561
# Manual BIC verification: 9.290 + 16 × ln(8) = 42.561
#
# Model: RXJ0911/NPFC/outNPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 70.045
# Individual Position Deltas (mas):
#   Image 1: 16.767
#   Image 2: 91.153
#   Image 3: 23.759
#   Image 4: 102.326
# Delta RMS of flux ratios at the observed position: 0.576
# Delta RMS of flux ratios at the predicted position: 0.122
# Absolute Flux Ratio Differences:
#   Image 1: 0.014
#   Image 3: 0.181
#   Image 4: 0.108
# Manual Chi²: 812.880
# Glafic Chi² (final, reference): 882.619
# Chi² Difference (Manual - Glafic): -69.740
# BIC (using manual Chi²): 827.267
# Manual BIC verification: 812.880 + 6 × ln(11) = 827.267
#
# Model: RXJ0911/NPFC/outNPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.577
# Individual Position Deltas (mas):
#   Image 1: 2.600
#   Image 2: 1.166
#   Image 3: 2.309
#   Image 4: 3.622
# Delta RMS of flux ratios at the observed position: 0.058
# Delta RMS of flux ratios at the predicted position: 0.057
# Absolute Flux Ratio Differences:
#   Image 1: 0.051
#   Image 3: 0.000
#   Image 4: 0.084
# Manual Chi²: 7.077
# Glafic Chi² (final, reference): 17.540
# Chi² Difference (Manual - Glafic): -10.463
# BIC (using manual Chi²): 33.454
# Manual BIC verification: 7.077 + 11 × ln(11) = 33.454
#
# Model: RXJ0911/NPFC/outNPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 49.480
# Individual Position Deltas (mas):
#   Image 1: 24.412
#   Image 2: 77.748
#   Image 3: 5.099
#   Image 4: 55.916
# Delta RMS of flux ratios at the observed position: 0.291
# Delta RMS of flux ratios at the predicted position: 0.105
# Absolute Flux Ratio Differences:
#   Image 1: 0.016
#   Image 3: 0.158
#   Image 4: 0.090
# Manual Chi²: 412.466
# Glafic Chi² (final, reference): 491.978
# Chi² Difference (Manual - Glafic): -79.512
# BIC (using manual Chi²): 438.843
# Manual BIC verification: 412.466 + 11 × ln(11) = 438.843
#
# Model: RXJ0911/NPFC/outNPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 16
# Delta RMS of Image Positions: 1.573
# Individual Position Deltas (mas):
#   Image 1: 1.992
#   Image 2: 0.825
#   Image 3: 1.000
#   Image 4: 2.062
# Delta RMS of flux ratios at the observed position: 0.050
# Delta RMS of flux ratios at the predicted position: 0.052
# Absolute Flux Ratio Differences:
#   Image 1: 0.037
#   Image 3: 0.080
#   Image 4: 0.019
# Manual Chi²: 5.453
# Glafic Chi² (final, reference): 6.581
# Chi² Difference (Manual - Glafic): -1.128
# BIC (using manual Chi²): 43.819
# Manual BIC verification: 5.453 + 16 × ln(11) = 43.819
#
# LaTeX Table Rows:
# Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC
# SIE & QSO Pos & 13.606 & 88.701 & 36.686 & 92.018 & 66.8 & 0.015 & 0.165 & 0.115 & 0.12 & 750.4 \\
# SIE + Shear & QSO Pos & 2.102 & 1.421 & 2.102 & 3.206 & 2.3 & 0.056 & 0.018 & 0.095 & 0.06 & 29.5 \\
# SIE + G2 & QSO Pos & 28.821 & 77.396 & 3.625 & 55.422 & 49.8 & 0.019 & 0.152 & 0.106 & 0.11 & 438.7 \\
# SIE + Shear + G2 & QSO Pos & 0.000 & 0.000 & 0.000 & 0.000 & 0.0 & 0.031 & 0.049 & 0.063 & 0.05 & 35.7 \\
# SIE & QSO Pos + FR & 15.384 & 88.514 & 35.386 & 92.337 & 66.8 & 0.017 & 0.164 & 0.113 & 0.12 & 751.0 \\
# SIE + Shear & QSO Pos + FR & 2.500 & 1.005 & 1.903 & 3.406 & 2.4 & 0.058 & 0.018 & 0.094 & 0.06 & 32.6 \\
# SIE + G2 & QSO Pos + FR & 24.873 & 77.435 & 3.941 & 59.318 & 50.4 & 0.020 & 0.153 & 0.106 & 0.11 & 451.7 \\
# SIE + Shear + G2 & QSO Pos + FR & 0.141 & 0.000 & 0.224 & 0.200 & 0.2 & 0.055 & 0.017 & 0.048 & 0.04 & 39.5 \\
# POW & QSO Pos & 20.216 & 90.127 & 26.931 & 110.262 & 73.2 & 0.015 & 0.182 & 0.112 & 0.12 & 897.8 \\
# POW + Shear & QSO Pos & 1.879 & 1.500 & 1.903 & 3.214 & 2.2 & 0.058 & 0.007 & 0.103 & 0.07 & 32.4 \\
# POW + G2 & QSO Pos & 14.730 & 66.001 & 9.688 & 62.219 & 46.2 & 0.022 & 0.134 & 0.110 & 0.10 & 383.4 \\
# POW + Shear + G2 & QSO Pos & 0.000 & 0.000 & 0.000 & 0.000 & 0.0 & 0.025 & 0.078 & 0.051 & 0.06 & 39.0 \\
# POW & QSO Pos + FR & 26.323 & 41.705 & 16.399 & 58.777 & 39.2 & 0.019 & 0.111 & 0.129 & 0.10 & 278.9 \\
# POW + Shear & QSO Pos + FR & 2.751 & 1.315 & 2.000 & 3.437 & 2.5 & 0.050 & 0.062 & 0.077 & 0.06 & 35.0 \\
# POW + G2 & QSO Pos + FR & 16.161 & 63.132 & 9.534 & 65.354 & 46.4 & 0.023 & 0.133 & 0.108 & 0.10 & 389.5 \\
# POW + Shear + G2 & QSO Pos + FR & 0.500 & 1.077 & 0.200 & 0.447 & 0.6 & 0.029 & 0.074 & 0.050 & 0.05 & 44.0 \\
# NFW & QSO Pos & 15.539 & 86.800 & 22.318 & 97.900 & 66.8 & 0.009 & 0.177 & 0.110 & 0.12 & 753.8 \\
# NFW + Shear & QSO Pos & 2.470 & 1.628 & 2.502 & 3.324 & 2.6 & 0.043 & 0.029 & 0.075 & 0.05 & 29.1 \\
# NFW + G2 & QSO Pos & 25.041 & 88.218 & 7.300 & 69.466 & 57.6 & 0.016 & 0.169 & 0.102 & 0.11 & 579.0 \\
# NFW + Shear + G2 & QSO Pos & 2.147 & 0.224 & 0.806 & 1.972 & 1.5 & 0.015 & 0.116 & 0.027 & 0.07 & 42.6 \\
# NFW & QSO Pos + FR & 16.767 & 91.153 & 23.759 & 102.326 & 70.0 & 0.014 & 0.181 & 0.108 & 0.12 & 827.3 \\
# NFW + Shear & QSO Pos + FR & 2.600 & 1.166 & 2.309 & 3.622 & 2.6 & 0.051 & 0.000 & 0.084 & 0.06 & 33.5 \\
# NFW + G2 & QSO Pos + FR & 24.412 & 77.748 & 5.099 & 55.916 & 49.5 & 0.016 & 0.158 & 0.090 & 0.11 & 438.8 \\
# NFW + Shear + G2 & QSO Pos + FR & 1.992 & 0.825 & 1.000 & 2.062 & 1.6 & 0.037 & 0.080 & 0.019 & 0.05 & 43.8 \\

# %%
# NEW LATEX AUTOMATED CODE WITH MANUAL CHI^2 CALCULATION with individual position delta RMS and flux ratio differences
# PSJ1606 
import numpy as np
import pandas as pd
from astropy.io import fits
import os

# Function to calculate distance
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Function to read observed positions, flux ratios, and uncertainties
def read_observed_positions(input_file):
    observed_positions = []
    observed_flux_ratios = []
    position_uncertainties = []
    flux_uncertainties = []
    with open(input_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            columns = line.split()
            if len(columns) >= 5:
                x1 = float(columns[0])
                y1 = float(columns[1])
                flux_ratio = float(columns[2])
                pos_err = float(columns[3])
                flux_err = float(columns[4])
                observed_positions.append((x1, y1))
                observed_flux_ratios.append(flux_ratio)
                position_uncertainties.append(pos_err)
                flux_uncertainties.append(flux_err)
    return observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties

# Function to read predicted positions and magnifications
def read_predicted_positions(output_file):
    predicted_positions = []
    predicted_magnifications = []
    with open(output_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            if line.startswith("#"):
                continue
            columns = line.split()
            if len(columns) >= 3:
                x2 = float(columns[0])
                y2 = float(columns[1])
                M2 = abs(float(columns[2]))
                predicted_positions.append((x2, y2))
                predicted_magnifications.append(M2)
    return predicted_positions, predicted_magnifications

# Function to pair predicted and observed positions
def pair_positions(observed_positions, predicted_positions, predicted_magnifications):
    paired_positions = []
    for observed_position in observed_positions:
        min_distance = float('inf')
        closest_index = None
        for i, predicted_position in enumerate(predicted_positions):
            distance = calculate_distance(*observed_position, *predicted_position)
            if distance < min_distance:
                min_distance = distance
                closest_index = i
        paired_positions.append((observed_position, predicted_positions[closest_index], predicted_magnifications[closest_index]))
    return paired_positions

# Function to calculate manual chi² with proper uncertainties
def calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties, 
                         predicted_positions, predicted_magnifications, green_index=1):
    # Pair positions
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Calculate predicted flux ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]
    
    chi2 = 0.0
    
    # Position contributions to chi²
    for i, (observed, predicted, _) in enumerate(paired_positions):
        dx = observed[0] - predicted[0]
        dy = observed[1] - predicted[1]
        pos_err = position_uncertainties[i]
        chi2 += (dx/pos_err)**2 + (dy/pos_err)**2
    
    # Flux ratio contributions to chi² (excluding the normalization image)
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_err = flux_uncertainties[i]
            chi2 += ((pred_flux - obs_flux)/flux_err)**2
    
    return chi2

# Function to extract the final chi^2 from optresult.dat file
def extract_glafic_chi2(optresult_path):
    chi2_value = None
    with open(optresult_path, 'r') as file:
        lines = file.readlines()
    
    # Find the last occurrence of chi^2 (final/best result)
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
    
    return chi2_value

# Function to process file group
def process_file_group(output_file, fits_file, input_file, n):
    observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties = read_observed_positions(input_file)
    predicted_positions, predicted_magnifications = read_predicted_positions(output_file)
    
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Calculate Delta RMS of Image Positions correctly
    squared_distances = 0.0
    individual_distances = []  # Store individual distances for each image
    for observed, predicted, _ in paired_positions:
        distance = calculate_distance(*observed, *predicted)
        individual_distances.append(distance * 1000)  # Convert to mas
        squared_distances += distance ** 2  # Summing squared distances
    
    mean_squared_distances = squared_distances / len(paired_positions)
    delta_rms = np.sqrt(mean_squared_distances)  # Taking square root of the mean of squared distances
    delta_rms *= 1000  # Convert to mas
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Determine the index of the "Green Image"
    green_index = 0  # CHOOSE WHICH IMAGE TO NORMALISE BY HERE !!!!!!!!!!!!!!!!!!!!!!!

    # Predicted Flux Ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]

    # Calculate absolute differences between predicted and observed flux ratios (excluding normalization image)
    flux_ratio_differences = []
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_ratio_differences.append(abs(pred_flux - obs_flux))

    # Calculate manual chi²
    manual_chi2 = calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties,
                                       predicted_positions, predicted_magnifications, green_index)

    with fits.open(fits_file) as hdul:
        mag = hdul[0].data[6]
    
    pixel_coords = [(int((x + mag.shape[1] // 2 * n) / n), int((y + mag.shape[0] // 2 * n) / n)) for x, y in observed_positions]
    values = [mag[y, x] for x, y in pixel_coords]
    
    abs_values = [1 / abs(value) for value in values]
    predicted_flux_ratios_observed = [abs_values[i] / abs_values[green_index] for i in range(len(abs_values))]

    # Calculate RMS excluding the green image
    squared_diffs_pred = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_rms = np.sqrt(sum(squared_diffs_pred) / len(squared_diffs_pred))

    squared_diffs_obs = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios_observed, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_observed_rms = np.sqrt(sum(squared_diffs_obs) / len(squared_diffs_obs))

    return {
        'delta_rms': delta_rms,
        'individual_position_deltas': individual_distances,  # Delta RMS for each of the 4 positions
        'flux_ratio_differences': flux_ratio_differences,    # Absolute differences for 3 flux ratios
        'predicted_flux_ratios_rms': predicted_flux_ratios_rms,
        'predicted_flux_ratios_observed_rms': predicted_flux_ratios_observed_rms,
        'manual_chi2': manual_chi2
    }

# Function to extract chi^2 and lens models from optresult.dat file (following Code 1's approach exactly)
def extract_chi2_and_lens_profiles(optresult_path):
    chi2_value = None
    profiles_used = []
    sie_count = 0

    with open(optresult_path, 'r') as file:
        lines = file.readlines()

    found_chi2 = False
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
            found_chi2 = True
            profiles_used = []
            sie_count = 0
        elif found_chi2:
            if line.startswith("lens   sie"):
                profiles_used.append("SIE")
                sie_count += 1
            elif line.startswith("lens   pow"):
                profiles_used.append("POW")
            elif line.startswith("lens   anfw"):
                profiles_used.append("NFW")
            elif line.startswith("lens   pert"):
                profiles_used.append("Shear")

    if chi2_value is None:
        raise ValueError("No chi^2 value found in the file.")

    profiles_used = list(set(profiles_used))
    return chi2_value, profiles_used, sie_count

# Function to calculate free parameters based on lens profiles (identical to Code 1)
def calculate_free_parameters(profiles_used, sie_count):
    profile_params = {
        "SIE": 5,
        "POW": 6,
        "NFW": 6,
        "Shear": 5
    }
    total_params = sum(profile_params[profile] for profile in profiles_used)
    if sie_count == 2:
        total_params += 5
    return total_params

# Function to calculate BIC (Bayesian Information Criterion)
def calculate_bic(chi2, n_data_points, n_free_params):
    return chi2 + n_free_params * np.log(n_data_points)

# Function to compute BIC using manual chi² but following Code 1's approach for free parameters
def compute_bic_with_tracking(manual_chi2, optresult_path):
    # Use Code 1's approach: extract profiles from optresult.dat file
    glafic_chi2, profiles_used, sie_count = extract_chi2_and_lens_profiles(optresult_path)
    n_free_params = calculate_free_parameters(profiles_used, sie_count)
    
    # Properly adjust n_data_points based on constraint type
    if "PF" in optresult_path:
        n_data_points = 4 * 2 + 3  # positions + flux ratios
    else:
        n_data_points = 4 * 2  # positions only
    
    # Always use manual chi² for BIC calculation
    bic_value = calculate_bic(manual_chi2, n_data_points, n_free_params)
    
    return bic_value, glafic_chi2, n_data_points, n_free_params

# Main function to process multiple files
def process_files(input_file, output_files, fits_files, optresult_files, n):
    results = []
    latex_rows = []
    bics = []  # Store BIC values separately
    glafic_chi2_values = []  # Store glafic chi² for reference
    data_points_used = []  # Store number of data points used
    free_params_used = []  # Store number of free parameters used

    for output_file, fits_file, optresult_file in zip(output_files, fits_files, optresult_files):
        # Process output and fits files
        result = process_file_group(output_file, fits_file, input_file, n)
        results.append(result)
        
        # Calculate BIC using manual chi² but track both values
        bic, glafic_chi2, n_data_points, n_free_params = compute_bic_with_tracking(result['manual_chi2'], optresult_file)
        bics.append(bic)
        glafic_chi2_values.append(glafic_chi2)
        data_points_used.append(n_data_points)
        free_params_used.append(n_free_params)
        
        # Create LaTeX row with additional information
        model_name, constraint_name = determine_model_and_constraint(output_file)
        # Format individual position deltas and flux ratio differences for LaTeX
        pos_deltas_str = " & ".join([f"{delta:.3f}" for delta in result['individual_position_deltas']])
        flux_diffs_str = " & ".join([f"{diff:.3f}" for diff in result['flux_ratio_differences']])
        
        latex_row = f"{model_name} & {constraint_name} & {pos_deltas_str} & {result['delta_rms']:.1f} & {flux_diffs_str} & {result['predicted_flux_ratios_rms']:.2f} & {bic:.1f} \\\\"
        latex_rows.append(latex_row)
    
    # Combine results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results['bic'] = bics  # Add BIC values to the DataFrame
    df_results['glafic_chi2'] = glafic_chi2_values  # Add glafic chi² for reference
    df_results['n_data_points'] = data_points_used  # Add number of data points used
    df_results['n_free_params'] = free_params_used  # Add number of free parameters used
    
    return df_results, latex_rows

# Determine model and constraint names from the filename
def determine_model_and_constraint(file_name):
    model_map = {'S': 'SIE', 'P': 'POW', 'N': 'NFW'}
    
    base_name = os.path.basename(file_name)
    model_key = base_name[3]
    constraint_key = base_name[4:6] if base_name[4:6] in ['PF'] else base_name[4]
    
    model_name = model_map.get(model_key, '')
    if 'R' in base_name:
        model_name += ' + Shear'
    if 'G' in base_name:
        model_name += ' + G2'
    
    constraint_name = 'QSO Pos + FR' if constraint_key == 'PF' else 'QSO Pos'
    
    return model_name, constraint_name

# Example usage with filenames
Input_file = "PSJ1606/SPFC/Lobs_point.dat"

Output_files = [
    "PSJ1606/SPC/outSP_point.dat",
    "PSJ1606/SPC/outSPR_point.dat",
    "PSJ1606/SPC/outSPG_point.dat",
    "PSJ1606/SPC/outSPGR_point.dat",
    "PSJ1606/SPFC/outSPF_point.dat",
    "PSJ1606/SPFC/outSPFR_point.dat",
    "PSJ1606/SPFC/outSPFG_point.dat",
    "PSJ1606/SPFC/outSPFGR_point.dat",
    "PSJ1606/PPC/outPP_point.dat",
    "PSJ1606/PPC/outPPR_point.dat",
    "PSJ1606/PPC/outPPG_point.dat",
    "PSJ1606/PPC/outPPGR_point.dat",
    "PSJ1606/PPFC/outPPF_point.dat",
    "PSJ1606/PPFC/outPPFR_point.dat",
    "PSJ1606/PPFC/outPPFG_point.dat",
    "PSJ1606/PPFC/outPPFGR_point.dat",
    "PSJ1606/NPC/outNP_point.dat",
    "PSJ1606/NPC/outNPR_point.dat",
    "PSJ1606/NPC/outNPG_point.dat",
    "PSJ1606/NPC/outNPGR_point.dat",
    "PSJ1606/NPFC/outNPF_point.dat",
    "PSJ1606/NPFC/outNPFR_point.dat",
    "PSJ1606/NPFC/outNPFG_point.dat",
    "PSJ1606/NPFC/outNPFGR_point.dat"
]

Fits_files = [
    "PSJ1606/SPC/outSP_lens.fits",
    "PSJ1606/SPC/outSPR_lens.fits",
    "PSJ1606/SPC/outSPG_lens.fits",
    "PSJ1606/SPC/outSPGR_lens.fits",
    "PSJ1606/SPFC/outSPF_lens.fits",
    "PSJ1606/SPFC/outSPFR_lens.fits",
    "PSJ1606/SPFC/outSPFG_lens.fits",
    "PSJ1606/SPFC/outSPFGR_lens.fits",
    "PSJ1606/PPC/outPP_lens.fits",
    "PSJ1606/PPC/outPPR_lens.fits",
    "PSJ1606/PPC/outPPG_lens.fits",
    "PSJ1606/PPC/outPPGR_lens.fits",
    "PSJ1606/PPFC/outPPF_lens.fits",
    "PSJ1606/PPFC/outPPFR_lens.fits",
    "PSJ1606/PPFC/outPPFG_lens.fits",
    "PSJ1606/PPFC/outPPFGR_lens.fits",
    "PSJ1606/NPC/outNP_lens.fits",
    "PSJ1606/NPC/outNPR_lens.fits",
    "PSJ1606/NPC/outNPG_lens.fits",
    "PSJ1606/NPC/outNPGR_lens.fits",
    "PSJ1606/NPFC/outNPF_lens.fits",
    "PSJ1606/NPFC/outNPFR_lens.fits",
    "PSJ1606/NPFC/outNPFG_lens.fits",
    "PSJ1606/NPFC/outNPFGR_lens.fits"
]

Optresult_files = [
    "PSJ1606/SPC/outSP_optresult.dat",
    "PSJ1606/SPC/outSPR_optresult.dat",
    "PSJ1606/SPC/outSPG_optresult.dat",
    "PSJ1606/SPC/outSPGR_optresult.dat",
    "PSJ1606/SPFC/outSPF_optresult.dat",
    "PSJ1606/SPFC/outSPFR_optresult.dat",
    "PSJ1606/SPFC/outSPFG_optresult.dat",
    "PSJ1606/SPFC/outSPFGR_optresult.dat",
    "PSJ1606/PPC/outPP_optresult.dat",
    "PSJ1606/PPC/outPPR_optresult.dat",
    "PSJ1606/PPC/outPPG_optresult.dat",
    "PSJ1606/PPC/outPPGR_optresult.dat",
    "PSJ1606/PPFC/outPPF_optresult.dat",
    "PSJ1606/PPFC/outPPFR_optresult.dat",
    "PSJ1606/PPFC/outPPFG_optresult.dat",
    "PSJ1606/PPFC/outPPFGR_optresult.dat",
    "PSJ1606/NPC/outNP_optresult.dat",
    "PSJ1606/NPC/outNPR_optresult.dat",
    "PSJ1606/NPC/outNPG_optresult.dat",
    "PSJ1606/NPC/outNPGR_optresult.dat",
    "PSJ1606/NPFC/outNPF_optresult.dat",
    "PSJ1606/NPFC/outNPFR_optresult.dat",
    "PSJ1606/NPFC/outNPFG_optresult.dat",
    "PSJ1606/NPFC/outNPFGR_optresult.dat"
]

n = 0.0025  # Example scale factor
results_df, latex_rows = process_files(Input_file, Output_files, Fits_files, Optresult_files, n)

# Print formatted results
for i, output_file in enumerate(Output_files):
    constraint_type = "PF" if "PF" in Optresult_files[i] else "P"
    print(f"Model: {output_file}")
    print(f"Constraint Type: {constraint_type}")
    print(f"Number of data points used: {results_df.iloc[i]['n_data_points']}")
    print(f"Number of free parameters: {results_df.iloc[i]['n_free_params']}")
    print(f"Delta RMS of Image Positions: {results_df.iloc[i]['delta_rms']:.3f}")
    
    # Print individual position deltas (4 positions)
    print(f"Individual Position Deltas (mas):")
    for j, delta in enumerate(results_df.iloc[i]['individual_position_deltas']):
        print(f"  Image {j+1}: {delta:.3f}")
    
    print(f"Delta RMS of flux ratios at the observed position: {results_df.iloc[i]['predicted_flux_ratios_observed_rms']:.3f}")
    print(f"Delta RMS of flux ratios at the predicted position: {results_df.iloc[i]['predicted_flux_ratios_rms']:.3f}")
    
    # Print absolute flux ratio differences (3 ratios, excluding normalization)
    print(f"Absolute Flux Ratio Differences:")
    flux_diff_indices = [0, 2, 3] if len(results_df.iloc[i]['flux_ratio_differences']) == 3 else range(len(results_df.iloc[i]['flux_ratio_differences']))
    for j, diff in enumerate(results_df.iloc[i]['flux_ratio_differences']):
        img_idx = flux_diff_indices[j] + 1
        print(f"  Image {img_idx}: {diff:.3f}")
    
    print(f"Manual Chi²: {results_df.iloc[i]['manual_chi2']:.3f}")
    if results_df.iloc[i]['glafic_chi2'] is not None:
        print(f"Glafic Chi² (final, reference): {results_df.iloc[i]['glafic_chi2']:.3f}")
        print(f"Chi² Difference (Manual - Glafic): {results_df.iloc[i]['manual_chi2'] - results_df.iloc[i]['glafic_chi2']:.3f}")
    else:
        print(f"Glafic Chi² (reference): Not found")
    print(f"BIC (using manual Chi²): {results_df.iloc[i]['bic']:.3f}")
    
    # Manual verification of BIC calculation
    manual_bic_check = results_df.iloc[i]['manual_chi2'] + results_df.iloc[i]['n_free_params'] * np.log(results_df.iloc[i]['n_data_points'])
    print(f"Manual BIC verification: {results_df.iloc[i]['manual_chi2']:.3f} + {results_df.iloc[i]['n_free_params']} × ln({results_df.iloc[i]['n_data_points']}) = {manual_bic_check:.3f}")
    print()

# Print LaTeX-formatted rows
print("LaTeX Table Rows:")
print("Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC")
for row in latex_rows:
    print(row)
# Out:
# Model: PSJ1606/SPC/outSP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 5
# Delta RMS of Image Positions: 45.026
# Individual Position Deltas (mas):
#   Image 1: 35.173
#   Image 2: 43.822
#   Image 3: 45.259
#   Image 4: 53.883
# Delta RMS of flux ratios at the observed position: 0.253
# Delta RMS of flux ratios at the predicted position: 0.252
# Absolute Flux Ratio Differences:
#   Image 1: 0.362
#   Image 3: 0.096
#   Image 4: 0.223
# Manual Chi²: 617.523
# Glafic Chi² (final, reference): 341.234
# Chi² Difference (Manual - Glafic): 276.290
# BIC (using manual Chi²): 627.920
# Manual BIC verification: 617.523 + 5 × ln(8) = 627.920
#
# Model: PSJ1606/SPC/outSPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 2.910
# Individual Position Deltas (mas):
#   Image 1: 0.985
#   Image 2: 1.900
#   Image 3: 3.847
#   Image 4: 3.808
# Delta RMS of flux ratios at the observed position: 0.164
# Delta RMS of flux ratios at the predicted position: 0.165
# Absolute Flux Ratio Differences:
#   Image 1: 0.281
#   Image 3: 0.052
#   Image 4: 0.018
# Manual Chi²: 96.697
# Glafic Chi² (final, reference): 6.804
# Chi² Difference (Manual - Glafic): 89.892
# BIC (using manual Chi²): 117.491
# Manual BIC verification: 96.697 + 10 × ln(8) = 117.491
#
# Model: PSJ1606/SPC/outSPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 16.500
# Individual Position Deltas (mas):
#   Image 1: 17.734
#   Image 2: 4.386
#   Image 3: 11.011
#   Image 4: 25.179
# Delta RMS of flux ratios at the observed position: 0.325
# Delta RMS of flux ratios at the predicted position: 0.317
# Absolute Flux Ratio Differences:
#   Image 1: 0.090
#   Image 3: 0.482
#   Image 4: 0.246
# Manual Chi²: 783.859
# Glafic Chi² (final, reference): 110.984
# Chi² Difference (Manual - Glafic): 672.875
# BIC (using manual Chi²): 804.653
# Manual BIC verification: 783.859 + 10 × ln(8) = 804.653
#
# Model: PSJ1606/SPC/outSPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 15
# Delta RMS of Image Positions: 0.000
# Individual Position Deltas (mas):
#   Image 1: 0.000
#   Image 2: 0.000
#   Image 3: 0.000
#   Image 4: 0.000
# Delta RMS of flux ratios at the observed position: 0.204
# Delta RMS of flux ratios at the predicted position: 0.205
# Absolute Flux Ratio Differences:
#   Image 1: 0.067
#   Image 3: 0.192
#   Image 4: 0.290
# Manual Chi²: 307.702
# Glafic Chi² (final, reference): 0.000
# Chi² Difference (Manual - Glafic): 307.702
# BIC (using manual Chi²): 338.893
# Manual BIC verification: 307.702 + 15 × ln(8) = 338.893
#
# Model: PSJ1606/SPFC/outSPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 5
# Delta RMS of Image Positions: 45.395
# Individual Position Deltas (mas):
#   Image 1: 34.392
#   Image 2: 42.609
#   Image 3: 49.595
#   Image 4: 52.773
# Delta RMS of flux ratios at the observed position: 0.251
# Delta RMS of flux ratios at the predicted position: 0.248
# Absolute Flux Ratio Differences:
#   Image 1: 0.354
#   Image 3: 0.106
#   Image 4: 0.219
# Manual Chi²: 616.586
# Glafic Chi² (final, reference): 628.033
# Chi² Difference (Manual - Glafic): -11.447
# BIC (using manual Chi²): 628.576
# Manual BIC verification: 616.586 + 5 × ln(11) = 628.576
#
# Model: PSJ1606/SPFC/outSPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 5.847
# Individual Position Deltas (mas):
#   Image 1: 3.821
#   Image 2: 4.982
#   Image 3: 6.500
#   Image 4: 7.420
# Delta RMS of flux ratios at the observed position: 0.186
# Delta RMS of flux ratios at the predicted position: 0.172
# Absolute Flux Ratio Differences:
#   Image 1: 0.277
#   Image 3: 0.090
#   Image 4: 0.065
# Manual Chi²: 121.829
# Glafic Chi² (final, reference): 45.922
# Chi² Difference (Manual - Glafic): 75.907
# BIC (using manual Chi²): 145.808
# Manual BIC verification: 121.829 + 10 × ln(11) = 145.808
#
# Model: PSJ1606/SPFC/outSPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 17.522
# Individual Position Deltas (mas):
#   Image 1: 19.366
#   Image 2: 16.416
#   Image 3: 8.160
#   Image 4: 22.737
# Delta RMS of flux ratios at the observed position: 0.099
# Delta RMS of flux ratios at the predicted position: 0.107
# Absolute Flux Ratio Differences:
#   Image 1: 0.113
#   Image 3: 0.005
#   Image 4: 0.148
# Manual Chi²: 117.839
# Glafic Chi² (final, reference): 226.419
# Chi² Difference (Manual - Glafic): -108.580
# BIC (using manual Chi²): 141.818
# Manual BIC verification: 117.839 + 10 × ln(11) = 141.818
#
# Model: PSJ1606/SPFC/outSPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 15
# Delta RMS of Image Positions: 2.644
# Individual Position Deltas (mas):
#   Image 1: 2.802
#   Image 2: 3.000
#   Image 3: 2.360
#   Image 4: 2.354
# Delta RMS of flux ratios at the observed position: 0.036
# Delta RMS of flux ratios at the predicted position: 0.025
# Absolute Flux Ratio Differences:
#   Image 1: 0.042
#   Image 3: 0.002
#   Image 4: 0.008
# Manual Chi²: 3.281
# Glafic Chi² (final, reference): 11.096
# Chi² Difference (Manual - Glafic): -7.815
# BIC (using manual Chi²): 39.249
# Manual BIC verification: 3.281 + 15 × ln(11) = 39.249
#
# Model: PSJ1606/PPC/outPP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 19.005
# Individual Position Deltas (mas):
#   Image 1: 20.302
#   Image 2: 5.903
#   Image 3: 23.614
#   Image 4: 20.977
# Delta RMS of flux ratios at the observed position: 0.387
# Delta RMS of flux ratios at the predicted position: 0.376
# Absolute Flux Ratio Differences:
#   Image 1: 0.419
#   Image 3: 0.395
#   Image 4: 0.304
# Manual Chi²: 874.816
# Glafic Chi² (final, reference): 67.057
# Chi² Difference (Manual - Glafic): 807.759
# BIC (using manual Chi²): 887.293
# Manual BIC verification: 874.816 + 6 × ln(8) = 887.293
#
# Model: PSJ1606/PPC/outPPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.020
# Individual Position Deltas (mas):
#   Image 1: 1.166
#   Image 2: 1.530
#   Image 3: 2.500
#   Image 4: 2.524
# Delta RMS of flux ratios at the observed position: 0.365
# Delta RMS of flux ratios at the predicted position: 0.365
# Absolute Flux Ratio Differences:
#   Image 1: 0.430
#   Image 3: 0.336
#   Image 4: 0.320
# Manual Chi²: 744.305
# Glafic Chi² (final, reference): 3.261
# Chi² Difference (Manual - Glafic): 741.044
# BIC (using manual Chi²): 767.179
# Manual BIC verification: 744.305 + 11 × ln(8) = 767.179
#
# Model: PSJ1606/PPC/outPPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 10.579
# Individual Position Deltas (mas):
#   Image 1: 11.316
#   Image 2: 4.701
#   Image 3: 11.238
#   Image 4: 13.086
# Delta RMS of flux ratios at the observed position: 0.178
# Delta RMS of flux ratios at the predicted position: 0.167
# Absolute Flux Ratio Differences:
#   Image 1: 0.101
#   Image 3: 0.256
#   Image 4: 0.087
# Manual Chi²: 212.204
# Glafic Chi² (final, reference): 37.721
# Chi² Difference (Manual - Glafic): 174.483
# BIC (using manual Chi²): 235.078
# Manual BIC verification: 212.204 + 11 × ln(8) = 235.078
#
# Model: PSJ1606/PPC/outPPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 16
# Delta RMS of Image Positions: 0.000
# Individual Position Deltas (mas):
#   Image 1: 0.000
#   Image 2: 0.000
#   Image 3: 0.000
#   Image 4: 0.000
# Delta RMS of flux ratios at the observed position: 0.198
# Delta RMS of flux ratios at the predicted position: 0.197
# Absolute Flux Ratio Differences:
#   Image 1: 0.299
#   Image 3: 0.154
#   Image 4: 0.051
# Manual Chi²: 165.286
# Glafic Chi² (final, reference): 0.000
# Chi² Difference (Manual - Glafic): 165.286
# BIC (using manual Chi²): 198.557
# Manual BIC verification: 165.286 + 16 × ln(8) = 198.557
#
# Model: PSJ1606/PPFC/outPPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 20.584
# Individual Position Deltas (mas):
#   Image 1: 18.742
#   Image 2: 13.073
#   Image 3: 29.405
#   Image 4: 17.548
# Delta RMS of flux ratios at the observed position: 0.391
# Delta RMS of flux ratios at the predicted position: 0.355
# Absolute Flux Ratio Differences:
#   Image 1: 0.391
#   Image 3: 0.366
#   Image 4: 0.303
# Manual Chi²: 801.221
# Glafic Chi² (final, reference): 181.978
# Chi² Difference (Manual - Glafic): 619.243
# BIC (using manual Chi²): 815.608
# Manual BIC verification: 801.221 + 6 × ln(11) = 815.608
#
# Model: PSJ1606/PPFC/outPPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 5.523
# Individual Position Deltas (mas):
#   Image 1: 3.394
#   Image 2: 4.855
#   Image 3: 5.873
#   Image 4: 7.242
# Delta RMS of flux ratios at the observed position: 0.200
# Delta RMS of flux ratios at the predicted position: 0.185
# Absolute Flux Ratio Differences:
#   Image 1: 0.292
#   Image 3: 0.103
#   Image 4: 0.085
# Manual Chi²: 144.210
# Glafic Chi² (final, reference): 46.872
# Chi² Difference (Manual - Glafic): 97.338
# BIC (using manual Chi²): 170.587
# Manual BIC verification: 144.210 + 11 × ln(11) = 170.587
#
# Model: PSJ1606/PPFC/outPPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 11.114
# Individual Position Deltas (mas):
#   Image 1: 11.982
#   Image 2: 8.016
#   Image 3: 8.570
#   Image 4: 14.588
# Delta RMS of flux ratios at the observed position: 0.048
# Delta RMS of flux ratios at the predicted position: 0.058
# Absolute Flux Ratio Differences:
#   Image 1: 0.082
#   Image 3: 0.055
#   Image 4: 0.014
# Manual Chi²: 35.435
# Glafic Chi² (final, reference): 64.463
# Chi² Difference (Manual - Glafic): -29.027
# BIC (using manual Chi²): 61.812
# Manual BIC verification: 35.435 + 11 × ln(11) = 61.812
#
# Model: PSJ1606/PPFC/outPPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 16
# Delta RMS of Image Positions: 4.181
# Individual Position Deltas (mas):
#   Image 1: 4.220
#   Image 2: 5.536
#   Image 3: 4.011
#   Image 4: 2.319
# Delta RMS of flux ratios at the observed position: 0.174
# Delta RMS of flux ratios at the predicted position: 0.156
# Absolute Flux Ratio Differences:
#   Image 1: 0.201
#   Image 3: 0.145
#   Image 4: 0.104
# Manual Chi²: 127.992
# Glafic Chi² (final, reference): 40.722
# Chi² Difference (Manual - Glafic): 87.270
# BIC (using manual Chi²): 166.358
# Manual BIC verification: 127.992 + 16 × ln(11) = 166.358
#
# Model: PSJ1606/NPC/outNP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 19.417
# Individual Position Deltas (mas):
#   Image 1: 20.752
#   Image 2: 5.474
#   Image 3: 24.933
#   Image 4: 20.635
# Delta RMS of flux ratios at the observed position: 0.291
# Delta RMS of flux ratios at the predicted position: 0.283
# Absolute Flux Ratio Differences:
#   Image 1: 0.397
#   Image 3: 0.252
#   Image 4: 0.135
# Manual Chi²: 440.127
# Glafic Chi² (final, reference): 70.093
# Chi² Difference (Manual - Glafic): 370.033
# BIC (using manual Chi²): 452.603
# Manual BIC verification: 440.127 + 6 × ln(8) = 452.603
#
# Model: PSJ1606/NPC/outNPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.890
# Individual Position Deltas (mas):
#   Image 1: 1.077
#   Image 2: 1.903
#   Image 3: 3.759
#   Image 4: 3.808
# Delta RMS of flux ratios at the observed position: 0.181
# Delta RMS of flux ratios at the predicted position: 0.181
# Absolute Flux Ratio Differences:
#   Image 1: 0.295
#   Image 3: 0.091
#   Image 4: 0.057
# Manual Chi²: 126.680
# Glafic Chi² (final, reference): 6.274
# Chi² Difference (Manual - Glafic): 120.406
# BIC (using manual Chi²): 149.554
# Manual BIC verification: 126.680 + 11 × ln(8) = 149.554
#
# Model: PSJ1606/NPC/outNPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 12.108
# Individual Position Deltas (mas):
#   Image 1: 13.609
#   Image 2: 3.774
#   Image 3: 10.787
#   Image 4: 16.451
# Delta RMS of flux ratios at the observed position: 0.356
# Delta RMS of flux ratios at the predicted position: 0.347
# Absolute Flux Ratio Differences:
#   Image 1: 0.045
#   Image 3: 0.587
#   Image 4: 0.122
# Manual Chi²: 925.090
# Glafic Chi² (final, reference): 51.674
# Chi² Difference (Manual - Glafic): 873.417
# BIC (using manual Chi²): 947.964
# Manual BIC verification: 925.090 + 11 × ln(8) = 947.964
#
# Model: PSJ1606/NPC/outNPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 16
# Delta RMS of Image Positions: 0.000
# Individual Position Deltas (mas):
#   Image 1: 0.000
#   Image 2: 0.000
#   Image 3: 0.000
#   Image 4: 0.000
# Delta RMS of flux ratios at the observed position: 0.110
# Delta RMS of flux ratios at the predicted position: 0.109
# Absolute Flux Ratio Differences:
#   Image 1: 0.173
#   Image 3: 0.074
#   Image 4: 0.017
# Manual Chi²: 47.530
# Glafic Chi² (final, reference): 0.000
# Chi² Difference (Manual - Glafic): 47.530
# BIC (using manual Chi²): 80.801
# Manual BIC verification: 47.530 + 16 × ln(8) = 80.801
#
# Model: PSJ1606/NPFC/outNPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 20.533
# Individual Position Deltas (mas):
#   Image 1: 18.928
#   Image 2: 10.017
#   Image 3: 30.176
#   Image 4: 17.810
# Delta RMS of flux ratios at the observed position: 0.236
# Delta RMS of flux ratios at the predicted position: 0.215
# Absolute Flux Ratio Differences:
#   Image 1: 0.350
#   Image 3: 0.127
#   Image 4: 0.020
# Manual Chi²: 244.559
# Glafic Chi² (final, reference): 149.038
# Chi² Difference (Manual - Glafic): 95.521
# BIC (using manual Chi²): 258.947
# Manual BIC verification: 244.559 + 6 × ln(11) = 258.947
#
# Model: PSJ1606/NPFC/outNPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 5.039
# Individual Position Deltas (mas):
#   Image 1: 2.759
#   Image 2: 4.579
#   Image 3: 5.270
#   Image 4: 6.723
# Delta RMS of flux ratios at the observed position: 0.210
# Delta RMS of flux ratios at the predicted position: 0.198
# Absolute Flux Ratio Differences:
#   Image 1: 0.306
#   Image 3: 0.119
#   Image 4: 0.100
# Manual Chi²: 168.327
# Glafic Chi² (final, reference): 48.494
# Chi² Difference (Manual - Glafic): 119.833
# BIC (using manual Chi²): 194.704
# Manual BIC verification: 168.327 + 11 × ln(11) = 194.704
#
# Model: PSJ1606/NPFC/outNPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 23.281
# Individual Position Deltas (mas):
#   Image 1: 22.091
#   Image 2: 13.396
#   Image 3: 32.201
#   Image 4: 21.534
# Delta RMS of flux ratios at the observed position: 0.248
# Delta RMS of flux ratios at the predicted position: 0.219
# Absolute Flux Ratio Differences:
#   Image 1: 0.307
#   Image 3: 0.216
#   Image 4: 0.058
# Manual Chi²: 316.680
# Glafic Chi² (final, reference): 162.648
# Chi² Difference (Manual - Glafic): 154.032
# BIC (using manual Chi²): 343.057
# Manual BIC verification: 316.680 + 11 × ln(11) = 343.057
#
# Model: PSJ1606/NPFC/outNPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 16
# Delta RMS of Image Positions: 1.370
# Individual Position Deltas (mas):
#   Image 1: 1.005
#   Image 2: 1.265
#   Image 3: 2.209
#   Image 4: 0.141
# Delta RMS of flux ratios at the observed position: 0.019
# Delta RMS of flux ratios at the predicted position: 0.014
# Absolute Flux Ratio Differences:
#   Image 1: 0.016
#   Image 3: 0.019
#   Image 4: 0.000
# Manual Chi²: 1.488
# Glafic Chi² (final, reference): 3.071
# Chi² Difference (Manual - Glafic): -1.583
# BIC (using manual Chi²): 39.854
# Manual BIC verification: 1.488 + 16 × ln(11) = 39.854
#
# LaTeX Table Rows:
# Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC
# SIE & QSO Pos & 35.173 & 43.822 & 45.259 & 53.883 & 45.0 & 0.362 & 0.096 & 0.223 & 0.25 & 627.9 \\
# SIE + Shear & QSO Pos & 0.985 & 1.900 & 3.847 & 3.808 & 2.9 & 0.281 & 0.052 & 0.018 & 0.17 & 117.5 \\
# SIE + G2 & QSO Pos & 17.734 & 4.386 & 11.011 & 25.179 & 16.5 & 0.090 & 0.482 & 0.246 & 0.32 & 804.7 \\
# SIE + Shear + G2 & QSO Pos & 0.000 & 0.000 & 0.000 & 0.000 & 0.0 & 0.067 & 0.192 & 0.290 & 0.20 & 338.9 \\
# SIE & QSO Pos + FR & 34.392 & 42.609 & 49.595 & 52.773 & 45.4 & 0.354 & 0.106 & 0.219 & 0.25 & 628.6 \\
# SIE + Shear & QSO Pos + FR & 3.821 & 4.982 & 6.500 & 7.420 & 5.8 & 0.277 & 0.090 & 0.065 & 0.17 & 145.8 \\
# SIE + G2 & QSO Pos + FR & 19.366 & 16.416 & 8.160 & 22.737 & 17.5 & 0.113 & 0.005 & 0.148 & 0.11 & 141.8 \\
# SIE + Shear + G2 & QSO Pos + FR & 2.802 & 3.000 & 2.360 & 2.354 & 2.6 & 0.042 & 0.002 & 0.008 & 0.02 & 39.2 \\
# POW & QSO Pos & 20.302 & 5.903 & 23.614 & 20.977 & 19.0 & 0.419 & 0.395 & 0.304 & 0.38 & 887.3 \\
# POW + Shear & QSO Pos & 1.166 & 1.530 & 2.500 & 2.524 & 2.0 & 0.430 & 0.336 & 0.320 & 0.37 & 767.2 \\
# POW + G2 & QSO Pos & 11.316 & 4.701 & 11.238 & 13.086 & 10.6 & 0.101 & 0.256 & 0.087 & 0.17 & 235.1 \\
# POW + Shear + G2 & QSO Pos & 0.000 & 0.000 & 0.000 & 0.000 & 0.0 & 0.299 & 0.154 & 0.051 & 0.20 & 198.6 \\
# POW & QSO Pos + FR & 18.742 & 13.073 & 29.405 & 17.548 & 20.6 & 0.391 & 0.366 & 0.303 & 0.36 & 815.6 \\
# POW + Shear & QSO Pos + FR & 3.394 & 4.855 & 5.873 & 7.242 & 5.5 & 0.292 & 0.103 & 0.085 & 0.19 & 170.6 \\
# POW + G2 & QSO Pos + FR & 11.982 & 8.016 & 8.570 & 14.588 & 11.1 & 0.082 & 0.055 & 0.014 & 0.06 & 61.8 \\
# POW + Shear + G2 & QSO Pos + FR & 4.220 & 5.536 & 4.011 & 2.319 & 4.2 & 0.201 & 0.145 & 0.104 & 0.16 & 166.4 \\
# NFW & QSO Pos & 20.752 & 5.474 & 24.933 & 20.635 & 19.4 & 0.397 & 0.252 & 0.135 & 0.28 & 452.6 \\
# NFW + Shear & QSO Pos & 1.077 & 1.903 & 3.759 & 3.808 & 2.9 & 0.295 & 0.091 & 0.057 & 0.18 & 149.6 \\
# NFW + G2 & QSO Pos & 13.609 & 3.774 & 10.787 & 16.451 & 12.1 & 0.045 & 0.587 & 0.122 & 0.35 & 948.0 \\
# NFW + Shear + G2 & QSO Pos & 0.000 & 0.000 & 0.000 & 0.000 & 0.0 & 0.173 & 0.074 & 0.017 & 0.11 & 80.8 \\
# NFW & QSO Pos + FR & 18.928 & 10.017 & 30.176 & 17.810 & 20.5 & 0.350 & 0.127 & 0.020 & 0.22 & 258.9 \\
# NFW + Shear & QSO Pos + FR & 2.759 & 4.579 & 5.270 & 6.723 & 5.0 & 0.306 & 0.119 & 0.100 & 0.20 & 194.7 \\
# NFW + G2 & QSO Pos + FR & 22.091 & 13.396 & 32.201 & 21.534 & 23.3 & 0.307 & 0.216 & 0.058 & 0.22 & 343.1 \\
# NFW + Shear + G2 & QSO Pos + FR & 1.005 & 1.265 & 2.209 & 0.141 & 1.4 & 0.016 & 0.019 & 0.000 & 0.01 & 39.9 \\

# %%
# NEW LATEX AUTOMATED CODE WITH MANUAL CHI^2 CALCULATION with individual position delta RMS and flux ratio differences
# WFI2033
import numpy as np
import pandas as pd
from astropy.io import fits
import os

# Function to calculate distance
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Function to read observed positions, flux ratios, and uncertainties
def read_observed_positions(input_file):
    observed_positions = []
    observed_flux_ratios = []
    position_uncertainties = []
    flux_uncertainties = []
    with open(input_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            columns = line.split()
            if len(columns) >= 5:
                x1 = float(columns[0])
                y1 = float(columns[1])
                flux_ratio = float(columns[2])
                pos_err = float(columns[3])
                flux_err = float(columns[4])
                observed_positions.append((x1, y1))
                observed_flux_ratios.append(flux_ratio)
                position_uncertainties.append(pos_err)
                flux_uncertainties.append(flux_err)
    return observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties

# Function to read predicted positions and magnifications
def read_predicted_positions(output_file):
    predicted_positions = []
    predicted_magnifications = []
    with open(output_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            if line.startswith("#"):
                continue
            columns = line.split()
            if len(columns) >= 3:
                x2 = float(columns[0])
                y2 = float(columns[1])
                M2 = abs(float(columns[2]))
                predicted_positions.append((x2, y2))
                predicted_magnifications.append(M2)
    return predicted_positions, predicted_magnifications

# Function to pair predicted and observed positions
def pair_positions(observed_positions, predicted_positions, predicted_magnifications):
    paired_positions = []
    for observed_position in observed_positions:
        min_distance = float('inf')
        closest_index = None
        for i, predicted_position in enumerate(predicted_positions):
            distance = calculate_distance(*observed_position, *predicted_position)
            if distance < min_distance:
                min_distance = distance
                closest_index = i
        paired_positions.append((observed_position, predicted_positions[closest_index], predicted_magnifications[closest_index]))
    return paired_positions

# Function to calculate manual chi² with proper uncertainties
def calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties, 
                         predicted_positions, predicted_magnifications, green_index=1):
    # Pair positions
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Calculate predicted flux ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]
    
    chi2 = 0.0
    
    # Position contributions to chi²
    for i, (observed, predicted, _) in enumerate(paired_positions):
        dx = observed[0] - predicted[0]
        dy = observed[1] - predicted[1]
        pos_err = position_uncertainties[i]
        chi2 += (dx/pos_err)**2 + (dy/pos_err)**2
    
    # Flux ratio contributions to chi² (excluding the normalization image)
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_err = flux_uncertainties[i]
            chi2 += ((pred_flux - obs_flux)/flux_err)**2
    
    return chi2

# Function to extract the final chi^2 from optresult.dat file
def extract_glafic_chi2(optresult_path):
    chi2_value = None
    with open(optresult_path, 'r') as file:
        lines = file.readlines()
    
    # Find the last occurrence of chi^2 (final/best result)
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
    
    return chi2_value

# Function to process file group
def process_file_group(output_file, fits_file, input_file, n):
    observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties = read_observed_positions(input_file)
    predicted_positions, predicted_magnifications = read_predicted_positions(output_file)
    
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Calculate Delta RMS of Image Positions correctly
    squared_distances = 0.0
    individual_distances = []  # Store individual distances for each image
    for observed, predicted, _ in paired_positions:
        distance = calculate_distance(*observed, *predicted)
        individual_distances.append(distance * 1000)  # Convert to mas
        squared_distances += distance ** 2  # Summing squared distances
    
    mean_squared_distances = squared_distances / len(paired_positions)
    delta_rms = np.sqrt(mean_squared_distances)  # Taking square root of the mean of squared distances
    delta_rms *= 1000  # Convert to mas
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Determine the index of the "Green Image"
    green_index = 0  # CHOOSE WHICH IMAGE TO NORMALISE BY HERE !!!!!!!!!!!!!!!!!!!!!!!

    # Predicted Flux Ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]

    # Calculate absolute differences between predicted and observed flux ratios (excluding normalization image)
    flux_ratio_differences = []
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_ratio_differences.append(abs(pred_flux - obs_flux))

    # Calculate manual chi²
    manual_chi2 = calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties,
                                       predicted_positions, predicted_magnifications, green_index)

    with fits.open(fits_file) as hdul:
        mag = hdul[0].data[6]
    
    pixel_coords = [(int((x + mag.shape[1] // 2 * n) / n), int((y + mag.shape[0] // 2 * n) / n)) for x, y in observed_positions]
    values = [mag[y, x] for x, y in pixel_coords]
    
    abs_values = [1 / abs(value) for value in values]
    predicted_flux_ratios_observed = [abs_values[i] / abs_values[green_index] for i in range(len(abs_values))]

    # Calculate RMS excluding the green image
    squared_diffs_pred = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_rms = np.sqrt(sum(squared_diffs_pred) / len(squared_diffs_pred))

    squared_diffs_obs = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios_observed, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_observed_rms = np.sqrt(sum(squared_diffs_obs) / len(squared_diffs_obs))

    return {
        'delta_rms': delta_rms,
        'individual_position_deltas': individual_distances,  # Delta RMS for each of the 4 positions
        'flux_ratio_differences': flux_ratio_differences,    # Absolute differences for 3 flux ratios
        'predicted_flux_ratios_rms': predicted_flux_ratios_rms,
        'predicted_flux_ratios_observed_rms': predicted_flux_ratios_observed_rms,
        'manual_chi2': manual_chi2
    }

# Function to extract chi^2 and lens models from optresult.dat file (following Code 1's approach exactly)
def extract_chi2_and_lens_profiles(optresult_path):
    chi2_value = None
    profiles_used = []
    sie_count = 0

    with open(optresult_path, 'r') as file:
        lines = file.readlines()

    found_chi2 = False
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
            found_chi2 = True
            profiles_used = []
            sie_count = 0
        elif found_chi2:
            if line.startswith("lens   sie"):
                profiles_used.append("SIE")
                sie_count += 1
            elif line.startswith("lens   pow"):
                profiles_used.append("POW")
            elif line.startswith("lens   anfw"):
                profiles_used.append("NFW")
            elif line.startswith("lens   pert"):
                profiles_used.append("Shear")

    if chi2_value is None:
        raise ValueError("No chi^2 value found in the file.")

    profiles_used = list(set(profiles_used))
    return chi2_value, profiles_used, sie_count

# Function to calculate free parameters based on lens profiles (identical to Code 1)
def calculate_free_parameters(profiles_used, sie_count):
    profile_params = {
        "SIE": 5,
        "POW": 6,
        "NFW": 6,
        "Shear": 5
    }
    total_params = sum(profile_params[profile] for profile in profiles_used)
    if sie_count == 2:
        total_params += 5
    return total_params

# Function to calculate BIC (Bayesian Information Criterion)
def calculate_bic(chi2, n_data_points, n_free_params):
    return chi2 + n_free_params * np.log(n_data_points)

# Function to compute BIC using manual chi² but following Code 1's approach for free parameters
def compute_bic_with_tracking(manual_chi2, optresult_path):
    # Use Code 1's approach: extract profiles from optresult.dat file
    glafic_chi2, profiles_used, sie_count = extract_chi2_and_lens_profiles(optresult_path)
    n_free_params = calculate_free_parameters(profiles_used, sie_count)
    
    # Properly adjust n_data_points based on constraint type
    if "PF" in optresult_path:
        n_data_points = 4 * 2 + 3  # positions + flux ratios
    else:
        n_data_points = 4 * 2  # positions only
    
    # Always use manual chi² for BIC calculation
    bic_value = calculate_bic(manual_chi2, n_data_points, n_free_params)
    
    return bic_value, glafic_chi2, n_data_points, n_free_params

# Main function to process multiple files
def process_files(input_file, output_files, fits_files, optresult_files, n):
    results = []
    latex_rows = []
    bics = []  # Store BIC values separately
    glafic_chi2_values = []  # Store glafic chi² for reference
    data_points_used = []  # Store number of data points used
    free_params_used = []  # Store number of free parameters used

    for output_file, fits_file, optresult_file in zip(output_files, fits_files, optresult_files):
        # Process output and fits files
        result = process_file_group(output_file, fits_file, input_file, n)
        results.append(result)
        
        # Calculate BIC using manual chi² but track both values
        bic, glafic_chi2, n_data_points, n_free_params = compute_bic_with_tracking(result['manual_chi2'], optresult_file)
        bics.append(bic)
        glafic_chi2_values.append(glafic_chi2)
        data_points_used.append(n_data_points)
        free_params_used.append(n_free_params)
        
        # Create LaTeX row with additional information
        model_name, constraint_name = determine_model_and_constraint(output_file)
        # Format individual position deltas and flux ratio differences for LaTeX
        pos_deltas_str = " & ".join([f"{delta:.3f}" for delta in result['individual_position_deltas']])
        flux_diffs_str = " & ".join([f"{diff:.3f}" for diff in result['flux_ratio_differences']])
        
        latex_row = f"{model_name} & {constraint_name} & {pos_deltas_str} & {result['delta_rms']:.1f} & {flux_diffs_str} & {result['predicted_flux_ratios_rms']:.2f} & {bic:.1f} \\\\"
        latex_rows.append(latex_row)
    
    # Combine results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results['bic'] = bics  # Add BIC values to the DataFrame
    df_results['glafic_chi2'] = glafic_chi2_values  # Add glafic chi² for reference
    df_results['n_data_points'] = data_points_used  # Add number of data points used
    df_results['n_free_params'] = free_params_used  # Add number of free parameters used
    
    return df_results, latex_rows

# Determine model and constraint names from the filename
def determine_model_and_constraint(file_name):
    model_map = {'S': 'SIE', 'P': 'POW', 'N': 'NFW'}
    
    base_name = os.path.basename(file_name)
    model_key = base_name[3]
    constraint_key = base_name[4:6] if base_name[4:6] in ['PF'] else base_name[4]
    
    model_name = model_map.get(model_key, '')
    if 'R' in base_name:
        model_name += ' + Shear'
    if 'G' in base_name:
        model_name += ' + G2'
    
    constraint_name = 'QSO Pos + FR' if constraint_key == 'PF' else 'QSO Pos'
    
    return model_name, constraint_name

# Example usage with filenames
Input_file = "WFI2033/obs_point.dat"

Output_files = [
    "WFI2033/SP/outSP_point.dat",
    "WFI2033/SPR/outSPR_point.dat",
    "WFI2033/SPG/outSPG_point.dat",
    "WFI2033/SPGR/outSPGR_point.dat",
    "WFI2033/SPF/outSPF_point.dat",
    "WFI2033/SPFR/outSPFR_point.dat",
    "WFI2033/SPFG/outSPFG_point.dat",
    "WFI2033/SPFGR/outSPFGR_point.dat",
    "WFI2033/PP/outPP_point.dat",
    "WFI2033/PPR/outPPR_point.dat",
    "WFI2033/PPG/outPPG_point.dat",
    "WFI2033/PPGR/outPPGR_point.dat",
    "WFI2033/PPF/outPPF_point.dat",
    "WFI2033/PPFR/outPPFR_point.dat",
    "WFI2033/PPFG/outPPFG_point.dat",
    "WFI2033/PPFGR/outPPFGR_point.dat",
    "WFI2033/NP/outNP_point.dat",
    "WFI2033/NPR/outNPR_point.dat",
    "WFI2033/NPG/outNPG_point.dat",
    "WFI2033/NPGR/outNPGR_point.dat",
    "WFI2033/NPF/outNPF_point.dat",
    "WFI2033/NPFR/outNPFR_point.dat",
    "WFI2033/NPFG/outNPFG_point.dat",
    "WFI2033/NPFGR/outNPFGR_point.dat"
]

Fits_files = [
    "WFI2033/SP/outSP_lens.fits",
    "WFI2033/SPR/outSPR_lens.fits",
    "WFI2033/SPG/outSPG_lens.fits",
    "WFI2033/SPGR/outSPGR_lens.fits",
    "WFI2033/SPF/outSPF_lens.fits",
    "WFI2033/SPFR/outSPFR_lens.fits",
    "WFI2033/SPFG/outSPFG_lens.fits",
    "WFI2033/SPFGR/outSPFGR_lens.fits",
    "WFI2033/PP/outPP_lens.fits",
    "WFI2033/PPR/outPPR_lens.fits",
    "WFI2033/PPG/outPPG_lens.fits",
    "WFI2033/PPGR/outPPGR_lens.fits",
    "WFI2033/PPF/outPPF_lens.fits",
    "WFI2033/PPFR/outPPFR_lens.fits",
    "WFI2033/PPFG/outPPFG_lens.fits",
    "WFI2033/PPFGR/outPPFGR_lens.fits",
    "WFI2033/NP/outNP_lens.fits",
    "WFI2033/NPR/outNPR_lens.fits",
    "WFI2033/NPG/outNPG_lens.fits",
    "WFI2033/NPGR/outNPGR_lens.fits",
    "WFI2033/NPF/outNPF_lens.fits",
    "WFI2033/NPFR/outNPFR_lens.fits",
    "WFI2033/NPFG/outNPFG_lens.fits",
    "WFI2033/NPFGR/outNPFGR_lens.fits"
]

Optresult_files = [
    "WFI2033/SP/outSP_optresult.dat",
    "WFI2033/SPR/outSPR_optresult.dat",
    "WFI2033/SPG/outSPG_optresult.dat",
    "WFI2033/SPGR/outSPGR_optresult.dat",
    "WFI2033/SPF/outSPF_optresult.dat",
    "WFI2033/SPFR/outSPFR_optresult.dat",
    "WFI2033/SPFG/outSPFG_optresult.dat",
    "WFI2033/SPFGR/outSPFGR_optresult.dat",
    "WFI2033/PP/outPP_optresult.dat",
    "WFI2033/PPR/outPPR_optresult.dat",
    "WFI2033/PPG/outPPG_optresult.dat",
    "WFI2033/PPGR/outPPGR_optresult.dat",
    "WFI2033/PPF/outPPF_optresult.dat",
    "WFI2033/PPFR/outPPFR_optresult.dat",
    "WFI2033/PPFG/outPPFG_optresult.dat",
    "WFI2033/PPFGR/outPPFGR_optresult.dat",
    "WFI2033/NP/outNP_optresult.dat",
    "WFI2033/NPR/outNPR_optresult.dat",
    "WFI2033/NPG/outNPG_optresult.dat",
    "WFI2033/NPGR/outNPGR_optresult.dat",
    "WFI2033/NPF/outNPF_optresult.dat",
    "WFI2033/NPFR/outNPFR_optresult.dat",
    "WFI2033/NPFG/outNPFG_optresult.dat",
    "WFI2033/NPFGR/outNPFGR_optresult.dat"
]

n = 0.0025  # Example scale factor
results_df, latex_rows = process_files(Input_file, Output_files, Fits_files, Optresult_files, n)

# Print formatted results
for i, output_file in enumerate(Output_files):
    constraint_type = "PF" if "PF" in Optresult_files[i] else "P"
    print(f"Model: {output_file}")
    print(f"Constraint Type: {constraint_type}")
    print(f"Number of data points used: {results_df.iloc[i]['n_data_points']}")
    print(f"Number of free parameters: {results_df.iloc[i]['n_free_params']}")
    print(f"Delta RMS of Image Positions: {results_df.iloc[i]['delta_rms']:.3f}")
    
    # Print individual position deltas (4 positions)
    print(f"Individual Position Deltas (mas):")
    for j, delta in enumerate(results_df.iloc[i]['individual_position_deltas']):
        print(f"  Image {j+1}: {delta:.3f}")
    
    print(f"Delta RMS of flux ratios at the observed position: {results_df.iloc[i]['predicted_flux_ratios_observed_rms']:.3f}")
    print(f"Delta RMS of flux ratios at the predicted position: {results_df.iloc[i]['predicted_flux_ratios_rms']:.3f}")
    
    # Print absolute flux ratio differences (3 ratios, excluding normalization)
    print(f"Absolute Flux Ratio Differences:")
    flux_diff_indices = [0, 2, 3] if len(results_df.iloc[i]['flux_ratio_differences']) == 3 else range(len(results_df.iloc[i]['flux_ratio_differences']))
    for j, diff in enumerate(results_df.iloc[i]['flux_ratio_differences']):
        img_idx = flux_diff_indices[j] + 1
        print(f"  Image {img_idx}: {diff:.3f}")
    
    print(f"Manual Chi²: {results_df.iloc[i]['manual_chi2']:.3f}")
    if results_df.iloc[i]['glafic_chi2'] is not None:
        print(f"Glafic Chi² (final, reference): {results_df.iloc[i]['glafic_chi2']:.3f}")
        print(f"Chi² Difference (Manual - Glafic): {results_df.iloc[i]['manual_chi2'] - results_df.iloc[i]['glafic_chi2']:.3f}")
    else:
        print(f"Glafic Chi² (reference): Not found")
    print(f"BIC (using manual Chi²): {results_df.iloc[i]['bic']:.3f}")
    
    # Manual verification of BIC calculation
    manual_bic_check = results_df.iloc[i]['manual_chi2'] + results_df.iloc[i]['n_free_params'] * np.log(results_df.iloc[i]['n_data_points'])
    print(f"Manual BIC verification: {results_df.iloc[i]['manual_chi2']:.3f} + {results_df.iloc[i]['n_free_params']} × ln({results_df.iloc[i]['n_data_points']}) = {manual_bic_check:.3f}")
    print()

# Print LaTeX-formatted rows
print("LaTeX Table Rows:")
print("Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC")
for row in latex_rows:
    print(row)
# Out:
# Model: WFI2033/SP/outSP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 5
# Delta RMS of Image Positions: 49.571
# Individual Position Deltas (mas):
#   Image 1: 16.353
#   Image 2: 67.724
#   Image 3: 48.887
#   Image 4: 50.843
# Delta RMS of flux ratios at the observed position: 0.185
# Delta RMS of flux ratios at the predicted position: 0.196
# Absolute Flux Ratio Differences:
#   Image 1: 0.015
#   Image 3: 0.086
#   Image 4: 0.329
# Manual Chi²: 681.936
# Glafic Chi² (final, reference): 501.343
# Chi² Difference (Manual - Glafic): 180.593
# BIC (using manual Chi²): 692.333
# Manual BIC verification: 681.936 + 5 × ln(8) = 692.333
#
# Model: WFI2033/SPR/outSPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 2.746
# Individual Position Deltas (mas):
#   Image 1: 2.500
#   Image 2: 1.726
#   Image 3: 2.343
#   Image 4: 3.929
# Delta RMS of flux ratios at the observed position: 0.235
# Delta RMS of flux ratios at the predicted position: 0.220
# Absolute Flux Ratio Differences:
#   Image 1: 0.293
#   Image 3: 0.060
#   Image 4: 0.235
# Manual Chi²: 243.594
# Glafic Chi² (final, reference): 16.830
# Chi² Difference (Manual - Glafic): 226.764
# BIC (using manual Chi²): 264.388
# Manual BIC verification: 243.594 + 10 × ln(8) = 264.388
#
# Model: WFI2033/SPG/outSPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 12.764
# Individual Position Deltas (mas):
#   Image 1: 17.964
#   Image 2: 12.034
#   Image 3: 9.463
#   Image 4: 9.725
# Delta RMS of flux ratios at the observed position: 0.133
# Delta RMS of flux ratios at the predicted position: 0.129
# Absolute Flux Ratio Differences:
#   Image 1: 0.038
#   Image 3: 0.097
#   Image 4: 0.197
# Manual Chi²: 148.562
# Glafic Chi² (final, reference): 9.576
# Chi² Difference (Manual - Glafic): 138.986
# BIC (using manual Chi²): 169.357
# Manual BIC verification: 148.562 + 10 × ln(8) = 169.357
#
# Model: WFI2033/SPGR/outSPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 15
# Delta RMS of Image Positions: 2.572
# Individual Position Deltas (mas):
#   Image 1: 1.924
#   Image 2: 3.962
#   Image 3: 0.412
#   Image 4: 2.625
# Delta RMS of flux ratios at the observed position: 0.138
# Delta RMS of flux ratios at the predicted position: 0.139
# Absolute Flux Ratio Differences:
#   Image 1: 0.116
#   Image 3: 0.163
#   Image 4: 0.133
# Manual Chi²: 126.466
# Glafic Chi² (final, reference): 0.513
# Chi² Difference (Manual - Glafic): 125.953
# BIC (using manual Chi²): 157.658
# Manual BIC verification: 126.466 + 15 × ln(8) = 157.658
#
# Model: WFI2033/SPF/outSPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 5
# Delta RMS of Image Positions: 50.794
# Individual Position Deltas (mas):
#   Image 1: 23.754
#   Image 2: 64.719
#   Image 3: 48.495
#   Image 4: 56.707
# Delta RMS of flux ratios at the observed position: 0.168
# Delta RMS of flux ratios at the predicted position: 0.189
# Absolute Flux Ratio Differences:
#   Image 1: 0.011
#   Image 3: 0.078
#   Image 4: 0.318
# Manual Chi²: 680.198
# Glafic Chi² (final, reference): 324.854
# Chi² Difference (Manual - Glafic): 355.344
# BIC (using manual Chi²): 692.187
# Manual BIC verification: 680.198 + 5 × ln(11) = 692.187
#
# Model: WFI2033/SPFR/outSPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 4.743
# Individual Position Deltas (mas):
#   Image 1: 3.667
#   Image 2: 4.518
#   Image 3: 5.239
#   Image 4: 5.354
# Delta RMS of flux ratios at the observed position: 0.170
# Delta RMS of flux ratios at the predicted position: 0.138
# Absolute Flux Ratio Differences:
#   Image 1: 0.208
#   Image 3: 0.102
#   Image 4: 0.060
# Manual Chi²: 86.620
# Glafic Chi² (final, reference): 119.351
# Chi² Difference (Manual - Glafic): -32.730
# BIC (using manual Chi²): 110.599
# Manual BIC verification: 86.620 + 10 × ln(11) = 110.599
#
# Model: WFI2033/SPFG/outSPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 6.371
# Individual Position Deltas (mas):
#   Image 1: 8.006
#   Image 2: 9.485
#   Image 3: 1.432
#   Image 4: 2.500
# Delta RMS of flux ratios at the observed position: 0.117
# Delta RMS of flux ratios at the predicted position: 0.116
# Absolute Flux Ratio Differences:
#   Image 1: 0.037
#   Image 3: 0.087
#   Image 4: 0.177
# Manual Chi²: 105.179
# Glafic Chi² (final, reference): 110.266
# Chi² Difference (Manual - Glafic): -5.087
# BIC (using manual Chi²): 129.158
# Manual BIC verification: 105.179 + 10 × ln(11) = 129.158
#
# Model: WFI2033/SPFGR/outSPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 15
# Delta RMS of Image Positions: 4.555
# Individual Position Deltas (mas):
#   Image 1: 7.155
#   Image 2: 3.551
#   Image 3: 1.253
#   Image 4: 4.198
# Delta RMS of flux ratios at the observed position: 0.083
# Delta RMS of flux ratios at the predicted position: 0.090
# Absolute Flux Ratio Differences:
#   Image 1: 0.094
#   Image 3: 0.020
#   Image 4: 0.123
# Manual Chi²: 51.746
# Glafic Chi² (final, reference): 44.816
# Chi² Difference (Manual - Glafic): 6.930
# BIC (using manual Chi²): 87.715
# Manual BIC verification: 51.746 + 15 × ln(11) = 87.715
#
# Model: WFI2033/PP/outPP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 45.120
# Individual Position Deltas (mas):
#   Image 1: 21.695
#   Image 2: 56.052
#   Image 3: 39.295
#   Image 4: 54.649
# Delta RMS of flux ratios at the observed position: 0.201
# Delta RMS of flux ratios at the predicted position: 0.215
# Absolute Flux Ratio Differences:
#   Image 1: 0.071
#   Image 3: 0.062
#   Image 4: 0.360
# Manual Chi²: 665.042
# Glafic Chi² (final, reference): 503.965
# Chi² Difference (Manual - Glafic): 161.076
# BIC (using manual Chi²): 677.518
# Manual BIC verification: 665.042 + 6 × ln(8) = 677.518
#
# Model: WFI2033/PPR/outPPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.660
# Individual Position Deltas (mas):
#   Image 1: 2.280
#   Image 2: 1.712
#   Image 3: 2.343
#   Image 4: 3.833
# Delta RMS of flux ratios at the observed position: 0.237
# Delta RMS of flux ratios at the predicted position: 0.222
# Absolute Flux Ratio Differences:
#   Image 1: 0.300
#   Image 3: 0.072
#   Image 4: 0.230
# Manual Chi²: 246.667
# Glafic Chi² (final, reference): 15.864
# Chi² Difference (Manual - Glafic): 230.803
# BIC (using manual Chi²): 269.541
# Manual BIC verification: 246.667 + 11 × ln(8) = 269.541
#
# Model: WFI2033/PPG/outPPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 0.768
# Individual Position Deltas (mas):
#   Image 1: 0.608
#   Image 2: 1.200
#   Image 3: 0.141
#   Image 4: 0.728
# Delta RMS of flux ratios at the observed position: 0.144
# Delta RMS of flux ratios at the predicted position: 0.145
# Absolute Flux Ratio Differences:
#   Image 1: 0.042
#   Image 3: 0.087
#   Image 4: 0.231
# Manual Chi²: 154.670
# Glafic Chi² (final, reference): 0.042
# Chi² Difference (Manual - Glafic): 154.628
# BIC (using manual Chi²): 177.543
# Manual BIC verification: 154.670 + 11 × ln(8) = 177.543
#
# Model: WFI2033/PPGR/outPPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 16
# Delta RMS of Image Positions: 0.000
# Individual Position Deltas (mas):
#   Image 1: 0.000
#   Image 2: 0.000
#   Image 3: 0.000
#   Image 4: 0.000
# Delta RMS of flux ratios at the observed position: 0.202
# Delta RMS of flux ratios at the predicted position: 0.202
# Absolute Flux Ratio Differences:
#   Image 1: 0.236
#   Image 3: 0.206
#   Image 4: 0.157
# Manual Chi²: 229.947
# Glafic Chi² (final, reference): 0.000
# Chi² Difference (Manual - Glafic): 229.947
# BIC (using manual Chi²): 263.218
# Manual BIC verification: 229.947 + 16 × ln(8) = 263.218
#
# Model: WFI2033/PPF/outPPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 55.717
# Individual Position Deltas (mas):
#   Image 1: 20.308
#   Image 2: 67.087
#   Image 3: 56.718
#   Image 4: 65.478
# Delta RMS of flux ratios at the observed position: 0.137
# Delta RMS of flux ratios at the predicted position: 0.176
# Absolute Flux Ratio Differences:
#   Image 1: 0.120
#   Image 3: 0.099
#   Image 4: 0.263
# Manual Chi²: 710.376
# Glafic Chi² (final, reference): 735.112
# Chi² Difference (Manual - Glafic): -24.736
# BIC (using manual Chi²): 724.763
# Manual BIC verification: 710.376 + 6 × ln(11) = 724.763
#
# Model: WFI2033/PPFR/outPPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 5.744
# Individual Position Deltas (mas):
#   Image 1: 5.743
#   Image 2: 8.193
#   Image 3: 4.441
#   Image 4: 3.483
# Delta RMS of flux ratios at the observed position: 0.108
# Delta RMS of flux ratios at the predicted position: 0.086
# Absolute Flux Ratio Differences:
#   Image 1: 0.127
#   Image 3: 0.077
#   Image 4: 0.008
# Manual Chi²: 38.290
# Glafic Chi² (final, reference): 22.250
# Chi² Difference (Manual - Glafic): 16.040
# BIC (using manual Chi²): 64.667
# Manual BIC verification: 38.290 + 11 × ln(11) = 64.667
#
# Model: WFI2033/PPFG/outPPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 6.659
# Individual Position Deltas (mas):
#   Image 1: 5.921
#   Image 2: 9.640
#   Image 3: 6.075
#   Image 4: 3.536
# Delta RMS of flux ratios at the observed position: 0.050
# Delta RMS of flux ratios at the predicted position: 0.057
# Absolute Flux Ratio Differences:
#   Image 1: 0.023
#   Image 3: 0.076
#   Image 4: 0.058
# Manual Chi²: 30.645
# Glafic Chi² (final, reference): 33.913
# Chi² Difference (Manual - Glafic): -3.269
# BIC (using manual Chi²): 57.021
# Manual BIC verification: 30.645 + 11 × ln(11) = 57.021
#
# Model: WFI2033/PPFGR/outPPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 16
# Delta RMS of Image Positions: 5.299
# Individual Position Deltas (mas):
#   Image 1: 5.413
#   Image 2: 8.509
#   Image 3: 1.360
#   Image 4: 2.961
# Delta RMS of flux ratios at the observed position: 0.065
# Delta RMS of flux ratios at the predicted position: 0.065
# Absolute Flux Ratio Differences:
#   Image 1: 0.040
#   Image 3: 0.050
#   Image 4: 0.093
# Manual Chi²: 34.101
# Glafic Chi² (final, reference): 36.991
# Chi² Difference (Manual - Glafic): -2.889
# BIC (using manual Chi²): 72.468
# Manual BIC verification: 34.101 + 16 × ln(11) = 72.468
#
# Model: WFI2033/NP/outNP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 63.867
# Individual Position Deltas (mas):
#   Image 1: 22.523
#   Image 2: 90.220
#   Image 3: 66.113
#   Image 4: 57.428
# Delta RMS of flux ratios at the observed position: 0.117
# Delta RMS of flux ratios at the predicted position: 0.186
# Absolute Flux Ratio Differences:
#   Image 1: 0.187
#   Image 3: 0.165
#   Image 4: 0.204
# Manual Chi²: 863.543
# Glafic Chi² (final, reference): 641.230
# Chi² Difference (Manual - Glafic): 222.313
# BIC (using manual Chi²): 876.020
# Manual BIC verification: 863.543 + 6 × ln(8) = 876.020
#
# Model: WFI2033/NPR/outNPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 0.000
# Individual Position Deltas (mas):
#   Image 1: 0.000
#   Image 2: 0.000
#   Image 3: 0.000
#   Image 4: 0.000
# Delta RMS of flux ratios at the observed position: 0.535
# Delta RMS of flux ratios at the predicted position: 0.241
# Absolute Flux Ratio Differences:
#   Image 1: 0.264
#   Image 3: 0.175
#   Image 4: 0.273
# Manual Chi²: 339.980
# Glafic Chi² (final, reference): 11.334
# Chi² Difference (Manual - Glafic): 328.646
# BIC (using manual Chi²): 362.854
# Manual BIC verification: 339.980 + 11 × ln(8) = 362.854
#
# Model: WFI2033/NPG/outNPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 9.187
# Individual Position Deltas (mas):
#   Image 1: 12.167
#   Image 2: 11.510
#   Image 3: 4.669
#   Image 4: 5.941
# Delta RMS of flux ratios at the observed position: 0.067
# Delta RMS of flux ratios at the predicted position: 0.061
# Absolute Flux Ratio Differences:
#   Image 1: 0.017
#   Image 3: 0.064
#   Image 4: 0.082
# Manual Chi²: 40.665
# Glafic Chi² (final, reference): 4.762
# Chi² Difference (Manual - Glafic): 35.903
# BIC (using manual Chi²): 63.539
# Manual BIC verification: 40.665 + 11 × ln(8) = 63.539
#
# Model: WFI2033/NPGR/outNPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 16
# Delta RMS of Image Positions: 6.057
# Individual Position Deltas (mas):
#   Image 1: 5.016
#   Image 2: 9.426
#   Image 3: 1.562
#   Image 4: 5.504
# Delta RMS of flux ratios at the observed position: 0.059
# Delta RMS of flux ratios at the predicted position: 0.060
# Absolute Flux Ratio Differences:
#   Image 1: 0.029
#   Image 3: 0.073
#   Image 4: 0.067
# Manual Chi²: 31.513
# Glafic Chi² (final, reference): 2.620
# Chi² Difference (Manual - Glafic): 28.893
# BIC (using manual Chi²): 64.784
# Manual BIC verification: 31.513 + 16 × ln(8) = 64.784
#
# Model: WFI2033/NPF/outNPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 63.654
# Individual Position Deltas (mas):
#   Image 1: 23.880
#   Image 2: 89.814
#   Image 3: 67.501
#   Image 4: 54.900
# Delta RMS of flux ratios at the observed position: 0.127
# Delta RMS of flux ratios at the predicted position: 0.179
# Absolute Flux Ratio Differences:
#   Image 1: 0.180
#   Image 3: 0.157
#   Image 4: 0.197
# Manual Chi²: 842.380
# Glafic Chi² (final, reference): 771.574
# Chi² Difference (Manual - Glafic): 70.807
# BIC (using manual Chi²): 856.768
# Manual BIC verification: 842.380 + 6 × ln(11) = 856.768
#
# Model: WFI2033/NPFR/outNPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 15.432
# Individual Position Deltas (mas):
#   Image 1: 0.894
#   Image 2: 30.128
#   Image 3: 2.476
#   Image 4: 6.159
# Delta RMS of flux ratios at the observed position: 0.423
# Delta RMS of flux ratios at the predicted position: 0.155
# Absolute Flux Ratio Differences:
#   Image 1: 0.253
#   Image 3: 0.024
#   Image 4: 0.083
# Manual Chi²: 128.224
# Glafic Chi² (final, reference): 90.940
# Chi² Difference (Manual - Glafic): 37.284
# BIC (using manual Chi²): 154.601
# Manual BIC verification: 128.224 + 11 × ln(11) = 154.601
#
# Model: WFI2033/NPFG/outNPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 7.308
# Individual Position Deltas (mas):
#   Image 1: 10.526
#   Image 2: 8.786
#   Image 3: 2.640
#   Image 4: 4.319
# Delta RMS of flux ratios at the observed position: 0.064
# Delta RMS of flux ratios at the predicted position: 0.061
# Absolute Flux Ratio Differences:
#   Image 1: 0.017
#   Image 3: 0.056
#   Image 4: 0.088
# Manual Chi²: 36.138
# Glafic Chi² (final, reference): 39.818
# Chi² Difference (Manual - Glafic): -3.680
# BIC (using manual Chi²): 62.515
# Manual BIC verification: 36.138 + 11 × ln(11) = 62.515
#
# Model: WFI2033/NPFGR/outNPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 16
# Delta RMS of Image Positions: 0.433
# Individual Position Deltas (mas):
#   Image 1: 0.400
#   Image 2: 0.447
#   Image 3: 0.361
#   Image 4: 0.510
# Delta RMS of flux ratios at the observed position: 0.012
# Delta RMS of flux ratios at the predicted position: 0.014
# Absolute Flux Ratio Differences:
#   Image 1: 0.016
#   Image 3: 0.007
#   Image 4: 0.016
# Manual Chi²: 1.084
# Glafic Chi² (final, reference): 0.732
# Chi² Difference (Manual - Glafic): 0.353
# BIC (using manual Chi²): 39.451
# Manual BIC verification: 1.084 + 16 × ln(11) = 39.451
#
# LaTeX Table Rows:
# Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC
# SIE & QSO Pos & 16.353 & 67.724 & 48.887 & 50.843 & 49.6 & 0.015 & 0.086 & 0.329 & 0.20 & 692.3 \\
# SIE + Shear & QSO Pos & 2.500 & 1.726 & 2.343 & 3.929 & 2.7 & 0.293 & 0.060 & 0.235 & 0.22 & 264.4 \\
# SIE + G2 & QSO Pos & 17.964 & 12.034 & 9.463 & 9.725 & 12.8 & 0.038 & 0.097 & 0.197 & 0.13 & 169.4 \\
# SIE + Shear + G2 & QSO Pos & 1.924 & 3.962 & 0.412 & 2.625 & 2.6 & 0.116 & 0.163 & 0.133 & 0.14 & 157.7 \\
# SIE & QSO Pos + FR & 23.754 & 64.719 & 48.495 & 56.707 & 50.8 & 0.011 & 0.078 & 0.318 & 0.19 & 692.2 \\
# SIE + Shear & QSO Pos + FR & 3.667 & 4.518 & 5.239 & 5.354 & 4.7 & 0.208 & 0.102 & 0.060 & 0.14 & 110.6 \\
# SIE + G2 & QSO Pos + FR & 8.006 & 9.485 & 1.432 & 2.500 & 6.4 & 0.037 & 0.087 & 0.177 & 0.12 & 129.2 \\
# SIE + Shear + G2 & QSO Pos + FR & 7.155 & 3.551 & 1.253 & 4.198 & 4.6 & 0.094 & 0.020 & 0.123 & 0.09 & 87.7 \\
# POW & QSO Pos & 21.695 & 56.052 & 39.295 & 54.649 & 45.1 & 0.071 & 0.062 & 0.360 & 0.21 & 677.5 \\
# POW + Shear & QSO Pos & 2.280 & 1.712 & 2.343 & 3.833 & 2.7 & 0.300 & 0.072 & 0.230 & 0.22 & 269.5 \\
# POW + G2 & QSO Pos & 0.608 & 1.200 & 0.141 & 0.728 & 0.8 & 0.042 & 0.087 & 0.231 & 0.14 & 177.5 \\
# POW + Shear + G2 & QSO Pos & 0.000 & 0.000 & 0.000 & 0.000 & 0.0 & 0.236 & 0.206 & 0.157 & 0.20 & 263.2 \\
# POW & QSO Pos + FR & 20.308 & 67.087 & 56.718 & 65.478 & 55.7 & 0.120 & 0.099 & 0.263 & 0.18 & 724.8 \\
# POW + Shear & QSO Pos + FR & 5.743 & 8.193 & 4.441 & 3.483 & 5.7 & 0.127 & 0.077 & 0.008 & 0.09 & 64.7 \\
# POW + G2 & QSO Pos + FR & 5.921 & 9.640 & 6.075 & 3.536 & 6.7 & 0.023 & 0.076 & 0.058 & 0.06 & 57.0 \\
# POW + Shear + G2 & QSO Pos + FR & 5.413 & 8.509 & 1.360 & 2.961 & 5.3 & 0.040 & 0.050 & 0.093 & 0.07 & 72.5 \\
# NFW & QSO Pos & 22.523 & 90.220 & 66.113 & 57.428 & 63.9 & 0.187 & 0.165 & 0.204 & 0.19 & 876.0 \\
# NFW + Shear & QSO Pos & 0.000 & 0.000 & 0.000 & 0.000 & 0.0 & 0.264 & 0.175 & 0.273 & 0.24 & 362.9 \\
# NFW + G2 & QSO Pos & 12.167 & 11.510 & 4.669 & 5.941 & 9.2 & 0.017 & 0.064 & 0.082 & 0.06 & 63.5 \\
# NFW + Shear + G2 & QSO Pos & 5.016 & 9.426 & 1.562 & 5.504 & 6.1 & 0.029 & 0.073 & 0.067 & 0.06 & 64.8 \\
# NFW & QSO Pos + FR & 23.880 & 89.814 & 67.501 & 54.900 & 63.7 & 0.180 & 0.157 & 0.197 & 0.18 & 856.8 \\
# NFW + Shear & QSO Pos + FR & 0.894 & 30.128 & 2.476 & 6.159 & 15.4 & 0.253 & 0.024 & 0.083 & 0.15 & 154.6 \\
# NFW + G2 & QSO Pos + FR & 10.526 & 8.786 & 2.640 & 4.319 & 7.3 & 0.017 & 0.056 & 0.088 & 0.06 & 62.5 \\
# NFW + Shear + G2 & QSO Pos + FR & 0.400 & 0.447 & 0.361 & 0.510 & 0.4 & 0.016 & 0.007 & 0.016 & 0.01 & 39.5 \\

# %%
# NEW LATEX AUTOMATED CODE WITH MANUAL CHI^2 CALCULATION with individual position delta RMS and flux ratio differences
# WFI2033
import numpy as np
import pandas as pd
from astropy.io import fits
import os

# Function to calculate distance
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Function to read observed positions, flux ratios, and uncertainties
def read_observed_positions(input_file):
    observed_positions = []
    observed_flux_ratios = []
    position_uncertainties = []
    flux_uncertainties = []
    with open(input_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            columns = line.split()
            if len(columns) >= 5:
                x1 = float(columns[0])
                y1 = float(columns[1])
                flux_ratio = float(columns[2])
                pos_err = float(columns[3])
                flux_err = float(columns[4])
                observed_positions.append((x1, y1))
                observed_flux_ratios.append(flux_ratio)
                position_uncertainties.append(pos_err)
                flux_uncertainties.append(flux_err)
    return observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties

# Function to read predicted positions and magnifications
def read_predicted_positions(output_file):
    predicted_positions = []
    predicted_magnifications = []
    with open(output_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            if line.startswith("#"):
                continue
            columns = line.split()
            if len(columns) >= 3:
                x2 = float(columns[0])
                y2 = float(columns[1])
                M2 = abs(float(columns[2]))
                predicted_positions.append((x2, y2))
                predicted_magnifications.append(M2)
    return predicted_positions, predicted_magnifications

# Function to pair predicted and observed positions
def pair_positions(observed_positions, predicted_positions, predicted_magnifications):
    paired_positions = []
    for observed_position in observed_positions:
        min_distance = float('inf')
        closest_index = None
        for i, predicted_position in enumerate(predicted_positions):
            distance = calculate_distance(*observed_position, *predicted_position)
            if distance < min_distance:
                min_distance = distance
                closest_index = i
        paired_positions.append((observed_position, predicted_positions[closest_index], predicted_magnifications[closest_index]))
    return paired_positions

# Function to calculate manual chi² with proper uncertainties
def calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties, 
                         predicted_positions, predicted_magnifications, green_index=1):
    # Pair positions
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Calculate predicted flux ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]
    
    chi2 = 0.0
    
    # Position contributions to chi²
    for i, (observed, predicted, _) in enumerate(paired_positions):
        dx = observed[0] - predicted[0]
        dy = observed[1] - predicted[1]
        pos_err = position_uncertainties[i]
        chi2 += (dx/pos_err)**2 + (dy/pos_err)**2
    
    # Flux ratio contributions to chi² (excluding the normalization image)
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_err = flux_uncertainties[i]
            chi2 += ((pred_flux - obs_flux)/flux_err)**2
    
    return chi2

# Function to extract the final chi^2 from optresult.dat file
def extract_glafic_chi2(optresult_path):
    chi2_value = None
    with open(optresult_path, 'r') as file:
        lines = file.readlines()
    
    # Find the last occurrence of chi^2 (final/best result)
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
    
    return chi2_value

# Function to process file group
def process_file_group(output_file, fits_file, input_file, n):
    observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties = read_observed_positions(input_file)
    predicted_positions, predicted_magnifications = read_predicted_positions(output_file)
    
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Calculate Delta RMS of Image Positions correctly
    squared_distances = 0.0
    individual_distances = []  # Store individual distances for each image
    for observed, predicted, _ in paired_positions:
        distance = calculate_distance(*observed, *predicted)
        individual_distances.append(distance * 1000)  # Convert to mas
        squared_distances += distance ** 2  # Summing squared distances
    
    mean_squared_distances = squared_distances / len(paired_positions)
    delta_rms = np.sqrt(mean_squared_distances)  # Taking square root of the mean of squared distances
    delta_rms *= 1000  # Convert to mas
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Determine the index of the "Green Image"
    green_index = 0  # CHOOSE WHICH IMAGE TO NORMALISE BY HERE !!!!!!!!!!!!!!!!!!!!!!!

    # Predicted Flux Ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]

    # Calculate absolute differences between predicted and observed flux ratios (excluding normalization image)
    flux_ratio_differences = []
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_ratio_differences.append(abs(pred_flux - obs_flux))

    # Calculate manual chi²
    manual_chi2 = calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties,
                                       predicted_positions, predicted_magnifications, green_index)

    with fits.open(fits_file) as hdul:
        mag = hdul[0].data[6]
    
    pixel_coords = [(int((x + mag.shape[1] // 2 * n) / n), int((y + mag.shape[0] // 2 * n) / n)) for x, y in observed_positions]
    values = [mag[y, x] for x, y in pixel_coords]
    
    abs_values = [1 / abs(value) for value in values]
    predicted_flux_ratios_observed = [abs_values[i] / abs_values[green_index] for i in range(len(abs_values))]

    # Calculate RMS excluding the green image
    squared_diffs_pred = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_rms = np.sqrt(sum(squared_diffs_pred) / len(squared_diffs_pred))

    squared_diffs_obs = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios_observed, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_observed_rms = np.sqrt(sum(squared_diffs_obs) / len(squared_diffs_obs))

    return {
        'delta_rms': delta_rms,
        'individual_position_deltas': individual_distances,  # Delta RMS for each of the 4 positions
        'flux_ratio_differences': flux_ratio_differences,    # Absolute differences for 3 flux ratios
        'predicted_flux_ratios_rms': predicted_flux_ratios_rms,
        'predicted_flux_ratios_observed_rms': predicted_flux_ratios_observed_rms,
        'manual_chi2': manual_chi2
    }

# Function to extract chi^2 and lens models from optresult.dat file (following Code 1's approach exactly)
def extract_chi2_and_lens_profiles(optresult_path):
    chi2_value = None
    profiles_used = []
    sie_count = 0

    with open(optresult_path, 'r') as file:
        lines = file.readlines()

    found_chi2 = False
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
            found_chi2 = True
            profiles_used = []
            sie_count = 0
        elif found_chi2:
            if line.startswith("lens   sie"):
                profiles_used.append("SIE")
                sie_count += 1
            elif line.startswith("lens   pow"):
                profiles_used.append("POW")
            elif line.startswith("lens   anfw"):
                profiles_used.append("NFW")
            elif line.startswith("lens   pert"):
                profiles_used.append("Shear")

    if chi2_value is None:
        raise ValueError("No chi^2 value found in the file.")

    profiles_used = list(set(profiles_used))
    return chi2_value, profiles_used, sie_count

# Function to calculate free parameters based on lens profiles (identical to Code 1)
def calculate_free_parameters(profiles_used, sie_count):
    profile_params = {
        "SIE": 5,
        "POW": 6,
        "NFW": 6,
        "Shear": 5
    }
    total_params = sum(profile_params[profile] for profile in profiles_used)
    if sie_count == 2:
        total_params += 5
    return total_params

# Function to calculate BIC (Bayesian Information Criterion)
def calculate_bic(chi2, n_data_points, n_free_params):
    return chi2 + n_free_params * np.log(n_data_points)

# Function to compute BIC using manual chi² but following Code 1's approach for free parameters
def compute_bic_with_tracking(manual_chi2, optresult_path):
    # Use Code 1's approach: extract profiles from optresult.dat file
    glafic_chi2, profiles_used, sie_count = extract_chi2_and_lens_profiles(optresult_path)
    n_free_params = calculate_free_parameters(profiles_used, sie_count)
    
    # Properly adjust n_data_points based on constraint type
    if "PF" in optresult_path:
        n_data_points = 4 * 2 + 3  # positions + flux ratios
    else:
        n_data_points = 4 * 2  # positions only
    
    # Always use manual chi² for BIC calculation
    bic_value = calculate_bic(manual_chi2, n_data_points, n_free_params)
    
    return bic_value, glafic_chi2, n_data_points, n_free_params

# Main function to process multiple files
def process_files(input_file, output_files, fits_files, optresult_files, n):
    results = []
    latex_rows = []
    bics = []  # Store BIC values separately
    glafic_chi2_values = []  # Store glafic chi² for reference
    data_points_used = []  # Store number of data points used
    free_params_used = []  # Store number of free parameters used

    for output_file, fits_file, optresult_file in zip(output_files, fits_files, optresult_files):
        # Process output and fits files
        result = process_file_group(output_file, fits_file, input_file, n)
        results.append(result)
        
        # Calculate BIC using manual chi² but track both values
        bic, glafic_chi2, n_data_points, n_free_params = compute_bic_with_tracking(result['manual_chi2'], optresult_file)
        bics.append(bic)
        glafic_chi2_values.append(glafic_chi2)
        data_points_used.append(n_data_points)
        free_params_used.append(n_free_params)
        
        # Create LaTeX row with additional information
        model_name, constraint_name = determine_model_and_constraint(output_file)
        # Format individual position deltas and flux ratio differences for LaTeX
        pos_deltas_str = " & ".join([f"{delta:.3f}" for delta in result['individual_position_deltas']])
        flux_diffs_str = " & ".join([f"{diff:.3f}" for diff in result['flux_ratio_differences']])
        
        latex_row = f"{model_name} & {constraint_name} & {pos_deltas_str} & {result['delta_rms']:.1f} & {flux_diffs_str} & {result['predicted_flux_ratios_rms']:.2f} & {bic:.1f} \\\\"
        latex_rows.append(latex_row)
    
    # Combine results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results['bic'] = bics  # Add BIC values to the DataFrame
    df_results['glafic_chi2'] = glafic_chi2_values  # Add glafic chi² for reference
    df_results['n_data_points'] = data_points_used  # Add number of data points used
    df_results['n_free_params'] = free_params_used  # Add number of free parameters used
    
    return df_results, latex_rows

# Determine model and constraint names from the filename
def determine_model_and_constraint(file_name):
    model_map = {'S': 'SIE', 'P': 'POW', 'N': 'NFW'}
    
    base_name = os.path.basename(file_name)
    model_key = base_name[3]
    constraint_key = base_name[4:6] if base_name[4:6] in ['PF'] else base_name[4]
    
    model_name = model_map.get(model_key, '')
    if 'R' in base_name:
        model_name += ' + Shear'
    if 'G' in base_name:
        model_name += ' + G2'
    
    constraint_name = 'QSO Pos + FR' if constraint_key == 'PF' else 'QSO Pos'
    
    return model_name, constraint_name

# Example usage with filenames
Input_file = "WFI2033/obs_point.dat"

Output_files = [
    "WFI2033/SP/outSP_point.dat",
    "WFI2033/SPR/outSPR_point.dat",
    "WFI2033/SPG/outSPG_point.dat",
    "WFI2033/SPGR/outSPGR_point.dat",
    "WFI2033/SPF/outSPF_point.dat",
    "WFI2033/SPFR/outSPFR_point.dat",
    "WFI2033/SPFG/outSPFG_point.dat",
    "WFI2033/SPFGR/outSPFGR_point.dat",
    "WFI2033/PP/outPP_point.dat",
    "WFI2033/PPR/outPPR_point.dat",
    "WFI2033/PPG/outPPG_point.dat",
    "WFI2033/PPGR/outPPGR_point.dat",
    "WFI2033/PPF/outPPF_point.dat",
    "WFI2033/PPFR/outPPFR_point.dat",
    "WFI2033/PPFG/outPPFG_point.dat",
    "WFI2033/PPFGR/outPPFGR_point.dat",
    "WFI2033/NP/outNP_point.dat",
    "WFI2033/NPR/outNPR_point.dat",
    "WFI2033/NPG/outNPG_point.dat",
    "WFI2033/NPGR/outNPGR_point.dat",
    "WFI2033/NPF/outNPF_point.dat",
    "WFI2033/NPFR/outNPFR_point.dat",
    "WFI2033/NPFG/outNPFG_point.dat",
    "WFI2033/NPFGR/outNPFGR_point.dat"
]

Fits_files = [
    "WFI2033/SP/outSP_lens.fits",
    "WFI2033/SPR/outSPR_lens.fits",
    "WFI2033/SPG/outSPG_lens.fits",
    "WFI2033/SPGR/outSPGR_lens.fits",
    "WFI2033/SPF/outSPF_lens.fits",
    "WFI2033/SPFR/outSPFR_lens.fits",
    "WFI2033/SPFG/outSPFG_lens.fits",
    "WFI2033/SPFGR/outSPFGR_lens.fits",
    "WFI2033/PP/outPP_lens.fits",
    "WFI2033/PPR/outPPR_lens.fits",
    "WFI2033/PPG/outPPG_lens.fits",
    "WFI2033/PPGR/outPPGR_lens.fits",
    "WFI2033/PPF/outPPF_lens.fits",
    "WFI2033/PPFR/outPPFR_lens.fits",
    "WFI2033/PPFG/outPPFG_lens.fits",
    "WFI2033/PPFGR/outPPFGR_lens.fits",
    "WFI2033/NP/outNP_lens.fits",
    "WFI2033/NPR/outNPR_lens.fits",
    "WFI2033/NPG/outNPG_lens.fits",
    "WFI2033/NPGR/outNPGR_lens.fits",
    "WFI2033/NPF/outNPF_lens.fits",
    "WFI2033/NPFR/outNPFR_lens.fits",
    "WFI2033/NPFG/outNPFG_lens.fits",
    "WFI2033/NPFGR/outNPFGR_lens.fits"
]

Optresult_files = [
    "WFI2033/SP/outSP_optresult.dat",
    "WFI2033/SPR/outSPR_optresult.dat",
    "WFI2033/SPG/outSPG_optresult.dat",
    "WFI2033/SPGR/outSPGR_optresult.dat",
    "WFI2033/SPF/outSPF_optresult.dat",
    "WFI2033/SPFR/outSPFR_optresult.dat",
    "WFI2033/SPFG/outSPFG_optresult.dat",
    "WFI2033/SPFGR/outSPFGR_optresult.dat",
    "WFI2033/PP/outPP_optresult.dat",
    "WFI2033/PPR/outPPR_optresult.dat",
    "WFI2033/PPG/outPPG_optresult.dat",
    "WFI2033/PPGR/outPPGR_optresult.dat",
    "WFI2033/PPF/outPPF_optresult.dat",
    "WFI2033/PPFR/outPPFR_optresult.dat",
    "WFI2033/PPFG/outPPFG_optresult.dat",
    "WFI2033/PPFGR/outPPFGR_optresult.dat",
    "WFI2033/NP/outNP_optresult.dat",
    "WFI2033/NPR/outNPR_optresult.dat",
    "WFI2033/NPG/outNPG_optresult.dat",
    "WFI2033/NPGR/outNPGR_optresult.dat",
    "WFI2033/NPF/outNPF_optresult.dat",
    "WFI2033/NPFR/outNPFR_optresult.dat",
    "WFI2033/NPFG/outNPFG_optresult.dat",
    "WFI2033/NPFGR/outNPFGR_optresult.dat"
]

n = 0.0025  # Example scale factor
results_df, latex_rows = process_files(Input_file, Output_files, Fits_files, Optresult_files, n)

# Print formatted results
for i, output_file in enumerate(Output_files):
    constraint_type = "PF" if "PF" in Optresult_files[i] else "P"
    print(f"Model: {output_file}")
    print(f"Constraint Type: {constraint_type}")
    print(f"Number of data points used: {results_df.iloc[i]['n_data_points']}")
    print(f"Number of free parameters: {results_df.iloc[i]['n_free_params']}")
    print(f"Delta RMS of Image Positions: {results_df.iloc[i]['delta_rms']:.3f}")
    
    # Print individual position deltas (4 positions)
    print(f"Individual Position Deltas (mas):")
    for j, delta in enumerate(results_df.iloc[i]['individual_position_deltas']):
        print(f"  Image {j+1}: {delta:.3f}")
    
    print(f"Delta RMS of flux ratios at the observed position: {results_df.iloc[i]['predicted_flux_ratios_observed_rms']:.3f}")
    print(f"Delta RMS of flux ratios at the predicted position: {results_df.iloc[i]['predicted_flux_ratios_rms']:.3f}")
    
    # Print absolute flux ratio differences (3 ratios, excluding normalization)
    print(f"Absolute Flux Ratio Differences:")
    flux_diff_indices = [0, 2, 3] if len(results_df.iloc[i]['flux_ratio_differences']) == 3 else range(len(results_df.iloc[i]['flux_ratio_differences']))
    for j, diff in enumerate(results_df.iloc[i]['flux_ratio_differences']):
        img_idx = flux_diff_indices[j] + 1
        print(f"  Image {img_idx}: {diff:.3f}")
    
    print(f"Manual Chi²: {results_df.iloc[i]['manual_chi2']:.3f}")
    if results_df.iloc[i]['glafic_chi2'] is not None:
        print(f"Glafic Chi² (final, reference): {results_df.iloc[i]['glafic_chi2']:.3f}")
        print(f"Chi² Difference (Manual - Glafic): {results_df.iloc[i]['manual_chi2'] - results_df.iloc[i]['glafic_chi2']:.3f}")
    else:
        print(f"Glafic Chi² (reference): Not found")
    print(f"BIC (using manual Chi²): {results_df.iloc[i]['bic']:.3f}")
    
    # Manual verification of BIC calculation
    manual_bic_check = results_df.iloc[i]['manual_chi2'] + results_df.iloc[i]['n_free_params'] * np.log(results_df.iloc[i]['n_data_points'])
    print(f"Manual BIC verification: {results_df.iloc[i]['manual_chi2']:.3f} + {results_df.iloc[i]['n_free_params']} × ln({results_df.iloc[i]['n_data_points']}) = {manual_bic_check:.3f}")
    print()

# Print LaTeX-formatted rows
print("LaTeX Table Rows:")
print("Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC")
for row in latex_rows:
    print(row)
# Out:
# Model: WFI2033/SP/outSP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 5
# Delta RMS of Image Positions: 49.571
# Individual Position Deltas (mas):
#   Image 1: 16.353
#   Image 2: 67.724
#   Image 3: 48.887
#   Image 4: 50.843
# Delta RMS of flux ratios at the observed position: 0.185
# Delta RMS of flux ratios at the predicted position: 0.196
# Absolute Flux Ratio Differences:
#   Image 1: 0.015
#   Image 3: 0.086
#   Image 4: 0.329
# Manual Chi²: 681.936
# Glafic Chi² (final, reference): 501.343
# Chi² Difference (Manual - Glafic): 180.593
# BIC (using manual Chi²): 692.333
# Manual BIC verification: 681.936 + 5 × ln(8) = 692.333
#
# Model: WFI2033/SPR/outSPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 2.746
# Individual Position Deltas (mas):
#   Image 1: 2.500
#   Image 2: 1.726
#   Image 3: 2.343
#   Image 4: 3.929
# Delta RMS of flux ratios at the observed position: 0.235
# Delta RMS of flux ratios at the predicted position: 0.220
# Absolute Flux Ratio Differences:
#   Image 1: 0.293
#   Image 3: 0.060
#   Image 4: 0.235
# Manual Chi²: 243.594
# Glafic Chi² (final, reference): 16.830
# Chi² Difference (Manual - Glafic): 226.764
# BIC (using manual Chi²): 264.388
# Manual BIC verification: 243.594 + 10 × ln(8) = 264.388
#
# Model: WFI2033/SPG/outSPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 12.764
# Individual Position Deltas (mas):
#   Image 1: 17.964
#   Image 2: 12.034
#   Image 3: 9.463
#   Image 4: 9.725
# Delta RMS of flux ratios at the observed position: 0.133
# Delta RMS of flux ratios at the predicted position: 0.129
# Absolute Flux Ratio Differences:
#   Image 1: 0.038
#   Image 3: 0.097
#   Image 4: 0.197
# Manual Chi²: 148.562
# Glafic Chi² (final, reference): 9.576
# Chi² Difference (Manual - Glafic): 138.986
# BIC (using manual Chi²): 169.357
# Manual BIC verification: 148.562 + 10 × ln(8) = 169.357
#
# Model: WFI2033/SPGR/outSPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 15
# Delta RMS of Image Positions: 2.572
# Individual Position Deltas (mas):
#   Image 1: 1.924
#   Image 2: 3.962
#   Image 3: 0.412
#   Image 4: 2.625
# Delta RMS of flux ratios at the observed position: 0.138
# Delta RMS of flux ratios at the predicted position: 0.139
# Absolute Flux Ratio Differences:
#   Image 1: 0.116
#   Image 3: 0.163
#   Image 4: 0.133
# Manual Chi²: 126.466
# Glafic Chi² (final, reference): 0.513
# Chi² Difference (Manual - Glafic): 125.953
# BIC (using manual Chi²): 157.658
# Manual BIC verification: 126.466 + 15 × ln(8) = 157.658
#
# Model: WFI2033/SPF/outSPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 5
# Delta RMS of Image Positions: 50.794
# Individual Position Deltas (mas):
#   Image 1: 23.754
#   Image 2: 64.719
#   Image 3: 48.495
#   Image 4: 56.707
# Delta RMS of flux ratios at the observed position: 0.168
# Delta RMS of flux ratios at the predicted position: 0.189
# Absolute Flux Ratio Differences:
#   Image 1: 0.011
#   Image 3: 0.078
#   Image 4: 0.318
# Manual Chi²: 680.198
# Glafic Chi² (final, reference): 324.854
# Chi² Difference (Manual - Glafic): 355.344
# BIC (using manual Chi²): 692.187
# Manual BIC verification: 680.198 + 5 × ln(11) = 692.187
#
# Model: WFI2033/SPFR/outSPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 4.743
# Individual Position Deltas (mas):
#   Image 1: 3.667
#   Image 2: 4.518
#   Image 3: 5.239
#   Image 4: 5.354
# Delta RMS of flux ratios at the observed position: 0.170
# Delta RMS of flux ratios at the predicted position: 0.138
# Absolute Flux Ratio Differences:
#   Image 1: 0.208
#   Image 3: 0.102
#   Image 4: 0.060
# Manual Chi²: 86.620
# Glafic Chi² (final, reference): 119.351
# Chi² Difference (Manual - Glafic): -32.730
# BIC (using manual Chi²): 110.599
# Manual BIC verification: 86.620 + 10 × ln(11) = 110.599
#
# Model: WFI2033/SPFG/outSPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 6.371
# Individual Position Deltas (mas):
#   Image 1: 8.006
#   Image 2: 9.485
#   Image 3: 1.432
#   Image 4: 2.500
# Delta RMS of flux ratios at the observed position: 0.117
# Delta RMS of flux ratios at the predicted position: 0.116
# Absolute Flux Ratio Differences:
#   Image 1: 0.037
#   Image 3: 0.087
#   Image 4: 0.177
# Manual Chi²: 105.179
# Glafic Chi² (final, reference): 110.266
# Chi² Difference (Manual - Glafic): -5.087
# BIC (using manual Chi²): 129.158
# Manual BIC verification: 105.179 + 10 × ln(11) = 129.158
#
# Model: WFI2033/SPFGR/outSPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 15
# Delta RMS of Image Positions: 4.555
# Individual Position Deltas (mas):
#   Image 1: 7.155
#   Image 2: 3.551
#   Image 3: 1.253
#   Image 4: 4.198
# Delta RMS of flux ratios at the observed position: 0.083
# Delta RMS of flux ratios at the predicted position: 0.090
# Absolute Flux Ratio Differences:
#   Image 1: 0.094
#   Image 3: 0.020
#   Image 4: 0.123
# Manual Chi²: 51.746
# Glafic Chi² (final, reference): 44.816
# Chi² Difference (Manual - Glafic): 6.930
# BIC (using manual Chi²): 87.715
# Manual BIC verification: 51.746 + 15 × ln(11) = 87.715
#
# Model: WFI2033/PP/outPP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 45.120
# Individual Position Deltas (mas):
#   Image 1: 21.695
#   Image 2: 56.052
#   Image 3: 39.295
#   Image 4: 54.649
# Delta RMS of flux ratios at the observed position: 0.201
# Delta RMS of flux ratios at the predicted position: 0.215
# Absolute Flux Ratio Differences:
#   Image 1: 0.071
#   Image 3: 0.062
#   Image 4: 0.360
# Manual Chi²: 665.042
# Glafic Chi² (final, reference): 503.965
# Chi² Difference (Manual - Glafic): 161.076
# BIC (using manual Chi²): 677.518
# Manual BIC verification: 665.042 + 6 × ln(8) = 677.518
#
# Model: WFI2033/PPR/outPPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.660
# Individual Position Deltas (mas):
#   Image 1: 2.280
#   Image 2: 1.712
#   Image 3: 2.343
#   Image 4: 3.833
# Delta RMS of flux ratios at the observed position: 0.237
# Delta RMS of flux ratios at the predicted position: 0.222
# Absolute Flux Ratio Differences:
#   Image 1: 0.300
#   Image 3: 0.072
#   Image 4: 0.230
# Manual Chi²: 246.667
# Glafic Chi² (final, reference): 15.864
# Chi² Difference (Manual - Glafic): 230.803
# BIC (using manual Chi²): 269.541
# Manual BIC verification: 246.667 + 11 × ln(8) = 269.541
#
# Model: WFI2033/PPG/outPPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 0.768
# Individual Position Deltas (mas):
#   Image 1: 0.608
#   Image 2: 1.200
#   Image 3: 0.141
#   Image 4: 0.728
# Delta RMS of flux ratios at the observed position: 0.144
# Delta RMS of flux ratios at the predicted position: 0.145
# Absolute Flux Ratio Differences:
#   Image 1: 0.042
#   Image 3: 0.087
#   Image 4: 0.231
# Manual Chi²: 154.670
# Glafic Chi² (final, reference): 0.042
# Chi² Difference (Manual - Glafic): 154.628
# BIC (using manual Chi²): 177.543
# Manual BIC verification: 154.670 + 11 × ln(8) = 177.543
#
# Model: WFI2033/PPGR/outPPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 16
# Delta RMS of Image Positions: 0.000
# Individual Position Deltas (mas):
#   Image 1: 0.000
#   Image 2: 0.000
#   Image 3: 0.000
#   Image 4: 0.000
# Delta RMS of flux ratios at the observed position: 0.202
# Delta RMS of flux ratios at the predicted position: 0.202
# Absolute Flux Ratio Differences:
#   Image 1: 0.236
#   Image 3: 0.206
#   Image 4: 0.157
# Manual Chi²: 229.947
# Glafic Chi² (final, reference): 0.000
# Chi² Difference (Manual - Glafic): 229.947
# BIC (using manual Chi²): 263.218
# Manual BIC verification: 229.947 + 16 × ln(8) = 263.218
#
# Model: WFI2033/PPF/outPPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 55.717
# Individual Position Deltas (mas):
#   Image 1: 20.308
#   Image 2: 67.087
#   Image 3: 56.718
#   Image 4: 65.478
# Delta RMS of flux ratios at the observed position: 0.137
# Delta RMS of flux ratios at the predicted position: 0.176
# Absolute Flux Ratio Differences:
#   Image 1: 0.120
#   Image 3: 0.099
#   Image 4: 0.263
# Manual Chi²: 710.376
# Glafic Chi² (final, reference): 735.112
# Chi² Difference (Manual - Glafic): -24.736
# BIC (using manual Chi²): 724.763
# Manual BIC verification: 710.376 + 6 × ln(11) = 724.763
#
# Model: WFI2033/PPFR/outPPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 5.744
# Individual Position Deltas (mas):
#   Image 1: 5.743
#   Image 2: 8.193
#   Image 3: 4.441
#   Image 4: 3.483
# Delta RMS of flux ratios at the observed position: 0.108
# Delta RMS of flux ratios at the predicted position: 0.086
# Absolute Flux Ratio Differences:
#   Image 1: 0.127
#   Image 3: 0.077
#   Image 4: 0.008
# Manual Chi²: 38.290
# Glafic Chi² (final, reference): 22.250
# Chi² Difference (Manual - Glafic): 16.040
# BIC (using manual Chi²): 64.667
# Manual BIC verification: 38.290 + 11 × ln(11) = 64.667
#
# Model: WFI2033/PPFG/outPPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 6.659
# Individual Position Deltas (mas):
#   Image 1: 5.921
#   Image 2: 9.640
#   Image 3: 6.075
#   Image 4: 3.536
# Delta RMS of flux ratios at the observed position: 0.050
# Delta RMS of flux ratios at the predicted position: 0.057
# Absolute Flux Ratio Differences:
#   Image 1: 0.023
#   Image 3: 0.076
#   Image 4: 0.058
# Manual Chi²: 30.645
# Glafic Chi² (final, reference): 33.913
# Chi² Difference (Manual - Glafic): -3.269
# BIC (using manual Chi²): 57.021
# Manual BIC verification: 30.645 + 11 × ln(11) = 57.021
#
# Model: WFI2033/PPFGR/outPPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 16
# Delta RMS of Image Positions: 5.299
# Individual Position Deltas (mas):
#   Image 1: 5.413
#   Image 2: 8.509
#   Image 3: 1.360
#   Image 4: 2.961
# Delta RMS of flux ratios at the observed position: 0.065
# Delta RMS of flux ratios at the predicted position: 0.065
# Absolute Flux Ratio Differences:
#   Image 1: 0.040
#   Image 3: 0.050
#   Image 4: 0.093
# Manual Chi²: 34.101
# Glafic Chi² (final, reference): 36.991
# Chi² Difference (Manual - Glafic): -2.889
# BIC (using manual Chi²): 72.468
# Manual BIC verification: 34.101 + 16 × ln(11) = 72.468
#
# Model: WFI2033/NP/outNP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 63.867
# Individual Position Deltas (mas):
#   Image 1: 22.523
#   Image 2: 90.220
#   Image 3: 66.113
#   Image 4: 57.428
# Delta RMS of flux ratios at the observed position: 0.117
# Delta RMS of flux ratios at the predicted position: 0.186
# Absolute Flux Ratio Differences:
#   Image 1: 0.187
#   Image 3: 0.165
#   Image 4: 0.204
# Manual Chi²: 863.543
# Glafic Chi² (final, reference): 641.230
# Chi² Difference (Manual - Glafic): 222.313
# BIC (using manual Chi²): 876.020
# Manual BIC verification: 863.543 + 6 × ln(8) = 876.020
#
# Model: WFI2033/NPR/outNPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 0.000
# Individual Position Deltas (mas):
#   Image 1: 0.000
#   Image 2: 0.000
#   Image 3: 0.000
#   Image 4: 0.000
# Delta RMS of flux ratios at the observed position: 0.535
# Delta RMS of flux ratios at the predicted position: 0.241
# Absolute Flux Ratio Differences:
#   Image 1: 0.264
#   Image 3: 0.175
#   Image 4: 0.273
# Manual Chi²: 339.980
# Glafic Chi² (final, reference): 11.334
# Chi² Difference (Manual - Glafic): 328.646
# BIC (using manual Chi²): 362.854
# Manual BIC verification: 339.980 + 11 × ln(8) = 362.854
#
# Model: WFI2033/NPG/outNPG_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 9.187
# Individual Position Deltas (mas):
#   Image 1: 12.167
#   Image 2: 11.510
#   Image 3: 4.669
#   Image 4: 5.941
# Delta RMS of flux ratios at the observed position: 0.067
# Delta RMS of flux ratios at the predicted position: 0.061
# Absolute Flux Ratio Differences:
#   Image 1: 0.017
#   Image 3: 0.064
#   Image 4: 0.082
# Manual Chi²: 40.665
# Glafic Chi² (final, reference): 4.762
# Chi² Difference (Manual - Glafic): 35.903
# BIC (using manual Chi²): 63.539
# Manual BIC verification: 40.665 + 11 × ln(8) = 63.539
#
# Model: WFI2033/NPGR/outNPGR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 16
# Delta RMS of Image Positions: 6.057
# Individual Position Deltas (mas):
#   Image 1: 5.016
#   Image 2: 9.426
#   Image 3: 1.562
#   Image 4: 5.504
# Delta RMS of flux ratios at the observed position: 0.059
# Delta RMS of flux ratios at the predicted position: 0.060
# Absolute Flux Ratio Differences:
#   Image 1: 0.029
#   Image 3: 0.073
#   Image 4: 0.067
# Manual Chi²: 31.513
# Glafic Chi² (final, reference): 2.620
# Chi² Difference (Manual - Glafic): 28.893
# BIC (using manual Chi²): 64.784
# Manual BIC verification: 31.513 + 16 × ln(8) = 64.784
#
# Model: WFI2033/NPF/outNPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 63.654
# Individual Position Deltas (mas):
#   Image 1: 23.880
#   Image 2: 89.814
#   Image 3: 67.501
#   Image 4: 54.900
# Delta RMS of flux ratios at the observed position: 0.127
# Delta RMS of flux ratios at the predicted position: 0.179
# Absolute Flux Ratio Differences:
#   Image 1: 0.180
#   Image 3: 0.157
#   Image 4: 0.197
# Manual Chi²: 842.380
# Glafic Chi² (final, reference): 771.574
# Chi² Difference (Manual - Glafic): 70.807
# BIC (using manual Chi²): 856.768
# Manual BIC verification: 842.380 + 6 × ln(11) = 856.768
#
# Model: WFI2033/NPFR/outNPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 15.432
# Individual Position Deltas (mas):
#   Image 1: 0.894
#   Image 2: 30.128
#   Image 3: 2.476
#   Image 4: 6.159
# Delta RMS of flux ratios at the observed position: 0.423
# Delta RMS of flux ratios at the predicted position: 0.155
# Absolute Flux Ratio Differences:
#   Image 1: 0.253
#   Image 3: 0.024
#   Image 4: 0.083
# Manual Chi²: 128.224
# Glafic Chi² (final, reference): 90.940
# Chi² Difference (Manual - Glafic): 37.284
# BIC (using manual Chi²): 154.601
# Manual BIC verification: 128.224 + 11 × ln(11) = 154.601
#
# Model: WFI2033/NPFG/outNPFG_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 7.308
# Individual Position Deltas (mas):
#   Image 1: 10.526
#   Image 2: 8.786
#   Image 3: 2.640
#   Image 4: 4.319
# Delta RMS of flux ratios at the observed position: 0.064
# Delta RMS of flux ratios at the predicted position: 0.061
# Absolute Flux Ratio Differences:
#   Image 1: 0.017
#   Image 3: 0.056
#   Image 4: 0.088
# Manual Chi²: 36.138
# Glafic Chi² (final, reference): 39.818
# Chi² Difference (Manual - Glafic): -3.680
# BIC (using manual Chi²): 62.515
# Manual BIC verification: 36.138 + 11 × ln(11) = 62.515
#
# Model: WFI2033/NPFGR/outNPFGR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 16
# Delta RMS of Image Positions: 0.433
# Individual Position Deltas (mas):
#   Image 1: 0.400
#   Image 2: 0.447
#   Image 3: 0.361
#   Image 4: 0.510
# Delta RMS of flux ratios at the observed position: 0.012
# Delta RMS of flux ratios at the predicted position: 0.014
# Absolute Flux Ratio Differences:
#   Image 1: 0.016
#   Image 3: 0.007
#   Image 4: 0.016
# Manual Chi²: 1.084
# Glafic Chi² (final, reference): 0.732
# Chi² Difference (Manual - Glafic): 0.353
# BIC (using manual Chi²): 39.451
# Manual BIC verification: 1.084 + 16 × ln(11) = 39.451
#
# LaTeX Table Rows:
# Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC
# SIE & QSO Pos & 16.353 & 67.724 & 48.887 & 50.843 & 49.6 & 0.015 & 0.086 & 0.329 & 0.20 & 692.3 \\
# SIE + Shear & QSO Pos & 2.500 & 1.726 & 2.343 & 3.929 & 2.7 & 0.293 & 0.060 & 0.235 & 0.22 & 264.4 \\
# SIE + G2 & QSO Pos & 17.964 & 12.034 & 9.463 & 9.725 & 12.8 & 0.038 & 0.097 & 0.197 & 0.13 & 169.4 \\
# SIE + Shear + G2 & QSO Pos & 1.924 & 3.962 & 0.412 & 2.625 & 2.6 & 0.116 & 0.163 & 0.133 & 0.14 & 157.7 \\
# SIE & QSO Pos + FR & 23.754 & 64.719 & 48.495 & 56.707 & 50.8 & 0.011 & 0.078 & 0.318 & 0.19 & 692.2 \\
# SIE + Shear & QSO Pos + FR & 3.667 & 4.518 & 5.239 & 5.354 & 4.7 & 0.208 & 0.102 & 0.060 & 0.14 & 110.6 \\
# SIE + G2 & QSO Pos + FR & 8.006 & 9.485 & 1.432 & 2.500 & 6.4 & 0.037 & 0.087 & 0.177 & 0.12 & 129.2 \\
# SIE + Shear + G2 & QSO Pos + FR & 7.155 & 3.551 & 1.253 & 4.198 & 4.6 & 0.094 & 0.020 & 0.123 & 0.09 & 87.7 \\
# POW & QSO Pos & 21.695 & 56.052 & 39.295 & 54.649 & 45.1 & 0.071 & 0.062 & 0.360 & 0.21 & 677.5 \\
# POW + Shear & QSO Pos & 2.280 & 1.712 & 2.343 & 3.833 & 2.7 & 0.300 & 0.072 & 0.230 & 0.22 & 269.5 \\
# POW + G2 & QSO Pos & 0.608 & 1.200 & 0.141 & 0.728 & 0.8 & 0.042 & 0.087 & 0.231 & 0.14 & 177.5 \\
# POW + Shear + G2 & QSO Pos & 0.000 & 0.000 & 0.000 & 0.000 & 0.0 & 0.236 & 0.206 & 0.157 & 0.20 & 263.2 \\
# POW & QSO Pos + FR & 20.308 & 67.087 & 56.718 & 65.478 & 55.7 & 0.120 & 0.099 & 0.263 & 0.18 & 724.8 \\
# POW + Shear & QSO Pos + FR & 5.743 & 8.193 & 4.441 & 3.483 & 5.7 & 0.127 & 0.077 & 0.008 & 0.09 & 64.7 \\
# POW + G2 & QSO Pos + FR & 5.921 & 9.640 & 6.075 & 3.536 & 6.7 & 0.023 & 0.076 & 0.058 & 0.06 & 57.0 \\
# POW + Shear + G2 & QSO Pos + FR & 5.413 & 8.509 & 1.360 & 2.961 & 5.3 & 0.040 & 0.050 & 0.093 & 0.07 & 72.5 \\
# NFW & QSO Pos & 22.523 & 90.220 & 66.113 & 57.428 & 63.9 & 0.187 & 0.165 & 0.204 & 0.19 & 876.0 \\
# NFW + Shear & QSO Pos & 0.000 & 0.000 & 0.000 & 0.000 & 0.0 & 0.264 & 0.175 & 0.273 & 0.24 & 362.9 \\
# NFW + G2 & QSO Pos & 12.167 & 11.510 & 4.669 & 5.941 & 9.2 & 0.017 & 0.064 & 0.082 & 0.06 & 63.5 \\
# NFW + Shear + G2 & QSO Pos & 5.016 & 9.426 & 1.562 & 5.504 & 6.1 & 0.029 & 0.073 & 0.067 & 0.06 & 64.8 \\
# NFW & QSO Pos + FR & 23.880 & 89.814 & 67.501 & 54.900 & 63.7 & 0.180 & 0.157 & 0.197 & 0.18 & 856.8 \\
# NFW + Shear & QSO Pos + FR & 0.894 & 30.128 & 2.476 & 6.159 & 15.4 & 0.253 & 0.024 & 0.083 & 0.15 & 154.6 \\
# NFW + G2 & QSO Pos + FR & 10.526 & 8.786 & 2.640 & 4.319 & 7.3 & 0.017 & 0.056 & 0.088 & 0.06 & 62.5 \\
# NFW + Shear + G2 & QSO Pos + FR & 0.400 & 0.447 & 0.361 & 0.510 & 0.4 & 0.016 & 0.007 & 0.016 & 0.01 & 39.5 \\

# %%
# NEW LATEX AUTOMATED CODE WITH MANUAL CHI^2 CALCULATION with individual position delta RMS and flux ratio differences
# SDSSJ1330
import numpy as np
import pandas as pd
from astropy.io import fits
import os

# Function to calculate distance
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Function to read observed positions, flux ratios, and uncertainties
def read_observed_positions(input_file):
    observed_positions = []
    observed_flux_ratios = []
    position_uncertainties = []
    flux_uncertainties = []
    with open(input_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            columns = line.split()
            if len(columns) >= 5:
                x1 = float(columns[0])
                y1 = float(columns[1])
                flux_ratio = float(columns[2])
                pos_err = float(columns[3])
                flux_err = float(columns[4])
                observed_positions.append((x1, y1))
                observed_flux_ratios.append(flux_ratio)
                position_uncertainties.append(pos_err)
                flux_uncertainties.append(flux_err)
    return observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties

# Function to read predicted positions and magnifications
def read_predicted_positions(output_file):
    predicted_positions = []
    predicted_magnifications = []
    with open(output_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            if line.startswith("#"):
                continue
            columns = line.split()
            if len(columns) >= 3:
                x2 = float(columns[0])
                y2 = float(columns[1])
                M2 = abs(float(columns[2]))
                predicted_positions.append((x2, y2))
                predicted_magnifications.append(M2)
    return predicted_positions, predicted_magnifications

# Function to pair predicted and observed positions
def pair_positions(observed_positions, predicted_positions, predicted_magnifications):
    paired_positions = []
    for observed_position in observed_positions:
        min_distance = float('inf')
        closest_index = None
        for i, predicted_position in enumerate(predicted_positions):
            distance = calculate_distance(*observed_position, *predicted_position)
            if distance < min_distance:
                min_distance = distance
                closest_index = i
        paired_positions.append((observed_position, predicted_positions[closest_index], predicted_magnifications[closest_index]))
    return paired_positions

# Function to calculate manual chi² with proper uncertainties
def calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties, 
                         predicted_positions, predicted_magnifications, green_index=1):
    # Pair positions
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Calculate predicted flux ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]
    
    chi2 = 0.0
    
    # Position contributions to chi²
    for i, (observed, predicted, _) in enumerate(paired_positions):
        dx = observed[0] - predicted[0]
        dy = observed[1] - predicted[1]
        pos_err = position_uncertainties[i]
        chi2 += (dx/pos_err)**2 + (dy/pos_err)**2
    
    # Flux ratio contributions to chi² (excluding the normalization image)
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_err = flux_uncertainties[i]
            chi2 += ((pred_flux - obs_flux)/flux_err)**2
    
    return chi2

# Function to extract the final chi^2 from optresult.dat file
def extract_glafic_chi2(optresult_path):
    chi2_value = None
    with open(optresult_path, 'r') as file:
        lines = file.readlines()
    
    # Find the last occurrence of chi^2 (final/best result)
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
    
    return chi2_value

# Function to process file group
def process_file_group(output_file, fits_file, input_file, n):
    observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties = read_observed_positions(input_file)
    predicted_positions, predicted_magnifications = read_predicted_positions(output_file)
    
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Calculate Delta RMS of Image Positions correctly
    squared_distances = 0.0
    individual_distances = []  # Store individual distances for each image
    for observed, predicted, _ in paired_positions:
        distance = calculate_distance(*observed, *predicted)
        individual_distances.append(distance * 1000)  # Convert to mas
        squared_distances += distance ** 2  # Summing squared distances
    
    mean_squared_distances = squared_distances / len(paired_positions)
    delta_rms = np.sqrt(mean_squared_distances)  # Taking square root of the mean of squared distances
    delta_rms *= 1000  # Convert to mas
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Determine the index of the "Green Image"
    green_index = 0  # CHOOSE WHICH IMAGE TO NORMALISE BY HERE !!!!!!!!!!!!!!!!!!!!!!!

    # Predicted Flux Ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]

    # Calculate absolute differences between predicted and observed flux ratios (excluding normalization image)
    flux_ratio_differences = []
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_ratio_differences.append(abs(pred_flux - obs_flux))

    # Calculate manual chi²
    manual_chi2 = calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties,
                                       predicted_positions, predicted_magnifications, green_index)

    with fits.open(fits_file) as hdul:
        mag = hdul[0].data[6]
    
    pixel_coords = [(int((x + mag.shape[1] // 2 * n) / n), int((y + mag.shape[0] // 2 * n) / n)) for x, y in observed_positions]
    values = [mag[y, x] for x, y in pixel_coords]
    
    abs_values = [1 / abs(value) for value in values]
    predicted_flux_ratios_observed = [abs_values[i] / abs_values[green_index] for i in range(len(abs_values))]

    # Calculate RMS excluding the green image
    squared_diffs_pred = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_rms = np.sqrt(sum(squared_diffs_pred) / len(squared_diffs_pred))

    squared_diffs_obs = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios_observed, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_observed_rms = np.sqrt(sum(squared_diffs_obs) / len(squared_diffs_obs))

    return {
        'delta_rms': delta_rms,
        'individual_position_deltas': individual_distances,  # Delta RMS for each of the 4 positions
        'flux_ratio_differences': flux_ratio_differences,    # Absolute differences for 3 flux ratios
        'predicted_flux_ratios_rms': predicted_flux_ratios_rms,
        'predicted_flux_ratios_observed_rms': predicted_flux_ratios_observed_rms,
        'manual_chi2': manual_chi2
    }

# Function to extract chi^2 and lens models from optresult.dat file (following Code 1's approach exactly)
def extract_chi2_and_lens_profiles(optresult_path):
    chi2_value = None
    profiles_used = []
    sie_count = 0

    with open(optresult_path, 'r') as file:
        lines = file.readlines()

    found_chi2 = False
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
            found_chi2 = True
            profiles_used = []
            sie_count = 0
        elif found_chi2:
            if line.startswith("lens   sie"):
                profiles_used.append("SIE")
                sie_count += 1
            elif line.startswith("lens   pow"):
                profiles_used.append("POW")
            elif line.startswith("lens   anfw"):
                profiles_used.append("NFW")
            elif line.startswith("lens   pert"):
                profiles_used.append("Shear")

    if chi2_value is None:
        raise ValueError("No chi^2 value found in the file.")

    profiles_used = list(set(profiles_used))
    return chi2_value, profiles_used, sie_count

# Function to calculate free parameters based on lens profiles (identical to Code 1)
def calculate_free_parameters(profiles_used, sie_count):
    profile_params = {
        "SIE": 5,
        "POW": 6,
        "NFW": 6,
        "Shear": 5
    }
    total_params = sum(profile_params[profile] for profile in profiles_used)
    if sie_count == 2:
        total_params += 5
    return total_params

# Function to calculate BIC (Bayesian Information Criterion)
def calculate_bic(chi2, n_data_points, n_free_params):
    return chi2 + n_free_params * np.log(n_data_points)

# Function to compute BIC using manual chi² but following Code 1's approach for free parameters
def compute_bic_with_tracking(manual_chi2, optresult_path):
    # Use Code 1's approach: extract profiles from optresult.dat file
    glafic_chi2, profiles_used, sie_count = extract_chi2_and_lens_profiles(optresult_path)
    n_free_params = calculate_free_parameters(profiles_used, sie_count)
    
    # Properly adjust n_data_points based on constraint type
    if "PF" in optresult_path:
        n_data_points = 4 * 2 + 3  # positions + flux ratios
    else:
        n_data_points = 4 * 2  # positions only
    
    # Always use manual chi² for BIC calculation
    bic_value = calculate_bic(manual_chi2, n_data_points, n_free_params)
    
    return bic_value, glafic_chi2, n_data_points, n_free_params

# Main function to process multiple files
def process_files(input_file, output_files, fits_files, optresult_files, n):
    results = []
    latex_rows = []
    bics = []  # Store BIC values separately
    glafic_chi2_values = []  # Store glafic chi² for reference
    data_points_used = []  # Store number of data points used
    free_params_used = []  # Store number of free parameters used

    for output_file, fits_file, optresult_file in zip(output_files, fits_files, optresult_files):
        # Process output and fits files
        result = process_file_group(output_file, fits_file, input_file, n)
        results.append(result)
        
        # Calculate BIC using manual chi² but track both values
        bic, glafic_chi2, n_data_points, n_free_params = compute_bic_with_tracking(result['manual_chi2'], optresult_file)
        bics.append(bic)
        glafic_chi2_values.append(glafic_chi2)
        data_points_used.append(n_data_points)
        free_params_used.append(n_free_params)
        
        # Create LaTeX row with additional information
        model_name, constraint_name = determine_model_and_constraint(output_file)
        # Format individual position deltas and flux ratio differences for LaTeX
        pos_deltas_str = " & ".join([f"{delta:.3f}" for delta in result['individual_position_deltas']])
        flux_diffs_str = " & ".join([f"{diff:.3f}" for diff in result['flux_ratio_differences']])
        
        latex_row = f"{model_name} & {constraint_name} & {pos_deltas_str} & {result['delta_rms']:.1f} & {flux_diffs_str} & {result['predicted_flux_ratios_rms']:.2f} & {bic:.1f} \\\\"
        latex_rows.append(latex_row)
    
    # Combine results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results['bic'] = bics  # Add BIC values to the DataFrame
    df_results['glafic_chi2'] = glafic_chi2_values  # Add glafic chi² for reference
    df_results['n_data_points'] = data_points_used  # Add number of data points used
    df_results['n_free_params'] = free_params_used  # Add number of free parameters used
    
    return df_results, latex_rows

# Determine model and constraint names from the filename
def determine_model_and_constraint(file_name):
    model_map = {'S': 'SIE', 'P': 'POW', 'N': 'NFW'}
    
    base_name = os.path.basename(file_name)
    model_key = base_name[3]
    constraint_key = base_name[4:6] if base_name[4:6] in ['PF'] else base_name[4]
    
    model_name = model_map.get(model_key, '')
    if 'R' in base_name:
        model_name += ' + Shear'
    if 'G' in base_name:
        model_name += ' + G2'
    
    constraint_name = 'QSO Pos + FR' if constraint_key == 'PF' else 'QSO Pos'
    
    return model_name, constraint_name

# Example usage with filenames
Input_file = "SDSSJ1330/SPFC/Robs_point.dat"

Output_files = [
    "SDSSJ1330/SPC/outSP_point.dat",
    "SDSSJ1330/SPC/outSPR_point.dat",
    "SDSSJ1330/SPFC/outSPF_point.dat",
    "SDSSJ1330/SPFC/outSPFR_point.dat",
    "SDSSJ1330/PPC/outPP_point.dat",
    "SDSSJ1330/PPC/outPPR_point.dat",
    "SDSSJ1330/PPFC/outPPF_point.dat",
    "SDSSJ1330/PPFC/outPPFR_point.dat",
    "SDSSJ1330/NPC/outNP_point.dat",
    "SDSSJ1330/NPC/outNPR_point.dat",
    "SDSSJ1330/NPFC/outNPF_point.dat",
    "SDSSJ1330/NPFC/outNPFR_point.dat",
]

Fits_files = [
    "SDSSJ1330/SPC/outSP_lens.fits",
    "SDSSJ1330/SPC/outSPR_lens.fits",
    "SDSSJ1330/SPFC/outSPF_lens.fits",
    "SDSSJ1330/SPFC/outSPFR_lens.fits",
    "SDSSJ1330/PPC/outPP_lens.fits",
    "SDSSJ1330/PPC/outPPR_lens.fits",
    "SDSSJ1330/PPFC/outPPF_lens.fits",
    "SDSSJ1330/PPFC/outPPFR_lens.fits",
    "SDSSJ1330/NPC/outNP_lens.fits",
    "SDSSJ1330/NPC/outNPR_lens.fits",
    "SDSSJ1330/NPFC/outNPF_lens.fits",
    "SDSSJ1330/NPFC/outNPFR_lens.fits",
]

Optresult_files = [
    "SDSSJ1330/SPC/outSP_optresult.dat",
    "SDSSJ1330/SPC/outSPR_optresult.dat",
    "SDSSJ1330/SPFC/outSPF_optresult.dat",
    "SDSSJ1330/SPFC/outSPFR_optresult.dat",
    "SDSSJ1330/PPC/outPP_optresult.dat",
    "SDSSJ1330/PPC/outPPR_optresult.dat",
    "SDSSJ1330/PPFC/outPPF_optresult.dat",
    "SDSSJ1330/PPFC/outPPFR_optresult.dat",
    "SDSSJ1330/NPC/outNP_optresult.dat",
    "SDSSJ1330/NPC/outNPR_optresult.dat",
    "SDSSJ1330/NPFC/outNPF_optresult.dat",
    "SDSSJ1330/NPFC/outNPFR_optresult.dat",
]

n = 0.0025  # Example scale factor
results_df, latex_rows = process_files(Input_file, Output_files, Fits_files, Optresult_files, n)

# Print formatted results
for i, output_file in enumerate(Output_files):
    constraint_type = "PF" if "PF" in Optresult_files[i] else "P"
    print(f"Model: {output_file}")
    print(f"Constraint Type: {constraint_type}")
    print(f"Number of data points used: {results_df.iloc[i]['n_data_points']}")
    print(f"Number of free parameters: {results_df.iloc[i]['n_free_params']}")
    print(f"Delta RMS of Image Positions: {results_df.iloc[i]['delta_rms']:.3f}")
    
    # Print individual position deltas (4 positions)
    print(f"Individual Position Deltas (mas):")
    for j, delta in enumerate(results_df.iloc[i]['individual_position_deltas']):
        print(f"  Image {j+1}: {delta:.3f}")
    
    print(f"Delta RMS of flux ratios at the observed position: {results_df.iloc[i]['predicted_flux_ratios_observed_rms']:.3f}")
    print(f"Delta RMS of flux ratios at the predicted position: {results_df.iloc[i]['predicted_flux_ratios_rms']:.3f}")
    
    # Print absolute flux ratio differences (3 ratios, excluding normalization)
    print(f"Absolute Flux Ratio Differences:")
    flux_diff_indices = [0, 2, 3] if len(results_df.iloc[i]['flux_ratio_differences']) == 3 else range(len(results_df.iloc[i]['flux_ratio_differences']))
    for j, diff in enumerate(results_df.iloc[i]['flux_ratio_differences']):
        img_idx = flux_diff_indices[j] + 1
        print(f"  Image {img_idx}: {diff:.3f}")
    
    print(f"Manual Chi²: {results_df.iloc[i]['manual_chi2']:.3f}")
    if results_df.iloc[i]['glafic_chi2'] is not None:
        print(f"Glafic Chi² (final, reference): {results_df.iloc[i]['glafic_chi2']:.3f}")
        print(f"Chi² Difference (Manual - Glafic): {results_df.iloc[i]['manual_chi2'] - results_df.iloc[i]['glafic_chi2']:.3f}")
    else:
        print(f"Glafic Chi² (reference): Not found")
    print(f"BIC (using manual Chi²): {results_df.iloc[i]['bic']:.3f}")
    
    # Manual verification of BIC calculation
    manual_bic_check = results_df.iloc[i]['manual_chi2'] + results_df.iloc[i]['n_free_params'] * np.log(results_df.iloc[i]['n_data_points'])
    print(f"Manual BIC verification: {results_df.iloc[i]['manual_chi2']:.3f} + {results_df.iloc[i]['n_free_params']} × ln({results_df.iloc[i]['n_data_points']}) = {manual_bic_check:.3f}")
    print()

# Print LaTeX-formatted rows
print("LaTeX Table Rows:")
print("Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC")
for row in latex_rows:
    print(row)
# Out:
# Model: SDSSJ1330/SPC/outSP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 5
# Delta RMS of Image Positions: 32.203
# Individual Position Deltas (mas):
#   Image 1: 23.211
#   Image 2: 18.700
#   Image 3: 39.086
#   Image 4: 41.616
# Delta RMS of flux ratios at the observed position: 0.651
# Delta RMS of flux ratios at the predicted position: 0.122
# Absolute Flux Ratio Differences:
#   Image 1: 0.181
#   Image 3: 0.082
#   Image 4: 0.074
# Manual Chi²: 196.709
# Glafic Chi² (final, reference): 173.491
# Chi² Difference (Manual - Glafic): 23.218
# BIC (using manual Chi²): 207.107
# Manual BIC verification: 196.709 + 5 × ln(8) = 207.107
#
# Model: SDSSJ1330/SPC/outSPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 0.887
# Individual Position Deltas (mas):
#   Image 1: 0.500
#   Image 2: 1.000
#   Image 3: 0.640
#   Image 4: 1.221
# Delta RMS of flux ratios at the observed position: 0.083
# Delta RMS of flux ratios at the predicted position: 0.079
# Absolute Flux Ratio Differences:
#   Image 1: 0.124
#   Image 3: 0.031
#   Image 4: 0.049
# Manual Chi²: 13.052
# Glafic Chi² (final, reference): 1.226
# Chi² Difference (Manual - Glafic): 11.826
# BIC (using manual Chi²): 33.846
# Manual BIC verification: 13.052 + 10 × ln(8) = 33.846
#
# Model: SDSSJ1330/SPFC/outSPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 5
# Delta RMS of Image Positions: 32.222
# Individual Position Deltas (mas):
#   Image 1: 23.377
#   Image 2: 18.777
#   Image 3: 39.061
#   Image 4: 41.572
# Delta RMS of flux ratios at the observed position: 0.627
# Delta RMS of flux ratios at the predicted position: 0.121
# Absolute Flux Ratio Differences:
#   Image 1: 0.180
#   Image 3: 0.078
#   Image 4: 0.073
# Manual Chi²: 196.126
# Glafic Chi² (final, reference): 198.213
# Chi² Difference (Manual - Glafic): -2.086
# BIC (using manual Chi²): 208.116
# Manual BIC verification: 196.126 + 5 × ln(11) = 208.116
#
# Model: SDSSJ1330/SPFC/outSPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 3.112
# Individual Position Deltas (mas):
#   Image 1: 3.705
#   Image 2: 4.785
#   Image 3: 0.707
#   Image 4: 1.265
# Delta RMS of flux ratios at the observed position: 0.059
# Delta RMS of flux ratios at the predicted position: 0.058
# Absolute Flux Ratio Differences:
#   Image 1: 0.078
#   Image 3: 0.041
#   Image 4: 0.048
# Manual Chi²: 9.048
# Glafic Chi² (final, reference): 7.994
# Chi² Difference (Manual - Glafic): 1.054
# BIC (using manual Chi²): 33.027
# Manual BIC verification: 9.048 + 10 × ln(11) = 33.027
#
# Model: SDSSJ1330/PPC/outPP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 32.107
# Individual Position Deltas (mas):
#   Image 1: 18.413
#   Image 2: 23.648
#   Image 3: 38.996
#   Image 4: 41.284
# Delta RMS of flux ratios at the observed position: 1.185
# Delta RMS of flux ratios at the predicted position: 0.159
# Absolute Flux Ratio Differences:
#   Image 1: 0.253
#   Image 3: 0.096
#   Image 4: 0.055
# Manual Chi²: 214.074
# Glafic Chi² (final, reference): 175.813
# Chi² Difference (Manual - Glafic): 38.261
# BIC (using manual Chi²): 226.551
# Manual BIC verification: 214.074 + 6 × ln(8) = 226.551
#
# Model: SDSSJ1330/PPC/outPPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 1.157
# Individual Position Deltas (mas):
#   Image 1: 0.671
#   Image 2: 0.608
#   Image 3: 1.063
#   Image 4: 1.844
# Delta RMS of flux ratios at the observed position: 0.124
# Delta RMS of flux ratios at the predicted position: 0.120
# Absolute Flux Ratio Differences:
#   Image 1: 0.204
#   Image 3: 0.025
#   Image 4: 0.032
# Manual Chi²: 27.740
# Glafic Chi² (final, reference): 2.837
# Chi² Difference (Manual - Glafic): 24.904
# BIC (using manual Chi²): 50.614
# Manual BIC verification: 27.740 + 11 × ln(8) = 50.614
#
# Model: SDSSJ1330/PPFC/outPPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 32.011
# Individual Position Deltas (mas):
#   Image 1: 19.220
#   Image 2: 23.303
#   Image 3: 38.472
#   Image 4: 41.306
# Delta RMS of flux ratios at the observed position: 1.150
# Delta RMS of flux ratios at the predicted position: 0.159
# Absolute Flux Ratio Differences:
#   Image 1: 0.253
#   Image 3: 0.094
#   Image 4: 0.052
# Manual Chi²: 212.421
# Glafic Chi² (final, reference): 209.357
# Chi² Difference (Manual - Glafic): 3.064
# BIC (using manual Chi²): 226.808
# Manual BIC verification: 212.421 + 6 × ln(11) = 226.808
#
# Model: SDSSJ1330/PPFC/outPPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 4.301
# Individual Position Deltas (mas):
#   Image 1: 4.589
#   Image 2: 6.772
#   Image 3: 1.703
#   Image 4: 2.040
# Delta RMS of flux ratios at the observed position: 0.084
# Delta RMS of flux ratios at the predicted position: 0.091
# Absolute Flux Ratio Differences:
#   Image 1: 0.154
#   Image 3: 0.015
#   Image 4: 0.027
# Manual Chi²: 18.774
# Glafic Chi² (final, reference): 15.740
# Chi² Difference (Manual - Glafic): 3.034
# BIC (using manual Chi²): 45.151
# Manual BIC verification: 18.774 + 11 × ln(11) = 45.151
#
# Model: SDSSJ1330/NPC/outNP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 30.875
# Individual Position Deltas (mas):
#   Image 1: 19.902
#   Image 2: 19.421
#   Image 3: 38.610
#   Image 4: 39.357
# Delta RMS of flux ratios at the observed position: 0.717
# Delta RMS of flux ratios at the predicted position: 0.149
# Absolute Flux Ratio Differences:
#   Image 1: 0.234
#   Image 3: 0.097
#   Image 4: 0.048
# Manual Chi²: 195.094
# Glafic Chi² (final, reference): 156.128
# Chi² Difference (Manual - Glafic): 38.966
# BIC (using manual Chi²): 207.570
# Manual BIC verification: 195.094 + 6 × ln(8) = 207.570
#
# Model: SDSSJ1330/NPC/outNPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 1.049
# Individual Position Deltas (mas):
#   Image 1: 0.510
#   Image 2: 0.707
#   Image 3: 0.860
#   Image 4: 1.703
# Delta RMS of flux ratios at the observed position: 0.116
# Delta RMS of flux ratios at the predicted position: 0.111
# Absolute Flux Ratio Differences:
#   Image 1: 0.189
#   Image 3: 0.017
#   Image 4: 0.038
# Manual Chi²: 24.162
# Glafic Chi² (final, reference): 2.196
# Chi² Difference (Manual - Glafic): 21.966
# BIC (using manual Chi²): 47.036
# Manual BIC verification: 24.162 + 11 × ln(8) = 47.036
#
# Model: SDSSJ1330/NPFC/outNPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 31.363
# Individual Position Deltas (mas):
#   Image 1: 27.202
#   Image 2: 12.879
#   Image 3: 37.827
#   Image 4: 39.974
# Delta RMS of flux ratios at the observed position: 0.382
# Delta RMS of flux ratios at the predicted position: 0.095
# Absolute Flux Ratio Differences:
#   Image 1: 0.128
#   Image 3: 0.073
#   Image 4: 0.073
# Manual Chi²: 176.965
# Glafic Chi² (final, reference): 176.601
# Chi² Difference (Manual - Glafic): 0.364
# BIC (using manual Chi²): 191.353
# Manual BIC verification: 176.965 + 6 × ln(11) = 191.353
#
# Model: SDSSJ1330/NPFC/outNPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 4.035
# Individual Position Deltas (mas):
#   Image 1: 4.357
#   Image 2: 6.429
#   Image 3: 1.503
#   Image 4: 1.600
# Delta RMS of flux ratios at the observed position: 0.072
# Delta RMS of flux ratios at the predicted position: 0.079
# Absolute Flux Ratio Differences:
#   Image 1: 0.132
#   Image 3: 0.000
#   Image 4: 0.038
# Manual Chi²: 15.012
# Glafic Chi² (final, reference): 12.841
# Chi² Difference (Manual - Glafic): 2.170
# BIC (using manual Chi²): 41.389
# Manual BIC verification: 15.012 + 11 × ln(11) = 41.389
#
# LaTeX Table Rows:
# Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC
# SIE & QSO Pos & 23.211 & 18.700 & 39.086 & 41.616 & 32.2 & 0.181 & 0.082 & 0.074 & 0.12 & 207.1 \\
# SIE + Shear & QSO Pos & 0.500 & 1.000 & 0.640 & 1.221 & 0.9 & 0.124 & 0.031 & 0.049 & 0.08 & 33.8 \\
# SIE & QSO Pos + FR & 23.377 & 18.777 & 39.061 & 41.572 & 32.2 & 0.180 & 0.078 & 0.073 & 0.12 & 208.1 \\
# SIE + Shear & QSO Pos + FR & 3.705 & 4.785 & 0.707 & 1.265 & 3.1 & 0.078 & 0.041 & 0.048 & 0.06 & 33.0 \\
# POW & QSO Pos & 18.413 & 23.648 & 38.996 & 41.284 & 32.1 & 0.253 & 0.096 & 0.055 & 0.16 & 226.6 \\
# POW + Shear & QSO Pos & 0.671 & 0.608 & 1.063 & 1.844 & 1.2 & 0.204 & 0.025 & 0.032 & 0.12 & 50.6 \\
# POW & QSO Pos + FR & 19.220 & 23.303 & 38.472 & 41.306 & 32.0 & 0.253 & 0.094 & 0.052 & 0.16 & 226.8 \\
# POW + Shear & QSO Pos + FR & 4.589 & 6.772 & 1.703 & 2.040 & 4.3 & 0.154 & 0.015 & 0.027 & 0.09 & 45.2 \\
# NFW & QSO Pos & 19.902 & 19.421 & 38.610 & 39.357 & 30.9 & 0.234 & 0.097 & 0.048 & 0.15 & 207.6 \\
# NFW + Shear & QSO Pos & 0.510 & 0.707 & 0.860 & 1.703 & 1.0 & 0.189 & 0.017 & 0.038 & 0.11 & 47.0 \\
# NFW & QSO Pos + FR & 27.202 & 12.879 & 37.827 & 39.974 & 31.4 & 0.128 & 0.073 & 0.073 & 0.10 & 191.4 \\
# NFW + Shear & QSO Pos + FR & 4.357 & 6.429 & 1.503 & 1.600 & 4.0 & 0.132 & 0.000 & 0.038 & 0.08 & 41.4 \\

# %%
# NEW LATEX AUTOMATED CODE WITH MANUAL CHI^2 CALCULATION with individual position delta RMS and flux ratio differences
# WFI2026
import numpy as np
import pandas as pd
from astropy.io import fits
import os

# Function to calculate distance
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Function to read observed positions, flux ratios, and uncertainties
def read_observed_positions(input_file):
    observed_positions = []
    observed_flux_ratios = []
    position_uncertainties = []
    flux_uncertainties = []
    with open(input_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            columns = line.split()
            if len(columns) >= 5:
                x1 = float(columns[0])
                y1 = float(columns[1])
                flux_ratio = float(columns[2])
                pos_err = float(columns[3])
                flux_err = float(columns[4])
                observed_positions.append((x1, y1))
                observed_flux_ratios.append(flux_ratio)
                position_uncertainties.append(pos_err)
                flux_uncertainties.append(flux_err)
    return observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties

# Function to read predicted positions and magnifications
def read_predicted_positions(output_file):
    predicted_positions = []
    predicted_magnifications = []
    with open(output_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            if line.startswith("#"):
                continue
            columns = line.split()
            if len(columns) >= 3:
                x2 = float(columns[0])
                y2 = float(columns[1])
                M2 = abs(float(columns[2]))
                predicted_positions.append((x2, y2))
                predicted_magnifications.append(M2)
    return predicted_positions, predicted_magnifications

# Function to pair predicted and observed positions
def pair_positions(observed_positions, predicted_positions, predicted_magnifications):
    paired_positions = []
    for observed_position in observed_positions:
        min_distance = float('inf')
        closest_index = None
        for i, predicted_position in enumerate(predicted_positions):
            distance = calculate_distance(*observed_position, *predicted_position)
            if distance < min_distance:
                min_distance = distance
                closest_index = i
        paired_positions.append((observed_position, predicted_positions[closest_index], predicted_magnifications[closest_index]))
    return paired_positions

# Function to calculate manual chi² with proper uncertainties
def calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties, 
                         predicted_positions, predicted_magnifications, green_index=1):
    # Pair positions
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Calculate predicted flux ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]
    
    chi2 = 0.0
    
    # Position contributions to chi²
    for i, (observed, predicted, _) in enumerate(paired_positions):
        dx = observed[0] - predicted[0]
        dy = observed[1] - predicted[1]
        pos_err = position_uncertainties[i]
        chi2 += (dx/pos_err)**2 + (dy/pos_err)**2
    
    # Flux ratio contributions to chi² (excluding the normalization image)
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_err = flux_uncertainties[i]
            chi2 += ((pred_flux - obs_flux)/flux_err)**2
    
    return chi2

# Function to extract the final chi^2 from optresult.dat file
def extract_glafic_chi2(optresult_path):
    chi2_value = None
    with open(optresult_path, 'r') as file:
        lines = file.readlines()
    
    # Find the last occurrence of chi^2 (final/best result)
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
    
    return chi2_value

# Function to process file group
def process_file_group(output_file, fits_file, input_file, n):
    observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties = read_observed_positions(input_file)
    predicted_positions, predicted_magnifications = read_predicted_positions(output_file)
    
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Calculate Delta RMS of Image Positions correctly
    squared_distances = 0.0
    individual_distances = []  # Store individual distances for each image
    for observed, predicted, _ in paired_positions:
        distance = calculate_distance(*observed, *predicted)
        individual_distances.append(distance * 1000)  # Convert to mas
        squared_distances += distance ** 2  # Summing squared distances
    
    mean_squared_distances = squared_distances / len(paired_positions)
    delta_rms = np.sqrt(mean_squared_distances)  # Taking square root of the mean of squared distances
    delta_rms *= 1000  # Convert to mas
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Determine the index of the "Green Image"
    green_index = 0  # CHOOSE WHICH IMAGE TO NORMALISE BY HERE !!!!!!!!!!!!!!!!!!!!!!!

    # Predicted Flux Ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]

    # Calculate absolute differences between predicted and observed flux ratios (excluding normalization image)
    flux_ratio_differences = []
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_ratio_differences.append(abs(pred_flux - obs_flux))

    # Calculate manual chi²
    manual_chi2 = calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties,
                                       predicted_positions, predicted_magnifications, green_index)

    with fits.open(fits_file) as hdul:
        mag = hdul[0].data[6]
    
    pixel_coords = [(int((x + mag.shape[1] // 2 * n) / n), int((y + mag.shape[0] // 2 * n) / n)) for x, y in observed_positions]
    values = [mag[y, x] for x, y in pixel_coords]
    
    abs_values = [1 / abs(value) for value in values]
    predicted_flux_ratios_observed = [abs_values[i] / abs_values[green_index] for i in range(len(abs_values))]

    # Calculate RMS excluding the green image
    squared_diffs_pred = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_rms = np.sqrt(sum(squared_diffs_pred) / len(squared_diffs_pred))

    squared_diffs_obs = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios_observed, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_observed_rms = np.sqrt(sum(squared_diffs_obs) / len(squared_diffs_obs))

    return {
        'delta_rms': delta_rms,
        'individual_position_deltas': individual_distances,  # Delta RMS for each of the 4 positions
        'flux_ratio_differences': flux_ratio_differences,    # Absolute differences for 3 flux ratios
        'predicted_flux_ratios_rms': predicted_flux_ratios_rms,
        'predicted_flux_ratios_observed_rms': predicted_flux_ratios_observed_rms,
        'manual_chi2': manual_chi2
    }

# Function to extract chi^2 and lens models from optresult.dat file (following Code 1's approach exactly)
def extract_chi2_and_lens_profiles(optresult_path):
    chi2_value = None
    profiles_used = []
    sie_count = 0

    with open(optresult_path, 'r') as file:
        lines = file.readlines()

    found_chi2 = False
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
            found_chi2 = True
            profiles_used = []
            sie_count = 0
        elif found_chi2:
            if line.startswith("lens   sie"):
                profiles_used.append("SIE")
                sie_count += 1
            elif line.startswith("lens   pow"):
                profiles_used.append("POW")
            elif line.startswith("lens   anfw"):
                profiles_used.append("NFW")
            elif line.startswith("lens   pert"):
                profiles_used.append("Shear")

    if chi2_value is None:
        raise ValueError("No chi^2 value found in the file.")

    profiles_used = list(set(profiles_used))
    return chi2_value, profiles_used, sie_count

# Function to calculate free parameters based on lens profiles (identical to Code 1)
def calculate_free_parameters(profiles_used, sie_count):
    profile_params = {
        "SIE": 5,
        "POW": 6,
        "NFW": 6,
        "Shear": 5
    }
    total_params = sum(profile_params[profile] for profile in profiles_used)
    if sie_count == 2:
        total_params += 5
    return total_params

# Function to calculate BIC (Bayesian Information Criterion)
def calculate_bic(chi2, n_data_points, n_free_params):
    return chi2 + n_free_params * np.log(n_data_points)

# Function to compute BIC using manual chi² but following Code 1's approach for free parameters
def compute_bic_with_tracking(manual_chi2, optresult_path):
    # Use Code 1's approach: extract profiles from optresult.dat file
    glafic_chi2, profiles_used, sie_count = extract_chi2_and_lens_profiles(optresult_path)
    n_free_params = calculate_free_parameters(profiles_used, sie_count)
    
    # Properly adjust n_data_points based on constraint type
    if "PF" in optresult_path:
        n_data_points = 4 * 2 + 3  # positions + flux ratios
    else:
        n_data_points = 4 * 2  # positions only
    
    # Always use manual chi² for BIC calculation
    bic_value = calculate_bic(manual_chi2, n_data_points, n_free_params)
    
    return bic_value, glafic_chi2, n_data_points, n_free_params

# Main function to process multiple files
def process_files(input_file, output_files, fits_files, optresult_files, n):
    results = []
    latex_rows = []
    bics = []  # Store BIC values separately
    glafic_chi2_values = []  # Store glafic chi² for reference
    data_points_used = []  # Store number of data points used
    free_params_used = []  # Store number of free parameters used

    for output_file, fits_file, optresult_file in zip(output_files, fits_files, optresult_files):
        # Process output and fits files
        result = process_file_group(output_file, fits_file, input_file, n)
        results.append(result)
        
        # Calculate BIC using manual chi² but track both values
        bic, glafic_chi2, n_data_points, n_free_params = compute_bic_with_tracking(result['manual_chi2'], optresult_file)
        bics.append(bic)
        glafic_chi2_values.append(glafic_chi2)
        data_points_used.append(n_data_points)
        free_params_used.append(n_free_params)
        
        # Create LaTeX row with additional information
        model_name, constraint_name = determine_model_and_constraint(output_file)
        # Format individual position deltas and flux ratio differences for LaTeX
        pos_deltas_str = " & ".join([f"{delta:.3f}" for delta in result['individual_position_deltas']])
        flux_diffs_str = " & ".join([f"{diff:.3f}" for diff in result['flux_ratio_differences']])
        
        latex_row = f"{model_name} & {constraint_name} & {pos_deltas_str} & {result['delta_rms']:.1f} & {flux_diffs_str} & {result['predicted_flux_ratios_rms']:.2f} & {bic:.1f} \\\\"
        latex_rows.append(latex_row)
    
    # Combine results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results['bic'] = bics  # Add BIC values to the DataFrame
    df_results['glafic_chi2'] = glafic_chi2_values  # Add glafic chi² for reference
    df_results['n_data_points'] = data_points_used  # Add number of data points used
    df_results['n_free_params'] = free_params_used  # Add number of free parameters used
    
    return df_results, latex_rows

# Determine model and constraint names from the filename
def determine_model_and_constraint(file_name):
    model_map = {'S': 'SIE', 'P': 'POW', 'N': 'NFW'}
    
    base_name = os.path.basename(file_name)
    model_key = base_name[3]
    constraint_key = base_name[4:6] if base_name[4:6] in ['PF'] else base_name[4]
    
    model_name = model_map.get(model_key, '')
    if 'R' in base_name:
        model_name += ' + Shear'
    if 'G' in base_name:
        model_name += ' + G2'
    
    constraint_name = 'QSO Pos + FR' if constraint_key == 'PF' else 'QSO Pos'
    
    return model_name, constraint_name

# Example usage with filenames
Input_file = "WFI2026/SPFC/Wobs_point.dat"

Output_files = [
    "WFI2026/SPC/outSP_point.dat",
    "WFI2026/SPC/outSPR_point.dat",
    "WFI2026/SPFC/outSPF_point.dat",
    "WFI2026/SPFC/outSPFR_point.dat",
    "WFI2026/PPC/outPP_point.dat",
    "WFI2026/PPC/outPPR_point.dat",
    "WFI2026/PPFC/outPPF_point.dat",
    "WFI2026/PPFC/outPPFR_point.dat",
    "WFI2026/NPC/outNP_point.dat",
    "WFI2026/NPC/outNPR_point.dat",
    "WFI2026/NPFC/outNPF_point.dat",
    "WFI2026/NPFC/outNPFR_point.dat",
]

Fits_files = [
    "WFI2026/SPC/outSP_lens.fits",
    "WFI2026/SPC/outSPR_lens.fits",
    "WFI2026/SPFC/outSPF_lens.fits",
    "WFI2026/SPFC/outSPFR_lens.fits",
    "WFI2026/PPC/outPP_lens.fits",
    "WFI2026/PPC/outPPR_lens.fits",
    "WFI2026/PPFC/outPPF_lens.fits",
    "WFI2026/PPFC/outPPFR_lens.fits",
    "WFI2026/NPC/outNP_lens.fits",
    "WFI2026/NPC/outNPR_lens.fits",
    "WFI2026/NPFC/outNPF_lens.fits",
    "WFI2026/NPFC/outNPFR_lens.fits",
]

Optresult_files = [
    "WFI2026/SPC/outSP_optresult.dat",
    "WFI2026/SPC/outSPR_optresult.dat",
    "WFI2026/SPFC/outSPF_optresult.dat",
    "WFI2026/SPFC/outSPFR_optresult.dat",
    "WFI2026/PPC/outPP_optresult.dat",
    "WFI2026/PPC/outPPR_optresult.dat",
    "WFI2026/PPFC/outPPF_optresult.dat",
    "WFI2026/PPFC/outPPFR_optresult.dat",
    "WFI2026/NPC/outNP_optresult.dat",
    "WFI2026/NPC/outNPR_optresult.dat",
    "WFI2026/NPFC/outNPF_optresult.dat",
    "WFI2026/NPFC/outNPFR_optresult.dat",
]

n = 0.0025  # Example scale factor
results_df, latex_rows = process_files(Input_file, Output_files, Fits_files, Optresult_files, n)

# Print formatted results
for i, output_file in enumerate(Output_files):
    constraint_type = "PF" if "PF" in Optresult_files[i] else "P"
    print(f"Model: {output_file}")
    print(f"Constraint Type: {constraint_type}")
    print(f"Number of data points used: {results_df.iloc[i]['n_data_points']}")
    print(f"Number of free parameters: {results_df.iloc[i]['n_free_params']}")
    print(f"Delta RMS of Image Positions: {results_df.iloc[i]['delta_rms']:.3f}")
    
    # Print individual position deltas (4 positions)
    print(f"Individual Position Deltas (mas):")
    for j, delta in enumerate(results_df.iloc[i]['individual_position_deltas']):
        print(f"  Image {j+1}: {delta:.3f}")
    
    print(f"Delta RMS of flux ratios at the observed position: {results_df.iloc[i]['predicted_flux_ratios_observed_rms']:.3f}")
    print(f"Delta RMS of flux ratios at the predicted position: {results_df.iloc[i]['predicted_flux_ratios_rms']:.3f}")
    
    # Print absolute flux ratio differences (3 ratios, excluding normalization)
    print(f"Absolute Flux Ratio Differences:")
    flux_diff_indices = [0, 2, 3] if len(results_df.iloc[i]['flux_ratio_differences']) == 3 else range(len(results_df.iloc[i]['flux_ratio_differences']))
    for j, diff in enumerate(results_df.iloc[i]['flux_ratio_differences']):
        img_idx = flux_diff_indices[j] + 1
        print(f"  Image {img_idx}: {diff:.3f}")
    
    print(f"Manual Chi²: {results_df.iloc[i]['manual_chi2']:.3f}")
    if results_df.iloc[i]['glafic_chi2'] is not None:
        print(f"Glafic Chi² (final, reference): {results_df.iloc[i]['glafic_chi2']:.3f}")
        print(f"Chi² Difference (Manual - Glafic): {results_df.iloc[i]['manual_chi2'] - results_df.iloc[i]['glafic_chi2']:.3f}")
    else:
        print(f"Glafic Chi² (reference): Not found")
    print(f"BIC (using manual Chi²): {results_df.iloc[i]['bic']:.3f}")
    
    # Manual verification of BIC calculation
    manual_bic_check = results_df.iloc[i]['manual_chi2'] + results_df.iloc[i]['n_free_params'] * np.log(results_df.iloc[i]['n_data_points'])
    print(f"Manual BIC verification: {results_df.iloc[i]['manual_chi2']:.3f} + {results_df.iloc[i]['n_free_params']} × ln({results_df.iloc[i]['n_data_points']}) = {manual_bic_check:.3f}")
    print()

# Print LaTeX-formatted rows
print("LaTeX Table Rows:")
print("Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC")
for row in latex_rows:
    print(row)
# Out:
# Model: WFI2026/SPC/outSP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 5
# Delta RMS of Image Positions: 15.162
# Individual Position Deltas (mas):
#   Image 1: 8.828
#   Image 2: 9.851
#   Image 3: 18.407
#   Image 4: 20.143
# Delta RMS of flux ratios at the observed position: 0.104
# Delta RMS of flux ratios at the predicted position: 0.034
# Absolute Flux Ratio Differences:
#   Image 1: 0.034
#   Image 3: 0.027
#   Image 4: 0.040
# Manual Chi²: 57.245
# Glafic Chi² (final, reference): 68.034
# Chi² Difference (Manual - Glafic): -10.790
# BIC (using manual Chi²): 67.642
# Manual BIC verification: 57.245 + 5 × ln(8) = 67.642
#
# Model: WFI2026/SPC/outSPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 5.065
# Individual Position Deltas (mas):
#   Image 1: 3.342
#   Image 2: 7.159
#   Image 3: 2.983
#   Image 4: 5.595
# Delta RMS of flux ratios at the observed position: 0.042
# Delta RMS of flux ratios at the predicted position: 0.034
# Absolute Flux Ratio Differences:
#   Image 1: 0.055
#   Image 3: 0.002
#   Image 4: 0.020
# Manual Chi²: 15.602
# Glafic Chi² (final, reference): 31.125
# Chi² Difference (Manual - Glafic): -15.524
# BIC (using manual Chi²): 36.396
# Manual BIC verification: 15.602 + 10 × ln(8) = 36.396
#
# Model: WFI2026/SPFC/outSPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 5
# Delta RMS of Image Positions: 16.351
# Individual Position Deltas (mas):
#   Image 1: 10.179
#   Image 2: 12.369
#   Image 3: 18.333
#   Image 4: 21.834
# Delta RMS of flux ratios at the observed position: 0.107
# Delta RMS of flux ratios at the predicted position: 0.030
# Absolute Flux Ratio Differences:
#   Image 1: 0.034
#   Image 3: 0.028
#   Image 4: 0.029
# Manual Chi²: 56.241
# Glafic Chi² (final, reference): 78.586
# Chi² Difference (Manual - Glafic): -22.345
# BIC (using manual Chi²): 68.231
# Manual BIC verification: 56.241 + 5 × ln(11) = 68.231
#
# Model: WFI2026/SPFC/outSPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 3.992
# Individual Position Deltas (mas):
#   Image 1: 1.530
#   Image 2: 2.563
#   Image 3: 4.837
#   Image 4: 5.608
# Delta RMS of flux ratios at the observed position: 0.009
# Delta RMS of flux ratios at the predicted position: 0.008
# Absolute Flux Ratio Differences:
#   Image 1: 0.011
#   Image 3: 0.004
#   Image 4: 0.007
# Manual Chi²: 3.436
# Glafic Chi² (final, reference): 34.124
# Chi² Difference (Manual - Glafic): -30.688
# BIC (using manual Chi²): 27.415
# Manual BIC verification: 3.436 + 10 × ln(11) = 27.415
#
# Model: WFI2026/PPC/outPP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 11.098
# Individual Position Deltas (mas):
#   Image 1: 1.476
#   Image 2: 8.807
#   Image 3: 14.000
#   Image 4: 14.728
# Delta RMS of flux ratios at the observed position: 0.110
# Delta RMS of flux ratios at the predicted position: 0.038
# Absolute Flux Ratio Differences:
#   Image 1: 0.052
#   Image 3: 0.039
#   Image 4: 0.002
# Manual Chi²: 30.414
# Glafic Chi² (final, reference): 56.204
# Chi² Difference (Manual - Glafic): -25.791
# BIC (using manual Chi²): 42.890
# Manual BIC verification: 30.414 + 6 × ln(8) = 42.890
#
# Model: WFI2026/PPC/outPPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 5.447
# Individual Position Deltas (mas):
#   Image 1: 3.640
#   Image 2: 7.829
#   Image 3: 2.961
#   Image 4: 5.948
# Delta RMS of flux ratios at the observed position: 0.033
# Delta RMS of flux ratios at the predicted position: 0.027
# Absolute Flux Ratio Differences:
#   Image 1: 0.031
#   Image 3: 0.025
#   Image 4: 0.025
# Manual Chi²: 14.736
# Glafic Chi² (final, reference): 33.472
# Chi² Difference (Manual - Glafic): -18.736
# BIC (using manual Chi²): 37.610
# Manual BIC verification: 14.736 + 11 × ln(8) = 37.610
#
# Model: WFI2026/PPFC/outPPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 11.391
# Individual Position Deltas (mas):
#   Image 1: 2.154
#   Image 2: 11.045
#   Image 3: 13.600
#   Image 4: 14.401
# Delta RMS of flux ratios at the observed position: 0.101
# Delta RMS of flux ratios at the predicted position: 0.034
# Absolute Flux Ratio Differences:
#   Image 1: 0.048
#   Image 3: 0.033
#   Image 4: 0.005
# Manual Chi²: 29.491
# Glafic Chi² (final, reference): 64.402
# Chi² Difference (Manual - Glafic): -34.911
# BIC (using manual Chi²): 43.879
# Manual BIC verification: 29.491 + 6 × ln(11) = 43.879
#
# Model: WFI2026/PPFC/outPPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 4.023
# Individual Position Deltas (mas):
#   Image 1: 1.432
#   Image 2: 3.036
#   Image 3: 4.727
#   Image 4: 5.580
# Delta RMS of flux ratios at the observed position: 0.011
# Delta RMS of flux ratios at the predicted position: 0.011
# Absolute Flux Ratio Differences:
#   Image 1: 0.011
#   Image 3: 0.013
#   Image 4: 0.009
# Manual Chi²: 4.129
# Glafic Chi² (final, reference): 35.530
# Chi² Difference (Manual - Glafic): -31.401
# BIC (using manual Chi²): 30.506
# Manual BIC verification: 4.129 + 11 × ln(11) = 30.506
#
# Model: WFI2026/NPC/outNP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 11.604
# Individual Position Deltas (mas):
#   Image 1: 5.247
#   Image 2: 7.382
#   Image 3: 14.603
#   Image 4: 15.600
# Delta RMS of flux ratios at the observed position: 0.107
# Delta RMS of flux ratios at the predicted position: 0.040
# Absolute Flux Ratio Differences:
#   Image 1: 0.037
#   Image 3: 0.057
#   Image 4: 0.012
# Manual Chi²: 34.372
# Glafic Chi² (final, reference): 59.878
# Chi² Difference (Manual - Glafic): -25.506
# BIC (using manual Chi²): 46.849
# Manual BIC verification: 34.372 + 6 × ln(8) = 46.849
#
# Model: WFI2026/NPC/outNPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 5.221
# Individual Position Deltas (mas):
#   Image 1: 2.759
#   Image 2: 7.424
#   Image 3: 2.864
#   Image 4: 6.174
# Delta RMS of flux ratios at the observed position: 0.031
# Delta RMS of flux ratios at the predicted position: 0.028
# Absolute Flux Ratio Differences:
#   Image 1: 0.006
#   Image 3: 0.033
#   Image 4: 0.034
# Manual Chi²: 18.954
# Glafic Chi² (final, reference): 35.460
# Chi² Difference (Manual - Glafic): -16.506
# BIC (using manual Chi²): 41.828
# Manual BIC verification: 18.954 + 11 × ln(8) = 41.828
#
# Model: WFI2026/NPFC/outNPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 13.411
# Individual Position Deltas (mas):
#   Image 1: 7.513
#   Image 2: 10.640
#   Image 3: 16.200
#   Image 4: 16.950
# Delta RMS of flux ratios at the observed position: 0.095
# Delta RMS of flux ratios at the predicted position: 0.026
# Absolute Flux Ratio Differences:
#   Image 1: 0.005
#   Image 3: 0.044
#   Image 4: 0.006
# Manual Chi²: 33.994
# Glafic Chi² (final, reference): 72.275
# Chi² Difference (Manual - Glafic): -38.281
# BIC (using manual Chi²): 48.381
# Manual BIC verification: 33.994 + 6 × ln(11) = 48.381
#
# Model: WFI2026/NPFC/outNPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 4.100
# Individual Position Deltas (mas):
#   Image 1: 1.581
#   Image 2: 3.534
#   Image 3: 4.653
#   Image 4: 5.532
# Delta RMS of flux ratios at the observed position: 0.010
# Delta RMS of flux ratios at the predicted position: 0.008
# Absolute Flux Ratio Differences:
#   Image 1: 0.010
#   Image 3: 0.004
#   Image 4: 0.007
# Manual Chi²: 3.546
# Glafic Chi² (final, reference): 34.105
# Chi² Difference (Manual - Glafic): -30.560
# BIC (using manual Chi²): 29.922
# Manual BIC verification: 3.546 + 11 × ln(11) = 29.922
#
# LaTeX Table Rows:
# Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC
# SIE & QSO Pos & 8.828 & 9.851 & 18.407 & 20.143 & 15.2 & 0.034 & 0.027 & 0.040 & 0.03 & 67.6 \\
# SIE + Shear & QSO Pos & 3.342 & 7.159 & 2.983 & 5.595 & 5.1 & 0.055 & 0.002 & 0.020 & 0.03 & 36.4 \\
# SIE & QSO Pos + FR & 10.179 & 12.369 & 18.333 & 21.834 & 16.4 & 0.034 & 0.028 & 0.029 & 0.03 & 68.2 \\
# SIE + Shear & QSO Pos + FR & 1.530 & 2.563 & 4.837 & 5.608 & 4.0 & 0.011 & 0.004 & 0.007 & 0.01 & 27.4 \\
# POW & QSO Pos & 1.476 & 8.807 & 14.000 & 14.728 & 11.1 & 0.052 & 0.039 & 0.002 & 0.04 & 42.9 \\
# POW + Shear & QSO Pos & 3.640 & 7.829 & 2.961 & 5.948 & 5.4 & 0.031 & 0.025 & 0.025 & 0.03 & 37.6 \\
# POW & QSO Pos + FR & 2.154 & 11.045 & 13.600 & 14.401 & 11.4 & 0.048 & 0.033 & 0.005 & 0.03 & 43.9 \\
# POW + Shear & QSO Pos + FR & 1.432 & 3.036 & 4.727 & 5.580 & 4.0 & 0.011 & 0.013 & 0.009 & 0.01 & 30.5 \\
# NFW & QSO Pos & 5.247 & 7.382 & 14.603 & 15.600 & 11.6 & 0.037 & 0.057 & 0.012 & 0.04 & 46.8 \\
# NFW + Shear & QSO Pos & 2.759 & 7.424 & 2.864 & 6.174 & 5.2 & 0.006 & 0.033 & 0.034 & 0.03 & 41.8 \\
# NFW & QSO Pos + FR & 7.513 & 10.640 & 16.200 & 16.950 & 13.4 & 0.005 & 0.044 & 0.006 & 0.03 & 48.4 \\
# NFW + Shear & QSO Pos + FR & 1.581 & 3.534 & 4.653 & 5.532 & 4.1 & 0.010 & 0.004 & 0.007 & 0.01 & 29.9 \\

# %%
# NEW LATEX AUTOMATED CODE WITH MANUAL CHI^2 CALCULATION with individual position delta RMS and flux ratio differences
# WFI2026
import numpy as np
import pandas as pd
from astropy.io import fits
import os

# Function to calculate distance
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Function to read observed positions, flux ratios, and uncertainties
def read_observed_positions(input_file):
    observed_positions = []
    observed_flux_ratios = []
    position_uncertainties = []
    flux_uncertainties = []
    with open(input_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            columns = line.split()
            if len(columns) >= 5:
                x1 = float(columns[0])
                y1 = float(columns[1])
                flux_ratio = float(columns[2])
                pos_err = float(columns[3])
                flux_err = float(columns[4])
                observed_positions.append((x1, y1))
                observed_flux_ratios.append(flux_ratio)
                position_uncertainties.append(pos_err)
                flux_uncertainties.append(flux_err)
    return observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties

# Function to read predicted positions and magnifications
def read_predicted_positions(output_file):
    predicted_positions = []
    predicted_magnifications = []
    with open(output_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            if line.startswith("#"):
                continue
            columns = line.split()
            if len(columns) >= 3:
                x2 = float(columns[0])
                y2 = float(columns[1])
                M2 = abs(float(columns[2]))
                predicted_positions.append((x2, y2))
                predicted_magnifications.append(M2)
    return predicted_positions, predicted_magnifications

# Function to pair predicted and observed positions
def pair_positions(observed_positions, predicted_positions, predicted_magnifications):
    paired_positions = []
    for observed_position in observed_positions:
        min_distance = float('inf')
        closest_index = None
        for i, predicted_position in enumerate(predicted_positions):
            distance = calculate_distance(*observed_position, *predicted_position)
            if distance < min_distance:
                min_distance = distance
                closest_index = i
        paired_positions.append((observed_position, predicted_positions[closest_index], predicted_magnifications[closest_index]))
    return paired_positions

# Function to calculate manual chi² with proper uncertainties
def calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties, 
                         predicted_positions, predicted_magnifications, green_index=1):
    # Pair positions
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Calculate predicted flux ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]
    
    chi2 = 0.0
    
    # Position contributions to chi²
    for i, (observed, predicted, _) in enumerate(paired_positions):
        dx = observed[0] - predicted[0]
        dy = observed[1] - predicted[1]
        pos_err = position_uncertainties[i]
        chi2 += (dx/pos_err)**2 + (dy/pos_err)**2
    
    # Flux ratio contributions to chi² (excluding the normalization image)
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_err = flux_uncertainties[i]
            chi2 += ((pred_flux - obs_flux)/flux_err)**2
    
    return chi2

# Function to extract the final chi^2 from optresult.dat file
def extract_glafic_chi2(optresult_path):
    chi2_value = None
    with open(optresult_path, 'r') as file:
        lines = file.readlines()
    
    # Find the last occurrence of chi^2 (final/best result)
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
    
    return chi2_value

# Function to process file group
def process_file_group(output_file, fits_file, input_file, n):
    observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties = read_observed_positions(input_file)
    predicted_positions, predicted_magnifications = read_predicted_positions(output_file)
    
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Calculate Delta RMS of Image Positions correctly
    squared_distances = 0.0
    individual_distances = []  # Store individual distances for each image
    for observed, predicted, _ in paired_positions:
        distance = calculate_distance(*observed, *predicted)
        individual_distances.append(distance * 1000)  # Convert to mas
        squared_distances += distance ** 2  # Summing squared distances
    
    mean_squared_distances = squared_distances / len(paired_positions)
    delta_rms = np.sqrt(mean_squared_distances)  # Taking square root of the mean of squared distances
    delta_rms *= 1000  # Convert to mas
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Determine the index of the "Green Image"
    green_index = 0  # CHOOSE WHICH IMAGE TO NORMALISE BY HERE !!!!!!!!!!!!!!!!!!!!!!!

    # Predicted Flux Ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]

    # Calculate absolute differences between predicted and observed flux ratios (excluding normalization image)
    flux_ratio_differences = []
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_ratio_differences.append(abs(pred_flux - obs_flux))

    # Calculate manual chi²
    manual_chi2 = calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties,
                                       predicted_positions, predicted_magnifications, green_index)

    with fits.open(fits_file) as hdul:
        mag = hdul[0].data[6]
    
    pixel_coords = [(int((x + mag.shape[1] // 2 * n) / n), int((y + mag.shape[0] // 2 * n) / n)) for x, y in observed_positions]
    values = [mag[y, x] for x, y in pixel_coords]
    
    abs_values = [1 / abs(value) for value in values]
    predicted_flux_ratios_observed = [abs_values[i] / abs_values[green_index] for i in range(len(abs_values))]

    # Calculate RMS excluding the green image
    squared_diffs_pred = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_rms = np.sqrt(sum(squared_diffs_pred) / len(squared_diffs_pred))

    squared_diffs_obs = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios_observed, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_observed_rms = np.sqrt(sum(squared_diffs_obs) / len(squared_diffs_obs))

    return {
        'delta_rms': delta_rms,
        'individual_position_deltas': individual_distances,  # Delta RMS for each of the 4 positions
        'flux_ratio_differences': flux_ratio_differences,    # Absolute differences for 3 flux ratios
        'predicted_flux_ratios_rms': predicted_flux_ratios_rms,
        'predicted_flux_ratios_observed_rms': predicted_flux_ratios_observed_rms,
        'manual_chi2': manual_chi2
    }

# Function to extract chi^2 and lens models from optresult.dat file (following Code 1's approach exactly)
def extract_chi2_and_lens_profiles(optresult_path):
    chi2_value = None
    profiles_used = []
    sie_count = 0

    with open(optresult_path, 'r') as file:
        lines = file.readlines()

    found_chi2 = False
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
            found_chi2 = True
            profiles_used = []
            sie_count = 0
        elif found_chi2:
            if line.startswith("lens   sie"):
                profiles_used.append("SIE")
                sie_count += 1
            elif line.startswith("lens   pow"):
                profiles_used.append("POW")
            elif line.startswith("lens   anfw"):
                profiles_used.append("NFW")
            elif line.startswith("lens   pert"):
                profiles_used.append("Shear")

    if chi2_value is None:
        raise ValueError("No chi^2 value found in the file.")

    profiles_used = list(set(profiles_used))
    return chi2_value, profiles_used, sie_count

# Function to calculate free parameters based on lens profiles (identical to Code 1)
def calculate_free_parameters(profiles_used, sie_count):
    profile_params = {
        "SIE": 5,
        "POW": 6,
        "NFW": 6,
        "Shear": 5
    }
    total_params = sum(profile_params[profile] for profile in profiles_used)
    if sie_count == 2:
        total_params += 5
    return total_params

# Function to calculate BIC (Bayesian Information Criterion)
def calculate_bic(chi2, n_data_points, n_free_params):
    return chi2 + n_free_params * np.log(n_data_points)

# Function to compute BIC using manual chi² but following Code 1's approach for free parameters
def compute_bic_with_tracking(manual_chi2, optresult_path):
    # Use Code 1's approach: extract profiles from optresult.dat file
    glafic_chi2, profiles_used, sie_count = extract_chi2_and_lens_profiles(optresult_path)
    n_free_params = calculate_free_parameters(profiles_used, sie_count)
    
    # Properly adjust n_data_points based on constraint type
    if "PF" in optresult_path:
        n_data_points = 4 * 2 + 3  # positions + flux ratios
    else:
        n_data_points = 4 * 2  # positions only
    
    # Always use manual chi² for BIC calculation
    bic_value = calculate_bic(manual_chi2, n_data_points, n_free_params)
    
    return bic_value, glafic_chi2, n_data_points, n_free_params

# Main function to process multiple files
def process_files(input_file, output_files, fits_files, optresult_files, n):
    results = []
    latex_rows = []
    bics = []  # Store BIC values separately
    glafic_chi2_values = []  # Store glafic chi² for reference
    data_points_used = []  # Store number of data points used
    free_params_used = []  # Store number of free parameters used

    for output_file, fits_file, optresult_file in zip(output_files, fits_files, optresult_files):
        # Process output and fits files
        result = process_file_group(output_file, fits_file, input_file, n)
        results.append(result)
        
        # Calculate BIC using manual chi² but track both values
        bic, glafic_chi2, n_data_points, n_free_params = compute_bic_with_tracking(result['manual_chi2'], optresult_file)
        bics.append(bic)
        glafic_chi2_values.append(glafic_chi2)
        data_points_used.append(n_data_points)
        free_params_used.append(n_free_params)
        
        # Create LaTeX row with additional information
        model_name, constraint_name = determine_model_and_constraint(output_file)
        # Format individual position deltas and flux ratio differences for LaTeX
        pos_deltas_str = " & ".join([f"{delta:.3f}" for delta in result['individual_position_deltas']])
        flux_diffs_str = " & ".join([f"{diff:.3f}" for diff in result['flux_ratio_differences']])
        
        latex_row = f"{model_name} & {constraint_name} & {pos_deltas_str} & {result['delta_rms']:.1f} & {flux_diffs_str} & {result['predicted_flux_ratios_rms']:.2f} & {bic:.1f} \\\\"
        latex_rows.append(latex_row)
    
    # Combine results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results['bic'] = bics  # Add BIC values to the DataFrame
    df_results['glafic_chi2'] = glafic_chi2_values  # Add glafic chi² for reference
    df_results['n_data_points'] = data_points_used  # Add number of data points used
    df_results['n_free_params'] = free_params_used  # Add number of free parameters used
    
    return df_results, latex_rows

# Determine model and constraint names from the filename
def determine_model_and_constraint(file_name):
    model_map = {'S': 'SIE', 'P': 'POW', 'N': 'NFW'}
    
    base_name = os.path.basename(file_name)
    model_key = base_name[3]
    constraint_key = base_name[4:6] if base_name[4:6] in ['PF'] else base_name[4]
    
    model_name = model_map.get(model_key, '')
    if 'R' in base_name:
        model_name += ' + Shear'
    if 'G' in base_name:
        model_name += ' + G2'
    
    constraint_name = 'QSO Pos + FR' if constraint_key == 'PF' else 'QSO Pos'
    
    return model_name, constraint_name

# Example usage with filenames
Input_file = "WFI2026/SPFC/Wobs_point.dat"

Output_files = [
    "WFI2026/SPC/outSP_point.dat",
    "WFI2026/SPC/outSPR_point.dat",
    "WFI2026/SPFC/outSPF_point.dat",
    "WFI2026/SPFC/outSPFR_point.dat",
    "WFI2026/PPC/outPP_point.dat",
    "WFI2026/PPC/outPPR_point.dat",
    "WFI2026/PPFC/outPPF_point.dat",
    "WFI2026/PPFC/outPPFR_point.dat",
    "WFI2026/NPC/outNP_point.dat",
    "WFI2026/NPC/outNPR_point.dat",
    "WFI2026/NPFC/outNPF_point.dat",
    "WFI2026/NPFC/outNPFR_point.dat",
]

Fits_files = [
    "WFI2026/SPC/outSP_lens.fits",
    "WFI2026/SPC/outSPR_lens.fits",
    "WFI2026/SPFC/outSPF_lens.fits",
    "WFI2026/SPFC/outSPFR_lens.fits",
    "WFI2026/PPC/outPP_lens.fits",
    "WFI2026/PPC/outPPR_lens.fits",
    "WFI2026/PPFC/outPPF_lens.fits",
    "WFI2026/PPFC/outPPFR_lens.fits",
    "WFI2026/NPC/outNP_lens.fits",
    "WFI2026/NPC/outNPR_lens.fits",
    "WFI2026/NPFC/outNPF_lens.fits",
    "WFI2026/NPFC/outNPFR_lens.fits",
]

Optresult_files = [
    "WFI2026/SPC/outSP_optresult.dat",
    "WFI2026/SPC/outSPR_optresult.dat",
    "WFI2026/SPFC/outSPF_optresult.dat",
    "WFI2026/SPFC/outSPFR_optresult.dat",
    "WFI2026/PPC/outPP_optresult.dat",
    "WFI2026/PPC/outPPR_optresult.dat",
    "WFI2026/PPFC/outPPF_optresult.dat",
    "WFI2026/PPFC/outPPFR_optresult.dat",
    "WFI2026/NPC/outNP_optresult.dat",
    "WFI2026/NPC/outNPR_optresult.dat",
    "WFI2026/NPFC/outNPF_optresult.dat",
    "WFI2026/NPFC/outNPFR_optresult.dat",
]

n = 0.0025  # Example scale factor
results_df, latex_rows = process_files(Input_file, Output_files, Fits_files, Optresult_files, n)

# Print formatted results
for i, output_file in enumerate(Output_files):
    constraint_type = "PF" if "PF" in Optresult_files[i] else "P"
    print(f"Model: {output_file}")
    print(f"Constraint Type: {constraint_type}")
    print(f"Number of data points used: {results_df.iloc[i]['n_data_points']}")
    print(f"Number of free parameters: {results_df.iloc[i]['n_free_params']}")
    print(f"Delta RMS of Image Positions: {results_df.iloc[i]['delta_rms']:.3f}")
    
    # Print individual position deltas (4 positions)
    print(f"Individual Position Deltas (mas):")
    for j, delta in enumerate(results_df.iloc[i]['individual_position_deltas']):
        print(f"  Image {j+1}: {delta:.3f}")
    
    print(f"Delta RMS of flux ratios at the observed position: {results_df.iloc[i]['predicted_flux_ratios_observed_rms']:.3f}")
    print(f"Delta RMS of flux ratios at the predicted position: {results_df.iloc[i]['predicted_flux_ratios_rms']:.3f}")
    
    # Print absolute flux ratio differences (3 ratios, excluding normalization)
    print(f"Absolute Flux Ratio Differences:")
    flux_diff_indices = [0, 2, 3] if len(results_df.iloc[i]['flux_ratio_differences']) == 3 else range(len(results_df.iloc[i]['flux_ratio_differences']))
    for j, diff in enumerate(results_df.iloc[i]['flux_ratio_differences']):
        img_idx = flux_diff_indices[j] + 1
        print(f"  Image {img_idx}: {diff:.3f}")
    
    print(f"Manual Chi²: {results_df.iloc[i]['manual_chi2']:.3f}")
    if results_df.iloc[i]['glafic_chi2'] is not None:
        print(f"Glafic Chi² (final, reference): {results_df.iloc[i]['glafic_chi2']:.3f}")
        print(f"Chi² Difference (Manual - Glafic): {results_df.iloc[i]['manual_chi2'] - results_df.iloc[i]['glafic_chi2']:.3f}")
    else:
        print(f"Glafic Chi² (reference): Not found")
    print(f"BIC (using manual Chi²): {results_df.iloc[i]['bic']:.3f}")
    
    # Manual verification of BIC calculation
    manual_bic_check = results_df.iloc[i]['manual_chi2'] + results_df.iloc[i]['n_free_params'] * np.log(results_df.iloc[i]['n_data_points'])
    print(f"Manual BIC verification: {results_df.iloc[i]['manual_chi2']:.3f} + {results_df.iloc[i]['n_free_params']} × ln({results_df.iloc[i]['n_data_points']}) = {manual_bic_check:.3f}")
    print()

# Print LaTeX-formatted rows
print("LaTeX Table Rows:")
print("Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC")
for row in latex_rows:
    print(row)
# Out:
# Model: WFI2026/SPC/outSP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 5
# Delta RMS of Image Positions: 15.162
# Individual Position Deltas (mas):
#   Image 1: 8.828
#   Image 2: 9.851
#   Image 3: 18.407
#   Image 4: 20.143
# Delta RMS of flux ratios at the observed position: 0.104
# Delta RMS of flux ratios at the predicted position: 0.034
# Absolute Flux Ratio Differences:
#   Image 1: 0.034
#   Image 3: 0.027
#   Image 4: 0.040
# Manual Chi²: 57.245
# Glafic Chi² (final, reference): 68.034
# Chi² Difference (Manual - Glafic): -10.790
# BIC (using manual Chi²): 67.642
# Manual BIC verification: 57.245 + 5 × ln(8) = 67.642
#
# Model: WFI2026/SPC/outSPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 5.065
# Individual Position Deltas (mas):
#   Image 1: 3.342
#   Image 2: 7.159
#   Image 3: 2.983
#   Image 4: 5.595
# Delta RMS of flux ratios at the observed position: 0.042
# Delta RMS of flux ratios at the predicted position: 0.034
# Absolute Flux Ratio Differences:
#   Image 1: 0.055
#   Image 3: 0.002
#   Image 4: 0.020
# Manual Chi²: 15.602
# Glafic Chi² (final, reference): 31.125
# Chi² Difference (Manual - Glafic): -15.524
# BIC (using manual Chi²): 36.396
# Manual BIC verification: 15.602 + 10 × ln(8) = 36.396
#
# Model: WFI2026/SPFC/outSPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 5
# Delta RMS of Image Positions: 16.351
# Individual Position Deltas (mas):
#   Image 1: 10.179
#   Image 2: 12.369
#   Image 3: 18.333
#   Image 4: 21.834
# Delta RMS of flux ratios at the observed position: 0.107
# Delta RMS of flux ratios at the predicted position: 0.030
# Absolute Flux Ratio Differences:
#   Image 1: 0.034
#   Image 3: 0.028
#   Image 4: 0.029
# Manual Chi²: 56.241
# Glafic Chi² (final, reference): 78.586
# Chi² Difference (Manual - Glafic): -22.345
# BIC (using manual Chi²): 68.231
# Manual BIC verification: 56.241 + 5 × ln(11) = 68.231
#
# Model: WFI2026/SPFC/outSPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 3.992
# Individual Position Deltas (mas):
#   Image 1: 1.530
#   Image 2: 2.563
#   Image 3: 4.837
#   Image 4: 5.608
# Delta RMS of flux ratios at the observed position: 0.009
# Delta RMS of flux ratios at the predicted position: 0.008
# Absolute Flux Ratio Differences:
#   Image 1: 0.011
#   Image 3: 0.004
#   Image 4: 0.007
# Manual Chi²: 3.436
# Glafic Chi² (final, reference): 34.124
# Chi² Difference (Manual - Glafic): -30.688
# BIC (using manual Chi²): 27.415
# Manual BIC verification: 3.436 + 10 × ln(11) = 27.415
#
# Model: WFI2026/PPC/outPP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 11.098
# Individual Position Deltas (mas):
#   Image 1: 1.476
#   Image 2: 8.807
#   Image 3: 14.000
#   Image 4: 14.728
# Delta RMS of flux ratios at the observed position: 0.110
# Delta RMS of flux ratios at the predicted position: 0.038
# Absolute Flux Ratio Differences:
#   Image 1: 0.052
#   Image 3: 0.039
#   Image 4: 0.002
# Manual Chi²: 30.414
# Glafic Chi² (final, reference): 56.204
# Chi² Difference (Manual - Glafic): -25.791
# BIC (using manual Chi²): 42.890
# Manual BIC verification: 30.414 + 6 × ln(8) = 42.890
#
# Model: WFI2026/PPC/outPPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 5.447
# Individual Position Deltas (mas):
#   Image 1: 3.640
#   Image 2: 7.829
#   Image 3: 2.961
#   Image 4: 5.948
# Delta RMS of flux ratios at the observed position: 0.033
# Delta RMS of flux ratios at the predicted position: 0.027
# Absolute Flux Ratio Differences:
#   Image 1: 0.031
#   Image 3: 0.025
#   Image 4: 0.025
# Manual Chi²: 14.736
# Glafic Chi² (final, reference): 33.472
# Chi² Difference (Manual - Glafic): -18.736
# BIC (using manual Chi²): 37.610
# Manual BIC verification: 14.736 + 11 × ln(8) = 37.610
#
# Model: WFI2026/PPFC/outPPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 11.391
# Individual Position Deltas (mas):
#   Image 1: 2.154
#   Image 2: 11.045
#   Image 3: 13.600
#   Image 4: 14.401
# Delta RMS of flux ratios at the observed position: 0.101
# Delta RMS of flux ratios at the predicted position: 0.034
# Absolute Flux Ratio Differences:
#   Image 1: 0.048
#   Image 3: 0.033
#   Image 4: 0.005
# Manual Chi²: 29.491
# Glafic Chi² (final, reference): 64.402
# Chi² Difference (Manual - Glafic): -34.911
# BIC (using manual Chi²): 43.879
# Manual BIC verification: 29.491 + 6 × ln(11) = 43.879
#
# Model: WFI2026/PPFC/outPPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 4.023
# Individual Position Deltas (mas):
#   Image 1: 1.432
#   Image 2: 3.036
#   Image 3: 4.727
#   Image 4: 5.580
# Delta RMS of flux ratios at the observed position: 0.011
# Delta RMS of flux ratios at the predicted position: 0.011
# Absolute Flux Ratio Differences:
#   Image 1: 0.011
#   Image 3: 0.013
#   Image 4: 0.009
# Manual Chi²: 4.129
# Glafic Chi² (final, reference): 35.530
# Chi² Difference (Manual - Glafic): -31.401
# BIC (using manual Chi²): 30.506
# Manual BIC verification: 4.129 + 11 × ln(11) = 30.506
#
# Model: WFI2026/NPC/outNP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 11.604
# Individual Position Deltas (mas):
#   Image 1: 5.247
#   Image 2: 7.382
#   Image 3: 14.603
#   Image 4: 15.600
# Delta RMS of flux ratios at the observed position: 0.107
# Delta RMS of flux ratios at the predicted position: 0.040
# Absolute Flux Ratio Differences:
#   Image 1: 0.037
#   Image 3: 0.057
#   Image 4: 0.012
# Manual Chi²: 34.372
# Glafic Chi² (final, reference): 59.878
# Chi² Difference (Manual - Glafic): -25.506
# BIC (using manual Chi²): 46.849
# Manual BIC verification: 34.372 + 6 × ln(8) = 46.849
#
# Model: WFI2026/NPC/outNPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 5.221
# Individual Position Deltas (mas):
#   Image 1: 2.759
#   Image 2: 7.424
#   Image 3: 2.864
#   Image 4: 6.174
# Delta RMS of flux ratios at the observed position: 0.031
# Delta RMS of flux ratios at the predicted position: 0.028
# Absolute Flux Ratio Differences:
#   Image 1: 0.006
#   Image 3: 0.033
#   Image 4: 0.034
# Manual Chi²: 18.954
# Glafic Chi² (final, reference): 35.460
# Chi² Difference (Manual - Glafic): -16.506
# BIC (using manual Chi²): 41.828
# Manual BIC verification: 18.954 + 11 × ln(8) = 41.828
#
# Model: WFI2026/NPFC/outNPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 13.411
# Individual Position Deltas (mas):
#   Image 1: 7.513
#   Image 2: 10.640
#   Image 3: 16.200
#   Image 4: 16.950
# Delta RMS of flux ratios at the observed position: 0.095
# Delta RMS of flux ratios at the predicted position: 0.026
# Absolute Flux Ratio Differences:
#   Image 1: 0.005
#   Image 3: 0.044
#   Image 4: 0.006
# Manual Chi²: 33.994
# Glafic Chi² (final, reference): 72.275
# Chi² Difference (Manual - Glafic): -38.281
# BIC (using manual Chi²): 48.381
# Manual BIC verification: 33.994 + 6 × ln(11) = 48.381
#
# Model: WFI2026/NPFC/outNPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 4.100
# Individual Position Deltas (mas):
#   Image 1: 1.581
#   Image 2: 3.534
#   Image 3: 4.653
#   Image 4: 5.532
# Delta RMS of flux ratios at the observed position: 0.010
# Delta RMS of flux ratios at the predicted position: 0.008
# Absolute Flux Ratio Differences:
#   Image 1: 0.010
#   Image 3: 0.004
#   Image 4: 0.007
# Manual Chi²: 3.546
# Glafic Chi² (final, reference): 34.105
# Chi² Difference (Manual - Glafic): -30.560
# BIC (using manual Chi²): 29.922
# Manual BIC verification: 3.546 + 11 × ln(11) = 29.922
#
# LaTeX Table Rows:
# Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC
# SIE & QSO Pos & 8.828 & 9.851 & 18.407 & 20.143 & 15.2 & 0.034 & 0.027 & 0.040 & 0.03 & 67.6 \\
# SIE + Shear & QSO Pos & 3.342 & 7.159 & 2.983 & 5.595 & 5.1 & 0.055 & 0.002 & 0.020 & 0.03 & 36.4 \\
# SIE & QSO Pos + FR & 10.179 & 12.369 & 18.333 & 21.834 & 16.4 & 0.034 & 0.028 & 0.029 & 0.03 & 68.2 \\
# SIE + Shear & QSO Pos + FR & 1.530 & 2.563 & 4.837 & 5.608 & 4.0 & 0.011 & 0.004 & 0.007 & 0.01 & 27.4 \\
# POW & QSO Pos & 1.476 & 8.807 & 14.000 & 14.728 & 11.1 & 0.052 & 0.039 & 0.002 & 0.04 & 42.9 \\
# POW + Shear & QSO Pos & 3.640 & 7.829 & 2.961 & 5.948 & 5.4 & 0.031 & 0.025 & 0.025 & 0.03 & 37.6 \\
# POW & QSO Pos + FR & 2.154 & 11.045 & 13.600 & 14.401 & 11.4 & 0.048 & 0.033 & 0.005 & 0.03 & 43.9 \\
# POW + Shear & QSO Pos + FR & 1.432 & 3.036 & 4.727 & 5.580 & 4.0 & 0.011 & 0.013 & 0.009 & 0.01 & 30.5 \\
# NFW & QSO Pos & 5.247 & 7.382 & 14.603 & 15.600 & 11.6 & 0.037 & 0.057 & 0.012 & 0.04 & 46.8 \\
# NFW + Shear & QSO Pos & 2.759 & 7.424 & 2.864 & 6.174 & 5.2 & 0.006 & 0.033 & 0.034 & 0.03 & 41.8 \\
# NFW & QSO Pos + FR & 7.513 & 10.640 & 16.200 & 16.950 & 13.4 & 0.005 & 0.044 & 0.006 & 0.03 & 48.4 \\
# NFW + Shear & QSO Pos + FR & 1.581 & 3.534 & 4.653 & 5.532 & 4.1 & 0.010 & 0.004 & 0.007 & 0.01 & 29.9 \\

# %%
# NEW LATEX AUTOMATED CODE WITH MANUAL CHI^2 CALCULATION with individual position delta RMS and flux ratio differences
# WGDJ0405
import numpy as np
import pandas as pd
from astropy.io import fits
import os

# Function to calculate distance
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Function to read observed positions, flux ratios, and uncertainties
def read_observed_positions(input_file):
    observed_positions = []
    observed_flux_ratios = []
    position_uncertainties = []
    flux_uncertainties = []
    with open(input_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            columns = line.split()
            if len(columns) >= 5:
                x1 = float(columns[0])
                y1 = float(columns[1])
                flux_ratio = float(columns[2])
                pos_err = float(columns[3])
                flux_err = float(columns[4])
                observed_positions.append((x1, y1))
                observed_flux_ratios.append(flux_ratio)
                position_uncertainties.append(pos_err)
                flux_uncertainties.append(flux_err)
    return observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties

# Function to read predicted positions and magnifications
def read_predicted_positions(output_file):
    predicted_positions = []
    predicted_magnifications = []
    with open(output_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            if line.startswith("#"):
                continue
            columns = line.split()
            if len(columns) >= 3:
                x2 = float(columns[0])
                y2 = float(columns[1])
                M2 = abs(float(columns[2]))
                predicted_positions.append((x2, y2))
                predicted_magnifications.append(M2)
    return predicted_positions, predicted_magnifications

# Function to pair predicted and observed positions
def pair_positions(observed_positions, predicted_positions, predicted_magnifications):
    paired_positions = []
    for observed_position in observed_positions:
        min_distance = float('inf')
        closest_index = None
        for i, predicted_position in enumerate(predicted_positions):
            distance = calculate_distance(*observed_position, *predicted_position)
            if distance < min_distance:
                min_distance = distance
                closest_index = i
        paired_positions.append((observed_position, predicted_positions[closest_index], predicted_magnifications[closest_index]))
    return paired_positions

# Function to calculate manual chi² with proper uncertainties
def calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties, 
                         predicted_positions, predicted_magnifications, green_index=1):
    # Pair positions
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Calculate predicted flux ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]
    
    chi2 = 0.0
    
    # Position contributions to chi²
    for i, (observed, predicted, _) in enumerate(paired_positions):
        dx = observed[0] - predicted[0]
        dy = observed[1] - predicted[1]
        pos_err = position_uncertainties[i]
        chi2 += (dx/pos_err)**2 + (dy/pos_err)**2
    
    # Flux ratio contributions to chi² (excluding the normalization image)
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_err = flux_uncertainties[i]
            chi2 += ((pred_flux - obs_flux)/flux_err)**2
    
    return chi2

# Function to extract the final chi^2 from optresult.dat file
def extract_glafic_chi2(optresult_path):
    chi2_value = None
    with open(optresult_path, 'r') as file:
        lines = file.readlines()
    
    # Find the last occurrence of chi^2 (final/best result)
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
    
    return chi2_value

# Function to process file group
def process_file_group(output_file, fits_file, input_file, n):
    observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties = read_observed_positions(input_file)
    predicted_positions, predicted_magnifications = read_predicted_positions(output_file)
    
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Calculate Delta RMS of Image Positions correctly
    squared_distances = 0.0
    individual_distances = []  # Store individual distances for each image
    for observed, predicted, _ in paired_positions:
        distance = calculate_distance(*observed, *predicted)
        individual_distances.append(distance * 1000)  # Convert to mas
        squared_distances += distance ** 2  # Summing squared distances
    
    mean_squared_distances = squared_distances / len(paired_positions)
    delta_rms = np.sqrt(mean_squared_distances)  # Taking square root of the mean of squared distances
    delta_rms *= 1000  # Convert to mas
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Determine the index of the "Green Image"
    green_index = 2  # CHOOSE WHICH IMAGE TO NORMALISE BY HERE !!!!!!!!!!!!!!!!!!!!!!!

    # Predicted Flux Ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]

    # Calculate absolute differences between predicted and observed flux ratios (excluding normalization image)
    flux_ratio_differences = []
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_ratio_differences.append(abs(pred_flux - obs_flux))

    # Calculate manual chi²
    manual_chi2 = calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties,
                                       predicted_positions, predicted_magnifications, green_index)

    with fits.open(fits_file) as hdul:
        mag = hdul[0].data[6]
    
    pixel_coords = [(int((x + mag.shape[1] // 2 * n) / n), int((y + mag.shape[0] // 2 * n) / n)) for x, y in observed_positions]
    values = [mag[y, x] for x, y in pixel_coords]
    
    abs_values = [1 / abs(value) for value in values]
    predicted_flux_ratios_observed = [abs_values[i] / abs_values[green_index] for i in range(len(abs_values))]

    # Calculate RMS excluding the green image
    squared_diffs_pred = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_rms = np.sqrt(sum(squared_diffs_pred) / len(squared_diffs_pred))

    squared_diffs_obs = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios_observed, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_observed_rms = np.sqrt(sum(squared_diffs_obs) / len(squared_diffs_obs))

    return {
        'delta_rms': delta_rms,
        'individual_position_deltas': individual_distances,  # Delta RMS for each of the 4 positions
        'flux_ratio_differences': flux_ratio_differences,    # Absolute differences for 3 flux ratios
        'predicted_flux_ratios_rms': predicted_flux_ratios_rms,
        'predicted_flux_ratios_observed_rms': predicted_flux_ratios_observed_rms,
        'manual_chi2': manual_chi2
    }

# Function to extract chi^2 and lens models from optresult.dat file (following Code 1's approach exactly)
def extract_chi2_and_lens_profiles(optresult_path):
    chi2_value = None
    profiles_used = []
    sie_count = 0

    with open(optresult_path, 'r') as file:
        lines = file.readlines()

    found_chi2 = False
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
            found_chi2 = True
            profiles_used = []
            sie_count = 0
        elif found_chi2:
            if line.startswith("lens   sie"):
                profiles_used.append("SIE")
                sie_count += 1
            elif line.startswith("lens   pow"):
                profiles_used.append("POW")
            elif line.startswith("lens   anfw"):
                profiles_used.append("NFW")
            elif line.startswith("lens   pert"):
                profiles_used.append("Shear")

    if chi2_value is None:
        raise ValueError("No chi^2 value found in the file.")

    profiles_used = list(set(profiles_used))
    return chi2_value, profiles_used, sie_count

# Function to calculate free parameters based on lens profiles (identical to Code 1)
def calculate_free_parameters(profiles_used, sie_count):
    profile_params = {
        "SIE": 5,
        "POW": 6,
        "NFW": 6,
        "Shear": 5
    }
    total_params = sum(profile_params[profile] for profile in profiles_used)
    if sie_count == 2:
        total_params += 5
    return total_params

# Function to calculate BIC (Bayesian Information Criterion)
def calculate_bic(chi2, n_data_points, n_free_params):
    return chi2 + n_free_params * np.log(n_data_points)

# Function to compute BIC using manual chi² but following Code 1's approach for free parameters
def compute_bic_with_tracking(manual_chi2, optresult_path):
    # Use Code 1's approach: extract profiles from optresult.dat file
    glafic_chi2, profiles_used, sie_count = extract_chi2_and_lens_profiles(optresult_path)
    n_free_params = calculate_free_parameters(profiles_used, sie_count)
    
    # Properly adjust n_data_points based on constraint type
    if "PF" in optresult_path:
        n_data_points = 4 * 2 + 3  # positions + flux ratios
    else:
        n_data_points = 4 * 2  # positions only
    
    # Always use manual chi² for BIC calculation
    bic_value = calculate_bic(manual_chi2, n_data_points, n_free_params)
    
    return bic_value, glafic_chi2, n_data_points, n_free_params

# Main function to process multiple files
def process_files(input_file, output_files, fits_files, optresult_files, n):
    results = []
    latex_rows = []
    bics = []  # Store BIC values separately
    glafic_chi2_values = []  # Store glafic chi² for reference
    data_points_used = []  # Store number of data points used
    free_params_used = []  # Store number of free parameters used

    for output_file, fits_file, optresult_file in zip(output_files, fits_files, optresult_files):
        # Process output and fits files
        result = process_file_group(output_file, fits_file, input_file, n)
        results.append(result)
        
        # Calculate BIC using manual chi² but track both values
        bic, glafic_chi2, n_data_points, n_free_params = compute_bic_with_tracking(result['manual_chi2'], optresult_file)
        bics.append(bic)
        glafic_chi2_values.append(glafic_chi2)
        data_points_used.append(n_data_points)
        free_params_used.append(n_free_params)
        
        # Create LaTeX row with additional information
        model_name, constraint_name = determine_model_and_constraint(output_file)
        # Format individual position deltas and flux ratio differences for LaTeX
        pos_deltas_str = " & ".join([f"{delta:.3f}" for delta in result['individual_position_deltas']])
        flux_diffs_str = " & ".join([f"{diff:.3f}" for diff in result['flux_ratio_differences']])
        
        latex_row = f"{model_name} & {constraint_name} & {pos_deltas_str} & {result['delta_rms']:.1f} & {flux_diffs_str} & {result['predicted_flux_ratios_rms']:.2f} & {bic:.1f} \\\\"
        latex_rows.append(latex_row)
    
    # Combine results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results['bic'] = bics  # Add BIC values to the DataFrame
    df_results['glafic_chi2'] = glafic_chi2_values  # Add glafic chi² for reference
    df_results['n_data_points'] = data_points_used  # Add number of data points used
    df_results['n_free_params'] = free_params_used  # Add number of free parameters used
    
    return df_results, latex_rows

# Determine model and constraint names from the filename
def determine_model_and_constraint(file_name):
    model_map = {'S': 'SIE', 'P': 'POW', 'N': 'NFW'}
    
    base_name = os.path.basename(file_name)
    model_key = base_name[3]
    constraint_key = base_name[4:6] if base_name[4:6] in ['PF'] else base_name[4]
    
    model_name = model_map.get(model_key, '')
    if 'R' in base_name:
        model_name += ' + Shear'
    if 'G' in base_name:
        model_name += ' + G2'
    
    constraint_name = 'QSO Pos + FR' if constraint_key == 'PF' else 'QSO Pos'
    
    return model_name, constraint_name

# Example usage with filenames
Input_file = "WGDJ0405/SPFC/Eobs_point.dat"

Output_files = [
    "WGDJ0405/SPC/outSP_point.dat",
    "WGDJ0405/SPC/outSPR_point.dat",
    "WGDJ0405/SPFC/outSPF_point.dat",
    "WGDJ0405/SPFC/outSPFR_point.dat",
    "WGDJ0405/PPC/outPP_point.dat",
    "WGDJ0405/PPC/outPPR_point.dat",
    "WGDJ0405/PPFC/outPPF_point.dat",
    "WGDJ0405/PPFC/outPPFR_point.dat",
    "WGDJ0405/NPC/outNP_point.dat",
    "WGDJ0405/NPC/outNPR_point.dat",
    "WGDJ0405/NPFC/outNPF_point.dat",
    "WGDJ0405/NPFC/outNPFR_point.dat"
]

Fits_files = [
    "WGDJ0405/SPC/outSP_lens.fits",
    "WGDJ0405/SPC/outSPR_lens.fits",
    "WGDJ0405/SPFC/outSPF_lens.fits",
    "WGDJ0405/SPFC/outSPFR_lens.fits",
    "WGDJ0405/PPC/outPP_lens.fits",
    "WGDJ0405/PPC/outPPR_lens.fits",
    "WGDJ0405/PPFC/outPPF_lens.fits",
    "WGDJ0405/PPFC/outPPFR_lens.fits",
    "WGDJ0405/NPC/outNP_lens.fits",
    "WGDJ0405/NPC/outNPR_lens.fits",
    "WGDJ0405/NPFC/outNPF_lens.fits",
    "WGDJ0405/NPFC/outNPFR_lens.fits"
]

Optresult_files = [
    "WGDJ0405/SPC/outSP_optresult.dat",
    "WGDJ0405/SPC/outSPR_optresult.dat",
    "WGDJ0405/SPFC/outSPF_optresult.dat",
    "WGDJ0405/SPFC/outSPFR_optresult.dat",
    "WGDJ0405/PPC/outPP_optresult.dat",
    "WGDJ0405/PPC/outPPR_optresult.dat",
    "WGDJ0405/PPFC/outPPF_optresult.dat",
    "WGDJ0405/PPFC/outPPFR_optresult.dat",
    "WGDJ0405/NPC/outNP_optresult.dat",
    "WGDJ0405/NPC/outNPR_optresult.dat",
    "WGDJ0405/NPFC/outNPF_optresult.dat",
    "WGDJ0405/NPFC/outNPFR_optresult.dat"
]

n = 0.0025  # Example scale factor
results_df, latex_rows = process_files(Input_file, Output_files, Fits_files, Optresult_files, n)

# Print formatted results
for i, output_file in enumerate(Output_files):
    constraint_type = "PF" if "PF" in Optresult_files[i] else "P"
    print(f"Model: {output_file}")
    print(f"Constraint Type: {constraint_type}")
    print(f"Number of data points used: {results_df.iloc[i]['n_data_points']}")
    print(f"Number of free parameters: {results_df.iloc[i]['n_free_params']}")
    print(f"Delta RMS of Image Positions: {results_df.iloc[i]['delta_rms']:.3f}")
    
    # Print individual position deltas (4 positions)
    print(f"Individual Position Deltas (mas):")
    for j, delta in enumerate(results_df.iloc[i]['individual_position_deltas']):
        print(f"  Image {j+1}: {delta:.3f}")
    
    print(f"Delta RMS of flux ratios at the observed position: {results_df.iloc[i]['predicted_flux_ratios_observed_rms']:.3f}")
    print(f"Delta RMS of flux ratios at the predicted position: {results_df.iloc[i]['predicted_flux_ratios_rms']:.3f}")
    
    # Print absolute flux ratio differences (3 ratios, excluding normalization)
    print(f"Absolute Flux Ratio Differences:")
    flux_diff_indices = [0, 2, 3] if len(results_df.iloc[i]['flux_ratio_differences']) == 3 else range(len(results_df.iloc[i]['flux_ratio_differences']))
    for j, diff in enumerate(results_df.iloc[i]['flux_ratio_differences']):
        img_idx = flux_diff_indices[j] + 1
        print(f"  Image {img_idx}: {diff:.3f}")
    
    print(f"Manual Chi²: {results_df.iloc[i]['manual_chi2']:.3f}")
    if results_df.iloc[i]['glafic_chi2'] is not None:
        print(f"Glafic Chi² (final, reference): {results_df.iloc[i]['glafic_chi2']:.3f}")
        print(f"Chi² Difference (Manual - Glafic): {results_df.iloc[i]['manual_chi2'] - results_df.iloc[i]['glafic_chi2']:.3f}")
    else:
        print(f"Glafic Chi² (reference): Not found")
    print(f"BIC (using manual Chi²): {results_df.iloc[i]['bic']:.3f}")
    
    # Manual verification of BIC calculation
    manual_bic_check = results_df.iloc[i]['manual_chi2'] + results_df.iloc[i]['n_free_params'] * np.log(results_df.iloc[i]['n_data_points'])
    print(f"Manual BIC verification: {results_df.iloc[i]['manual_chi2']:.3f} + {results_df.iloc[i]['n_free_params']} × ln({results_df.iloc[i]['n_data_points']}) = {manual_bic_check:.3f}")
    print()

# Print LaTeX-formatted rows
print("LaTeX Table Rows:")
print("Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC")
for row in latex_rows:
    print(row)
# Out:
# Model: WGDJ0405/SPC/outSP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 5
# Delta RMS of Image Positions: 17.938
# Individual Position Deltas (mas):
#   Image 1: 19.241
#   Image 2: 21.660
#   Image 3: 10.872
#   Image 4: 18.154
# Delta RMS of flux ratios at the observed position: 0.193
# Delta RMS of flux ratios at the predicted position: 0.118
# Absolute Flux Ratio Differences:
#   Image 1: 0.127
#   Image 3: 0.153
#   Image 4: 0.045
# Manual Chi²: 77.445
# Glafic Chi² (final, reference): 54.976
# Chi² Difference (Manual - Glafic): 22.469
# BIC (using manual Chi²): 87.842
# Manual BIC verification: 77.445 + 5 × ln(8) = 87.842
#
# Model: WGDJ0405/SPC/outSPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 10
# Delta RMS of Image Positions: 1.655
# Individual Position Deltas (mas):
#   Image 1: 2.102
#   Image 2: 1.237
#   Image 3: 0.949
#   Image 4: 2.025
# Delta RMS of flux ratios at the observed position: 0.213
# Delta RMS of flux ratios at the predicted position: 0.191
# Absolute Flux Ratio Differences:
#   Image 1: 0.206
#   Image 3: 0.146
#   Image 4: 0.213
# Manual Chi²: 68.508
# Glafic Chi² (final, reference): 4.831
# Chi² Difference (Manual - Glafic): 63.677
# BIC (using manual Chi²): 89.302
# Manual BIC verification: 68.508 + 10 × ln(8) = 89.302
#
# Model: WGDJ0405/SPFC/outSPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 5
# Delta RMS of Image Positions: 18.027
# Individual Position Deltas (mas):
#   Image 1: 18.001
#   Image 2: 21.358
#   Image 3: 11.718
#   Image 4: 19.553
# Delta RMS of flux ratios at the observed position: 0.153
# Delta RMS of flux ratios at the predicted position: 0.111
# Absolute Flux Ratio Differences:
#   Image 1: 0.120
#   Image 3: 0.145
#   Image 4: 0.040
# Manual Chi²: 75.123
# Glafic Chi² (final, reference): 69.438
# Chi² Difference (Manual - Glafic): 5.685
# BIC (using manual Chi²): 87.112
# Manual BIC verification: 75.123 + 5 × ln(11) = 87.112
#
# Model: WGDJ0405/SPFC/outSPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 10
# Delta RMS of Image Positions: 2.658
# Individual Position Deltas (mas):
#   Image 1: 3.140
#   Image 2: 2.766
#   Image 3: 2.508
#   Image 4: 2.110
# Delta RMS of flux ratios at the observed position: 0.054
# Delta RMS of flux ratios at the predicted position: 0.079
# Absolute Flux Ratio Differences:
#   Image 1: 0.047
#   Image 3: 0.126
#   Image 4: 0.023
# Manual Chi²: 12.741
# Glafic Chi² (final, reference): 14.043
# Chi² Difference (Manual - Glafic): -1.301
# BIC (using manual Chi²): 36.720
# Manual BIC verification: 12.741 + 10 × ln(11) = 36.720
#
# Model: WGDJ0405/PPC/outPP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 17.946
# Individual Position Deltas (mas):
#   Image 1: 19.425
#   Image 2: 21.545
#   Image 3: 10.653
#   Image 4: 18.254
# Delta RMS of flux ratios at the observed position: 0.200
# Delta RMS of flux ratios at the predicted position: 0.098
# Absolute Flux Ratio Differences:
#   Image 1: 0.065
#   Image 3: 0.156
#   Image 4: 0.020
# Manual Chi²: 69.669
# Glafic Chi² (final, reference): 55.281
# Chi² Difference (Manual - Glafic): 14.388
# BIC (using manual Chi²): 82.145
# Manual BIC verification: 69.669 + 6 × ln(8) = 82.145
#
# Model: WGDJ0405/PPC/outPPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.289
# Individual Position Deltas (mas):
#   Image 1: 2.608
#   Image 2: 1.910
#   Image 3: 2.140
#   Image 4: 2.435
# Delta RMS of flux ratios at the observed position: 0.064
# Delta RMS of flux ratios at the predicted position: 0.083
# Absolute Flux Ratio Differences:
#   Image 1: 0.049
#   Image 3: 0.133
#   Image 4: 0.022
# Manual Chi²: 13.772
# Glafic Chi² (final, reference): 14.647
# Chi² Difference (Manual - Glafic): -0.875
# BIC (using manual Chi²): 36.646
# Manual BIC verification: 13.772 + 11 × ln(8) = 36.646
#
# Model: WGDJ0405/PPFC/outPPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 18.064
# Individual Position Deltas (mas):
#   Image 1: 17.420
#   Image 2: 21.455
#   Image 3: 11.799
#   Image 4: 20.056
# Delta RMS of flux ratios at the observed position: 0.149
# Delta RMS of flux ratios at the predicted position: 0.093
# Absolute Flux Ratio Differences:
#   Image 1: 0.063
#   Image 3: 0.147
#   Image 4: 0.020
# Manual Chi²: 68.515
# Glafic Chi² (final, reference): 69.366
# Chi² Difference (Manual - Glafic): -0.851
# BIC (using manual Chi²): 82.902
# Manual BIC verification: 68.515 + 6 × ln(11) = 82.902
#
# Model: WGDJ0405/PPFC/outPPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.278
# Individual Position Deltas (mas):
#   Image 1: 2.702
#   Image 2: 1.910
#   Image 3: 2.081
#   Image 4: 2.341
# Delta RMS of flux ratios at the observed position: 0.068
# Delta RMS of flux ratios at the predicted position: 0.085
# Absolute Flux Ratio Differences:
#   Image 1: 0.050
#   Image 3: 0.137
#   Image 4: 0.023
# Manual Chi²: 14.406
# Glafic Chi² (final, reference): 15.027
# Chi² Difference (Manual - Glafic): -0.621
# BIC (using manual Chi²): 40.783
# Manual BIC verification: 14.406 + 11 × ln(11) = 40.783
#
# Model: WGDJ0405/NPC/outNP_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 6
# Delta RMS of Image Positions: 17.913
# Individual Position Deltas (mas):
#   Image 1: 19.402
#   Image 2: 21.518
#   Image 3: 10.841
#   Image 4: 18.071
# Delta RMS of flux ratios at the observed position: 0.187
# Delta RMS of flux ratios at the predicted position: 0.131
# Absolute Flux Ratio Differences:
#   Image 1: 0.149
#   Image 3: 0.158
#   Image 4: 0.068
# Manual Chi²: 83.668
# Glafic Chi² (final, reference): 54.940
# Chi² Difference (Manual - Glafic): 28.728
# BIC (using manual Chi²): 96.144
# Manual BIC verification: 83.668 + 6 × ln(8) = 96.144
#
# Model: WGDJ0405/NPC/outNPR_point.dat
# Constraint Type: P
# Number of data points used: 8
# Number of free parameters: 11
# Delta RMS of Image Positions: 1.596
# Individual Position Deltas (mas):
#   Image 1: 2.147
#   Image 2: 0.854
#   Image 3: 0.412
#   Image 4: 2.163
# Delta RMS of flux ratios at the observed position: 0.110
# Delta RMS of flux ratios at the predicted position: 0.098
# Absolute Flux Ratio Differences:
#   Image 1: 0.064
#   Image 3: 0.155
#   Image 4: 0.032
# Manual Chi²: 18.521
# Glafic Chi² (final, reference): 4.614
# Chi² Difference (Manual - Glafic): 13.908
# BIC (using manual Chi²): 41.395
# Manual BIC verification: 18.521 + 11 × ln(8) = 41.395
#
# Model: WGDJ0405/NPFC/outNPF_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 6
# Delta RMS of Image Positions: 18.051
# Individual Position Deltas (mas):
#   Image 1: 18.573
#   Image 2: 21.308
#   Image 3: 11.789
#   Image 4: 19.113
# Delta RMS of flux ratios at the observed position: 0.157
# Delta RMS of flux ratios at the predicted position: 0.121
# Absolute Flux Ratio Differences:
#   Image 1: 0.134
#   Image 3: 0.152
#   Image 4: 0.056
# Manual Chi²: 79.694
# Glafic Chi² (final, reference): 71.167
# Chi² Difference (Manual - Glafic): 8.528
# BIC (using manual Chi²): 94.082
# Manual BIC verification: 79.694 + 6 × ln(11) = 94.082
#
# Model: WGDJ0405/NPFC/outNPFR_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 11
# Delta RMS of Image Positions: 2.155
# Individual Position Deltas (mas):
#   Image 1: 2.608
#   Image 2: 1.825
#   Image 3: 1.703
#   Image 4: 2.354
# Delta RMS of flux ratios at the observed position: 0.078
# Delta RMS of flux ratios at the predicted position: 0.090
# Absolute Flux Ratio Differences:
#   Image 1: 0.051
#   Image 3: 0.146
#   Image 4: 0.021
# Manual Chi²: 15.915
# Glafic Chi² (final, reference): 16.215
# Chi² Difference (Manual - Glafic): -0.300
# BIC (using manual Chi²): 42.292
# Manual BIC verification: 15.915 + 11 × ln(11) = 42.292
#
# LaTeX Table Rows:
# Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC
# SIE & QSO Pos & 19.241 & 21.660 & 10.872 & 18.154 & 17.9 & 0.127 & 0.153 & 0.045 & 0.12 & 87.8 \\
# SIE + Shear & QSO Pos & 2.102 & 1.237 & 0.949 & 2.025 & 1.7 & 0.206 & 0.146 & 0.213 & 0.19 & 89.3 \\
# SIE & QSO Pos + FR & 18.001 & 21.358 & 11.718 & 19.553 & 18.0 & 0.120 & 0.145 & 0.040 & 0.11 & 87.1 \\
# SIE + Shear & QSO Pos + FR & 3.140 & 2.766 & 2.508 & 2.110 & 2.7 & 0.047 & 0.126 & 0.023 & 0.08 & 36.7 \\
# POW & QSO Pos & 19.425 & 21.545 & 10.653 & 18.254 & 17.9 & 0.065 & 0.156 & 0.020 & 0.10 & 82.1 \\
# POW + Shear & QSO Pos & 2.608 & 1.910 & 2.140 & 2.435 & 2.3 & 0.049 & 0.133 & 0.022 & 0.08 & 36.6 \\
# POW & QSO Pos + FR & 17.420 & 21.455 & 11.799 & 20.056 & 18.1 & 0.063 & 0.147 & 0.020 & 0.09 & 82.9 \\
# POW + Shear & QSO Pos + FR & 2.702 & 1.910 & 2.081 & 2.341 & 2.3 & 0.050 & 0.137 & 0.023 & 0.09 & 40.8 \\
# NFW & QSO Pos & 19.402 & 21.518 & 10.841 & 18.071 & 17.9 & 0.149 & 0.158 & 0.068 & 0.13 & 96.1 \\
# NFW + Shear & QSO Pos & 2.147 & 0.854 & 0.412 & 2.163 & 1.6 & 0.064 & 0.155 & 0.032 & 0.10 & 41.4 \\
# NFW & QSO Pos + FR & 18.573 & 21.308 & 11.789 & 19.113 & 18.1 & 0.134 & 0.152 & 0.056 & 0.12 & 94.1 \\
# NFW + Shear & QSO Pos + FR & 2.608 & 1.825 & 1.703 & 2.354 & 2.2 & 0.051 & 0.146 & 0.021 & 0.09 & 42.3 \\

# %%
# NEW LATEX AUTOMATED CODE WITH MANUAL CHI^2 CALCULATION with individual position delta RMS and flux ratio differences
# WGD2038
import numpy as np
import pandas as pd
from astropy.io import fits
import os

# Function to calculate distance
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Function to read observed positions, flux ratios, and uncertainties
def read_observed_positions(input_file):
    observed_positions = []
    observed_flux_ratios = []
    position_uncertainties = []
    flux_uncertainties = []
    with open(input_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            columns = line.split()
            if len(columns) >= 5:
                x1 = float(columns[0])
                y1 = float(columns[1])
                flux_ratio = float(columns[2])
                pos_err = float(columns[3])
                flux_err = float(columns[4])
                observed_positions.append((x1, y1))
                observed_flux_ratios.append(flux_ratio)
                position_uncertainties.append(pos_err)
                flux_uncertainties.append(flux_err)
    return observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties

# Function to read predicted positions and magnifications
def read_predicted_positions(output_file):
    predicted_positions = []
    predicted_magnifications = []
    with open(output_file, 'r') as file:
        lines = file.readlines()[1:]  # Skip the first line
        for line in lines:
            if line.startswith("#"):
                continue
            columns = line.split()
            if len(columns) >= 3:
                x2 = float(columns[0])
                y2 = float(columns[1])
                M2 = abs(float(columns[2]))
                predicted_positions.append((x2, y2))
                predicted_magnifications.append(M2)
    return predicted_positions, predicted_magnifications

# Function to pair predicted and observed positions
def pair_positions(observed_positions, predicted_positions, predicted_magnifications):
    paired_positions = []
    for observed_position in observed_positions:
        min_distance = float('inf')
        closest_index = None
        for i, predicted_position in enumerate(predicted_positions):
            distance = calculate_distance(*observed_position, *predicted_position)
            if distance < min_distance:
                min_distance = distance
                closest_index = i
        paired_positions.append((observed_position, predicted_positions[closest_index], predicted_magnifications[closest_index]))
    return paired_positions

# Function to calculate manual chi² with proper uncertainties
def calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties, 
                         predicted_positions, predicted_magnifications, green_index=1):
    # Pair positions
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Calculate predicted flux ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]
    
    chi2 = 0.0
    
    # Position contributions to chi²
    for i, (observed, predicted, _) in enumerate(paired_positions):
        dx = observed[0] - predicted[0]
        dy = observed[1] - predicted[1]
        pos_err = position_uncertainties[i]
        chi2 += (dx/pos_err)**2 + (dy/pos_err)**2
    
    # Flux ratio contributions to chi² (excluding the normalization image)
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_err = flux_uncertainties[i]
            chi2 += ((pred_flux - obs_flux)/flux_err)**2
    
    return chi2

# Function to extract the final chi^2 from optresult.dat file
def extract_glafic_chi2(optresult_path):
    chi2_value = None
    with open(optresult_path, 'r') as file:
        lines = file.readlines()
    
    # Find the last occurrence of chi^2 (final/best result)
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
    
    return chi2_value

# Function to process file group
def process_file_group(output_file, fits_file, input_file, n):
    observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties = read_observed_positions(input_file)
    predicted_positions, predicted_magnifications = read_predicted_positions(output_file)
    
    paired_positions = pair_positions(observed_positions, predicted_positions, predicted_magnifications)
    
    # Calculate Delta RMS of Image Positions correctly
    squared_distances = 0.0
    individual_distances = []  # Store individual distances for each image
    for observed, predicted, _ in paired_positions:
        distance = calculate_distance(*observed, *predicted)
        individual_distances.append(distance * 1000)  # Convert to mas
        squared_distances += distance ** 2  # Summing squared distances
    
    mean_squared_distances = squared_distances / len(paired_positions)
    delta_rms = np.sqrt(mean_squared_distances)  # Taking square root of the mean of squared distances
    delta_rms *= 1000  # Convert to mas
    
    # Order predicted positions and magnifications based on observed order
    predicted_positions_ordered = [pair[1] for pair in paired_positions]
    predicted_magnifications_ordered = [pair[2] for pair in paired_positions]
    
    # Determine the index of the "Green Image"
    green_index = 1  # CHOOSE WHICH IMAGE TO NORMALISE BY HERE !!!!!!!!!!!!!!!!!!!!!!!

    # Predicted Flux Ratios
    predicted_flux_ratios = [m / predicted_magnifications_ordered[green_index] for m in predicted_magnifications_ordered]

    # Calculate absolute differences between predicted and observed flux ratios (excluding normalization image)
    flux_ratio_differences = []
    for i, (pred_flux, obs_flux) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)):
        if i != green_index:  # Exclude the green image used for normalization
            flux_ratio_differences.append(abs(pred_flux - obs_flux))

    # Calculate manual chi²
    manual_chi2 = calculate_manual_chi2(observed_positions, observed_flux_ratios, position_uncertainties, flux_uncertainties,
                                       predicted_positions, predicted_magnifications, green_index)

    with fits.open(fits_file) as hdul:
        mag = hdul[0].data[6]
    
    pixel_coords = [(int((x + mag.shape[1] // 2 * n) / n), int((y + mag.shape[0] // 2 * n) / n)) for x, y in observed_positions]
    values = [mag[y, x] for x, y in pixel_coords]
    
    abs_values = [1 / abs(value) for value in values]
    predicted_flux_ratios_observed = [abs_values[i] / abs_values[green_index] for i in range(len(abs_values))]

    # Calculate RMS excluding the green image
    squared_diffs_pred = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_rms = np.sqrt(sum(squared_diffs_pred) / len(squared_diffs_pred))

    squared_diffs_obs = [(pred - obs) ** 2 for i, (pred, obs) in enumerate(zip(predicted_flux_ratios_observed, observed_flux_ratios)) if i != green_index]
    predicted_flux_ratios_observed_rms = np.sqrt(sum(squared_diffs_obs) / len(squared_diffs_obs))

    return {
        'delta_rms': delta_rms,
        'individual_position_deltas': individual_distances,  # Delta RMS for each of the 4 positions
        'flux_ratio_differences': flux_ratio_differences,    # Absolute differences for 3 flux ratios
        'predicted_flux_ratios_rms': predicted_flux_ratios_rms,
        'predicted_flux_ratios_observed_rms': predicted_flux_ratios_observed_rms,
        'manual_chi2': manual_chi2
    }

# Function to extract chi^2 and lens models from optresult.dat file (following Code 1's approach exactly)
def extract_chi2_and_lens_profiles(optresult_path):
    chi2_value = None
    profiles_used = []
    sie_count = 0

    with open(optresult_path, 'r') as file:
        lines = file.readlines()

    found_chi2 = False
    for line in lines:
        if line.startswith("chi^2"):
            chi2_value = float(line.split()[2])
            found_chi2 = True
            profiles_used = []
            sie_count = 0
        elif found_chi2:
            if line.startswith("lens   sie"):
                profiles_used.append("SIE")
                sie_count += 1
            elif line.startswith("lens   pow"):
                profiles_used.append("POW")
            elif line.startswith("lens   anfw"):
                profiles_used.append("NFW")
            elif line.startswith("lens   pert"):
                profiles_used.append("Shear")

    if chi2_value is None:
        raise ValueError("No chi^2 value found in the file.")

    profiles_used = list(set(profiles_used))
    return chi2_value, profiles_used, sie_count

# Function to calculate free parameters based on lens profiles (identical to Code 1)
def calculate_free_parameters(profiles_used, sie_count):
    profile_params = {
        "SIE": 5,
        "POW": 6,
        "NFW": 6,
        "Shear": 5
    }
    total_params = sum(profile_params[profile] for profile in profiles_used)
    if sie_count == 2:
        total_params += 5
    return total_params

# Function to calculate BIC (Bayesian Information Criterion)
def calculate_bic(chi2, n_data_points, n_free_params):
    return chi2 + n_free_params * np.log(n_data_points)

# Function to compute BIC using manual chi² but following Code 1's approach for free parameters
def compute_bic_with_tracking(manual_chi2, optresult_path):
    # Use Code 1's approach: extract profiles from optresult.dat file
    glafic_chi2, profiles_used, sie_count = extract_chi2_and_lens_profiles(optresult_path)
    n_free_params = calculate_free_parameters(profiles_used, sie_count)
    
    # Properly adjust n_data_points based on constraint type
    if "PF" in optresult_path:
        n_data_points = 4 * 2 + 3  # positions + flux ratios
    else:
        n_data_points = 4 * 2  # positions only
    
    # Always use manual chi² for BIC calculation
    bic_value = calculate_bic(manual_chi2, n_data_points, n_free_params)
    
    return bic_value, glafic_chi2, n_data_points, n_free_params

# Main function to process multiple files
def process_files(input_file, output_files, fits_files, optresult_files, n):
    results = []
    latex_rows = []
    bics = []  # Store BIC values separately
    glafic_chi2_values = []  # Store glafic chi² for reference
    data_points_used = []  # Store number of data points used
    free_params_used = []  # Store number of free parameters used

    for output_file, fits_file, optresult_file in zip(output_files, fits_files, optresult_files):
        # Process output and fits files
        result = process_file_group(output_file, fits_file, input_file, n)
        results.append(result)
        
        # Calculate BIC using manual chi² but track both values
        bic, glafic_chi2, n_data_points, n_free_params = compute_bic_with_tracking(result['manual_chi2'], optresult_file)
        bics.append(bic)
        glafic_chi2_values.append(glafic_chi2)
        data_points_used.append(n_data_points)
        free_params_used.append(n_free_params)
        
        # Create LaTeX row with additional information
        model_name, constraint_name = determine_model_and_constraint(output_file)
        # Format individual position deltas and flux ratio differences for LaTeX
        pos_deltas_str = " & ".join([f"{delta:.3f}" for delta in result['individual_position_deltas']])
        flux_diffs_str = " & ".join([f"{diff:.3f}" for diff in result['flux_ratio_differences']])
        
        latex_row = f"{model_name} & {constraint_name} & {pos_deltas_str} & {result['delta_rms']:.1f} & {flux_diffs_str} & {result['predicted_flux_ratios_rms']:.2f} & {bic:.1f} \\\\"
        latex_rows.append(latex_row)
    
    # Combine results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results['bic'] = bics  # Add BIC values to the DataFrame
    df_results['glafic_chi2'] = glafic_chi2_values  # Add glafic chi² for reference
    df_results['n_data_points'] = data_points_used  # Add number of data points used
    df_results['n_free_params'] = free_params_used  # Add number of free parameters used
    
    return df_results, latex_rows

# Determine model and constraint names from the filename
def determine_model_and_constraint(file_name):
    model_map = {'S': 'SIE', 'P': 'POW', 'N': 'NFW'}
    
    base_name = os.path.basename(file_name)
    model_key = base_name[3]
    constraint_key = base_name[4:6] if base_name[4:6] in ['PF'] else base_name[4]
    
    model_name = model_map.get(model_key, '')
    if 'R' in base_name:
        model_name += ' + Shear'
    if 'G' in base_name:
        model_name += ' + G2'
    
    constraint_name = 'QSO Pos + FR' if constraint_key == 'PF' else 'QSO Pos'
    
    return model_name, constraint_name

# Example usage with filenames
Input_file = "WGD2038/SPFC/Robs_point_MT.dat"

Output_files = [
#    "WGD2038/SPC/outSP_point.dat",
#    "WGD2038/SPC/outSPR_point.dat",
#    "WGD2038/SPFC/outSPF_point.dat",
#    "WGD2038/SPFC/outSPFR_point.dat",
    "WGD2038/SPFC/outSPF_MT_point.dat",
#    "WGD2038/SPFC/outSPF_PT_point.dat",
#    "WGD2038/PPC/outPP_point.dat",
#    "WGD2038/PPC/outPPR_point.dat",
#    "WGD2038/PPFC/outPPF_point.dat",
#    "WGD2038/PPFC/outPPFR_point.dat",
#    "WGD2038/NPC/outNP_point.dat",
#    "WGD2038/NPC/outNPR_point.dat",
#    "WGD2038/NPFC/outNPF_point.dat",
#    "WGD2038/NPFC/outNPFR_point.dat"
]

Fits_files = [
#    "WGD2038/SPC/outSP_lens.fits",
#    "WGD2038/SPC/outSPR_lens.fits",
#    "WGD2038/SPFC/outSPF_lens.fits",
#    "WGD2038/SPFC/outSPFR_lens.fits",
    "WGD2038/SPFC/outSPF_MT_lens.fits",
#    "WGD2038/SPFC/outSPF_PT_lens.fits",
#    "WGD2038/PPC/outPP_lens.fits",
#    "WGD2038/PPC/outPPR_lens.fits",
#    "WGD2038/PPFC/outPPF_lens.fits",
#    "WGD2038/PPFC/outPPFR_lens.fits",
#    "WGD2038/NPC/outNP_lens.fits",
#    "WGD2038/NPC/outNPR_lens.fits",
#    "WGD2038/NPFC/outNPF_lens.fits",
#    "WGD2038/NPFC/outNPFR_lens.fits"
]

Optresult_files = [
#    "WGD2038/SPC/outSP_optresult.dat",
#    "WGD2038/SPC/outSPR_optresult.dat",
#    "WGD2038/SPFC/outSPF_optresult.dat",
#    "WGD2038/SPFC/outSPFR_optresult.dat",
    "WGD2038/SPFC/outSPF_MT_optresult.dat",
#    "WGD2038/SPFC/outSPF_PT_optresult.dat",
#    "WGD2038/PPC/outPP_optresult.dat",
#    "WGD2038/PPC/outPPR_optresult.dat",
#    "WGD2038/PPFC/outPPF_optresult.dat",
#    "WGD2038/PPFC/outPPFR_optresult.dat",
#    "WGD2038/NPC/outNP_optresult.dat",
#    "WGD2038/NPC/outNPR_optresult.dat",
#    "WGD2038/NPFC/outNPF_optresult.dat",
#    "WGD2038/NPFC/outNPFR_optresult.dat"
]

n = 0.0025  # Example scale factor
results_df, latex_rows = process_files(Input_file, Output_files, Fits_files, Optresult_files, n)

# Print formatted results
for i, output_file in enumerate(Output_files):
    constraint_type = "PF" if "PF" in Optresult_files[i] else "P"
    print(f"Model: {output_file}")
    print(f"Constraint Type: {constraint_type}")
    print(f"Number of data points used: {results_df.iloc[i]['n_data_points']}")
    print(f"Number of free parameters: {results_df.iloc[i]['n_free_params']}")
    print(f"Delta RMS of Image Positions: {results_df.iloc[i]['delta_rms']:.3f}")
    
    # Print individual position deltas (4 positions)
    print(f"Individual Position Deltas (mas):")
    for j, delta in enumerate(results_df.iloc[i]['individual_position_deltas']):
        print(f"  Image {j+1}: {delta:.3f}")
    
    print(f"Delta RMS of flux ratios at the observed position: {results_df.iloc[i]['predicted_flux_ratios_observed_rms']:.3f}")
    print(f"Delta RMS of flux ratios at the predicted position: {results_df.iloc[i]['predicted_flux_ratios_rms']:.3f}")
    
    # Print absolute flux ratio differences (3 ratios, excluding normalization)
    print(f"Absolute Flux Ratio Differences:")
    flux_diff_indices = [0, 2, 3] if len(results_df.iloc[i]['flux_ratio_differences']) == 3 else range(len(results_df.iloc[i]['flux_ratio_differences']))
    for j, diff in enumerate(results_df.iloc[i]['flux_ratio_differences']):
        img_idx = flux_diff_indices[j] + 1
        print(f"  Image {img_idx}: {diff:.3f}")
    
    print(f"Manual Chi²: {results_df.iloc[i]['manual_chi2']:.3f}")
    if results_df.iloc[i]['glafic_chi2'] is not None:
        print(f"Glafic Chi² (final, reference): {results_df.iloc[i]['glafic_chi2']:.3f}")
        print(f"Chi² Difference (Manual - Glafic): {results_df.iloc[i]['manual_chi2'] - results_df.iloc[i]['glafic_chi2']:.3f}")
    else:
        print(f"Glafic Chi² (reference): Not found")
    print(f"BIC (using manual Chi²): {results_df.iloc[i]['bic']:.3f}")
    
    # Manual verification of BIC calculation
    manual_bic_check = results_df.iloc[i]['manual_chi2'] + results_df.iloc[i]['n_free_params'] * np.log(results_df.iloc[i]['n_data_points'])
    print(f"Manual BIC verification: {results_df.iloc[i]['manual_chi2']:.3f} + {results_df.iloc[i]['n_free_params']} × ln({results_df.iloc[i]['n_data_points']}) = {manual_bic_check:.3f}")
    print()

# Print LaTeX-formatted rows
print("LaTeX Table Rows:")
print("Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC")
for row in latex_rows:
    print(row)
# Out:
# Model: WGD2038/SPFC/outSPF_MT_point.dat
# Constraint Type: PF
# Number of data points used: 11
# Number of free parameters: 5
# Delta RMS of Image Positions: 5.538
# Individual Position Deltas (mas):
#   Image 1: 6.435
#   Image 2: 2.789
#   Image 3: 4.701
#   Image 4: 7.169
# Delta RMS of flux ratios at the observed position: 0.452
# Delta RMS of flux ratios at the predicted position: 0.004
# Absolute Flux Ratio Differences:
#   Image 1: 0.004
#   Image 3: 0.000
#   Image 4: 0.005
# Manual Chi²: 5.289
# Glafic Chi² (final, reference): 5.945
# Chi² Difference (Manual - Glafic): -0.656
# BIC (using manual Chi²): 17.278
# Manual BIC verification: 5.289 + 5 × ln(11) = 17.278
#
# LaTeX Table Rows:
# Format: Model & Constraint & Pos1 & Pos2 & Pos3 & Pos4 & Overall ΔRMS & FluxDiff1 & FluxDiff2 & FluxDiff3 & Flux RMS & BIC
# SIE & QSO Pos + FR & 6.435 & 2.789 & 4.701 & 7.169 & 5.5 & 0.004 & 0.000 & 0.005 & 0.00 & 17.3 \\
