# %%
def extract_sie_parameters(filename):
    """
    Extract the NFW lens parameters from the last "lens anfw" line that appears in the file.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()

    last_sie_index = None
    for index, line in enumerate(lines):
        if "lens   anfw" in line:
            last_sie_index = index

    if last_sie_index is None:
        print(f"Error: 'lens anfw' line not found in file: {filename}.")
        return None

    line = lines[last_sie_index]
    parts = line.split()
    try:
        lens_redshift = float(parts[2])
        dm_mass = float(parts[3])
        x_coord = float(parts[4])
        y_coord = float(parts[5])
        ellipticity = float(parts[6])
        position_angle = float(parts[7])
        concentration_para = float(parts[8])
        return (lens_redshift, dm_mass, x_coord, y_coord, ellipticity, position_angle, concentration_para)
    except (ValueError, IndexError):
        print(f"Error: Failed to extract numbers from line: {line} in file: {filename}.")
        return None

def rename_file(file_path):
    parts = file_path.split("/")
    lens_system = parts[0]
    file_name = parts[-1]

    key = file_name.split("_optresult")[0][3:]
    profile_map = {"S": "SIE", "P": "POW", "N": "NFW"}
    profile = profile_map.get(key[0], "Unknown")

    constraint = "Unknown constraint"
    if key[1:3] == "PF":
        constraint = "QSO Pos + FR"
    elif key[1] == "P":
        constraint = "QSO Pos"

    extras = []
    if "G" in key:
        extras.append("G2")
    if "R" in key:
        extras.append("Shear")

    if len(extras) == 2:
        profile_description = f"{profile} + {extras[0]} + {extras[1]}"
    elif len(extras) == 1:
        profile_description = f"{profile} + {extras[0]}"
    else:
        profile_description = profile

    new_name = f"{lens_system} & {profile_description} & {constraint}"
    return new_name

def process_multiple_files(file_list):
    results = []
    for file_name in file_list:
        model_description = rename_file(file_name)
        sie_parameters = extract_sie_parameters(file_name)
        if sie_parameters:
            lens_redshift, dm_mass, x_coord, y_coord, ellipticity, position_angle, concentration_para = sie_parameters
            result_text = f"{model_description} & {lens_redshift:.3f} & {dm_mass:e} & {x_coord:.3f} & {y_coord:.3f} & {ellipticity:.3f} & {position_angle:.3f} & {concentration_para:.3f} \\\\"
            results.append(result_text)
            print(f"Model: {file_name}")
            print(f"Lens Redshift: {lens_redshift:.3f}")
            print(f"DM Mass: {dm_mass:e}")
            print(f"X Coordinate: {x_coord:.3f}")
            print(f"Y Coordinate: {y_coord:.3f}")
            print(f"Ellipticity: {ellipticity:.3f}")
            print(f"Position Angle: {position_angle:.3f}")
            print(f"Concentration Parameter: {concentration_para:.3f}\n")
        else:
            results.append(f"{model_description} Failed to extract SIE parameters.")
            print(f"Model: {file_name} Failed to extract SIE parameters.\n")
    return results

# List of file paths to process
file_list = [
    "RXJ0911/NPC/outNP_optresult.dat",
    "RXJ0911/NPC/outNPR_optresult.dat",
    "RXJ0911/NPC/outNPG_optresult.dat",
    "RXJ0911/NPC/outNPGR_optresult.dat",
    "RXJ0911/NPFC/outNPF_optresult.dat",
    "RXJ0911/NPFC/outNPFR_optresult.dat",
    "RXJ0911/NPFC/outNPFG_optresult.dat",
    "RXJ0911/NPFC/outNPFGR_optresult.dat",
    "PSJ1606/NPC/outNP_optresult.dat",
    "PSJ1606/NPC/outNPR_optresult.dat",
    "PSJ1606/NPC/outNPG_optresult.dat",
    "PSJ1606/NPC/outNPGR_optresult.dat",
    "PSJ1606/NPFC/outNPF_optresult.dat",
    "PSJ1606/NPFC/outNPFR_optresult.dat",
    "PSJ1606/NPFC/outNPFG_optresult.dat",
    "PSJ1606/NPFC/outNPFGR_optresult.dat",
    "WFI2033/NP/outNP_optresult.dat",
    "WFI2033/NPR/outNPR_optresult.dat",
    "WFI2033/NPG/outNPG_optresult.dat",
    "WFI2033/NPGR/outNPGR_optresult.dat",
    "WFI2033/NPF/outNPF_optresult.dat",
    "WFI2033/NPFR/outNPFR_optresult.dat",
    "WFI2033/NPFG/outNPFG_optresult.dat",
    "WFI2033/NPFGR/outNPFGR_optresult.dat",
    "SDSSJ1330/NPC/outNP_optresult.dat",
    "SDSSJ1330/NPC/outNPR_optresult.dat",
    "SDSSJ1330/NPFC/outNPF_optresult.dat",
    "SDSSJ1330/NPFC/outNPFR_optresult.dat",
    "WFI2026/NPC/outNP_optresult.dat",
    "WFI2026/NPC/outNPR_optresult.dat",
    "WFI2026/NPFC/outNPF_optresult.dat",
    "WFI2026/NPFC/outNPFR_optresult.dat",
    "WGDJ0405/NPC/outNP_optresult.dat",
    "WGDJ0405/NPC/outNPR_optresult.dat",
    "WGDJ0405/NPFC/outNPF_optresult.dat",
    "WGDJ0405/NPFC/outNPFR_optresult.dat",
    "WGD2038/NPC/outNP_optresult.dat",
    "WGD2038/NPC/outNPR_optresult.dat",
    "WGD2038/NPFC/outNPF_optresult.dat",
    "WGD2038/NPFC/outNPFR_optresult.dat"
]

# Execute the function and print LaTeX-formatted results
latex_results = process_multiple_files(file_list)
for result in latex_results:
    print(result)
# Out:
# Model: RXJ0911/NPC/outNP_optresult.dat
# Lens Redshift: 0.769
# DM Mass: 3.315409e+12
# X Coordinate: -0.057
# Y Coordinate: 0.032
# Ellipticity: 0.600
# Position Angle: 174.181
# Concentration Parameter: 36.463
#
# Model: RXJ0911/NPC/outNPR_optresult.dat
# Lens Redshift: 0.769
# DM Mass: 6.074486e+11
# X Coordinate: 0.000
# Y Coordinate: 0.036
# Ellipticity: 0.281
# Position Angle: 205.056
# Concentration Parameter: 39.832
#
# Model: RXJ0911/NPC/outNPG_optresult.dat
# Lens Redshift: 0.769
# DM Mass: 2.303631e+12
# X Coordinate: 0.009
# Y Coordinate: -0.058
# Ellipticity: 0.600
# Position Angle: 355.965
# Concentration Parameter: 38.572
#
# Model: RXJ0911/NPC/outNPGR_optresult.dat
# Lens Redshift: 0.769
# DM Mass: 3.497114e+11
# X Coordinate: 0.000
# Y Coordinate: -0.015
# Ellipticity: 0.323
# Position Angle: 260.981
# Concentration Parameter: 40.060
#
# Model: RXJ0911/NPFC/outNPF_optresult.dat
# Lens Redshift: 0.769
# DM Mass: 3.094526e+12
# X Coordinate: -0.078
# Y Coordinate: 0.034
# Ellipticity: 0.600
# Position Angle: 174.198
# Concentration Parameter: 39.445
#
# Model: RXJ0911/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.769
# DM Mass: 2.170073e+11
# X Coordinate: -0.001
# Y Coordinate: 0.036
# Ellipticity: 0.270
# Position Angle: 210.400
# Concentration Parameter: 39.525
#
# Model: RXJ0911/NPFC/outNPFG_optresult.dat
# Lens Redshift: 0.769
# DM Mass: 2.543897e+12
# X Coordinate: 0.054
# Y Coordinate: -0.072
# Ellipticity: 0.600
# Position Angle: 356.521
# Concentration Parameter: 33.369
#
# Model: RXJ0911/NPFC/outNPFGR_optresult.dat
# Lens Redshift: 0.769
# DM Mass: 2.281835e+11
# X Coordinate: 0.004
# Y Coordinate: -0.010
# Ellipticity: 0.284
# Position Angle: 257.646
# Concentration Parameter: 39.541
#
# Model: PSJ1606/NPC/outNP_optresult.dat
# Lens Redshift: 0.300
# DM Mass: 1.191725e+12
# X Coordinate: -0.028
# Y Coordinate: 0.014
# Ellipticity: 0.452
# Position Angle: -340.598
# Concentration Parameter: 40.068
#
# Model: PSJ1606/NPC/outNPR_optresult.dat
# Lens Redshift: 0.300
# DM Mass: 1.397836e+11
# X Coordinate: -0.017
# Y Coordinate: 0.014
# Ellipticity: 0.201
# Position Angle: 177.516
# Concentration Parameter: 76.886
#
# Model: PSJ1606/NPC/outNPG_optresult.dat
# Lens Redshift: 0.300
# DM Mass: 1.167976e+12
# X Coordinate: 0.039
# Y Coordinate: 0.035
# Ellipticity: 0.342
# Position Angle: 213.223
# Concentration Parameter: 35.825
#
# Model: PSJ1606/NPC/outNPGR_optresult.dat
# Lens Redshift: 0.300
# DM Mass: 1.334585e+11
# X Coordinate: 0.000
# Y Coordinate: 0.000
# Ellipticity: 0.427
# Position Angle: 194.677
# Concentration Parameter: 40.125
#
# Model: PSJ1606/NPFC/outNPF_optresult.dat
# Lens Redshift: 0.300
# DM Mass: 9.182368e+11
# X Coordinate: -0.030
# Y Coordinate: 0.000
# Ellipticity: 0.524
# Position Angle: 19.421
# Concentration Parameter: 48.460
#
# Model: PSJ1606/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.300
# DM Mass: 4.986301e+10
# X Coordinate: -0.017
# Y Coordinate: 0.008
# Ellipticity: 0.224
# Position Angle: 180.501
# Concentration Parameter: 39.980
#
# Model: PSJ1606/NPFC/outNPFG_optresult.dat
# Lens Redshift: 0.300
# DM Mass: 9.630332e+11
# X Coordinate: -0.019
# Y Coordinate: 0.006
# Ellipticity: 0.480
# Position Angle: 201.281
# Concentration Parameter: 45.060
#
# Model: PSJ1606/NPFC/outNPFGR_optresult.dat
# Lens Redshift: 0.300
# DM Mass: 2.535378e+11
# X Coordinate: 0.014
# Y Coordinate: -0.001
# Ellipticity: 0.326
# Position Angle: 193.804
# Concentration Parameter: 45.384
#
# Model: WFI2033/NP/outNP_optresult.dat
# Lens Redshift: 0.661
# DM Mass: 5.005271e+12
# X Coordinate: -0.035
# Y Coordinate: 0.034
# Ellipticity: 0.340
# Position Angle: 334.723
# Concentration Parameter: 24.697
#
# Model: WFI2033/NPR/outNPR_optresult.dat
# Lens Redshift: 0.661
# DM Mass: 2.837863e+12
# X Coordinate: -0.015
# Y Coordinate: 0.029
# Ellipticity: 0.275
# Position Angle: 92.039
# Concentration Parameter: 25.848
#
# Model: WFI2033/NPG/outNPG_optresult.dat
# Lens Redshift: 0.661
# DM Mass: 3.462069e+12
# X Coordinate: -0.009
# Y Coordinate: -0.007
# Ellipticity: 0.274
# Position Angle: 144.277
# Concentration Parameter: 29.891
#
# Model: WFI2033/NPGR/outNPGR_optresult.dat
# Lens Redshift: 0.661
# DM Mass: 3.022328e+12
# X Coordinate: 0.000
# Y Coordinate: -0.011
# Ellipticity: 0.254
# Position Angle: 143.579
# Concentration Parameter: 26.186
#
# Model: WFI2033/NPF/outNPF_optresult.dat
# Lens Redshift: 0.661
# DM Mass: 4.985502e+12
# X Coordinate: -0.038
# Y Coordinate: 0.039
# Ellipticity: 0.345
# Position Angle: 334.666
# Concentration Parameter: 24.775
#
# Model: WFI2033/NPFR/outNPFR_optresult.dat
# Lens Redshift: 0.661
# DM Mass: 2.626549e+12
# X Coordinate: 0.027
# Y Coordinate: 0.052
# Ellipticity: 0.453
# Position Angle: 77.332
# Concentration Parameter: 23.754
#
# Model: WFI2033/NPFG/outNPFG_optresult.dat
# Lens Redshift: 0.661
# DM Mass: 3.469248e+12
# X Coordinate: -0.016
# Y Coordinate: -0.010
# Ellipticity: 0.279
# Position Angle: 144.751
# Concentration Parameter: 29.893
#
# Model: WFI2033/NPFGR/outNPFGR_optresult.dat
# Lens Redshift: 0.661
# DM Mass: 4.423596e+12
# X Coordinate: 0.002
# Y Coordinate: -0.004
# Ellipticity: 0.039
# Position Angle: 219.087
# Concentration Parameter: 22.362
#
# Model: SDSSJ1330/NPC/outNP_optresult.dat
# Lens Redshift: 0.373
# DM Mass: 1.695000e+12
# X Coordinate: -0.019
# Y Coordinate: -0.005
# Ellipticity: 0.192
# Position Angle: 146.717
# Concentration Parameter: 40.769
#
# Model: SDSSJ1330/NPC/outNPR_optresult.dat
# Lens Redshift: 0.373
# DM Mass: 3.934858e+11
# X Coordinate: -0.009
# Y Coordinate: 0.011
# Ellipticity: 0.346
# Position Angle: 158.438
# Concentration Parameter: 46.517
#
# Model: SDSSJ1330/NPFC/outNPF_optresult.dat
# Lens Redshift: 0.373
# DM Mass: 7.198888e+11
# X Coordinate: -0.011
# Y Coordinate: -0.006
# Ellipticity: 0.356
# Position Angle: 147.533
# Concentration Parameter: 90.012
#
# Model: SDSSJ1330/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.373
# DM Mass: 3.506676e+11
# X Coordinate: -0.002
# Y Coordinate: 0.014
# Ellipticity: 0.423
# Position Angle: 156.390
# Concentration Parameter: 50.051
#
# Model: WFI2026/NPC/outNP_optresult.dat
# Lens Redshift: 1.040
# DM Mass: 1.832304e+12
# X Coordinate: -0.061
# Y Coordinate: 0.012
# Ellipticity: 0.353
# Position Angle: 89.873
# Concentration Parameter: 30.081
#
# Model: WFI2026/NPC/outNPR_optresult.dat
# Lens Redshift: 1.040
# DM Mass: 5.493120e+11
# X Coordinate: -0.052
# Y Coordinate: 0.021
# Ellipticity: 0.342
# Position Angle: 81.005
# Concentration Parameter: 30.073
#
# Model: WFI2026/NPFC/outNPF_optresult.dat
# Lens Redshift: 1.040
# DM Mass: 1.410240e+12
# X Coordinate: -0.062
# Y Coordinate: 0.000
# Ellipticity: 0.430
# Position Angle: 89.645
# Concentration Parameter: 38.183
#
# Model: WFI2026/NPFC/outNPFR_optresult.dat
# Lens Redshift: 1.040
# DM Mass: 1.432360e+11
# X Coordinate: -0.052
# Y Coordinate: 0.018
# Ellipticity: 0.341
# Position Angle: 81.155
# Concentration Parameter: 38.871
#
# Model: WGDJ0405/NPC/outNP_optresult.dat
# Lens Redshift: 0.290
# DM Mass: 3.692184e+11
# X Coordinate: 0.014
# Y Coordinate: -0.012
# Ellipticity: 0.174
# Position Angle: -30.818
# Concentration Parameter: 90.476
#
# Model: WGDJ0405/NPC/outNPR_optresult.dat
# Lens Redshift: 0.290
# DM Mass: 4.267108e+11
# X Coordinate: 0.015
# Y Coordinate: -0.014
# Ellipticity: 0.179
# Position Angle: -45.466
# Concentration Parameter: 45.005
#
# Model: WGDJ0405/NPFC/outNPF_optresult.dat
# Lens Redshift: 0.290
# DM Mass: 3.698924e+11
# X Coordinate: 0.014
# Y Coordinate: -0.013
# Ellipticity: 0.164
# Position Angle: -30.811
# Concentration Parameter: 90.256
#
# Model: WGDJ0405/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.290
# DM Mass: 4.278096e+11
# X Coordinate: 0.015
# Y Coordinate: -0.015
# Ellipticity: 0.173
# Position Angle: -46.896
# Concentration Parameter: 45.002
#
# Model: WGD2038/NPC/outNP_optresult.dat
# Lens Redshift: 0.230
# DM Mass: 4.441525e+12
# X Coordinate: -0.003
# Y Coordinate: 0.005
# Ellipticity: 0.203
# Position Angle: -35.497
# Concentration Parameter: 28.576
#
# Model: WGD2038/NPC/outNPR_optresult.dat
# Lens Redshift: 0.230
# DM Mass: 5.873966e+11
# X Coordinate: -0.000
# Y Coordinate: 0.000
# Ellipticity: 0.295
# Position Angle: -37.245
# Concentration Parameter: 75.572
#
# Model: WGD2038/NPFC/outNPF_optresult.dat
# Lens Redshift: 0.230
# DM Mass: 2.655840e+12
# X Coordinate: 0.021
# Y Coordinate: 0.026
# Ellipticity: 0.296
# Position Angle: -35.496
# Concentration Parameter: 39.984
#
# Model: WGD2038/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.230
# DM Mass: 1.339283e+11
# X Coordinate: 0.004
# Y Coordinate: 0.000
# Ellipticity: 0.369
# Position Angle: -36.414
# Concentration Parameter: 69.887
#
# RXJ0911 & NFW & QSO Pos & 0.769 & 3.315409e+12 & -0.057 & 0.032 & 0.600 & 174.181 & 36.463 \\
# RXJ0911 & NFW + Shear & QSO Pos & 0.769 & 6.074486e+11 & 0.000 & 0.036 & 0.281 & 205.056 & 39.832 \\
# RXJ0911 & NFW + G2 & QSO Pos & 0.769 & 2.303631e+12 & 0.009 & -0.058 & 0.600 & 355.965 & 38.572 \\
# RXJ0911 & NFW + G2 + Shear & QSO Pos & 0.769 & 3.497114e+11 & 0.000 & -0.015 & 0.323 & 260.981 & 40.060 \\
# RXJ0911 & NFW & QSO Pos + FR & 0.769 & 3.094526e+12 & -0.078 & 0.034 & 0.600 & 174.198 & 39.445 \\
# RXJ0911 & NFW + Shear & QSO Pos + FR & 0.769 & 2.170073e+11 & -0.001 & 0.036 & 0.270 & 210.400 & 39.525 \\
# RXJ0911 & NFW + G2 & QSO Pos + FR & 0.769 & 2.543897e+12 & 0.054 & -0.072 & 0.600 & 356.521 & 33.369 \\
# RXJ0911 & NFW + G2 + Shear & QSO Pos + FR & 0.769 & 2.281835e+11 & 0.004 & -0.010 & 0.284 & 257.646 & 39.541 \\
# PSJ1606 & NFW & QSO Pos & 0.300 & 1.191725e+12 & -0.028 & 0.014 & 0.452 & -340.598 & 40.068 \\
# PSJ1606 & NFW + Shear & QSO Pos & 0.300 & 1.397836e+11 & -0.017 & 0.014 & 0.201 & 177.516 & 76.886 \\
# PSJ1606 & NFW + G2 & QSO Pos & 0.300 & 1.167976e+12 & 0.039 & 0.035 & 0.342 & 213.223 & 35.825 \\
# PSJ1606 & NFW + G2 + Shear & QSO Pos & 0.300 & 1.334585e+11 & 0.000 & 0.000 & 0.427 & 194.677 & 40.125 \\
# PSJ1606 & NFW & QSO Pos + FR & 0.300 & 9.182368e+11 & -0.030 & 0.000 & 0.524 & 19.421 & 48.460 \\
# PSJ1606 & NFW + Shear & QSO Pos + FR & 0.300 & 4.986301e+10 & -0.017 & 0.008 & 0.224 & 180.501 & 39.980 \\
# PSJ1606 & NFW + G2 & QSO Pos + FR & 0.300 & 9.630332e+11 & -0.019 & 0.006 & 0.480 & 201.281 & 45.060 \\
# PSJ1606 & NFW + G2 + Shear & QSO Pos + FR & 0.300 & 2.535378e+11 & 0.014 & -0.001 & 0.326 & 193.804 & 45.384 \\
# WFI2033 & NFW & QSO Pos & 0.661 & 5.005271e+12 & -0.035 & 0.034 & 0.340 & 334.723 & 24.697 \\
# WFI2033 & NFW + Shear & QSO Pos & 0.661 & 2.837863e+12 & -0.015 & 0.029 & 0.275 & 92.039 & 25.848 \\
# WFI2033 & NFW + G2 & QSO Pos & 0.661 & 3.462069e+12 & -0.009 & -0.007 & 0.274 & 144.277 & 29.891 \\
# WFI2033 & NFW + G2 + Shear & QSO Pos & 0.661 & 3.022328e+12 & 0.000 & -0.011 & 0.254 & 143.579 & 26.186 \\
# WFI2033 & NFW & QSO Pos + FR & 0.661 & 4.985502e+12 & -0.038 & 0.039 & 0.345 & 334.666 & 24.775 \\
# WFI2033 & NFW + Shear & QSO Pos + FR & 0.661 & 2.626549e+12 & 0.027 & 0.052 & 0.453 & 77.332 & 23.754 \\
# WFI2033 & NFW + G2 & QSO Pos + FR & 0.661 & 3.469248e+12 & -0.016 & -0.010 & 0.279 & 144.751 & 29.893 \\
# WFI2033 & NFW + G2 + Shear & QSO Pos + FR & 0.661 & 4.423596e+12 & 0.002 & -0.004 & 0.039 & 219.087 & 22.362 \\
# SDSSJ1330 & NFW & QSO Pos & 0.373 & 1.695000e+12 & -0.019 & -0.005 & 0.192 & 146.717 & 40.769 \\
# SDSSJ1330 & NFW + Shear & QSO Pos & 0.373 & 3.934858e+11 & -0.009 & 0.011 & 0.346 & 158.438 & 46.517 \\
# SDSSJ1330 & NFW & QSO Pos + FR & 0.373 & 7.198888e+11 & -0.011 & -0.006 & 0.356 & 147.533 & 90.012 \\
# SDSSJ1330 & NFW + Shear & QSO Pos + FR & 0.373 & 3.506676e+11 & -0.002 & 0.014 & 0.423 & 156.390 & 50.051 \\
# WFI2026 & NFW & QSO Pos & 1.040 & 1.832304e+12 & -0.061 & 0.012 & 0.353 & 89.873 & 30.081 \\
# WFI2026 & NFW + Shear & QSO Pos & 1.040 & 5.493120e+11 & -0.052 & 0.021 & 0.342 & 81.005 & 30.073 \\
# WFI2026 & NFW & QSO Pos + FR & 1.040 & 1.410240e+12 & -0.062 & 0.000 & 0.430 & 89.645 & 38.183 \\
# WFI2026 & NFW + Shear & QSO Pos + FR & 1.040 & 1.432360e+11 & -0.052 & 0.018 & 0.341 & 81.155 & 38.871 \\
# WGDJ0405 & NFW & QSO Pos & 0.290 & 3.692184e+11 & 0.014 & -0.012 & 0.174 & -30.818 & 90.476 \\
# WGDJ0405 & NFW + Shear & QSO Pos & 0.290 & 4.267108e+11 & 0.015 & -0.014 & 0.179 & -45.466 & 45.005 \\
# WGDJ0405 & NFW & QSO Pos + FR & 0.290 & 3.698924e+11 & 0.014 & -0.013 & 0.164 & -30.811 & 90.256 \\
# WGDJ0405 & NFW + Shear & QSO Pos + FR & 0.290 & 4.278096e+11 & 0.015 & -0.015 & 0.173 & -46.896 & 45.002 \\
# WGD2038 & NFW & QSO Pos & 0.230 & 4.441525e+12 & -0.003 & 0.005 & 0.203 & -35.497 & 28.576 \\
# WGD2038 & NFW + Shear & QSO Pos & 0.230 & 5.873966e+11 & -0.000 & 0.000 & 0.295 & -37.245 & 75.572 \\
# WGD2038 & NFW & QSO Pos + FR & 0.230 & 2.655840e+12 & 0.021 & 0.026 & 0.296 & -35.496 & 39.984 \\
# WGD2038 & NFW + Shear & QSO Pos + FR & 0.230 & 1.339283e+11 & 0.004 & 0.000 & 0.369 & -36.414 & 69.887 \\
