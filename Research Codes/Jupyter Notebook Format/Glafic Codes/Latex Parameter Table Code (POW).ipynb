# %%
def extract_sie_parameters(filename):
    """
    Extract the POW lens parameters from the last "lens pow" line that appears in the file.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()

    last_sie_index = None
    for index, line in enumerate(lines):
        if "lens   pow" in line:
            last_sie_index = index

    if last_sie_index is None:
        print(f"Error: 'lens pow' line not found in file: {filename}.")
        return None

    line = lines[last_sie_index]
    parts = line.split()
    try:
        lens_redshift = float(parts[3])
        source_redshift = float(parts[2])
        x_coord = float(parts[4])
        y_coord = float(parts[5])
        ellipticity = float(parts[6])
        position_angle = float(parts[7])
        einstein_radius = float(parts[8])
        pwi = float(parts[9])
        return (lens_redshift, source_redshift, x_coord, y_coord, ellipticity, position_angle, einstein_radius, pwi)
    except (ValueError, IndexError):
        print(f"Error: Failed to extract numbers from line: {line} in file: {filename}.")
        return None

def rename_file(file_path):
    parts = file_path.split("/")
    lens_system = parts[0]
    file_name = parts[-1]

    key = file_name.split("_optresult")[0][3:]
    profile_map = {"S": "SIE", "P": "POW", "N": "NFW"}
    profile = profile_map.get(key[0], "Unknown")

    constraint = "Unknown constraint"
    if key[1:3] == "PF":
        constraint = "QSO Pos + FR"
    elif key[1] == "P":
        constraint = "QSO Pos"

    extras = []
    if "G" in key:
        extras.append("G2")
    if "R" in key:
        extras.append("Shear")

    if len(extras) == 2:
        profile_description = f"{profile} + {extras[0]} + {extras[1]}"
    elif len(extras) == 1:
        profile_description = f"{profile} + {extras[0]}"
    else:
        profile_description = profile

    new_name = f"{lens_system} & {profile_description} & {constraint}"
    return new_name

def process_multiple_files(file_list):
    results = []
    for file_name in file_list:
        model_description = rename_file(file_name)
        sie_parameters = extract_sie_parameters(file_name)
        if sie_parameters:
            source_redshift, lens_redshift, x_coord, y_coord, ellipticity, position_angle, einstein_radius, pwi = sie_parameters
            result_text = f"{model_description} & {lens_redshift:.3f} & {source_redshift:.3f} & {x_coord:.3f} & {y_coord:.3f} & {ellipticity:.3f} & {position_angle:.3f} & {einstein_radius:.3f} & {pwi:.3f} \\\\"
            results.append(result_text)
            print(f"Model: {file_name}")
            print(f"Lens Redshift: {lens_redshift:.3f}")
            print(f"Source Redshift: {source_redshift:.3f}")
            print(f"X Coordinate: {x_coord:.3f}")
            print(f"Y Coordinate: {y_coord:.3f}")
            print(f"Ellipticity: {ellipticity:.3f}")
            print(f"Position Angle: {position_angle:.3f}")
            print(f"Einstein Radius: {einstein_radius:.3f}")
            print(f"PWI: {pwi:.3f}\n")
        else:
            results.append(f"{model_description} Failed to extract SIE parameters.")
            print(f"Model: {file_name} Failed to extract SIE parameters.\n")
    return results

# List of file paths to process
file_list = [
    "RXJ0911/PPC/outPP_optresult.dat",
    "RXJ0911/PPC/outPPR_optresult.dat",
    "RXJ0911/PPC/outPPG_optresult.dat",
    "RXJ0911/PPC/outPPGR_optresult.dat",
    "RXJ0911/PPFC/outPPF_optresult.dat",
    "RXJ0911/PPFC/outPPFR_optresult.dat",
    "RXJ0911/PPFC/outPPFG_optresult.dat",
    "RXJ0911/PPFC/outPPFGR_optresult.dat",
    "PSJ1606/PPC/outPP_optresult.dat",
    "PSJ1606/PPC/outPPR_optresult.dat",
    "PSJ1606/PPC/outPPG_optresult.dat",
    "PSJ1606/PPC/outPPGR_optresult.dat",
    "PSJ1606/PPFC/outPPF_optresult.dat",
    "PSJ1606/PPFC/outPPFR_optresult.dat",
    "PSJ1606/PPFC/outPPFG_optresult.dat",
    "PSJ1606/PPFC/outPPFGR_optresult.dat",
    "WFI2033/PP/outPP_optresult.dat",
    "WFI2033/PPR/outPPR_optresult.dat",
    "WFI2033/PPG/outPPG_optresult.dat",
    "WFI2033/PPGR/outPPGR_optresult.dat",
    "WFI2033/PPF/outPPF_optresult.dat",
    "WFI2033/PPFR/outPPFR_optresult.dat",
    "WFI2033/PPFG/outPPFG_optresult.dat",
    "WFI2033/PPFGR/outPPFGR_optresult.dat",
    "SDSSJ1330/PPC/outPP_optresult.dat",
    "SDSSJ1330/PPC/outPPR_optresult.dat",
    "SDSSJ1330/PPFC/outPPF_optresult.dat",
    "SDSSJ1330/PPFC/outPPFR_optresult.dat",
    "WFI2026/PPC/outPP_optresult.dat",
    "WFI2026/PPC/outPPR_optresult.dat",
    "WFI2026/PPFC/outPPF_optresult.dat",
    "WFI2026/PPFC/outPPFR_optresult.dat",
    "WGDJ0405/PPC/outPP_optresult.dat",
    "WGDJ0405/PPC/outPPR_optresult.dat",
    "WGDJ0405/PPFC/outPPF_optresult.dat",
    "WGDJ0405/PPFC/outPPFR_optresult.dat",
    "WGD2038/PPC/outPP_optresult.dat",
    "WGD2038/PPC/outPPR_optresult.dat",
    "WGD2038/PPFC/outPPF_optresult.dat",
    "WGD2038/PPFC/outPPFR_optresult.dat",
]

# Execute the function and print LaTeX-formatted results
latex_results = process_multiple_files(file_list)
for result in latex_results:
    print(result)
# Out:
# Model: RXJ0911/PPC/outPP_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.163
# Y Coordinate: 0.041
# Ellipticity: 0.600
# Position Angle: 174.220
# Einstein Radius: 1.482
# PWI: 2.100
#
# Model: RXJ0911/PPC/outPPR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.000
# Y Coordinate: 0.031
# Ellipticity: 0.297
# Position Angle: 213.320
# Einstein Radius: 0.921
# PWI: 2.100
#
# Model: RXJ0911/PPC/outPPG_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 0.021
# Y Coordinate: -0.021
# Ellipticity: 0.600
# Position Angle: 175.676
# Einstein Radius: 1.283
# PWI: 1.900
#
# Model: RXJ0911/PPC/outPPGR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.000
# Y Coordinate: 0.000
# Ellipticity: 0.167
# Position Angle: 226.238
# Einstein Radius: 0.814
# PWI: 1.800
#
# Model: RXJ0911/PPFC/outPPF_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 0.057
# Y Coordinate: 0.026
# Ellipticity: 0.600
# Position Angle: 174.102
# Einstein Radius: 1.411
# PWI: 1.800
#
# Model: RXJ0911/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 0.001
# Y Coordinate: 0.033
# Ellipticity: 0.336
# Position Angle: 201.231
# Einstein Radius: 0.990
# PWI: 1.800
#
# Model: RXJ0911/PPFC/outPPFG_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 0.021
# Y Coordinate: -0.019
# Ellipticity: 0.600
# Position Angle: 175.682
# Einstein Radius: 1.289
# PWI: 1.900
#
# Model: RXJ0911/PPFC/outPPFGR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.000
# Y Coordinate: -0.002
# Ellipticity: 0.170
# Position Angle: 222.946
# Einstein Radius: 0.821
# PWI: 1.800
#
# Model: PSJ1606/PPC/outPP_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.015
# Y Coordinate: 0.026
# Ellipticity: 0.150
# Position Angle: 199.364
# Einstein Radius: 0.707
# PWI: 1.300
#
# Model: PSJ1606/PPC/outPPR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.015
# Y Coordinate: 0.006
# Ellipticity: 0.274
# Position Angle: 186.198
# Einstein Radius: 0.642
# PWI: 1.300
#
# Model: PSJ1606/PPC/outPPG_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: 0.033
# Y Coordinate: 0.029
# Ellipticity: 0.232
# Position Angle: 209.830
# Einstein Radius: 0.644
# PWI: 1.500
#
# Model: PSJ1606/PPC/outPPGR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.000
# Y Coordinate: 0.000
# Ellipticity: 0.481
# Position Angle: 195.139
# Einstein Radius: 0.649
# PWI: 1.500
#
# Model: PSJ1606/PPFC/outPPF_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.014
# Y Coordinate: 0.018
# Ellipticity: 0.153
# Position Angle: 199.325
# Einstein Radius: 0.706
# PWI: 1.300
#
# Model: PSJ1606/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.014
# Y Coordinate: 0.014
# Ellipticity: 0.173
# Position Angle: 162.392
# Einstein Radius: 0.652
# PWI: 1.900
#
# Model: PSJ1606/PPFC/outPPFG_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: 0.049
# Y Coordinate: 0.022
# Ellipticity: 0.228
# Position Angle: 214.731
# Einstein Radius: 0.622
# PWI: 1.500
#
# Model: PSJ1606/PPFC/outPPFGR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: 0.028
# Y Coordinate: 0.002
# Ellipticity: 0.364
# Position Angle: 195.706
# Einstein Radius: 0.616
# PWI: 1.500
#
# Model: WFI2033/PP/outPP_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: -0.126
# Y Coordinate: 0.045
# Ellipticity: 0.684
# Position Angle: 335.633
# Einstein Radius: 1.247
# PWI: 2.100
#
# Model: WFI2033/PPR/outPPR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: -0.018
# Y Coordinate: 0.034
# Ellipticity: 0.326
# Position Angle: 272.737
# Einstein Radius: 0.880
# PWI: 1.900
#
# Model: WFI2033/PPG/outPPG_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: -0.000
# Y Coordinate: -0.001
# Ellipticity: 0.413
# Position Angle: 323.128
# Einstein Radius: 1.091
# PWI: 2.100
#
# Model: WFI2033/PPGR/outPPGR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: -0.000
# Y Coordinate: 0.000
# Ellipticity: 0.349
# Position Angle: 319.974
# Einstein Radius: 1.017
# PWI: 2.100
#
# Model: WFI2033/PPF/outPPF_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: -0.044
# Y Coordinate: 0.043
# Ellipticity: 0.392
# Position Angle: 334.533
# Einstein Radius: 1.179
# PWI: 1.800
#
# Model: WFI2033/PPFR/outPPFR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.074
# Y Coordinate: 0.085
# Ellipticity: 0.472
# Position Angle: 256.951
# Einstein Radius: 1.017
# PWI: 1.600
#
# Model: WFI2033/PPFG/outPPFG_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.008
# Y Coordinate: -0.009
# Ellipticity: 0.133
# Position Angle: 324.168
# Einstein Radius: 1.087
# PWI: 1.500
#
# Model: WFI2033/PPFGR/outPPFGR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.002
# Y Coordinate: -0.017
# Ellipticity: 0.386
# Position Angle: 330.125
# Einstein Radius: 1.040
# PWI: 1.500
#
# Model: SDSSJ1330/PPC/outPP_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: -0.029
# Y Coordinate: -0.015
# Ellipticity: 0.118
# Position Angle: 146.465
# Einstein Radius: 0.944
# PWI: 1.600
#
# Model: SDSSJ1330/PPC/outPPR_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: -0.010
# Y Coordinate: 0.012
# Ellipticity: 0.344
# Position Angle: -21.396
# Einstein Radius: 0.783
# PWI: 1.600
#
# Model: SDSSJ1330/PPFC/outPPF_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: -0.031
# Y Coordinate: -0.017
# Ellipticity: 0.117
# Position Angle: 146.475
# Einstein Radius: 0.943
# PWI: 1.600
#
# Model: SDSSJ1330/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: -0.004
# Y Coordinate: 0.016
# Ellipticity: 0.419
# Position Angle: -23.664
# Einstein Radius: 0.831
# PWI: 1.600
#
# Model: WFI2026/PPC/outPP_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: -0.056
# Y Coordinate: 0.023
# Ellipticity: 0.265
# Position Angle: 90.183
# Einstein Radius: 0.671
# PWI: 1.700
#
# Model: WFI2026/PPC/outPPR_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: -0.051
# Y Coordinate: 0.015
# Ellipticity: 0.414
# Position Angle: 80.657
# Einstein Radius: 0.679
# PWI: 1.800
#
# Model: WFI2026/PPFC/outPPF_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: -0.057
# Y Coordinate: 0.020
# Ellipticity: 0.271
# Position Angle: 90.205
# Einstein Radius: 0.671
# PWI: 1.700
#
# Model: WFI2026/PPFC/outPPFR_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: -0.053
# Y Coordinate: 0.017
# Ellipticity: 0.370
# Position Angle: 81.298
# Einstein Radius: 0.647
# PWI: 1.900
#
# Model: WGDJ0405/PPC/outPP_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: 0.018
# Y Coordinate: -0.008
# Ellipticity: 0.064
# Position Angle: -30.830
# Einstein Radius: 0.700
# PWI: 1.700
#
# Model: WGDJ0405/PPC/outPPR_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: 0.017
# Y Coordinate: -0.013
# Ellipticity: 0.165
# Position Angle: -50.652
# Einstein Radius: 0.683
# PWI: 1.800
#
# Model: WGDJ0405/PPFC/outPPF_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: 0.017
# Y Coordinate: -0.010
# Ellipticity: 0.068
# Position Angle: -30.820
# Einstein Radius: 0.700
# PWI: 1.700
#
# Model: WGDJ0405/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: 0.016
# Y Coordinate: -0.014
# Ellipticity: 0.169
# Position Angle: -49.290
# Einstein Radius: 0.682
# PWI: 1.700
#
# Model: WGD2038/PPC/outPP_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: 0.002
# Y Coordinate: 0.002
# Ellipticity: 0.341
# Position Angle: -35.402
# Einstein Radius: 1.392
# PWI: 1.900
#
# Model: WGD2038/PPC/outPPR_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: -0.000
# Y Coordinate: 0.000
# Ellipticity: 0.317
# Position Angle: -37.084
# Einstein Radius: 1.238
# PWI: 1.900
#
# Model: WGD2038/PPFC/outPPF_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: 0.008
# Y Coordinate: 0.004
# Ellipticity: 0.416
# Position Angle: -35.332
# Einstein Radius: 1.401
# PWI: 2.000
#
# Model: WGD2038/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: 0.002
# Y Coordinate: -0.003
# Ellipticity: 0.393
# Position Angle: -36.260
# Einstein Radius: 1.355
# PWI: 2.100
#
# RXJ0911 & POW & QSO Pos & 0.769 & 2.763 & -0.163 & 0.041 & 0.600 & 174.220 & 1.482 & 2.100 \\
# RXJ0911 & POW + Shear & QSO Pos & 0.769 & 2.763 & -0.000 & 0.031 & 0.297 & 213.320 & 0.921 & 2.100 \\
# RXJ0911 & POW + G2 & QSO Pos & 0.769 & 2.763 & 0.021 & -0.021 & 0.600 & 175.676 & 1.283 & 1.900 \\
# RXJ0911 & POW + G2 + Shear & QSO Pos & 0.769 & 2.763 & -0.000 & 0.000 & 0.167 & 226.238 & 0.814 & 1.800 \\
# RXJ0911 & POW & QSO Pos + FR & 0.769 & 2.763 & 0.057 & 0.026 & 0.600 & 174.102 & 1.411 & 1.800 \\
# RXJ0911 & POW + Shear & QSO Pos + FR & 0.769 & 2.763 & 0.001 & 0.033 & 0.336 & 201.231 & 0.990 & 1.800 \\
# RXJ0911 & POW + G2 & QSO Pos + FR & 0.769 & 2.763 & 0.021 & -0.019 & 0.600 & 175.682 & 1.289 & 1.900 \\
# RXJ0911 & POW + G2 + Shear & QSO Pos + FR & 0.769 & 2.763 & -0.000 & -0.002 & 0.170 & 222.946 & 0.821 & 1.800 \\
# PSJ1606 & POW & QSO Pos & 0.300 & 1.696 & -0.015 & 0.026 & 0.150 & 199.364 & 0.707 & 1.300 \\
# PSJ1606 & POW + Shear & QSO Pos & 0.300 & 1.696 & -0.015 & 0.006 & 0.274 & 186.198 & 0.642 & 1.300 \\
# PSJ1606 & POW + G2 & QSO Pos & 0.300 & 1.696 & 0.033 & 0.029 & 0.232 & 209.830 & 0.644 & 1.500 \\
# PSJ1606 & POW + G2 + Shear & QSO Pos & 0.300 & 1.696 & -0.000 & 0.000 & 0.481 & 195.139 & 0.649 & 1.500 \\
# PSJ1606 & POW & QSO Pos + FR & 0.300 & 1.696 & -0.014 & 0.018 & 0.153 & 199.325 & 0.706 & 1.300 \\
# PSJ1606 & POW + Shear & QSO Pos + FR & 0.300 & 1.696 & -0.014 & 0.014 & 0.173 & 162.392 & 0.652 & 1.900 \\
# PSJ1606 & POW + G2 & QSO Pos + FR & 0.300 & 1.696 & 0.049 & 0.022 & 0.228 & 214.731 & 0.622 & 1.500 \\
# PSJ1606 & POW + G2 + Shear & QSO Pos + FR & 0.300 & 1.696 & 0.028 & 0.002 & 0.364 & 195.706 & 0.616 & 1.500 \\
# WFI2033 & POW & QSO Pos & 0.661 & 1.660 & -0.126 & 0.045 & 0.684 & 335.633 & 1.247 & 2.100 \\
# WFI2033 & POW + Shear & QSO Pos & 0.661 & 1.660 & -0.018 & 0.034 & 0.326 & 272.737 & 0.880 & 1.900 \\
# WFI2033 & POW + G2 & QSO Pos & 0.661 & 1.660 & -0.000 & -0.001 & 0.413 & 323.128 & 1.091 & 2.100 \\
# WFI2033 & POW + G2 + Shear & QSO Pos & 0.661 & 1.660 & -0.000 & 0.000 & 0.349 & 319.974 & 1.017 & 2.100 \\
# WFI2033 & POW & QSO Pos + FR & 0.661 & 1.660 & -0.044 & 0.043 & 0.392 & 334.533 & 1.179 & 1.800 \\
# WFI2033 & POW + Shear & QSO Pos + FR & 0.661 & 1.660 & 0.074 & 0.085 & 0.472 & 256.951 & 1.017 & 1.600 \\
# WFI2033 & POW + G2 & QSO Pos + FR & 0.661 & 1.660 & 0.008 & -0.009 & 0.133 & 324.168 & 1.087 & 1.500 \\
# WFI2033 & POW + G2 + Shear & QSO Pos + FR & 0.661 & 1.660 & 0.002 & -0.017 & 0.386 & 330.125 & 1.040 & 1.500 \\
# SDSSJ1330 & POW & QSO Pos & 0.373 & 1.383 & -0.029 & -0.015 & 0.118 & 146.465 & 0.944 & 1.600 \\
# SDSSJ1330 & POW + Shear & QSO Pos & 0.373 & 1.383 & -0.010 & 0.012 & 0.344 & -21.396 & 0.783 & 1.600 \\
# SDSSJ1330 & POW & QSO Pos + FR & 0.373 & 1.383 & -0.031 & -0.017 & 0.117 & 146.475 & 0.943 & 1.600 \\
# SDSSJ1330 & POW + Shear & QSO Pos + FR & 0.373 & 1.383 & -0.004 & 0.016 & 0.419 & -23.664 & 0.831 & 1.600 \\
# WFI2026 & POW & QSO Pos & 1.040 & 2.230 & -0.056 & 0.023 & 0.265 & 90.183 & 0.671 & 1.700 \\
# WFI2026 & POW + Shear & QSO Pos & 1.040 & 2.230 & -0.051 & 0.015 & 0.414 & 80.657 & 0.679 & 1.800 \\
# WFI2026 & POW & QSO Pos + FR & 1.040 & 2.230 & -0.057 & 0.020 & 0.271 & 90.205 & 0.671 & 1.700 \\
# WFI2026 & POW + Shear & QSO Pos + FR & 1.040 & 2.230 & -0.053 & 0.017 & 0.370 & 81.298 & 0.647 & 1.900 \\
# WGDJ0405 & POW & QSO Pos & 0.290 & 1.713 & 0.018 & -0.008 & 0.064 & -30.830 & 0.700 & 1.700 \\
# WGDJ0405 & POW + Shear & QSO Pos & 0.290 & 1.713 & 0.017 & -0.013 & 0.165 & -50.652 & 0.683 & 1.800 \\
# WGDJ0405 & POW & QSO Pos + FR & 0.290 & 1.713 & 0.017 & -0.010 & 0.068 & -30.820 & 0.700 & 1.700 \\
# WGDJ0405 & POW + Shear & QSO Pos + FR & 0.290 & 1.713 & 0.016 & -0.014 & 0.169 & -49.290 & 0.682 & 1.700 \\
# WGD2038 & POW & QSO Pos & 0.230 & 0.777 & 0.002 & 0.002 & 0.341 & -35.402 & 1.392 & 1.900 \\
# WGD2038 & POW + Shear & QSO Pos & 0.230 & 0.777 & -0.000 & 0.000 & 0.317 & -37.084 & 1.238 & 1.900 \\
# WGD2038 & POW & QSO Pos + FR & 0.230 & 0.777 & 0.008 & 0.004 & 0.416 & -35.332 & 1.401 & 2.000 \\
# WGD2038 & POW + Shear & QSO Pos + FR & 0.230 & 0.777 & 0.002 & -0.003 & 0.393 & -36.260 & 1.355 & 2.100 \\
