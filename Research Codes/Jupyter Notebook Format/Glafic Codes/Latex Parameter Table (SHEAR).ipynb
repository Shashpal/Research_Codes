# %%
def extract_sie_parameters(filename):
    """
    Extract the SHEAR lens parameters from the last "lens pert" line that appears in the file.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()

    last_sie_index = None
    for index, line in enumerate(lines):
        if "lens   pert" in line:
            last_sie_index = index

    if last_sie_index is None:
        print(f"Error: 'lens pert' line not found in file: {filename}.")
        return None

    line = lines[last_sie_index]
    parts = line.split()
    try:
        lens_redshift = float(parts[3])
        source_redshift = float(parts[2])
        x_coord = float(parts[4])
        y_coord = float(parts[5])
        shear_strength = float(parts[6])
        shear_angle = float(parts[7])
        convergence = float(parts[9])
        return (lens_redshift, source_redshift, x_coord, y_coord, shear_strength, shear_angle, convergence)
    except (ValueError, IndexError):
        print(f"Error: Failed to extract numbers from line: {line} in file: {filename}.")
        return None

def rename_file(file_path):
    parts = file_path.split("/")
    lens_system = parts[0]
    file_name = parts[-1]

    key = file_name.split("_optresult")[0][3:]
    profile_map = {"S": "SIE", "P": "POW", "N": "NFW"}
    profile = profile_map.get(key[0], "Unknown")

    constraint = "Unknown constraint"
    if key[1:3] == "PF":
        constraint = "QSO Pos + FR"
    elif key[1] == "P":
        constraint = "QSO Pos"

    extras = []
    if "G" in key:
        extras.append("G2")
    if "R" in key:
        extras.append("Shear")

    if len(extras) == 2:
        profile_description = f"{profile} + {extras[0]} + {extras[1]}"
    elif len(extras) == 1:
        profile_description = f"{profile} + {extras[0]}"
    else:
        profile_description = profile

    new_name = f"{lens_system} & {profile_description} & {constraint}"
    return new_name

def process_multiple_files(file_list):
    results = []
    for file_name in file_list:
        model_description = rename_file(file_name)
        sie_parameters = extract_sie_parameters(file_name)
        if sie_parameters:
            source_redshift, lens_redshift, x_coord, y_coord, shear_strength, shear_angle, convergence = sie_parameters
            result_text = f"{model_description} & {lens_redshift:.3f} & {source_redshift:.3f} & {x_coord:.3f} & {y_coord:.3f} & {shear_strength:.3f} & {shear_angle:.3f} & {convergence:.3f} \\\\"
            results.append(result_text)
            print(f"Model: {file_name}")
            print(f"Lens Redshift: {lens_redshift:.3f}")
            print(f"Source Redshift: {source_redshift:.3f}")
            print(f"X Coordinate: {x_coord:.3f}")
            print(f"Y Coordinate: {y_coord:.3f}")
            print(f"Shear Strength: {shear_strength:.3f}")
            print(f"Shear Position Angle: {shear_angle:.3f}")
            print(f"Convergence: {convergence:.3f}\n")
        else:
            results.append(f"{model_description} Failed to extract SIE parameters.")
            print(f"Model: {file_name} Failed to extract SIE parameters.\n")
    return results

# List of file paths to process
file_list = [
    "RXJ0911/SPC/outSPR_optresult.dat",
    "RXJ0911/SPC/outSPGR_optresult.dat",
    "RXJ0911/SPFC/outSPFR_optresult.dat",
    "RXJ0911/SPFC/outSPFGR_optresult.dat",
    "RXJ0911/PPC/outPPR_optresult.dat",
    "RXJ0911/PPC/outPPGR_optresult.dat",
    "RXJ0911/PPFC/outPPFR_optresult.dat",
    "RXJ0911/PPFC/outPPFGR_optresult.dat",
    "RXJ0911/NPC/outNPR_optresult.dat",
    "RXJ0911/NPC/outNPGR_optresult.dat",
    "RXJ0911/NPFC/outNPFR_optresult.dat",
    "RXJ0911/NPFC/outNPFGR_optresult.dat",
    "PSJ1606/SPC/outSPR_optresult.dat",
    "PSJ1606/SPC/outSPGR_optresult.dat",
    "PSJ1606/SPFC/outSPFR_optresult.dat",
    "PSJ1606/SPFC/outSPFGR_optresult.dat",
    "PSJ1606/PPC/outPPR_optresult.dat",
    "PSJ1606/PPC/outPPGR_optresult.dat",
    "PSJ1606/PPFC/outPPFR_optresult.dat",
    "PSJ1606/PPFC/outPPFGR_optresult.dat",
    "PSJ1606/NPC/outNPR_optresult.dat",
    "PSJ1606/NPC/outNPGR_optresult.dat",
    "PSJ1606/NPFC/outNPFR_optresult.dat",
    "PSJ1606/NPFC/outNPFGR_optresult.dat",
    "WFI2033/SPR/outSPR_optresult.dat",
    "WFI2033/SPGR/outSPGR_optresult.dat",
    "WFI2033/SPFR/outSPFR_optresult.dat",
    "WFI2033/SPFGR/outSPFGR_optresult.dat",
    "WFI2033/PPR/outPPR_optresult.dat",
    "WFI2033/PPGR/outPPGR_optresult.dat",
    "WFI2033/PPFR/outPPFR_optresult.dat",
    "WFI2033/PPFGR/outPPFGR_optresult.dat",
    "WFI2033/NPR/outNPR_optresult.dat",
    "WFI2033/NPGR/outNPGR_optresult.dat",
    "WFI2033/NPFR/outNPFR_optresult.dat",
    "WFI2033/NPFGR/outNPFGR_optresult.dat",
    "SDSSJ1330/SPC/outSPR_optresult.dat",
    "SDSSJ1330/SPFC/outSPFR_optresult.dat",
    "SDSSJ1330/PPC/outPPR_optresult.dat",
    "SDSSJ1330/PPFC/outPPFR_optresult.dat",
    "SDSSJ1330/NPC/outNPR_optresult.dat",
    "SDSSJ1330/NPFC/outNPFR_optresult.dat",
    "WFI2026/SPC/outSPR_optresult.dat",
    "WFI2026/SPFC/outSPFR_optresult.dat",
    "WFI2026/PPC/outPPR_optresult.dat",
    "WFI2026/PPFC/outPPFR_optresult.dat",
    "WFI2026/NPC/outNPR_optresult.dat",
    "WFI2026/NPFC/outNPFR_optresult.dat",
    "WGDJ0405/SPC/outSPR_optresult.dat",
    "WGDJ0405/SPFC/outSPFR_optresult.dat",
    "WGDJ0405/PPC/outPPR_optresult.dat",
    "WGDJ0405/PPFC/outPPFR_optresult.dat",
    "WGDJ0405/NPC/outNPR_optresult.dat",
    "WGDJ0405/NPFC/outNPFR_optresult.dat",
    "WGD2038/SPC/outSPR_optresult.dat",
    "WGD2038/SPFC/outSPFR_optresult.dat",
    "WGD2038/PPC/outPPR_optresult.dat",
    "WGD2038/PPFC/outPPFR_optresult.dat",
    "WGD2038/NPC/outNPR_optresult.dat",
    "WGD2038/NPFC/outNPFR_optresult.dat",
]

# Execute the function and print LaTeX-formatted results
latex_results = process_multiple_files(file_list)
for result in latex_results:
    print(result)
# Out:
# Model: RXJ0911/SPC/outSPR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 0.038
# Y Coordinate: 0.127
# Shear Strength: 0.204
# Shear Position Angle: -13.555
# Convergence: 0.316
#
# Model: RXJ0911/SPC/outSPGR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 0.043
# Y Coordinate: 0.020
# Shear Strength: 0.314
# Shear Position Angle: -12.075
# Convergence: 0.007
#
# Model: RXJ0911/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.007
# Y Coordinate: -0.013
# Shear Strength: 0.239
# Shear Position Angle: -13.662
# Convergence: 0.198
#
# Model: RXJ0911/SPFC/outSPFGR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 0.674
# Y Coordinate: -0.120
# Shear Strength: 0.286
# Shear Position Angle: -11.872
# Convergence: 0.112
#
# Model: RXJ0911/PPC/outPPR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.036
# Y Coordinate: 0.001
# Shear Strength: 0.272
# Shear Position Angle: -12.171
# Convergence: 0.191
#
# Model: RXJ0911/PPC/outPPGR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.575
# Y Coordinate: -0.005
# Shear Strength: 0.220
# Shear Position Angle: -13.527
# Convergence: 0.130
#
# Model: RXJ0911/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 0.007
# Y Coordinate: -0.029
# Shear Strength: 0.182
# Shear Position Angle: -18.722
# Convergence: 0.144
#
# Model: RXJ0911/PPFC/outPPFGR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.595
# Y Coordinate: -0.165
# Shear Strength: 0.224
# Shear Position Angle: -13.741
# Convergence: 0.126
#
# Model: RXJ0911/NPC/outNPR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.000
# Y Coordinate: -0.011
# Shear Strength: 0.147
# Shear Position Angle: -10.987
# Convergence: 0.558
#
# Model: RXJ0911/NPC/outNPGR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 0.799
# Y Coordinate: -0.002
# Shear Strength: 0.135
# Shear Position Angle: -9.061
# Convergence: 0.574
#
# Model: RXJ0911/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: -0.763
# Y Coordinate: 0.673
# Shear Strength: 0.079
# Shear Position Angle: -10.240
# Convergence: 0.785
#
# Model: RXJ0911/NPFC/outNPFGR_optresult.dat
# Lens Redshift: 0.769
# Source Redshift: 2.763
# X Coordinate: 1.063
# Y Coordinate: 0.581
# Shear Strength: 0.121
# Shear Position Angle: -14.050
# Convergence: 0.656
#
# Model: PSJ1606/SPC/outSPR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: 0.003
# Y Coordinate: -0.063
# Shear Strength: 0.190
# Shear Position Angle: 27.139
# Convergence: 0.029
#
# Model: PSJ1606/SPC/outSPGR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.398
# Y Coordinate: 0.456
# Shear Strength: 0.100
# Shear Position Angle: 62.397
# Convergence: 0.058
#
# Model: PSJ1606/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.030
# Y Coordinate: 0.007
# Shear Strength: 0.208
# Shear Position Angle: 27.135
# Convergence: 0.064
#
# Model: PSJ1606/SPFC/outSPFGR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: 0.025
# Y Coordinate: 0.264
# Shear Strength: 0.179
# Shear Position Angle: 28.266
# Convergence: 0.006
#
# Model: PSJ1606/PPC/outPPR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: 0.465
# Y Coordinate: 0.793
# Shear Strength: 0.076
# Shear Position Angle: 83.200
# Convergence: 0.034
#
# Model: PSJ1606/PPC/outPPGR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: 0.145
# Y Coordinate: -0.393
# Shear Strength: 0.125
# Shear Position Angle: 95.569
# Convergence: 0.043
#
# Model: PSJ1606/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.096
# Y Coordinate: 0.038
# Shear Strength: 0.182
# Shear Position Angle: 28.296
# Convergence: 0.045
#
# Model: PSJ1606/PPFC/outPPFGR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.044
# Y Coordinate: -0.036
# Shear Strength: 0.085
# Shear Position Angle: 88.394
# Convergence: 0.030
#
# Model: PSJ1606/NPC/outNPR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: 0.069
# Y Coordinate: 0.058
# Shear Strength: 0.101
# Shear Position Angle: 25.201
# Convergence: 0.537
#
# Model: PSJ1606/NPC/outNPGR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.008
# Y Coordinate: 0.008
# Shear Strength: 0.029
# Shear Position Angle: 45.057
# Convergence: 0.708
#
# Model: PSJ1606/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: 0.082
# Y Coordinate: -0.023
# Shear Strength: 0.029
# Shear Position Angle: 26.416
# Convergence: 0.850
#
# Model: PSJ1606/NPFC/outNPFGR_optresult.dat
# Lens Redshift: 0.300
# Source Redshift: 1.696
# X Coordinate: -0.464
# Y Coordinate: 0.324
# Shear Strength: 0.058
# Shear Position Angle: 45.093
# Convergence: 0.498
#
# Model: WFI2033/SPR/outSPR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: -0.000
# Y Coordinate: -0.000
# Shear Strength: 0.234
# Shear Position Angle: -12.542
# Convergence: 0.005
#
# Model: WFI2033/SPGR/outSPGR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.416
# Y Coordinate: -0.025
# Shear Strength: 0.066
# Shear Position Angle: 95.815
# Convergence: 0.044
#
# Model: WFI2033/SPFR/outSPFR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.000
# Y Coordinate: 0.000
# Shear Strength: 0.208
# Shear Position Angle: -14.047
# Convergence: 0.284
#
# Model: WFI2033/SPFGR/outSPFGR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.030
# Y Coordinate: -0.581
# Shear Strength: 0.088
# Shear Position Angle: 145.290
# Convergence: 0.152
#
# Model: WFI2033/PPR/outPPR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.000
# Y Coordinate: 0.000
# Shear Strength: 0.179
# Shear Position Angle: -11.636
# Convergence: 0.202
#
# Model: WFI2033/PPGR/outPPGR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: -22.101
# Y Coordinate: 16.775
# Shear Strength: 0.009
# Shear Position Angle: 124.984
# Convergence: 0.045
#
# Model: WFI2033/PPFR/outPPFR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.063
# Y Coordinate: 0.095
# Shear Strength: 0.264
# Shear Position Angle: -14.251
# Convergence: 0.068
#
# Model: WFI2033/PPFGR/outPPFGR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.321
# Y Coordinate: -0.006
# Shear Strength: 0.128
# Shear Position Angle: 64.043
# Convergence: 0.033
#
# Model: WFI2033/NPR/outNPR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: -0.000
# Y Coordinate: 0.000
# Shear Strength: 0.155
# Shear Position Angle: 168.081
# Convergence: 0.228
#
# Model: WFI2033/NPGR/outNPGR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 0.531
# Y Coordinate: -1.138
# Shear Strength: 0.000
# Shear Position Angle: 97.809
# Convergence: 0.169
#
# Model: WFI2033/NPFR/outNPFR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: -0.329
# Y Coordinate: 0.717
# Shear Strength: 0.192
# Shear Position Angle: -15.330
# Convergence: 0.309
#
# Model: WFI2033/NPFGR/outNPFGR_optresult.dat
# Lens Redshift: 0.661
# Source Redshift: 1.660
# X Coordinate: 4.281
# Y Coordinate: 2.468
# Shear Strength: 0.081
# Shear Position Angle: 141.588
# Convergence: 0.075
#
# Model: SDSSJ1330/SPC/outSPR_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: 0.653
# Y Coordinate: -0.467
# Shear Strength: 0.047
# Shear Position Angle: 86.253
# Convergence: 0.457
#
# Model: SDSSJ1330/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: 0.486
# Y Coordinate: -0.361
# Shear Strength: 0.022
# Shear Position Angle: 260.841
# Convergence: 0.780
#
# Model: SDSSJ1330/PPC/outPPR_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: 0.047
# Y Coordinate: 0.033
# Shear Strength: 0.096
# Shear Position Angle: 76.725
# Convergence: 0.112
#
# Model: SDSSJ1330/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: 1.321
# Y Coordinate: -3.187
# Shear Strength: 0.131
# Shear Position Angle: 71.598
# Convergence: 0.085
#
# Model: SDSSJ1330/NPC/outNPR_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: -0.249
# Y Coordinate: -0.441
# Shear Strength: 0.027
# Shear Position Angle: 96.231
# Convergence: 0.563
#
# Model: SDSSJ1330/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.373
# Source Redshift: 1.383
# X Coordinate: -0.139
# Y Coordinate: -0.357
# Shear Strength: 0.029
# Shear Position Angle: 87.367
# Convergence: 0.580
#
# Model: WFI2026/SPC/outSPR_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: -0.006
# Y Coordinate: -0.035
# Shear Strength: 0.042
# Shear Position Angle: 129.264
# Convergence: 0.280
#
# Model: WFI2026/SPFC/outSPFR_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: 0.057
# Y Coordinate: -0.020
# Shear Strength: 0.041
# Shear Position Angle: 113.888
# Convergence: 0.288
#
# Model: WFI2026/PPC/outPPR_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: 0.156
# Y Coordinate: 0.068
# Shear Strength: 0.065
# Shear Position Angle: 150.925
# Convergence: 0.006
#
# Model: WFI2026/PPFC/outPPFR_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: 0.059
# Y Coordinate: 0.067
# Shear Strength: 0.043
# Shear Position Angle: 128.335
# Convergence: 0.036
#
# Model: WFI2026/NPC/outNPR_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: 0.082
# Y Coordinate: -0.025
# Shear Strength: 0.024
# Shear Position Angle: 115.922
# Convergence: 0.529
#
# Model: WFI2026/NPFC/outNPFR_optresult.dat
# Lens Redshift: 1.040
# Source Redshift: 2.230
# X Coordinate: 0.020
# Y Coordinate: 0.014
# Shear Strength: 0.020
# Shear Position Angle: 101.114
# Convergence: 0.782
#
# Model: WGDJ0405/SPC/outSPR_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: -0.015
# Y Coordinate: 0.013
# Shear Strength: 0.037
# Shear Position Angle: 34.400
# Convergence: 0.228
#
# Model: WGDJ0405/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: 0.086
# Y Coordinate: 0.060
# Shear Strength: 0.036
# Shear Position Angle: 12.155
# Convergence: 0.168
#
# Model: WGDJ0405/PPC/outPPR_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: 0.019
# Y Coordinate: -0.268
# Shear Strength: 0.044
# Shear Position Angle: 21.468
# Convergence: 0.021
#
# Model: WGDJ0405/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: 0.015
# Y Coordinate: -0.274
# Shear Strength: 0.047
# Shear Position Angle: 26.636
# Convergence: 0.020
#
# Model: WGDJ0405/NPC/outNPR_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: 0.098
# Y Coordinate: -0.068
# Shear Strength: 0.026
# Shear Position Angle: 25.371
# Convergence: 0.355
#
# Model: WGDJ0405/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.290
# Source Redshift: 1.713
# X Coordinate: 0.132
# Y Coordinate: -0.024
# Shear Strength: 0.027
# Shear Position Angle: 22.988
# Convergence: 0.354
#
# Model: WGD2038/SPC/outSPR_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: 0.018
# Y Coordinate: 0.217
# Shear Strength: 0.018
# Shear Position Angle: -25.518
# Convergence: 0.160
#
# Model: WGD2038/SPFC/outSPFR_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: -0.007
# Y Coordinate: 0.047
# Shear Strength: 0.001
# Shear Position Angle: -3.482
# Convergence: 0.812
#
# Model: WGD2038/PPC/outPPR_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: 0.327
# Y Coordinate: -0.126
# Shear Strength: 0.010
# Shear Position Angle: -12.045
# Convergence: 0.098
#
# Model: WGD2038/PPFC/outPPFR_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: -0.122
# Y Coordinate: 0.140
# Shear Strength: 0.029
# Shear Position Angle: -30.794
# Convergence: 0.029
#
# Model: WGD2038/NPC/outNPR_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: 3.224
# Y Coordinate: -3.174
# Shear Strength: 0.039
# Shear Position Angle: -32.434
# Convergence: 0.410
#
# Model: WGD2038/NPFC/outNPFR_optresult.dat
# Lens Redshift: 0.230
# Source Redshift: 0.777
# X Coordinate: 0.168
# Y Coordinate: -0.021
# Shear Strength: 0.015
# Shear Position Angle: -33.627
# Convergence: 0.809
#
# RXJ0911 & SIE + Shear & QSO Pos & 0.769 & 2.763 & 0.038 & 0.127 & 0.204 & -13.555 & 0.316 \\
# RXJ0911 & SIE + G2 + Shear & QSO Pos & 0.769 & 2.763 & 0.043 & 0.020 & 0.314 & -12.075 & 0.007 \\
# RXJ0911 & SIE + Shear & QSO Pos + FR & 0.769 & 2.763 & -0.007 & -0.013 & 0.239 & -13.662 & 0.198 \\
# RXJ0911 & SIE + G2 + Shear & QSO Pos + FR & 0.769 & 2.763 & 0.674 & -0.120 & 0.286 & -11.872 & 0.112 \\
# RXJ0911 & POW + Shear & QSO Pos & 0.769 & 2.763 & -0.036 & 0.001 & 0.272 & -12.171 & 0.191 \\
# RXJ0911 & POW + G2 + Shear & QSO Pos & 0.769 & 2.763 & -0.575 & -0.005 & 0.220 & -13.527 & 0.130 \\
# RXJ0911 & POW + Shear & QSO Pos + FR & 0.769 & 2.763 & 0.007 & -0.029 & 0.182 & -18.722 & 0.144 \\
# RXJ0911 & POW + G2 + Shear & QSO Pos + FR & 0.769 & 2.763 & -0.595 & -0.165 & 0.224 & -13.741 & 0.126 \\
# RXJ0911 & NFW + Shear & QSO Pos & 0.769 & 2.763 & -0.000 & -0.011 & 0.147 & -10.987 & 0.558 \\
# RXJ0911 & NFW + G2 + Shear & QSO Pos & 0.769 & 2.763 & 0.799 & -0.002 & 0.135 & -9.061 & 0.574 \\
# RXJ0911 & NFW + Shear & QSO Pos + FR & 0.769 & 2.763 & -0.763 & 0.673 & 0.079 & -10.240 & 0.785 \\
# RXJ0911 & NFW + G2 + Shear & QSO Pos + FR & 0.769 & 2.763 & 1.063 & 0.581 & 0.121 & -14.050 & 0.656 \\
# PSJ1606 & SIE + Shear & QSO Pos & 0.300 & 1.696 & 0.003 & -0.063 & 0.190 & 27.139 & 0.029 \\
# PSJ1606 & SIE + G2 + Shear & QSO Pos & 0.300 & 1.696 & -0.398 & 0.456 & 0.100 & 62.397 & 0.058 \\
# PSJ1606 & SIE + Shear & QSO Pos + FR & 0.300 & 1.696 & -0.030 & 0.007 & 0.208 & 27.135 & 0.064 \\
# PSJ1606 & SIE + G2 + Shear & QSO Pos + FR & 0.300 & 1.696 & 0.025 & 0.264 & 0.179 & 28.266 & 0.006 \\
# PSJ1606 & POW + Shear & QSO Pos & 0.300 & 1.696 & 0.465 & 0.793 & 0.076 & 83.200 & 0.034 \\
# PSJ1606 & POW + G2 + Shear & QSO Pos & 0.300 & 1.696 & 0.145 & -0.393 & 0.125 & 95.569 & 0.043 \\
# PSJ1606 & POW + Shear & QSO Pos + FR & 0.300 & 1.696 & -0.096 & 0.038 & 0.182 & 28.296 & 0.045 \\
# PSJ1606 & POW + G2 + Shear & QSO Pos + FR & 0.300 & 1.696 & -0.044 & -0.036 & 0.085 & 88.394 & 0.030 \\
# PSJ1606 & NFW + Shear & QSO Pos & 0.300 & 1.696 & 0.069 & 0.058 & 0.101 & 25.201 & 0.537 \\
# PSJ1606 & NFW + G2 + Shear & QSO Pos & 0.300 & 1.696 & -0.008 & 0.008 & 0.029 & 45.057 & 0.708 \\
# PSJ1606 & NFW + Shear & QSO Pos + FR & 0.300 & 1.696 & 0.082 & -0.023 & 0.029 & 26.416 & 0.850 \\
# PSJ1606 & NFW + G2 + Shear & QSO Pos + FR & 0.300 & 1.696 & -0.464 & 0.324 & 0.058 & 45.093 & 0.498 \\
# WFI2033 & SIE + Shear & QSO Pos & 0.661 & 1.660 & -0.000 & -0.000 & 0.234 & -12.542 & 0.005 \\
# WFI2033 & SIE + G2 + Shear & QSO Pos & 0.661 & 1.660 & 0.416 & -0.025 & 0.066 & 95.815 & 0.044 \\
# WFI2033 & SIE + Shear & QSO Pos + FR & 0.661 & 1.660 & 0.000 & 0.000 & 0.208 & -14.047 & 0.284 \\
# WFI2033 & SIE + G2 + Shear & QSO Pos + FR & 0.661 & 1.660 & 0.030 & -0.581 & 0.088 & 145.290 & 0.152 \\
# WFI2033 & POW + Shear & QSO Pos & 0.661 & 1.660 & 0.000 & 0.000 & 0.179 & -11.636 & 0.202 \\
# WFI2033 & POW + G2 + Shear & QSO Pos & 0.661 & 1.660 & -22.101 & 16.775 & 0.009 & 124.984 & 0.045 \\
# WFI2033 & POW + Shear & QSO Pos + FR & 0.661 & 1.660 & 0.063 & 0.095 & 0.264 & -14.251 & 0.068 \\
# WFI2033 & POW + G2 + Shear & QSO Pos + FR & 0.661 & 1.660 & 0.321 & -0.006 & 0.128 & 64.043 & 0.033 \\
# WFI2033 & NFW + Shear & QSO Pos & 0.661 & 1.660 & -0.000 & 0.000 & 0.155 & 168.081 & 0.228 \\
# WFI2033 & NFW + G2 + Shear & QSO Pos & 0.661 & 1.660 & 0.531 & -1.138 & 0.000 & 97.809 & 0.169 \\
# WFI2033 & NFW + Shear & QSO Pos + FR & 0.661 & 1.660 & -0.329 & 0.717 & 0.192 & -15.330 & 0.309 \\
# WFI2033 & NFW + G2 + Shear & QSO Pos + FR & 0.661 & 1.660 & 4.281 & 2.468 & 0.081 & 141.588 & 0.075 \\
# SDSSJ1330 & SIE + Shear & QSO Pos & 0.373 & 1.383 & 0.653 & -0.467 & 0.047 & 86.253 & 0.457 \\
# SDSSJ1330 & SIE + Shear & QSO Pos + FR & 0.373 & 1.383 & 0.486 & -0.361 & 0.022 & 260.841 & 0.780 \\
# SDSSJ1330 & POW + Shear & QSO Pos & 0.373 & 1.383 & 0.047 & 0.033 & 0.096 & 76.725 & 0.112 \\
# SDSSJ1330 & POW + Shear & QSO Pos + FR & 0.373 & 1.383 & 1.321 & -3.187 & 0.131 & 71.598 & 0.085 \\
# SDSSJ1330 & NFW + Shear & QSO Pos & 0.373 & 1.383 & -0.249 & -0.441 & 0.027 & 96.231 & 0.563 \\
# SDSSJ1330 & NFW + Shear & QSO Pos + FR & 0.373 & 1.383 & -0.139 & -0.357 & 0.029 & 87.367 & 0.580 \\
# WFI2026 & SIE + Shear & QSO Pos & 1.040 & 2.230 & -0.006 & -0.035 & 0.042 & 129.264 & 0.280 \\
# WFI2026 & SIE + Shear & QSO Pos + FR & 1.040 & 2.230 & 0.057 & -0.020 & 0.041 & 113.888 & 0.288 \\
# WFI2026 & POW + Shear & QSO Pos & 1.040 & 2.230 & 0.156 & 0.068 & 0.065 & 150.925 & 0.006 \\
# WFI2026 & POW + Shear & QSO Pos + FR & 1.040 & 2.230 & 0.059 & 0.067 & 0.043 & 128.335 & 0.036 \\
# WFI2026 & NFW + Shear & QSO Pos & 1.040 & 2.230 & 0.082 & -0.025 & 0.024 & 115.922 & 0.529 \\
# WFI2026 & NFW + Shear & QSO Pos + FR & 1.040 & 2.230 & 0.020 & 0.014 & 0.020 & 101.114 & 0.782 \\
# WGDJ0405 & SIE + Shear & QSO Pos & 0.290 & 1.713 & -0.015 & 0.013 & 0.037 & 34.400 & 0.228 \\
# WGDJ0405 & SIE + Shear & QSO Pos + FR & 0.290 & 1.713 & 0.086 & 0.060 & 0.036 & 12.155 & 0.168 \\
# WGDJ0405 & POW + Shear & QSO Pos & 0.290 & 1.713 & 0.019 & -0.268 & 0.044 & 21.468 & 0.021 \\
# WGDJ0405 & POW + Shear & QSO Pos + FR & 0.290 & 1.713 & 0.015 & -0.274 & 0.047 & 26.636 & 0.020 \\
# WGDJ0405 & NFW + Shear & QSO Pos & 0.290 & 1.713 & 0.098 & -0.068 & 0.026 & 25.371 & 0.355 \\
# WGDJ0405 & NFW + Shear & QSO Pos + FR & 0.290 & 1.713 & 0.132 & -0.024 & 0.027 & 22.988 & 0.354 \\
# WGD2038 & SIE + Shear & QSO Pos & 0.230 & 0.777 & 0.018 & 0.217 & 0.018 & -25.518 & 0.160 \\
# WGD2038 & SIE + Shear & QSO Pos + FR & 0.230 & 0.777 & -0.007 & 0.047 & 0.001 & -3.482 & 0.812 \\
# WGD2038 & POW + Shear & QSO Pos & 0.230 & 0.777 & 0.327 & -0.126 & 0.010 & -12.045 & 0.098 \\
# WGD2038 & POW + Shear & QSO Pos + FR & 0.230 & 0.777 & -0.122 & 0.140 & 0.029 & -30.794 & 0.029 \\
# WGD2038 & NFW + Shear & QSO Pos & 0.230 & 0.777 & 3.224 & -3.174 & 0.039 & -32.434 & 0.410 \\
# WGD2038 & NFW + Shear & QSO Pos + FR & 0.230 & 0.777 & 0.168 & -0.021 & 0.015 & -33.627 & 0.809 \\
